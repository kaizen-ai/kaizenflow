# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import logging

import numpy as np
import pandas as pd

import core.timeseries_study as ctimstud
import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint

# %%
print(henv.get_system_signature())
hprint.config_notebook()
hdbg.init_logger(verbosity=logging.INFO)
_LOG = logging.getLogger(__name__)
# Out:
# ('# Packages\n         python: 3.7.3\n         joblib: 0.14.0\n          numpy: 1.17.3\n         pandas: 0.25.3\n        pyarrow: 0.15.1\n          scipy: 1.3.1\n        seaborn: 0.9.0\n        sklearn: 0.21.3\n    statsmodels: 0.10.1\n# Last commits:\n  * 77b92ee paul     Make n_splits refer to number of output splits.                   (  13 hours ago) Tue Nov 12 00:29:04 2019  (HEAD -> PTask482_CORE_Improvements_to_TimeSeriesStudy, origin/master, origin/HEAD, master)\n  * 976f555 paul     Update documentation                                              (  16 hours ago) Mon Nov 11 21:27:11 2019           \n  * b3bea34 paul     Clean up documentation.                                           (  16 hours ago) Mon Nov 11 21:06:34 2019           ', 0)
# WARNING: Running in Jupyter

# %% [markdown]
# # Generate time series

# %% [markdown]
# ## Daily

# %%
idx = pd.date_range("2018-12-31", "2019-01-31")
vals = np.random.randn(len(idx))
ts_daily = pd.Series(vals, index=idx)
ts_daily.name = "ts"
ts_daily.head()
# Out:
# 2018-12-31   -0.523148
# 2019-01-01   -0.518380
# 2019-01-02   -1.017447
# 2019-01-03    0.638121
# 2019-01-04   -1.044346
# Freq: D, Name: ts, dtype: float64

# %%
ts_daily.plot()

# %% [markdown]
# ## Minutely

# %%
idx = pd.date_range("2018-12-31", "2019-01-31", freq="5T")
vals = np.random.randn(len(idx))
ts_minutely = pd.Series(vals, index=idx)
ts_minutely.name = "ts"
ts_minutely.head()
# Out:
# 2018-12-31 00:00:00    0.855949
# 2018-12-31 00:05:00   -0.479641
# 2018-12-31 00:10:00    0.277618
# 2018-12-31 00:15:00   -1.236581
# 2018-12-31 00:20:00   -0.133356
# Freq: 5T, Name: ts, dtype: float64

# %%
ts_minutely.plot()

# %% [markdown]
# # Examples

# %% [markdown]
# ## Daily

# %%
tsds = ctimstud.TimeSeriesDailyStudy(ts_daily)
tsds.execute()
# Out:
# /wd/julia/.conda/envs/develop/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1085: UserWarning: Attempting to set identical left == right == 17896.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)

# %% [markdown]
# ## Minutely

# %%
tsms = ctimstud.TimeSeriesMinutelyStudy(ts_minutely)
tsms.execute()
