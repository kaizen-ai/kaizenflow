# %%
# %load_ext autoreload
# %autoreload 2

import datetime as dt
import os
from typing import Dict

import pandas as pd

import helpers.s3 as hs3
import instrument_master.kibot.data.load as kdl
import instrument_master.kibot.data.load.kibot_file_path_generator as fpgen
import instrument_master.common.data.types as types

# %%
file = "s3://external-p1/kibot/sp_500_1min/AAPL.csv.gz"
#file = "s3://external-p1/kibot/sp_500_1min/A.csv.gz"

df = pd.read_csv(file)
df.head(5)

# %%
#file = "s3://external-p1/kibot/pq/all_stocks_1min/AAPL.pq"
file = "s3://external-p1/kibot/pq/sp_500_1min/AAPL.pq"

pd.read_parquet(file)
