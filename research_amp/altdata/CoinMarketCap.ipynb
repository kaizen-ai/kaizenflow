# %% [markdown]
# Review of the Coin Market Cap API endpoints availiable on `basic` plan:
#
# * v1/cryptocurrency/categories
# * v1/cryptocurrency/category
# * v1/cryptocurrency/map
# * v2/cryptocurrency/info
# * v1/cryptocurrency/listings/latest
# * v2/cryptocurrency/quotes/latest
# * v1/fiat/map
# * v1/exchange/assets
# * v1/global-metrics/quotes/latest

# %% [markdown]
# # Imports

# %%
import json
import os
from typing import Dict

from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects

# %% [markdown]
# # Set-up

# %%
key = "6714e467-49e5-49bc-9484-30a6331d6fb3"
api_url = "https://sandbox-api.coinmarketcap.com"

# %%
headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": key,
}

session = Session()
session.headers.update(headers)

# %%
def get_data(session: Session, url: str, params: Dict[str, str]):
    """
    Make query to API endpoint.
    """
    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        return data
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        return e

# %% [markdown]
# # Cryptocurrency API access

# %% [markdown]
# **/categories**

# %% [markdown]
# Returns information about all coin categories available on CoinMarketCap. Includes a paginated list of cryptocurrency quotes and metadata from each category.

# %%
url = os.path.join(api_url, "v1/cryptocurrency/categories")
parameters = {"start": "1", "limit": "5000", "symbol": "ETH,BTC"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-04T09:25:57.009Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 0,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'ETH,BTC': {'data': [{'id': 'lmz5d88skxi',
#      'name': 'd4gbq1k964w',
#      'title': 'nmolybaqt6',
#      'description': 'giccguqfyoq',
#      'num_tokens': 6935,
#      'avg_price_change': 0.8576278832648236,
#      'market_cap': 0.8011885467512954,
#      'market_cap_change': 0.5731948037498498,
#      'volume': 0.1485760778585874,
#      'volume_change': 0.019952022321780172,
#      'last_updated': 8597},
#     {'id': 'erbh6kxho6o',
#      'name': '2ipewzmgmd3',
#      'title': 'ik1pwexxchi',
#      'description': 'e02czuf1jyw',
#      'num_tokens': 4538,
#      'avg_price_change': 0.4665821049324974,
#      'market_cap': 0.6467861713771943,
#      'market_cap_change': 0.16819834426366587,
#      'volume': 0.5499975692076757,
#      'volume_change': 0.15366381433977372,
#      'last_updated': 6975},
#     {'id': 's6rikzlr6oi',
#      'name': 'ykqn6m6uy3',
#      'title': 'umzk1os905c',
#      'description': '7tnhir3p3cy',
#      'num_tokens': 963,
#      'avg_price_change': 0.9353011550501538,
#      'market_cap': 0.24357352106892538,
#      'market_cap_change': 0.9287076278316204,
#      'volume': 0.3361056474649413,
#      'volume_change': 0.9925307359716142,
#      'last_updated': 1494},
#     {'id': 'gfgswcxn72h',
#      'name': 'o4odd4nobw',
#      'title': 'xd9ek1jpil9',
#      'description': 'mf556z49vu',
#      'num_tokens': 2199,
#      'avg_price_change': 0.45544157349061076,
#      'market_cap': 0.38759043062977905,
#      'market_cap_change': 0.921009300468951,
#      'volume': 0.44194209289931097,
#      'volume_change': 0.7382914013664472,
#      'last_updated': 4340},
#     {'id': 'vdsngqpcb6j',
#      'name': 'vwv2zocbq7',
#      'title': 'k2vv01wc1be',
#      'description': 'v47kky1pre',
#      'num_tokens': 1390,
#      'avg_price_change': 0.33089991398183605,
#      'market_cap': 0.7185761634409409,
#      'market_cap_change': 0.9566843619840415,
#      'volume': 0.7947288194821385,
#      'volume_change': 0.9761626452669339,
#      'last_updated': 4911},
#     {'id': '5g1s3jfgn89',
#      'name': 'fzwa8kkiywj',
#      'title': 'hpjfxz1swbn',
#      'description': 'eulsxec5n79',
#      'num_tokens': 6221,
#      'avg_price_change': 0.3773136838855444,
#      'market_cap': 0.24036333075132377,
#      'market_cap_change': 0.1561584299162151,
#      'volume': 0.24703455280280906,
#      'volume_change': 0.6059153693952255,
#      'last_updated': 491},
#     {'id': '3d0lsl2s7tk',
#      'name': 'hue9os4bztw',
#      'title': 'jyi318861b',
#      'description': 'ojvc1uw7ass',
#      'num_tokens': 926,
#      'avg_price_change': 0.44472906406937684,
#      'market_cap': 0.4697672269333486,
#      'market_cap_change': 0.28185048780181865,
#      'volume': 0.6452935437339256,
#      'volume_change': 0.37611860659596674,
#      'last_updated': 1319},
#     {'id': 's6zs5ilz2i',
#      'name': 'r4co6z4okqg',
#      'title': '1gey7w4z5h6',
#      'description': 'q7ivnxecjm',
#      'num_tokens': 5232,
#      'avg_price_change': 0.08528687541655144,
#      'market_cap': 0.27120957771911613,
#      'market_cap_change': 0.41394403262658663,
#      'volume': 0.11979999497795224,
#      'volume_change': 0.7579334626586616,
#      'last_updated': 1278},
#     {'id': 'miy31an26ur',
#      'name': 'wi50i8vhx9e',
#      'title': 'iaxwjq4ebbn',
#      'description': 'k83nvc51w2b',
#      'num_tokens': 4116,
#      'avg_price_change': 0.42003542792344706,
#      'market_cap': 0.4254297531184539,
#      'market_cap_change': 0.6239790435985479,
#      'volume': 0.24098584749418683,
#      'volume_change': 0.4914972632518164,
#      'last_updated': 778},
#     {'id': 'qisclrimb',
#      'name': 'b6riphk0rdu',
#      'title': 'tpdwz79l5zg',
#      'description': 'puiv7guihx',
#      'num_tokens': 4196,
#      'avg_price_change': 0.4498310906380094,
#      'market_cap': 0.37408557885468907,
#      'market_cap_change': 0.7048242802329163,
#      'volume': 0.4510343786637878,
#      'volume_change': 0.2169995236118072,
#      'last_updated': 9932}],
#    'status': {'timestamp': '2023-01-04T09:25:57.009Z',
#     'error_code': None,
#     'error_message': None,
#     'elapsed': 4860,
#     'credit_count': 7340}}}}

# %% [markdown]
# **/category**

# %% [markdown]
# Returns information about a single coin category available on CoinMarketCap. Includes a paginated list of the cryptocurrency quotes and metadata for the category.

# %%
url = os.path.join(api_url, "v1/cryptocurrency/category")
parameters = {"id": "qisclrimb", "start": "1", "limit": "100"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-04T09:55:24.650Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 14,
#   'credit_count': 0,
#   'notice': None},
#  'data': {'qisclrimb': {'id': None,
#    'name': 'lktu4o9eqla',
#    'title': 'ialynyolr9',
#    'description': 'mh7pr6rade',
#    'num_tokens': 2546,
#    'avg_price_change': 0.1574724869077868,
#    'market_cap': 0.6946360881834175,
#    'market_cap_change': 0.979249404372101,
#    'volume': 0.26230669406698515,
#    'volume_change': 0.8476932498536967,
#    'coins': [{'id': 325,
#      'name': 'sgcjc8owscq',
#      'symbol': '55u8fe64eg7',
#      'slug': 'znkb8jq6a0g',
#      'cmc_rank': 8024,
#      'num_market_pairs': 7611,
#      'circulating_supply': 8292,
#      'total_supply': 9958,
#      'max_supply': 2880,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['sa1hzytg7o8',
#       'g6xj9tgmyx8',
#       'grkevoib78o',
#       'ozo9f5ftg1p',
#       'es29va94xgu',
#       '76g5ysggug6',
#       'jsbfs6f87wd',
#       'ky9ck1d1fdb',
#       '3116scguh7r',
#       'isija9302n'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.8943982668559072,
#        'volume_24h': 5077,
#        'percent_change_1h': 0.5414609832746202,
#        'percent_change_24h': 0.9054924159529087,
#        'percent_change_7d': 0.48593951073013875,
#        'market_cap': 4894,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 7831,
#        'volume_24h': 1675,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 8400,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 2264,
#      'name': 'rqd4z0i5yc',
#      'symbol': 'd43t7swqsl9',
#      'slug': 'av0r4seukni',
#      'cmc_rank': 4823,
#      'num_market_pairs': 331,
#      'circulating_supply': 6464,
#      'total_supply': 4942,
#      'max_supply': 8167,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['muzge25kb3a',
#       'ufo9ifomb3a',
#       'bsia5awelht',
#       'abbab837in5',
#       'zdb6er9261',
#       'vmucccp01u',
#       'kasw56479fm',
#       'zkvg777r2u',
#       '244p5q0gnk5',
#       'vdbazhd6ua'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.7965093981232099,
#        'volume_24h': 9831,
#        'percent_change_1h': 0.11439313602434464,
#        'percent_change_24h': 0.3002779084365672,
#        'percent_change_7d': 0.37018216370000645,
#        'market_cap': 2103,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 6584,
#        'volume_24h': 2923,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 9902,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 6835,
#      'name': 'gmo9j05oifs',
#      'symbol': '59ezh1k410e',
#      'slug': 'zl7qq31o0zl',
#      'cmc_rank': 5697,
#      'num_market_pairs': 8013,
#      'circulating_supply': 1799,
#      'total_supply': 2659,
#      'max_supply': 9565,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['flu2mgx6fsp',
#       'w2ycq7kax',
#       'iavli9foml',
#       'sovhwyf0dgr',
#       'zsl8b0vkn7',
#       'iae9xnjswz',
#       '7yhat5p9wk',
#       'bfor5qyu4hj',
#       'm7qje0m37jf',
#       't7kqrylv9lf'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.4933936907060066,
#        'volume_24h': 6722,
#        'percent_change_1h': 0.6444674090826319,
#        'percent_change_24h': 0.27690664585810554,
#        'percent_change_7d': 0.8079443186535058,
#        'market_cap': 7951,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 350,
#        'volume_24h': 5164,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 8544,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 4887,
#      'name': 'rawi0l1f36',
#      'symbol': '41fewjv5hzr',
#      'slug': '0p61cx8zt5f',
#      'cmc_rank': 4160,
#      'num_market_pairs': 931,
#      'circulating_supply': 8001,
#      'total_supply': 3178,
#      'max_supply': 4410,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['3npndheme3k',
#       '9saqeg1pe1o',
#       'ab8y2ynuzgr',
#       'mfx62re2mzk',
#       '3w77p17vztx',
#       'pjwkoty2ov',
#       '46ovequd95p',
#       '3r3zu2fssq9',
#       'jem1hqlfy6j',
#       '1i0c9mjpp0f'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.908909490321927,
#        'volume_24h': 4908,
#        'percent_change_1h': 0.05909462002084531,
#        'percent_change_24h': 0.06734912271717186,
#        'percent_change_7d': 0.09095204311180471,
#        'market_cap': 2133,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 6815,
#        'volume_24h': 6055,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 9249,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 5457,
#      'name': 'hgsyd1nzuko',
#      'symbol': 'viuh20cx2tc',
#      'slug': '9dam7h0ld9',
#      'cmc_rank': 3166,
#      'num_market_pairs': 8914,
#      'circulating_supply': 7597,
#      'total_supply': 8656,
#      'max_supply': 5272,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['rsta1hkw9c',
#       'of987xx53nq',
#       'te4qugctc0o',
#       'cs8criduxar',
#       'a81vqtm2a6s',
#       '5ymbykx9ios',
#       'd1w2i1kdtm',
#       'l2pqt9t5xlm',
#       'dleyq40zuq9',
#       'jwbn5wnjg7c'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.698912664887358,
#        'volume_24h': 3860,
#        'percent_change_1h': 0.42324468325027076,
#        'percent_change_24h': 0.9400373688837602,
#        'percent_change_7d': 0.5265146615973815,
#        'market_cap': 7453,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 1292,
#        'volume_24h': 9732,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 945,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 690,
#      'name': 'vc4xlj7cthf',
#      'symbol': 'wjz8y3k2nff',
#      'slug': 'y2c1q6ck1up',
#      'cmc_rank': 1503,
#      'num_market_pairs': 902,
#      'circulating_supply': 725,
#      'total_supply': 2876,
#      'max_supply': 2503,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['nbpxkstq1mg',
#       'bwhnviq1sbl',
#       'i041937kn2',
#       'qw2x5lvmrai',
#       'm7s6sjd43e',
#       'qqkjxu17m8',
#       'iyu51uxx1m',
#       'ka29oovp8m',
#       'u5nfodw0uz',
#       't1ymf2w3is'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.5991116173980644,
#        'volume_24h': 5342,
#        'percent_change_1h': 0.39354353637172834,
#        'percent_change_24h': 0.03842531408603178,
#        'percent_change_7d': 0.5146226803026386,
#        'market_cap': 8059,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 9594,
#        'volume_24h': 4387,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 8794,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 5965,
#      'name': 'fv8ist1wcde',
#      'symbol': 'ygk66o359kh',
#      'slug': 'fo3ny3bkp0e',
#      'cmc_rank': 9331,
#      'num_market_pairs': 3344,
#      'circulating_supply': 6133,
#      'total_supply': 5092,
#      'max_supply': 9022,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['qju4cc5mjan',
#       'fnc8hp6o28g',
#       '3k4384ih6xm',
#       '3u68ggbpetv',
#       'm87wmivi3rd',
#       'atwnalmwjam',
#       'y0o45u1koh',
#       'kda8p3oznm',
#       'vepxydzfq8',
#       'uv5sqcrr2zm'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.439933592788752,
#        'volume_24h': 4532,
#        'percent_change_1h': 0.29324189552370394,
#        'percent_change_24h': 0.0060905509671354,
#        'percent_change_7d': 0.9512890247156693,
#        'market_cap': 7518,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 7296,
#        'volume_24h': 937,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 9939,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 2128,
#      'name': 'zivd7btymlr',
#      'symbol': 'mua6mw5w9e',
#      'slug': 'rlgmoxgpqgp',
#      'cmc_rank': 4630,
#      'num_market_pairs': 9498,
#      'circulating_supply': 8991,
#      'total_supply': 3947,
#      'max_supply': 2837,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['rf6ze91jep',
#       '067vljqchnu',
#       'g68ztv6uzda',
#       'd46h8ht1b2l',
#       'lqwej13iyxb',
#       'h86eogxukm',
#       'zt9b642kn08',
#       'wjiqq0d3lzr',
#       'staglqb8tum',
#       'zv7pyya9yzo'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.7188941891707887,
#        'volume_24h': 3968,
#        'percent_change_1h': 0.32466930826246165,
#        'percent_change_24h': 0.674109888312566,
#        'percent_change_7d': 0.025833245866225152,
#        'market_cap': 8292,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 9907,
#        'volume_24h': 7859,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 4489,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 6784,
#      'name': '2d9tt3d26cl',
#      'symbol': 'rai3g97x48h',
#      'slug': 'hnm71a8n6qf',
#      'cmc_rank': 4461,
#      'num_market_pairs': 9085,
#      'circulating_supply': 8494,
#      'total_supply': 3345,
#      'max_supply': 5784,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['qlpoewmuunc',
#       'lfadcok1rxj',
#       '4iwzxzgvh7m',
#       'yn76xf7t309',
#       'cnsgjv1s5xs',
#       '5l1ysobhqf',
#       'mqe5n272vr',
#       'dx6c5u1xe2m',
#       'bmdr2p1i9xq',
#       'c5prau48e3f'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.454048805372405,
#        'volume_24h': 527,
#        'percent_change_1h': 0.6343597002241783,
#        'percent_change_24h': 0.6131620648860416,
#        'percent_change_7d': 0.6491806025987439,
#        'market_cap': 7441,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 7595,
#        'volume_24h': 5277,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 4139,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}},
#     {'id': 8335,
#      'name': 'w4xveh8vpaa',
#      'symbol': 'fuzshm60far',
#      'slug': 'v17wj0y4iqh',
#      'cmc_rank': 4933,
#      'num_market_pairs': 2437,
#      'circulating_supply': 6409,
#      'total_supply': 7927,
#      'max_supply': 1039,
#      'last_updated': '2023-01-04T09:55:24.650Z',
#      'date_added': '2023-01-04T09:55:24.650Z',
#      'tags': ['m9mh7uvgrxk',
#       'a9ygqkgsm76',
#       'dh9rfvzfyem',
#       'lyi3epnh8vh',
#       'tcwix5feo6q',
#       '36k0ymmpim1',
#       'gg1p87ap5dh',
#       '1g4lvmaf9h4',
#       '14pgsnhvvmp',
#       '0fwmg9bvnuwo'],
#      'platform': None,
#      'quote': {'USD': {'price': 0.0834620140738398,
#        'volume_24h': 493,
#        'percent_change_1h': 0.7486179649746108,
#        'percent_change_24h': 0.3132204874772031,
#        'percent_change_7d': 0.07876562869175996,
#        'market_cap': 8215,
#        'last_updated': '2023-01-04T09:55:24.650Z'},
#       'BTC': {'price': 9016,
#        'volume_24h': 6376,
#        'percent_change_1h': None,
#        'percent_change_24h': None,
#        'percent_change_7d': None,
#        'market_cap': 2437,
#        'last_updated': '2023-01-04T09:55:24.650Z'}}}],
#    'last_updated': 3889}}}

# %% [markdown]
# **/map**

# %% [markdown]
# Returns a mapping of all cryptocurrencies to unique CoinMarketCap ids. By default this endpoint returns cryptocurrencies that have actively tracked markets on supported exchanges.

# %%
url = os.path.join(api_url, "v1/cryptocurrency/map")
parameters = {"start": "1", "limit": "5000", "sort": "id", "symbol": "ETH,BTC"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T14:29:32.675Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 0,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'ETH,BTC': [{'id': 5049,
#     'rank': 9744,
#     'name': '1kbkezlnix5',
#     'symbol': 'jn1gzw697jh',
#     'slug': 'rpvb9om75d9',
#     'is_active': 5249,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 2098,
#     'rank': 7478,
#     'name': 'mqlelhl40tb',
#     'symbol': '8z3jb2ro69t',
#     'slug': 'c3mxc7r6neq',
#     'is_active': 7616,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 2243,
#     'rank': 5530,
#     'name': '1gja53ltyvr',
#     'symbol': 'j7veca7oies',
#     'slug': '2f0dwggs61m',
#     'is_active': 1021,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 1096,
#     'rank': 5190,
#     'name': '0fj8ffgeduxd',
#     'symbol': 'rtoefkisja',
#     'slug': 'bhsxdx5na47',
#     'is_active': 192,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 5975,
#     'rank': 5066,
#     'name': 'h9efspttf0w',
#     'symbol': '9rlzpi4364l',
#     'slug': 'laxqzhzsy4d',
#     'is_active': 7873,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 8,
#     'rank': 1328,
#     'name': '5vrh59ywejp',
#     'symbol': 'kvfyj0esp2a',
#     'slug': 'eb1mfaiya8v',
#     'is_active': 4172,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 7577,
#     'rank': 8380,
#     'name': 'qd7rmohx9bn',
#     'symbol': 'brooyna8zr6',
#     'slug': 'e04r7o60dj',
#     'is_active': 3050,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 8902,
#     'rank': 6532,
#     'name': 'zeppmvbo7kd',
#     'symbol': 'shehz7bbt2a',
#     'slug': '1lb6f1fqews',
#     'is_active': 429,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 2796,
#     'rank': 4754,
#     'name': '3zvjqggltfc',
#     'symbol': '8fzh7pwc7s2',
#     'slug': 'jzsd2jeus8p',
#     'is_active': 4678,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None},
#    {'id': 5710,
#     'rank': 7262,
#     'name': '7o38zpgi5s',
#     'symbol': 'fif2mrkjphs',
#     'slug': 'sj9ywwmv5w',
#     'is_active': 8469,
#     'first_historical_data': '2023-01-03T14:29:32.675Z',
#     'last_historical_data': '2023-01-03T14:29:32.675Z',
#     'platform': None}]}}

# %% [markdown]
# It looks like `name`, `symbol`, `slug` and other string typed values are encrypted, I'll figure out what it is.

# %% [markdown]
# **/info**

# %% [markdown]
# Returns all static metadata available for one or more cryptocurrencies. This information includes details like logo, description, official website URL, social links, and links to a cryptocurrency's technical documentation.

# %%
url = os.path.join(api_url, "v2/cryptocurrency/info")
parameters = {"symbol": "ETH,BTC"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:42:23.874Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 1,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'BTC': {'urls': {'website': ['qqmm6bkmba',
#      '4xxv5x9mfqi',
#      'v4pyfua3ct',
#      'ivmf48ywp7e',
#      '22vwbvlld4n',
#      't4cq9imt10h',
#      'ysrkuh0rgp',
#      'oxaoieql0e',
#      'm2tx3m7mz',
#      'zci9cchoc9'],
#     'technical_doc': ['lwk01vpovc',
#      'un3frr47cli',
#      'rqu34rk3bq',
#      '0z8zy2md7uaq',
#      'fv23o7iq5v7',
#      'f29tofamft',
#      'v6s4k0nhfu',
#      '198y384p8lt',
#      'jmfh2yzf9or',
#      '2oovnczltlq'],
#     'twitter': [],
#     'reddit': ['r85ksfobz5',
#      'nlnd8x9e2g',
#      'c2yrubqmk4',
#      '9qx7ao4gs7',
#      'kqb57dinunp',
#      'slx6ads78a',
#      'jgbl8t8eex',
#      '18q0tw97jep',
#      '7ktu57sjay7',
#      'uni4ln610r8'],
#     'message_board': ['86ish83f2pb',
#      'ftl3am9esk',
#      'gcd02mrq5q',
#      'hpn6cufde98',
#      '5trj1loldts',
#      'iwuadbd5mkh',
#      'uiy6gh9qw7',
#      'st4zj363lv',
#      'duzx3btayqb',
#      'gbfkmy3mbmk'],
#     'announcement': [],
#     'chat': [],
#     'explorer': ['kd1vfekjqo',
#      '2hd1m5b077z',
#      'ls3mkaq3k1',
#      'hy6jj7faq8g',
#      '5hrefanhaul',
#      'wev2dvy5uzg',
#      '2v76ez2278m',
#      'sbhj9ckg0jj',
#      'lwfi4k9cn7',
#      'ad26qgggaja'],
#     'source_code': ['ostbq95khgc',
#      't2k98eqzt8i',
#      'lbu2y6du1i',
#      'kaftv0uk3gd',
#      'zuy9td3qd1f',
#      'avjk5n1ba6',
#      'vdhqaoh6kak',
#      '8fw75au3ulc',
#      'w3xyoimj0i',
#      'hshgjmv6jd']},
#    'logo': 'rsecsaa3nc',
#    'id': 3909,
#    'name': 'npvic9rn389',
#    'symbol': 'BTC',
#    'slug': 'dxqmvuawmpd',
#    'description': 'ee5f4oisbm6',
#    'date_added': '2023-01-03T13:42:23.874Z',
#    'date_launched': '2023-01-03T13:42:23.874Z',
#    'tags': ['zrprvxs2s6',
#     'jfkizulvmf',
#     'bmec7qoyaei',
#     '6za7hnn7z2o',
#     '9xynvgmbp7l',
#     '4wwj930wq4',
#     '04zy6l2i5lnp',
#     'p54ilbme90f',
#     'woh2k0z4em',
#     'n7svwyyp9r'],
#    'platform': None,
#    'category': 'ocluqiq2b5'},
#   'ETH': {'urls': {'website': ['wsrcbpvm4zr',
#      'mfeue034pw',
#      'shegem9946q',
#      'apfct4lsegq',
#      '8c8flxn5ro8',
#      'sovsjh608on',
#      'q1nuvawupsa',
#      '671dovss7zw',
#      'teaj6tq1iof',
#      'w08ja4yumbq'],
#     'technical_doc': ['d20hpv5gran',
#      'dpcai68tvbl',
#      'lcn5oidspn',
#      '7lgcv70ehiw',
#      'z6lyiexvwu',
#      'q3dk7efgrue',
#      'e3srp1jt3j',
#      '6g0oxpxl45',
#      'gtam83xd788',
#      'sxsocb91log'],
#     'twitter': [],
#     'reddit': ['7z6f2uar6y',
#      'em4kkht0wg',
#      'joupprthhyd',
#      'eqte7murf2r',
#      'dzzkzzvz6w',
#      'cg9u4aj724',
#      'g7jhmvks0un',
#      'ip82t39wavq',
#      '9zmet3uw7h',
#      'jqfsqb6j1d'],
#     'message_board': ['yeaqazn92p',
#      'x1zfck7st3s',
#      'eb09wa68qgh',
#      'ljr0jz1degl',
#      '8fmtsb7il97',
#      'qwbq1vlfytk',
#      '5h6y63mcs0r',
#      'un67seopxib',
#      'z99vje7f4w',
#      '2e01jtsfsr4'],
#     'announcement': [],
#     'chat': [],
#     'explorer': ['x5mrkfimfji',
#      'npeh3v82cpp',
#      'coqrgd93ti7',
#      '006injvcdshb7',
#      '89riixywh3',
#      'soo19nc9k2',
#      '7zajp9iudog',
#      'p7bf3ntbiac',
#      'thbjmsej7mn',
#      'n1kkyjjr49'],
#     'source_code': ['an61byn4lyb',
#      'ubajtnvrgdr',
#      'v8dzlopeupq',
#      '4997u55gdp',
#      'xe2qcdhwcyc',
#      'jumohrl5i4',
#      'prope64vyja',
#      'st4tefcfzq',
#      '1p488b5nxye',
#      'xvguixpq8fr']},
#    'logo': 'p6zl9jlhmq',
#    'id': 2140,
#    'name': 'p3axmm11sz7',
#    'symbol': 'ETH',
#    'slug': 'ufbnj47d0v',
#    'description': 'uhr8v7po27',
#    'date_added': '2023-01-03T13:42:23.874Z',
#    'date_launched': '2023-01-03T13:42:23.874Z',
#    'tags': ['7j67me8wow4',
#     'qjewmbevbqr',
#     '2cdtnzoklyi',
#     'i7oc97syy9a',
#     'ee4kjyamt5g',
#     '0s0aben11ita',
#     'xq7by17179k',
#     '0f7itajja7lv',
#     'mt9bbh9mr5i',
#     'hafkzzdawbo'],
#    'platform': None,
#    'category': 'k84q74znwkg'}}}

# %% [markdown]
# **/listings/latest**

# %% [markdown]
# Returns a paginated list of all active cryptocurrencies with latest market data. The default "market_cap" sort returns cryptocurrency in order of CoinMarketCap's market cap rank (as outlined in our methodology) but it may be configured  to order by another market ranking field. "convert" option is used to return market values in multiple fiat and cryptocurrency conversions in the same call.

# %%
url = os.path.join(api_url, "v1/cryptocurrency/listings/latest")
parameters = {
    "start": "1",
    "limit": "5000",
    "convert": "USD",
    "market_cap_min": 10000000000000,
    "market_cap_max": 9000000000000000,
}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:55:54.632Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 1,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 9345,
#    'name': 'gha783sqxs',
#    'symbol': 'vi0g434o6r',
#    'slug': 'dvylefh35hh',
#    'cmc_rank': 7046,
#    'num_market_pairs': 8616,
#    'circulating_supply': 788,
#    'total_supply': 5784,
#    'max_supply': 9705,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['chg1epax9wq',
#     '886z9x0gxm',
#     'uutgnqosq5f',
#     'hojxzolqis',
#     'jsbbfyhigm',
#     'wa3shxwabtq',
#     'w7xmtgl76t',
#     'ikjnxpvpik',
#     'd0duhz0qd0k',
#     'pnnv8biog6'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.6527696018694471,
#      'volume_24h': 7773,
#      'volume_change_24h': 0.4797001011509945,
#      'percent_change_1h': 0.804669671603232,
#      'percent_change_24h': 0.9878535623735722,
#      'percent_change_7d': 0.13702131158584674,
#      'market_cap': 0.8270815668144944,
#      'market_cap_dominance': 9293,
#      'fully_diluted_market_cap': 0.2969826105133859,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 3882,
#    'name': 'ejizzeagnv',
#    'symbol': 'ahg8zqlt6ah',
#    'slug': 'o87hfkcad2',
#    'cmc_rank': 5668,
#    'num_market_pairs': 7100,
#    'circulating_supply': 7780,
#    'total_supply': 5428,
#    'max_supply': 8973,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['kle3b6po8ta',
#     'etw411op5gl',
#     '10nc609x0vga',
#     'xdozupo87js',
#     '5lkwtf36b2b',
#     'rq007tsag09',
#     'nte2qcj9hb8',
#     '4tfxzjtrdx4',
#     'pnvkpe3hlg',
#     'r3y78ndutq'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.4628694061095737,
#      'volume_24h': 2813,
#      'volume_change_24h': 0.040543699690777535,
#      'percent_change_1h': 0.6622472907950185,
#      'percent_change_24h': 0.8741508108215796,
#      'percent_change_7d': 0.046869217299819965,
#      'market_cap': 0.34835810079371043,
#      'market_cap_dominance': 7868,
#      'fully_diluted_market_cap': 0.24309524078169442,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 8973,
#    'name': '00fgy2l0xf879',
#    'symbol': 'lg68t04fpun',
#    'slug': '0l213n513gf',
#    'cmc_rank': 4913,
#    'num_market_pairs': 6602,
#    'circulating_supply': 610,
#    'total_supply': 7609,
#    'max_supply': 8424,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['h7y1h8l6v7u',
#     'zbynqcc5ot',
#     'rvaolpdsje',
#     'fouyjbkr1pt',
#     'ocvwkmpaup',
#     '6x30he05x5u',
#     '66v0wflt93p',
#     'v1x0uchdcgd',
#     'gec6f1713yc',
#     'g3pzrm6bf8c'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.44513910632640297,
#      'volume_24h': 7849,
#      'volume_change_24h': 0.2799253457515376,
#      'percent_change_1h': 0.5648009925133828,
#      'percent_change_24h': 0.8841396818924214,
#      'percent_change_7d': 0.6938288935510102,
#      'market_cap': 0.36838032165030543,
#      'market_cap_dominance': 728,
#      'fully_diluted_market_cap': 0.8005812764809168,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 1487,
#    'name': 'sj7elzr8u5o',
#    'symbol': 'txecb2tmygh',
#    'slug': '4h9ax13vxjs',
#    'cmc_rank': 7214,
#    'num_market_pairs': 7485,
#    'circulating_supply': 6969,
#    'total_supply': 3573,
#    'max_supply': 7636,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['7g4xvn5roax',
#     'anyqedm9vx5',
#     'k3fyv7i59e',
#     'l841sgdaaar',
#     'hewtnhyta8i',
#     'qe00pkqko1h',
#     '5mlbx097ph6',
#     '4idvaxdomls',
#     'd857270eoqh',
#     'ehdmqeiq6dn'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.848583922627421,
#      'volume_24h': 3916,
#      'volume_change_24h': 0.9726113404613723,
#      'percent_change_1h': 0.7077816918281246,
#      'percent_change_24h': 0.3764888260876964,
#      'percent_change_7d': 0.03565417064321963,
#      'market_cap': 0.3440037003340928,
#      'market_cap_dominance': 4017,
#      'fully_diluted_market_cap': 0.8787243208850326,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 1048,
#    'name': 't89d5xhgwnq',
#    'symbol': '3wu8fiqqnmc',
#    'slug': '265dek1gzts',
#    'cmc_rank': 2819,
#    'num_market_pairs': 8433,
#    'circulating_supply': 8899,
#    'total_supply': 4175,
#    'max_supply': 9956,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['d9za8gs9mc4',
#     'ljxjna614uo',
#     'jl2jvqvn3b',
#     'afmmc2u4us7',
#     'n3pb7b8nmr',
#     'pp7q2xwwkfg',
#     'pxzkkjcgu0n',
#     '7248hxtl95g',
#     '20xgwn1zy16',
#     '3d48obfve0j'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.9855053302623298,
#      'volume_24h': 3222,
#      'volume_change_24h': 0.07105085067906303,
#      'percent_change_1h': 0.5167119004328364,
#      'percent_change_24h': 0.4805664657704318,
#      'percent_change_7d': 0.2287887063881049,
#      'market_cap': 0.5491822720516075,
#      'market_cap_dominance': 6685,
#      'fully_diluted_market_cap': 0.31935363563433383,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 1670,
#    'name': '2caqzxhoshh',
#    'symbol': 'ypmqs5t248e',
#    'slug': 'y6fmz72uvp',
#    'cmc_rank': 7414,
#    'num_market_pairs': 1403,
#    'circulating_supply': 746,
#    'total_supply': 7262,
#    'max_supply': 8929,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['3f8s03wga3k',
#     'u4qz1igws1s',
#     'ih9kp5h79i',
#     'b1094yksqcc',
#     'm1wmc7egxz',
#     '8jl9eeo5ydu',
#     '49a0sswqzca',
#     '1835h66zpoej',
#     '5az2zqvvvfj',
#     'vq94827ie0a'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.27067560019152936,
#      'volume_24h': 2168,
#      'volume_change_24h': 0.1593577093346532,
#      'percent_change_1h': 0.6400135440776269,
#      'percent_change_24h': 0.3056145632304199,
#      'percent_change_7d': 0.024509062840278872,
#      'market_cap': 0.7826902270985512,
#      'market_cap_dominance': 4723,
#      'fully_diluted_market_cap': 0.8451633941805097,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 2472,
#    'name': 'm02pbuoq1b',
#    'symbol': 'fog8mtfm8ae',
#    'slug': 'wwwktu3730b',
#    'cmc_rank': 5930,
#    'num_market_pairs': 9034,
#    'circulating_supply': 149,
#    'total_supply': 2644,
#    'max_supply': 5239,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['92shs8m3o7r',
#     'wihd5j2mwgb',
#     '9yk6w7jymuo',
#     'mujm51g0vq',
#     'x3fa5gd5m5m',
#     'jls3t7otdtg',
#     'plqvidhndo',
#     'hk143x3526l',
#     'yytaa6j68wb',
#     'umvhz5zeyw'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.9499192025112673,
#      'volume_24h': 8981,
#      'volume_change_24h': 0.8922719810791857,
#      'percent_change_1h': 0.5603670547488908,
#      'percent_change_24h': 0.6936443869731246,
#      'percent_change_7d': 0.2281085273786514,
#      'market_cap': 0.22281011333267853,
#      'market_cap_dominance': 9575,
#      'fully_diluted_market_cap': 0.05849048626442599,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 9754,
#    'name': '6ecirhpb4d2',
#    'symbol': 'tgcny7u6',
#    'slug': 'npxgofxsl8',
#    'cmc_rank': 9181,
#    'num_market_pairs': 4017,
#    'circulating_supply': 8443,
#    'total_supply': 5969,
#    'max_supply': 3963,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['dywlmvn555k',
#     '4vutokpg7e9',
#     'nxccu0z9uw8',
#     'bomxmmqs78e',
#     'm6zh6ffhpqh',
#     're9x9ygywo',
#     'nyii5i5z96d',
#     'a88ca2q8mee',
#     '9di3nuueuqc',
#     'pdwftnzkah'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.17441592856311194,
#      'volume_24h': 1867,
#      'volume_change_24h': 0.16198970847245553,
#      'percent_change_1h': 0.7517044278210241,
#      'percent_change_24h': 0.2660783142971057,
#      'percent_change_7d': 0.695188666471314,
#      'market_cap': 0.4981932092409449,
#      'market_cap_dominance': 2513,
#      'fully_diluted_market_cap': 0.4225349817245623,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 94,
#    'name': '6efz68xbivn',
#    'symbol': '3u50d2k98uw',
#    'slug': '2jfna4l73o5',
#    'cmc_rank': 9355,
#    'num_market_pairs': 5169,
#    'circulating_supply': 1513,
#    'total_supply': 4908,
#    'max_supply': 3476,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['3xgm86pm6qh',
#     'sj70dy64i2s',
#     '9xra29y0ur',
#     '37h0b5vj4yc',
#     '6i9wqtz71yy',
#     '5lj8m2h9mxs',
#     'i0adxg8bi5',
#     'd2eal7ap5wt',
#     'aq4qqdls42a',
#     '0wk2yy7gle6'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.5777538394802317,
#      'volume_24h': 2014,
#      'volume_change_24h': 0.5064008393333648,
#      'percent_change_1h': 0.5685618089767563,
#      'percent_change_24h': 0.3918831890846721,
#      'percent_change_7d': 0.8996610732564994,
#      'market_cap': 0.7714462613212552,
#      'market_cap_dominance': 8866,
#      'fully_diluted_market_cap': 0.7676920755894314,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}},
#   {'id': 1095,
#    'name': 'eepc5gfy6xk',
#    'symbol': 'dl8td3vdho',
#    'slug': 'l9s32qwqysa',
#    'cmc_rank': 9945,
#    'num_market_pairs': 2425,
#    'circulating_supply': 9286,
#    'total_supply': 5529,
#    'max_supply': 7380,
#    'last_updated': '2023-01-03T13:55:54.632Z',
#    'date_added': '2023-01-03T13:55:54.632Z',
#    'tags': ['80ma37fr52v',
#     '6fdhjdpg5ex',
#     '91tt4zex32l',
#     'm7lrsj71dds',
#     'sest2oo1ezg',
#     '7kc7d1nc48r',
#     'vo98rpsy7we',
#     'glnvqyj1xgf',
#     '9sj59qblnos',
#     'q5qv31suxg8'],
#    'platform': None,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'quote': {'USD': {'price': 0.6667759814686312,
#      'volume_24h': 3192,
#      'volume_change_24h': 0.5097680657728694,
#      'percent_change_1h': 0.7606558881498977,
#      'percent_change_24h': 0.36131645565442305,
#      'percent_change_7d': 0.7464018025513834,
#      'market_cap': 0.7882225712010729,
#      'market_cap_dominance': 5283,
#      'fully_diluted_market_cap': 0.15140597904422903,
#      'last_updated': '2023-01-03T13:55:54.632Z'}}}]}

# %% [markdown]
# **/quotes/latest**

# %% [markdown]
# Returns the latest market quote for 1 or more cryptocurrencies. "convert" is used option to return market values in multiple fiat and cryptocurrency conversions in the same call.

# %%
url = os.path.join(api_url, "v2/cryptocurrency/quotes/latest")
parameters = {"convert": "USD", "symbol": "ETH,BTC"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:43:59.754Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 0,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'BTC': [{'id': 7332,
#     'name': 'vwqo5wxvqr',
#     'symbol': 'BTC',
#     'slug': 'qa92h0mjah',
#     'is_active': 9950,
#     'is_fiat': None,
#     'circulating_supply': 802,
#     'total_supply': 6425,
#     'max_supply': 220,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 2851,
#     'cmc_rank': 7078,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['xt3dgyk687f',
#      '1mttnhy7jbn',
#      'grh510g9pa6',
#      'l0ipt4tkofa',
#      'mcf4c9ze6ps',
#      'qweghbt9fg',
#      'ca10f1pw7',
#      'b2iknhaxvlr',
#      '4q79msema4c',
#      '4dcthze3kp4'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.5935265615020064,
#       'volume_24h': 0.01050240282436432,
#       'volume_change_24h': 0.5169063886035214,
#       'percent_change_1h': 0.7541051245916102,
#       'percent_change_24h': 0.5950493649797262,
#       'percent_change_7d': 0.7128186147370199,
#       'percent_change_30d': 0.8383367027623525,
#       'market_cap': 0.718883138584643,
#       'market_cap_dominance': 3134,
#       'fully_diluted_market_cap': 0.5299352927073151,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}},
#    {'id': 6335,
#     'name': 'dohz5jmorjw',
#     'symbol': 'BTC',
#     'slug': '5bmfxxhp25y',
#     'is_active': 5814,
#     'is_fiat': None,
#     'circulating_supply': 4040,
#     'total_supply': 2695,
#     'max_supply': 1948,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 7361,
#     'cmc_rank': 7170,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['hs6jv3sa37b',
#      'anz666jz4ve',
#      'kj58ylzedn',
#      'nsxyi86v05',
#      't648dl5k7r',
#      'kjy0l7h6g3',
#      'nw5y4abuyab',
#      '1vqb8vxfng1',
#      'g0ql0252kc',
#      'rt0by4zx00m'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.20387786645654948,
#       'volume_24h': 0.013728492908664292,
#       'volume_change_24h': 0.06726672059924566,
#       'percent_change_1h': 0.17886736963118133,
#       'percent_change_24h': 0.8434853456503615,
#       'percent_change_7d': 0.6313462684546651,
#       'percent_change_30d': 0.12625090318134968,
#       'market_cap': 0.635561721156582,
#       'market_cap_dominance': 6995,
#       'fully_diluted_market_cap': 0.4192702150664911,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}},
#    {'id': 1862,
#     'name': 'oovhvldnyx',
#     'symbol': 'BTC',
#     'slug': 'akfu17oq8kj',
#     'is_active': 6613,
#     'is_fiat': None,
#     'circulating_supply': 3365,
#     'total_supply': 7101,
#     'max_supply': 6920,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 5376,
#     'cmc_rank': 9876,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['dxw91wn2ih5',
#      'g28p0n48iwe',
#      'vo7kgr04b8',
#      '2a1tmz782k7',
#      'e21977oome5',
#      'vwk672ubx',
#      '5ay7g1xm5vo',
#      'n9r61o8mxlb',
#      'oynwuan58gn',
#      'wakxytofgkr'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.5090601250834084,
#       'volume_24h': 0.5473347808774651,
#       'volume_change_24h': 0.4680265754567723,
#       'percent_change_1h': 0.8254373262190493,
#       'percent_change_24h': 0.6272077579336099,
#       'percent_change_7d': 0.2554756639175364,
#       'percent_change_30d': 0.3394207614808089,
#       'market_cap': 0.9529912343526594,
#       'market_cap_dominance': 1065,
#       'fully_diluted_market_cap': 0.4819279405825496,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}}],
#   'ETH': [{'id': 3806,
#     'name': 'j7cu38q5178',
#     'symbol': 'ETH',
#     'slug': '0kbfi8hrh3hb',
#     'is_active': 5268,
#     'is_fiat': None,
#     'circulating_supply': 4125,
#     'total_supply': 9616,
#     'max_supply': 8803,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 9671,
#     'cmc_rank': 1374,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['axijyc2um5r',
#      'zt95nfbm47',
#      '7ygl1bkdck6',
#      'zrnrnj18ibm',
#      'kj8nmuz4jpj',
#      'taydsz4lin7',
#      'o9t5nqp0np9',
#      'q5eqmzyqem',
#      '3q4uhaaqo0n',
#      '781ltsrxp0e'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.8886648166746638,
#       'volume_24h': 0.24448465495609106,
#       'volume_change_24h': 0.8544968399967467,
#       'percent_change_1h': 0.7786624594607157,
#       'percent_change_24h': 0.28357628968359516,
#       'percent_change_7d': 0.6380894391760084,
#       'percent_change_30d': 0.9937583308913465,
#       'market_cap': 0.4417923894475744,
#       'market_cap_dominance': 3465,
#       'fully_diluted_market_cap': 0.0988604058069833,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}},
#    {'id': 205,
#     'name': '0vv06y5ck0i',
#     'symbol': 'ETH',
#     'slug': 'phofwdvi1l',
#     'is_active': 7220,
#     'is_fiat': None,
#     'circulating_supply': 9106,
#     'total_supply': 3208,
#     'max_supply': 8355,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 9195,
#     'cmc_rank': 8566,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['ibnyzpa0y7d',
#      '5m7g9r31jpd',
#      'ff6e2pap7kw',
#      'jzesjbj0bje',
#      'hlf87seva2s',
#      '3r03bi9bhk1',
#      '0v3jxml8iby',
#      'ea7y58w8wzf',
#      'sma8xedqfm',
#      '4ztfjzbzu9n'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.6269121507549387,
#       'volume_24h': 0.9157629504745624,
#       'volume_change_24h': 0.8495125264955896,
#       'percent_change_1h': 0.06340529172594267,
#       'percent_change_24h': 0.9801705124243911,
#       'percent_change_7d': 0.258880574522963,
#       'percent_change_30d': 0.465385295237261,
#       'market_cap': 0.6807088382274125,
#       'market_cap_dominance': 6588,
#       'fully_diluted_market_cap': 0.8198410081841354,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}},
#    {'id': 4587,
#     'name': 'tolgova364',
#     'symbol': 'ETH',
#     'slug': 'ln8gt2c84a',
#     'is_active': 748,
#     'is_fiat': None,
#     'circulating_supply': 8891,
#     'total_supply': 6268,
#     'max_supply': 9533,
#     'date_added': '2023-01-03T13:43:59.754Z',
#     'num_market_pairs': 5049,
#     'cmc_rank': 4419,
#     'last_updated': '2023-01-03T13:43:59.754Z',
#     'tags': ['evao6eyvumn',
#      'xspyp4jrhc',
#      'fl4klwjfteb',
#      '4mbxvp3rlet',
#      'fy5faqbvzkq',
#      'ocx32u51mt',
#      '1vynpfmczkt',
#      'w8f89zorbx',
#      'w3tc3hl4be',
#      'gwyxfz72igr'],
#     'platform': None,
#     'self_reported_circulating_supply': None,
#     'self_reported_market_cap': None,
#     'quote': {'USD': {'price': 0.31302390068482144,
#       'volume_24h': 0.33089369389457834,
#       'volume_change_24h': 0.2004899046231352,
#       'percent_change_1h': 0.47030998743175667,
#       'percent_change_24h': 0.9006918285284267,
#       'percent_change_7d': 0.3350358955524917,
#       'percent_change_30d': 0.4680710753974393,
#       'market_cap': 0.24875832988227264,
#       'market_cap_dominance': 488,
#       'fully_diluted_market_cap': 0.606779057765394,
#       'last_updated': '2023-01-03T13:43:59.754Z'}}}]}}

# %% [markdown]
# # Fiat API access

# %% [markdown]
# Returns a mapping of all supported fiat currencies to unique CoinMarketCap ids.

# %%
url = os.path.join(api_url, "v1/fiat/map")
parameters = {"start": "1", "limit": "5000"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:45:14.025Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 1,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 2781,
#    'name': 'United States Dollar',
#    'sign': '$',
#    'symbol': 'USD'},
#   {'id': 2782, 'name': 'Australian Dollar', 'sign': '$', 'symbol': 'AUD'},
#   {'id': 2783, 'name': 'Brazilian Real', 'sign': 'R$', 'symbol': 'BRL'},
#   {'id': 2784, 'name': 'Canadian Dollar', 'sign': '$', 'symbol': 'CAD'},
#   {'id': 2785, 'name': 'Swiss Franc', 'sign': 'Fr', 'symbol': 'CHF'},
#   {'id': 2786, 'name': 'Chilean Peso', 'sign': '$', 'symbol': 'CLP'},
#   {'id': 2787, 'name': 'Chinese Yuan', 'sign': '¥', 'symbol': 'CNY'},
#   {'id': 2788, 'name': 'Czech Koruna', 'sign': 'Kč', 'symbol': 'CZK'},
#   {'id': 2789, 'name': 'Danish Krone', 'sign': 'kr', 'symbol': 'DKK'},
#   {'id': 2790, 'name': 'Euro', 'sign': '€', 'symbol': 'EUR'},
#   {'id': 2791, 'name': 'Pound Sterling', 'sign': '£', 'symbol': 'GBP'},
#   {'id': 2792, 'name': 'Hong Kong Dollar', 'sign': '$', 'symbol': 'HKD'},
#   {'id': 2793, 'name': 'Hungarian Forint', 'sign': 'Ft', 'symbol': 'HUF'},
#   {'id': 2794, 'name': 'Indonesian Rupiah', 'sign': 'Rp', 'symbol': 'IDR'},
#   {'id': 2795, 'name': 'Israeli New Shekel', 'sign': '₪', 'symbol': 'ILS'},
#   {'id': 2796, 'name': 'Indian Rupee', 'sign': '₹', 'symbol': 'INR'},
#   {'id': 2797, 'name': 'Japanese Yen', 'sign': '¥', 'symbol': 'JPY'},
#   {'id': 2798, 'name': 'South Korean Won', 'sign': '₩', 'symbol': 'KRW'},
#   {'id': 2799, 'name': 'Mexican Peso', 'sign': '$', 'symbol': 'MXN'},
#   {'id': 2800, 'name': 'Malaysian Ringgit', 'sign': 'RM', 'symbol': 'MYR'},
#   {'id': 2801, 'name': 'Norwegian Krone', 'sign': 'kr', 'symbol': 'NOK'},
#   {'id': 2802, 'name': 'New Zealand Dollar', 'sign': '$', 'symbol': 'NZD'},
#   {'id': 2803, 'name': 'Philippine Peso', 'sign': '₱', 'symbol': 'PHP'},
#   {'id': 2804, 'name': 'Pakistani Rupee', 'sign': '₨', 'symbol': 'PKR'},
#   {'id': 2805, 'name': 'Polish Złoty', 'sign': 'zł', 'symbol': 'PLN'},
#   {'id': 2806, 'name': 'Russian Ruble', 'sign': '₽', 'symbol': 'RUB'},
#   {'id': 2807, 'name': 'Swedish Krona', 'sign': 'kr', 'symbol': 'SEK'},
#   {'id': 2808, 'name': 'Singapore Dollar', 'sign': 'S$', 'symbol': 'SGD'},
#   {'id': 2809, 'name': 'Thai Baht', 'sign': '฿', 'symbol': 'THB'},
#   {'id': 2810, 'name': 'Turkish Lira', 'sign': '₺', 'symbol': 'TRY'},
#   {'id': 2811, 'name': 'New Taiwan Dollar', 'sign': 'NT$', 'symbol': 'TWD'},
#   {'id': 2812, 'name': 'South African Rand', 'sign': 'R', 'symbol': 'ZAR'},
#   {'id': 2813,
#    'name': 'United Arab Emirates Dirham',
#    'sign': 'د.إ',
#    'symbol': 'AED'},
#   {'id': 2814, 'name': 'Bulgarian Lev', 'sign': 'лв', 'symbol': 'BGN'},
#   {'id': 2815, 'name': 'Croatian Kuna', 'sign': 'kn', 'symbol': 'HRK'},
#   {'id': 2816, 'name': 'Mauritian Rupee', 'sign': '₨', 'symbol': 'MUR'},
#   {'id': 2817, 'name': 'Romanian Leu', 'sign': 'lei', 'symbol': 'RON'},
#   {'id': 2818, 'name': 'Icelandic Króna', 'sign': 'kr', 'symbol': 'ISK'},
#   {'id': 2819, 'name': 'Nigerian Naira', 'sign': '₦', 'symbol': 'NGN'},
#   {'id': 2820, 'name': 'Colombian Peso', 'sign': '$', 'symbol': 'COP'},
#   {'id': 2821, 'name': 'Argentine Peso', 'sign': '$', 'symbol': 'ARS'},
#   {'id': 2822, 'name': 'Peruvian Sol', 'sign': 'S/.', 'symbol': 'PEN'},
#   {'id': 2823, 'name': 'Vietnamese Dong', 'sign': '₫', 'symbol': 'VND'},
#   {'id': 2824, 'name': 'Ukrainian Hryvnia', 'sign': '₴', 'symbol': 'UAH'},
#   {'id': 2832, 'name': 'Bolivian Boliviano', 'sign': 'Bs.', 'symbol': 'BOB'},
#   {'id': 3526, 'name': 'Albanian Lek', 'sign': 'L', 'symbol': 'ALL'},
#   {'id': 3527, 'name': 'Armenian Dram', 'sign': '֏', 'symbol': 'AMD'},
#   {'id': 3528, 'name': 'Azerbaijani Manat', 'sign': '₼', 'symbol': 'AZN'},
#   {'id': 3529,
#    'name': 'Bosnia-Herzegovina Convertible Mark',
#    'sign': 'KM',
#    'symbol': 'BAM'},
#   {'id': 3530, 'name': 'Bangladeshi Taka', 'sign': '৳', 'symbol': 'BDT'},
#   {'id': 3531, 'name': 'Bahraini Dinar', 'sign': '.د.ب', 'symbol': 'BHD'},
#   {'id': 3532, 'name': 'Bermudan Dollar', 'sign': '$', 'symbol': 'BMD'},
#   {'id': 3533, 'name': 'Belarusian Ruble', 'sign': 'Br', 'symbol': 'BYN'},
#   {'id': 3534, 'name': 'Costa Rican Colón', 'sign': '₡', 'symbol': 'CRC'},
#   {'id': 3535, 'name': 'Cuban Peso', 'sign': '$', 'symbol': 'CUP'},
#   {'id': 3536, 'name': 'Dominican Peso', 'sign': '$', 'symbol': 'DOP'},
#   {'id': 3537, 'name': 'Algerian Dinar', 'sign': 'د.ج', 'symbol': 'DZD'},
#   {'id': 3538, 'name': 'Egyptian Pound', 'sign': '£', 'symbol': 'EGP'},
#   {'id': 3539, 'name': 'Georgian Lari', 'sign': '₾', 'symbol': 'GEL'},
#   {'id': 3540, 'name': 'Ghanaian Cedi', 'sign': '₵', 'symbol': 'GHS'},
#   {'id': 3541, 'name': 'Guatemalan Quetzal', 'sign': 'Q', 'symbol': 'GTQ'},
#   {'id': 3542, 'name': 'Honduran Lempira', 'sign': 'L', 'symbol': 'HNL'},
#   {'id': 3543, 'name': 'Iraqi Dinar', 'sign': 'ع.د', 'symbol': 'IQD'},
#   {'id': 3544, 'name': 'Iranian Rial', 'sign': '﷼', 'symbol': 'IRR'},
#   {'id': 3545, 'name': 'Jamaican Dollar', 'sign': '$', 'symbol': 'JMD'},
#   {'id': 3546, 'name': 'Jordanian Dinar', 'sign': 'د.ا', 'symbol': 'JOD'},
#   {'id': 3547, 'name': 'Kenyan Shilling', 'sign': 'Sh', 'symbol': 'KES'},
#   {'id': 3548, 'name': 'Kyrgystani Som', 'sign': 'с', 'symbol': 'KGS'},
#   {'id': 3549, 'name': 'Cambodian Riel', 'sign': '៛', 'symbol': 'KHR'},
#   {'id': 3550, 'name': 'Kuwaiti Dinar', 'sign': 'د.ك', 'symbol': 'KWD'},
#   {'id': 3551, 'name': 'Kazakhstani Tenge', 'sign': '₸', 'symbol': 'KZT'},
#   {'id': 3552, 'name': 'Lebanese Pound', 'sign': 'ل.ل', 'symbol': 'LBP'},
#   {'id': 3553, 'name': 'Sri Lankan Rupee', 'sign': 'Rs', 'symbol': 'LKR'},
#   {'id': 3554, 'name': 'Moroccan Dirham', 'sign': 'د.م.', 'symbol': 'MAD'},
#   {'id': 3555, 'name': 'Moldovan Leu', 'sign': 'L', 'symbol': 'MDL'},
#   {'id': 3556, 'name': 'Macedonian Denar', 'sign': 'ден', 'symbol': 'MKD'},
#   {'id': 3557, 'name': 'Myanma Kyat', 'sign': 'Ks', 'symbol': 'MMK'},
#   {'id': 3558, 'name': 'Mongolian Tugrik', 'sign': '₮', 'symbol': 'MNT'},
#   {'id': 3559, 'name': 'Namibian Dollar', 'sign': '$', 'symbol': 'NAD'},
#   {'id': 3560, 'name': 'Nicaraguan Córdoba', 'sign': 'C$', 'symbol': 'NIO'},
#   {'id': 3561, 'name': 'Nepalese Rupee', 'sign': '₨', 'symbol': 'NPR'},
#   {'id': 3562, 'name': 'Omani Rial', 'sign': 'ر.ع.', 'symbol': 'OMR'},
#   {'id': 3563, 'name': 'Panamanian Balboa', 'sign': 'B/.', 'symbol': 'PAB'},
#   {'id': 3564, 'name': 'Qatari Rial', 'sign': 'ر.ق', 'symbol': 'QAR'},
#   {'id': 3565, 'name': 'Serbian Dinar', 'sign': 'дин.', 'symbol': 'RSD'},
#   {'id': 3566, 'name': 'Saudi Riyal', 'sign': 'ر.س', 'symbol': 'SAR'},
#   {'id': 3567, 'name': 'South Sudanese Pound', 'sign': '£', 'symbol': 'SSP'},
#   {'id': 3568, 'name': 'Tunisian Dinar', 'sign': 'د.ت', 'symbol': 'TND'},
#   {'id': 3569,
#    'name': 'Trinidad and Tobago Dollar',
#    'sign': '$',
#    'symbol': 'TTD'},
#   {'id': 3570, 'name': 'Ugandan Shilling', 'sign': 'Sh', 'symbol': 'UGX'},
#   {'id': 3571, 'name': 'Uruguayan Peso', 'sign': '$', 'symbol': 'UYU'},
#   {'id': 3572, 'name': 'Uzbekistan Som', 'sign': "so'm", 'symbol': 'UZS'},
#   {'id': 3573, 'name': 'Sovereign Bolivar', 'sign': 'Bs.', 'symbol': 'VES'}]}

# %% [markdown]
# # Exchange API access

# %% [markdown]
# Returns the exchange assets in the form of token holdings. This information includes details like wallet address, cryptocurrency, blockchain platform, balance, and etc.

# %%
url = os.path.join(api_url, "v1/exchange/assets")
parameters = {"id": "270"}  # CoinMarketCap exchange ID for binance

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:49:37.939Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 1,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'270': [{'wallet_address': 'ngv59reb55r',
#     'balance': 3714,
#     'platform': {'crypto_id': 9941,
#      'symbol': '5pz2l3fvx8l',
#      'name': 'jowl016ftx'},
#     'currency': {'crypto_id': 7202,
#      'price_usd': 0.1540572732507164,
#      'symbol': 'tg9co85qza',
#      'name': 'iaipo1f4jv'}},
#    {'wallet_address': 'almxgv13n9i',
#     'balance': 6455,
#     'platform': {'crypto_id': 4998,
#      'symbol': 'dfenppy0f9b',
#      'name': 'q2zp2jwtpxm'},
#     'currency': {'crypto_id': 8764,
#      'price_usd': 0.9642128570939037,
#      'symbol': '4sklp0n387d',
#      'name': '3ad5dcewwja'}},
#    {'wallet_address': 'dyndsylykk',
#     'balance': 4100,
#     'platform': {'crypto_id': 9922,
#      'symbol': '8tsov42cpsc',
#      'name': 'zd8i66qvsu'},
#     'currency': {'crypto_id': 8771,
#      'price_usd': 0.5931473434154995,
#      'symbol': '5jk7yu4tabv',
#      'name': 'nj2k089l7x'}},
#    {'wallet_address': 'yclenmto6qi',
#     'balance': 6207,
#     'platform': {'crypto_id': 2732,
#      'symbol': '6ugynot87m2',
#      'name': 'wo51bigwdpi'},
#     'currency': {'crypto_id': 6730,
#      'price_usd': 0.08132103867587626,
#      'symbol': 'dgk0gwsz0jf',
#      'name': 'i7vh2gvxqup'}},
#    {'wallet_address': '5yhwxeyolts',
#     'balance': 4362,
#     'platform': {'crypto_id': 1935,
#      'symbol': 'bv2mh0o6r0v',
#      'name': '8xidmqm2gb9'},
#     'currency': {'crypto_id': 4756,
#      'price_usd': 0.4065183616135768,
#      'symbol': 'vc5umnjkm9g',
#      'name': '9ln17yhjxzl'}},
#    {'wallet_address': 'wwipxpy3lhl',
#     'balance': 9560,
#     'platform': {'crypto_id': 2623,
#      'symbol': 'nlhwy3xbx9t',
#      'name': '1v98hrdx708'},
#     'currency': {'crypto_id': 5371,
#      'price_usd': 0.12086815863073408,
#      'symbol': '70rclgpl5kg',
#      'name': 'h3ill367hij'}},
#    {'wallet_address': 'odocawxmdzo',
#     'balance': 69,
#     'platform': {'crypto_id': 1543,
#      'symbol': '8sc20iygjid',
#      'name': '0lfgjp9tx0d'},
#     'currency': {'crypto_id': 9198,
#      'price_usd': 0.6206880145012041,
#      'symbol': '4d0je9wkp1q',
#      'name': 'ulte8477sfr'}},
#    {'wallet_address': '0245uiq5irid',
#     'balance': 6986,
#     'platform': {'crypto_id': 7272,
#      'symbol': '8mkstlpard2',
#      'name': 'uz38moeqr9e'},
#     'currency': {'crypto_id': 3457,
#      'price_usd': 0.50668802642833,
#      'symbol': '7eu3fdqq12n',
#      'name': '58r982rzgtb'}},
#    {'wallet_address': 'paz0irf2i4',
#     'balance': 6640,
#     'platform': {'crypto_id': 6716,
#      'symbol': '7aiacr5m5e3',
#      'name': 'umm7s0o0bnk'},
#     'currency': {'crypto_id': 8538,
#      'price_usd': 0.6566264234794954,
#      'symbol': '0rh11v3s546',
#      'name': '7sg423vk7hh'}},
#    {'wallet_address': '07u3p089pnfc',
#     'balance': 7035,
#     'platform': {'crypto_id': 5039,
#      'symbol': '1qxf11h4lw4',
#      'name': 'godhzcoyfms'},
#     'currency': {'crypto_id': 8096,
#      'price_usd': 0.4041094624681987,
#      'symbol': 'gdokq7hbxtc',
#      'name': '8rjhgyhnnwg'}}]}}

# %% [markdown]
# # Global Market API access

# %% [markdown]
# Returns the latest global cryptocurrency market metrics. Use the "convert" option to return market values in multiple fiat and cryptocurrency conversions in the same call.

# %%
url = os.path.join(api_url, "v1/global-metrics/quotes/latest")
parameters = {"convert": "USD"}

data = get_data(session, url, parameters)
data
# Out:
# {'status': {'timestamp': '2023-01-03T13:52:01.135Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 0,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'active_cryptocurrencies': 4312,
#   'total_cryptocurrencies': 3141,
#   'active_market_pairs': 6515,
#   'active_exchanges': 1105,
#   'total_exchanges': 1918,
#   'eth_dominance': 0.7424321860309622,
#   'btc_dominance': 0.635159990570612,
#   'eth_dominance_yesterday': 0.42233305452074843,
#   'btc_dominance_yesterday': 0.20249402398097582,
#   'eth_dominance_24h_percentage_change': 0.9152624260280902,
#   'btc_dominance_24h_percentage_change': 0.9906628299586242,
#   'defi_volume_24h': 0.33566764101292135,
#   'defi_volume_24h_reported': 0.9972982812848861,
#   'defi_market_cap': 0.656932235950558,
#   'defi_24h_percentage_change': 0.14023714723039293,
#   'stablecoin_volume_24h': 0.19603058411559315,
#   'stablecoin_volume_24h_reported': 0.8524932618991903,
#   'stablecoin_market_cap': 0.3547044633277048,
#   'stablecoin_24h_percentage_change': 0.48666846584657275,
#   'derivatives_volume_24h': 0.6979505517362306,
#   'derivatives_volume_24h_reported': 0.8761044956966921,
#   'derivatives_24h_percentage_change': 0.10948304035216427,
#   'quote': {'USD': {'total_market_cap': 0.4959033144342433,
#     'total_volume_24h': 0.27148236685660754,
#     'total_volume_24h_reported': 0.5969568059634855,
#     'altcoin_volume_24h': 0.1711456731384975,
#     'altcoin_volume_24h_reported': 0.7823072053853068,
#     'altcoin_market_cap': 0.6288448886169844,
#     'defi_volume_24h': 0.9964181891041701,
#     'defi_volume_24h_reported': 0.8563548945030945,
#     'defi_24h_percentage_change': 0.7703820323086159,
#     'defi_market_cap': 0.1790406945369909,
#     'stablecoin_volume_24h': 0.07222652184877743,
#     'stablecoin_volume_24h_reported': 0.06856215686085432,
#     'stablecoin_24h_percentage_change': 0.7641346356681613,
#     'stablecoin_market_cap': 0.675211965473409,
#     'derivatives_volume_24h': 0.2758507923481157,
#     'derivatives_volume_24h_reported': 0.37503356220053186,
#     'derivatives_24h_percentage_change': 0.020102040713711578,
#     'last_updated': '2023-01-03T13:52:01.135Z',
#     'total_market_cap_yesterday': 0.30498566255280624,
#     'total_volume_24h_yesterday': 0.9911167279625839,
#     'total_market_cap_yesterday_percentage_change': 0.4963069915101619,
#     'total_volume_24h_yesterday_percentage_change': 0.16123326679188832}},
#   'last_updated': '2023-01-03T13:52:01.135Z'}}
