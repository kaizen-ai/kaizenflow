# %% [markdown]
# # Description

# %% [markdown]
# This notebook contains examples of the API endpoints for Coingecko.com.
#
# The API is accessed through an API wrapper `pycoingecko` (https://github.com/man-c/pycoingecko).

# %% [markdown]
# # Imports

# %% [markdown]
# ## Installing pycoingecko

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --upgrade pip)"
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install -U pycoingecko)"
# Out:
# Requirement already satisfied: pip in /venv/lib/python3.8/site-packages (22.3.1)
# Requirement already satisfied: pycoingecko in /venv/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: requests in /venv/lib/python3.8/site-packages (from pycoingecko) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /venv/lib/python3.8/site-packages (from requests->pycoingecko) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /venv/lib/python3.8/site-packages (from requests->pycoingecko) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/lib/python3.8/site-packages (from requests->pycoingecko) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /venv/lib/python3.8/site-packages (from requests->pycoingecko) (2.1.1)

# %%
import requests
from pycoingecko import CoinGeckoAPI

# %% [markdown]
# # Examples of the free API endpoints

# %% [markdown]
# API reference: https://www.coingecko.com/en/api/documentation
#
# `pycoingecko` documentation: https://github.com/man-c/pycoingecko#api-documentation

# %%
cg = CoinGeckoAPI()

# %% [markdown]
# ## Getting a list of IDs

# %% [markdown]
# ### Coins

# %%
# Get IDs of supported coins.
all_coins = cg.get_coins_list()
print(len(all_coins))
bitcoin = [c for c in all_coins if c["name"].lower() == "bitcoin"][0]
print(bitcoin)
bitcoin_id = bitcoin["id"]
# Out:
# 12466
# {'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin'}

# %% [markdown]
# ### Exchanges

# %%
# Get IDs of supported exchanges.
all_exchanges = cg.get_exchanges_list()
print(len(all_exchanges))
print(all_exchanges[:3])
binance_id = cg.get_exchanges_by_id("binance")
# Out:
# 100
# [{'id': 'gdax', 'name': 'Coinbase Exchange', 'year_established': 2012, 'country': 'United States', 'description': '', 'url': 'https://www.coinbase.com', 'image': 'https://assets.coingecko.com/markets/images/23/small/Coinbase_Coin_Primary.png?1621471875', 'has_trading_incentive': False, 'trust_score': 10, 'trust_score_rank': 1, 'trade_volume_24h_btc': 90485.90208240162, 'trade_volume_24h_btc_normalized': 90485.90208240162}, {'id': 'okex', 'name': 'OKX', 'year_established': 2017, 'country': 'Seychelles', 'description': '', 'url': 'https://www.okx.com', 'image': 'https://assets.coingecko.com/markets/images/96/small/WeChat_Image_20220117220452.png?1642428377', 'has_trading_incentive': False, 'trust_score': 10, 'trust_score_rank': 2, 'trade_volume_24h_btc': 65959.74301508609, 'trade_volume_24h_btc_normalized': 44196.48679615447}, {'id': 'kucoin', 'name': 'KuCoin', 'year_established': 2014, 'country': 'Seychelles', 'description': '', 'url': 'https://www.kucoin.com/', 'image': 'https://assets.coingecko.com/markets/images/61/small/kucoin.png?1640584259', 'has_trading_incentive': False, 'trust_score': 10, 'trust_score_rank': 3, 'trade_volume_24h_btc': 36882.716242829876, 'trade_volume_24h_btc_normalized': 36882.716242829876}]

# %% [markdown]
# ## /simple

# %%
supported_vs_currencies = cg.get_supported_vs_currencies()

# %%
usd_id = "usd"

# %%
# Get full latest price data for BTC/USD.
kwargs = {
    "include_market_cap": True,
    "include_24hr_vol": True,
    "include_24hr_change": True,
    "include_last_updated_at": True,
}
cg.get_price(bitcoin_id, usd_id, **kwargs)
# Out:
# {'bitcoin': {'usd': 22995,
#   'usd_market_cap': 443128694993.29596,
#   'usd_24h_vol': 37449301794.207214,
#   'usd_24h_change': 2.3479335991513,
#   'last_updated_at': 1674510003}}

# %%
# Get ETH price given a contract address.
eth_id = "ethereum"
contract_address = "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
cg.get_token_price(eth_id, contract_address, usd_id, **kwargs)
# Out:
# {'0x1f9840a85d5af5bf1d1762f925bdaddc4201f984': {'usd': 6.75,
#   'usd_market_cap': 5086299301.922629,
#   'usd_24h_vol': 178904153.92873192,
#   'usd_24h_change': -0.9782273311665642,
#   'last_updated_at': 1674510029}}

# %% [markdown]
# ## /coins

# %%
kwargs = {
    "ids": f"{bitcoin_id},{eth_id}",
    "per_page": 10,
    "sparkline": True,
    "price_change_percentage": "1h,24h",
}
cg.get_coins_markets(usd_id, **kwargs)
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 22995,
#   'market_cap': 443128694993,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 482896535403,
#   'total_volume': 37449301794,
#   'high_24h': 23165,
#   'low_24h': 22468,
#   'price_change_24h': 527.52,
#   'price_change_percentage_24h': 2.34793,
#   'market_cap_change_24h': 10381919019,
#   'market_cap_change_percentage_24h': 2.39907,
#   'circulating_supply': 19270593.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -66.69542,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 33811.53551,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-01-23T21:40:03.869Z',
#   'sparkline_in_7d': {'price': [21100.504618517323,
#     21218.833092977453,
#     21339.084564658813,
#     21291.821112503225,
#     21140.66776867305,
#     21196.7043539542,
#     21167.444996055972,
#     21087.189102768214,
#     21035.72416889137,
#     21091.322083737952,
#     21172.113197961044,
#     21163.030385333517,
#     21145.6834326599,
#     21078.016212611372,
#     21143.37185759893,
#     21201.941740865605,
#     21176.316447906156,
#     21147.625909358103,
#     21194.878269385026,
#     21260.553260427037,
#     21225.208422953252,
#     21167.102796860785,
#     21138.35118965325,
#     21240.172245106583,
#     21198.319122314566,
#     21356.44102222878,
#     21338.670970458825,
#     21326.41137103781,
#     21320.63011839789,
#     21247.502058233295,
#     21133.228554777954,
#     21210.654453673727,
#     21228.94986922072,
#     21316.610964520347,
#     21300.16714992632,
#     21273.860887323823,
#     21291.29088890238,
#     21267.62240006751,
#     21311.80322871148,
#     21236.33404462805,
#     21230.590444690875,
#     21176.790798372233,
#     21213.180310576274,
#     21272.503908492723,
#     21434.158598677062,
#     21470.68464261412,
#     21255.367139697784,
#     1556.2875663805717,
#     1564.7284340864392,
#     1584.415484479559,
#     1591.403835332103,
#     1593.1259753144298,
#     1595.0478669118854,
#     1634.9827428151825,
#     1638.359178594817,
#     1654.2590225254203,
#     1661.649680052114,
#     1655.9278330290683,
#     1654.2171517919444,
#     1648.674881694453,
#     1649.1747725123207,
#     1650.8254082792994,
#     1648.3803879236655,
#     1653.6997459031586,
#     1652.29336955584,
#     1649.8187284814728,
#     1660.8150358304094,
#     1636.7452755095412,
#     1647.6756095335952,
#     1658.8280558207375,
#     1649.3593037017083,
#     1650.3943642405143,
#     1657.7379208005045,
#     1658.4036992555089,
#     1653.3491679762787,
#     1659.8059043391431,
#     1664.7838706718228,
#     1654.6766217824934,
#     1661.9744454024076,
#     1651.6994948880863,
#     1625.6494400624342,
#     1635.9563156082677,
#     1625.7264161858143,
#     1617.0312913391954,
#     1622.724621293557,
#     1627.1716585157355,
#     1628.2972114246456,
#     1630.1352387833017,
#     1627.868228153007,
#     1630.3379241832054,
#     1625.9244727058338,
#     1627.8378447120235,
#     1627.9290588979597,
#     1631.6522759507156,
#     1633.7381445190917,
#     1645.108849759205,
#     1639.317453405259,
#     1637.8629710470366,
#     1657.002342884512,
#     1647.637701621544,
#     1645.2810643842279,
#     1620.3127278998365,
#     1624.0749864856464,
#     1625.3942911267939,
#     1629.6598792691484,
#     1637.8288029427913,
#     1638.9916223581047,
#     1640.6982095568817,
#     1631.9866403430176,
#     1635.9167483164804,
#     1632.9188671931395,
#     1637.194989717473,
#     1634.6656613012283,
#     1632.043274003787,
#     1635.5697289044863,
#     1638.82380024131,
#     1636.291934815383,
#     1635.729170565942,
#     1624.2869822995929,
#     1630.7357348692426,
#     1622.8150193721183,
#     1619.5040014363303]},
#   'price_change_percentage_1h_in_currency': 0.46729353618757713,
#   'price_change_percentage_24h_in_currency': 1.2651999901559514}]

# %%
# Get metadata and market data for BTC.
kwargs = {"sparkline": True}
coin_by_id = cg.get_coin_by_id(bitcoin_id, **kwargs)
coin_by_id.keys()
# Out:
# dict_keys(['id', 'symbol', 'name', 'asset_platform_id', 'platforms', 'detail_platforms', 'block_time_in_minutes', 'hashing_algorithm', 'categories', 'public_notice', 'additional_notices', 'localization', 'description', 'links', 'image', 'country_origin', 'genesis_date', 'sentiment_votes_up_percentage', 'sentiment_votes_down_percentage', 'market_cap_rank', 'coingecko_rank', 'coingecko_score', 'developer_score', 'community_score', 'liquidity_score', 'public_interest_score', 'market_data', 'community_data', 'developer_data', 'public_interest_stats', 'status_updates', 'last_updated', 'tickers'])

# %%
# Get ticker for BTC.
tickers = cg.get_coin_ticker_by_id(bitcoin_id)
print(tickers.keys())
tickers["tickers"][:2]
# Out:
# dict_keys(['name', 'tickers'])
# [{'base': 'BTC',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 22987.35,
#   'volume': 297903.40566024056,
#   'converted_last': {'btc': 1.000545, 'eth': 14.073866, 'usd': 22986},
#   'converted_volume': {'btc': 298066, 'eth': 4192653, 'usd': 6847596246},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.014178,
#   'timestamp': '2023-01-23T21:34:44+00:00',
#   'last_traded_at': '2023-01-23T21:34:44+00:00',
#   'last_fetch_at': '2023-01-23T21:34:44+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BTC_USDT?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'bitcoin',
#   'target_coin_id': 'tether'},
#  {'base': 'BTC',
#   'target': 'BUSD',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 22989.6,
#   'volume': 180474.6870857792,
#   'converted_last': {'btc': 1.000445, 'eth': 14.067987, 'usd': 23002},
#   'converted_volume': {'btc': 180555, 'eth': 2538916, 'usd': 4151335732},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.016047,
#   'timestamp': '2023-01-23T21:30:39+00:00',
#   'last_traded_at': '2023-01-23T21:30:39+00:00',
#   'last_fetch_at': '2023-01-23T21:30:39+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BTC_BUSD?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'bitcoin',
#   'target_coin_id': 'binance-usd'}]

# %%
# Get metadata and historical data for BTC/USD on 01-01-2021.
kwargs = {"localization": False}
date = "01-01-2021"
cg.get_coin_history_by_id(bitcoin_id, date, **kwargs)
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 106599.57494529981,
#    'ars': 2440049.9299405254,
#    'aud': 37695.73911032242,
#    'bch': 84.444492909334,
#    'bdt': 2456238.547854169,
#    'bhd': 10940.871286661732,
#    'bmd': 29022.41839530417,
#    'bnb': 776.2872215178629,
#    'brl': 150730.83217785193,
#    'btc': 1.0,
#    'cad': 36945.538617222206,
#    'chf': 25624.938008276353,
#    'clp': 20620415.529021926,
#    'cny': 189594.75265100395,
#    'czk': 623047.473626711,
#    'dkk': 176801.67062235318,
#    'dot': 3084.279681794566,
#    'eos': 11174.994329144789,
#    'eth': 39.28260457764448,
#    'eur': 23758.680415784707,
#    'gbp': 21227.635307530203,
#    'hkd': 225026.77214891047,
#    'huf': 8617336.469933717,
#    'idr': 405045200.55894524,
#    'ils': 93249.61075248031,
#    'inr': 2120302.429673093,
#    'jpy': 2996288.986340402,
#    'krw': 31508188.530862022,
#    'kwd': 8826.123747869542,
#    'lkr': 5375287.618146333,
#    'ltc': 232.40596218700907,
#    'mmk': 38533783.78874901,
#    'mxn': 577517.1036481581,
#    'myr': 117555.30571017938,
#    'ngn': 11248100.4020907,
#    'nok': 249584.81703455708,
#    'nzd': 40421.205399407074,
#    'php': 1393494.3830909333,
#    'pkr': 4648426.924897198,
#    'pln': 108202.83138229314,
#    'rub': 2146097.5551428394,
#    'sar': 108867.038449688,
#    'sek': 238788.76761568766,
#    'sgd': 38367.78223068412,
#    'thb': 870557.1877460047,
#    'try': 215891.96595898844,
#    'twd': 815323.8977374409,
#    'uah': 822180.1248367298,
#    'usd': 29022.41839530417,
#    'vef': 7211712319.180966,
#    'vnd': 673116092.5780954,
#    'xag': 1099.9621368219416,
#    'xau': 15.289010010646287,
#    'xdr': 20122.72281680256,
#    'xlm': 225583.96318195065,
#    'xrp': 131703.22463725976,
#    'yfi': 1.2700373975781651,
#    'zar': 425538.30747930834,
#    'bits': 1000330.8927134494,
#    'link': 2579.060589861794,
#    'sats': 100033089.27134494},
#   'market_cap': {'aed': 1981360223332.5154,
#    'ars': 45353068964958.53,
#    'aud': 700648554186.4335,
#    'bch': 1569564976.3696952,
#    'bdt': 45653965883368.21,
#    'bhd': 203357350975.51825,
#    'bmd': 539438036435.6701,
#    'bnb': 14428806337.98089,
#    'brl': 2801625386032.2993,
#    'btc': 18586943.0,
#    'cad': 686704620382.608,
#    'chf': 476289262138.366,
#    'clp': 383270488074245.44,
#    'cny': 3523986860623.3086,
#    'czk': 11580547878593.682,
#    'dkk': 3286202574162.4536,
#    'dot': 57327330641.57374,
#    'eos': 207708982621.13745,
#    'eth': 730143532.1762171,
#    'eur': 441601238643.4067,
#    'gbp': 394556847485.8513,
#    'hkd': 4182559787405.787,
#    'huf': 160169941778479.22,
#    'idr': 7528552055212683,
#    'ils': 1733225199828.5386,
#    'inr': 39409940403095.29,
#    'jpy': 55691852600636.83,
#    'krw': 585640904256386.1,
#    'kwd': 164050659012.59753,
#    'lkr': 99910164567091.66,
#    'ltc': 4319716372.030093,
#    'mmk': 716225242855801.9,
#    'mxn': 10734277487033.406,
#    'myr': 2184993766582.679,
#    'ngn': 209067801031936.9,
#    'nok': 4639018767886.742,
#    'nzd': 751306640750.0714,
#    'php': 25900800669331.336,
#    'pkr': 86400046292729.5,
#    'pln': 2011159859341.293,
#    'rub': 39889392929879.305,
#    'sar': 2023505438243.1592,
#    'sek': 4438353212713.033,
#    'sgd': 713139781358.1385,
#    'thb': 16180996826875.287,
#    'try': 4012771665437.6577,
#    'twd': 15154378813783.643,
#    'uah': 15281815116073.182,
#    'usd': 539438036435.6701,
#    'vef': 134043685809014420,
#    'vnd': 12511170445131782,
#    'xag': 20444933539.267635,
#    'xau': 284175957.594312,
#    'xdr': 374019902000.7086,
#    'xlm': 4192916265377.0146,
#    'xrp': 2447960329248.9434,
#    'yfi': 23606112.71665369,
#    'zar': 7909456265434.377,
#    'bits': 18593093284003.992,
#    'link': 47936852177.30754,
#    'sats': 1859309328400399.2},
#   'total_volume': {'aed': 159788764365.11526,
#    'ars': 3657543320359.869,
#    'aud': 56504498984.718994,
#    'bch': 126579127.41533086,
#    'bdt': 3681809451388.322,
#    'bhd': 16399955674.030851,
#    'bmd': 43503516563.294876,
#    'bnb': 1163625427.0471375,
#    'brl': 225939863623.12857,
#    'btc': 1499458.4864428907,
#    'cad': 55379976585.07438,
#    'chf': 38410820900.32943,
#    'clp': 30909229420177.227,
#    'cny': 284195422653.03705,
#    'czk': 933924792877.5022,
#    'dkk': 265019072551.93564,
#    'dot': 4623219553.767222,
#    'eos': 16750897332.916132,
#    'eth': 58883150.79798536,
#    'eur': 35613370771.24331,
#    'gbp': 31819429091.758324,
#    'hkd': 337306690849.3348,
#    'huf': 12917064137973.52,
#    'idr': 607147562666598.2,
#    'ils': 139777668788.19788,
#    'inr': 3178253810971.2563,
#    'jpy': 4491324801752.849,
#    'krw': 47229592756941.164,
#    'kwd': 13230028436.129873,
#    'lkr': 8057354516201.822,
#    'ltc': 348367819.9280219,
#    'mmk': 57760696523191.91,
#    'mxn': 865676476093.0055,
#    'myr': 176210993839.62567,
#    'ngn': 16860480594102.75,
#    'nok': 374118278977.281,
#    'nzd': 60589870721.66149,
#    'php': 2088795811222.3835,
#    'pkr': 6967817601073.893,
#    'pln': 162191985627.1047,
#    'rub': 3216919736492.7134,
#    'sar': 163187607107.17215,
#    'sek': 357935405850.9006,
#    'sgd': 57511866414.2587,
#    'thb': 1304932570420.5088,
#    'try': 323613959011.03766,
#    'twd': 1222139940460.9873,
#    'uah': 1232417167710.3845,
#    'usd': 43503516563.294876,
#    'vef': 10810086260005446,
#    'vnd': 1008975774645626.5,
#    'xag': 1648801984.2610035,
#    'xau': 22917652.52554382,
#    'xdr': 30163206712.677097,
#    'xlm': 338141899308.00354,
#    'xrp': 197418193632.45822,
#    'yfi': 1903738.4207266914,
#    'zar': 637865961257.6555,
#    'bits': 1499458486442.8909,
#    'link': 3865915085.386107,
#    'sats': 149945848644289.1}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 74537,
#   'reddit_average_posts_48h': 6.25,
#   'reddit_average_comments_48h': 975.917,
#   'reddit_subscribers': 1864490,
#   'reddit_accounts_active_48h': '9021.53846153846'},
#  'developer_data': {'forks': 26937,
#   'stars': 47253,
#   'subscribers': 3624,
#   'total_issues': 5885,
#   'closed_issues': 5288,
#   'pull_requests_merged': 8185,
#   'pull_request_contributors': 706,
#   'code_additions_deletions_4_weeks': {'additions': 1819, 'deletions': -1561},
#   'commit_count_4_weeks': 298},
#  'public_interest_stats': {'alexa_rank': None, 'bing_matches': None}}

# %%
# Get BTC/USD market chart for a single day.
days = 1
cg.get_coin_market_chart_by_id(bitcoin_id, usd_id, days)
# Out:
# {'prices': [[1674423894251, 22467.54996000632],
#   [1674424262517, 22473.348286443925],
#   [1674424489986, 22584.278502618527],
#   [1674424824019, 22552.164997205764],
#   [1674425124549, 22576.764498445576],
#   [1674425417990, 22578.34609032974],
#   [1674425754895, 22612.982551383786],
#   [1674425992909, 22594.63907236312],
#   [1674426335265, 22598.755027518808],
#   [1674426605578, 22587.289236613666],
#   [1674426902934, 22559.671553486667],
#   [1674427262232, 22578.8660258258],
#  [1674477000000, 22887.26, 22948.27, 22841.13, 22948.27],
#  [1674478800000, 22902.74, 22912.88, 22876.38, 22905.64],
#  [1674480600000, 22945.22, 22945.22, 22904.51, 22904.51],
#  [1674482400000, 22886.41, 22886.41, 22744.15, 22819.03],
#  [1674484200000, 22841.6, 22841.6, 22761.11, 22811.14],
#  [1674486000000, 22875.8, 22948.57, 22794.4, 22948.57],
#  [1674487800000, 22882.03, 22882.03, 22716.39, 22735.59],
#  [1674489600000, 22845.96, 22896.2, 22824.42, 22896.2],
#  [1674491400000, 22881.59, 22912.23, 22881.59, 22901.16],
#  [1674493200000, 22884.53, 22891.49, 22863.34, 22891.49],
#  [1674495000000, 22916.13, 22926.48, 22896.88, 22926.48],
#  [1674496800000, 22921.41, 22970.85, 22878.38, 22970.85],
#  [1674498600000, 22967.02, 23165.31, 22967.02, 23165.31],
#  [1674500400000, 23126.86, 23148.7, 23098.42, 23098.42],
#  [1674502200000, 23066.96, 23066.96, 22849.33, 22870.65],
#  [1674504000000, 22818.99, 22869.14, 22725.85, 22725.85],
#  [1674505800000, 22804.53, 22882.01, 22785.45, 22882.01],
#  [1674507600000, 22843.87, 22879.18, 22828.53, 22877.78],
#  [1674509400000, 23014.03, 23015.2, 22988.37, 22991.41]]

# %% [markdown]
# ### Commentary

# %% [markdown]
# - CoinGecko provides quasi-real-time data which is updated online; the concrete way the resampling for prices works is unclear, however, we know that `volume` the cumulative. The delay between data updates is still to be determined.
# - It is possible to get many kinds of historic data, but granularity becomes larger and larger the farther in the past the requested dates are. It is unclear whether this can be fixed by purchasing a Pro account, but the probability is low.
# - For further endpoints, there will be only 1 represented for each category. The structure is almost the same throughout:
#    - endpoints for quasi-real-time data by ID (see `get_price`)
#    - endpoints for historical data (see `get_coin_history_by_id`)
#    - endpoints for lists of IDs (see `get_exchanges_list`)
#    - The data that can be received are prices, market charts and various metadata on coins and exchanges.
# - The user may consult the extensive documentation by both CoinGecko and the `pycoingecko` library.

# %% [markdown]
# ## /contract

# %%
# Get market chart for 1 day, ETH/USD, based on contract address.
contract_address = "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
days = 1
market_chart = cg.get_coin_market_chart_from_contract_address_by_id(
    eth_id, "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984", usd_id, days
)
print(market_chart.keys())
print(market_chart["prices"][:2])
print(market_chart["market_caps"][:2])
print(market_chart["total_volumes"][:2])
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])
# [[1674423954942, 6.809933040833817], [1674424245505, 6.796241921005203]]
# [[1674423954942, 5134612704.130799], [1674424245505, 5122866589.759095]]
# [[1674423954942, 203085908.85524994], [1674424245505, 202867061.41181672]]

# %% [markdown]
# ## /asset_platforms

# %%
# Get list of supported Blockchain networks.
cg.get_asset_platforms()[:3]
# Out:
# [{'id': 'factom', 'chain_identifier': None, 'name': 'Factom', 'shortname': ''},
#  {'id': 'openledger',
#   'chain_identifier': None,
#   'name': 'OpenLedger',
#   'shortname': ''},
#  {'id': 'cosmos', 'chain_identifier': None, 'name': 'Cosmos', 'shortname': ''}]

# %% [markdown]
# ## /categories

# %%
# Get all supported categories of coins with market information.
cg.get_coins_categories()[:2]
# Out:
# [{'id': 'ethereum-ecosystem',
#   'name': 'Ethereum Ecosystem',
#   'market_cap': 490393335425.34863,
#   'market_cap_change_24h': 1.3600921704795426,
#   'content': '',
#   'top_3_coins': ['https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880',
#    'https://assets.coingecko.com/coins/images/325/small/Tether.png?1668148663',
#    'https://assets.coingecko.com/coins/images/6319/small/USD_Coin_icon.png?1547042389'],
#   'volume_24h': 84073098468.61961,
#   'updated_at': '2023-01-23T21:35:24.076Z'},
#  {'id': 'smart-contract-platform',
#   'name': 'Smart Contract Platform',
#   'market_cap': 316833891342.97406,
#   'market_cap_change_24h': 1.5461981662179465,
#   'content': 'Smart contract platforms are usually blockchains that host smart contracts or decentralized applications. Users can interact with different smart contracts on these platforms to perform various actions such as lending and borrowing funds, staking their assets or minting NFTs.\r\n\r\nSmart contracts are programs that are stored on the blockchain and are automatically executed when certain conditions are met. To interact with these smart contracts, transaction fees may need to be paid and the amount and asset required will vary based on the platform’s architecture. Usually, the smart contract platform’s native token is used to pay for transaction fees. Some popular examples of smart contract platforms include Ethereum, Solana and Polygon.',
#   'top_3_coins': ['https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880',
#    'https://assets.coingecko.com/coins/images/825/small/bnb-icon2_2x.png?1644979850',
#    'https://assets.coingecko.com/coins/images/975/small/cardano.png?1547034860'],
#   'volume_24h': 15442547023.457233,
#   'updated_at': '2023-01-23T21:35:14.490Z'}]

# %% [markdown]
# ## /exchanges

# %%
# Get 100 tickers from Binance exchange.
#  Note: does not work due to 414 error below, looks like a failure of the python lib.
#  This holds for all endpoints in `exchanges` category.
kwargs = {"coin_ids": f"{bitcoin_id},{eth_id}", "page": 1}
cg.get_exchanges_tickers_by_id(binance_id, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In [20], line 5
#       1 # Get 100 tickers from Binance exchange.
#       2 #  Note: does not work due to 414 error below, looks like a failure of the python lib.
#       3 #  This holds for all endpoints in `exchanges` category.
#       4 kwargs={"coin_ids": f"{bitcoin_id},{eth_id}", "page": 1}
# ----> 5 cg.get_exchanges_tickers_by_id(binance_id, **kwargs)
#
# File /venv/lib/python3.8/site-packages/pycoingecko/utils.py:12, in func_args_preprocessing.<locals>.input_args(*args, **kwargs)
#       9 # check in *args for lists and booleans
#      10 args = [arg_preprocessing(v) for v in args]
# ---> 12 return func(*args, **kwargs)
#
# File /venv/lib/python3.8/site-packages/pycoingecko/api.py:307, in CoinGeckoAPI.get_exchanges_tickers_by_id(self, id, **kwargs)
#     304 api_url = '{0}exchanges/{1}/tickers'.format(self.api_base_url, id)
#     305 api_url = self.__api_url_params(api_url, kwargs)
# --> 307 return self.__request(api_url)
#
# File /venv/lib/python3.8/site-packages/pycoingecko/api.py:34, in CoinGeckoAPI.__request(self, url)
#      31     raise
#      33 try:
# ---> 34     response.raise_for_status()
#      35     content = json.loads(response.content.decode('utf-8'))
#      36     return content
#
# File /venv/lib/python3.8/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 414 Client Error: Request-URI Too Large for url: https://api.coingecko.com/api/v3/exchanges/%7B'name':%20'Binance',%20'year_established':%202017,%20'country':%20'Cayman%20Islands',%20'description':%20'',%20'url':%20'https://www.binance.com/',%20'image':%20'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',%20'facebook_url':%20'https://www.facebook.com/binanceexchange',%20'reddit_url':%20'https://www.reddit.com/r/binance/',%20'telegram_url':%20'',%20'slack_url':%20'',%20'other_url_1':%20'https://medium.com/binanceexchange',%20'other_url_2':%20'https://steemit.com/@binanceexchange',%20'twitter_handle':%20'binance',%20'has_trading_incentive':%20False,%20'centralized':%20True,%20'public_notice':%20'',%20'alert_notice':%20'',%20'trust_score':%209,%20'trust_score_rank':%2010,%20'trade_volume_24h_btc':%20885139.140261976,%20'trade_volume_24h_btc_normalized':%20407371.48853423126,%20'tickers':%20%5B%7B'base':%20'BUSD',%20'target':%20'USDT',%20'market':%20%7B'name':%20'Binance',%20'identifier':%20'binance',%20'has_trading_incentive':%20False%7D,%20'last':%200.9998,%20'volume':%20890045365.9754951,%20'converted_last':%20%7B'btc':%204.352e-05,%20'eth':%200.00061209,%20'usd':%201.001%7D,%20'converted_volume':%20%7B'btc':%2038732,%20'eth':%20544790,%20'usd':%20890527365%7D,%20'trust_score':%20'green',%20'bid_ask_spread_percentage':%200.010001,%20'timestamp':%20'2023-01-23T21:35:55+00:00',%20'last_traded_at':%20'2023-01-23T21:35:55+00:00',%20'last_fetch_at':%20'2023-01-23T21:35:55+00:00',%20'is_anomaly':%20False,%20'is_stale':%20False,%20'trade_url':%20'https://www.binance.com/en/trade/BUSD_USDT?ref=37754157',%20'token_info_url':%20None,%20'coin_id':%20'binance-usd',%20'target_coin_id':%20'tether'%7D,%20%7B'base':%20'BTC',%20'target':%20'USDT',%20'market':%20%7B'name':%20'Binance',%20'identifier':%20'binance',%20'has_trading_incentive':%20False%7D,%20'last':%2022987.35,%20'volume':%20297903.40566024056,%20'converted_last':%20%7B'btc':%201.000545,%20'eth':%2014.073866,%20'usd':%2022986%7D,%20'converted_volume':%20%7B'btc':%20298066,%20'eth':%204192653,%20'usd':%206847596246%7D,%20'trust_score':%20'green',%20'bid_ask_spread_percentage':%200.014178,%20'timestamp':%20'2023-01-23T21:34:44+00:00',%20'last_traded_at':%20'2023-01-23T21:34:44+00:00',%20'last_fetch_at':%20'2023-01-23T21:34:44+00:00',%20'is_anomaly':%20False,%20'is_stale':%20False,%20'trade_url':%20'https://www.binance.com/en/trade/BTC_USDT?ref=37754157',%20'token_info_url':%20None,%20'coin_id':%20'bitcoin',%20'target_coin_id':%20'tether'%7D,%20%7B'base':%20'BTC',%20'target':%20'BUSD',%20'market':%20%7B'name':%20'Binance',%20'identifier':%20'binance',%20'has_trading_incentive':%20False%7D,%20'last':%2022989.6,%20'volume':%20180474.6870857792,%20'converted_last':%20%7B'btc':%201.000445,%20'eth':%2014.067987,%20'usd':%2023002%7D,%20'converted_volume':%20%7B'btc':%20180555,%20'eth':%202538916,%20'usd':%204151335732%7D,%20'trust_score':%20'green',%20'bid_ask_spread_percentage':%200.016047,%20'timestamp':%20'2023-01-23T21:30:39+00:00',%20'last_traded_at':%20'2023-01-23T21:30:39+00:00',%20'last_fetch_at':%20'2023-01-23T21:30:39+00:00',%20'is_anomaly':%20False,%20'is_stale':%20False,%20'trade_url':%20'https://www.binance.com/en/trade/BTC_BUSD?ref=37754157',%20'token_info_url':%20None,%20'coin_id':%20'bitcoin',%20'target_coin_id':%20'binance-usd'%7D,%20%7B'base':%20'ETH',%20'target':%20'BUSD',%20'market':%20%7B'name':%20'Binance',%20'identifier':%20'binance',%20'has_trading_incentive':%20False%7D,%20'last':%201632.99,%20'volume':%20314582.3181335489,%20'converted_last':%20%7B'btc':%200.07103168,%20'eth':%200.9988286,%20'usd':%201633.17%7D,%20'converted_volume':%20%7B'btc':%2022345,%20'eth':%20314214,%20'usd':%20513765421%7D,%20'trust_score':%20'green',%20'bid_ask_spread_percentage':%200.010612,%20'timestamp':%20'2023-01-23T21:30:43+00:00',%20'last_traded_at':%20'2023-01-23T21:30:43+00:00',%20'last_fetch_at':%20'2023-01-23T21:30:43+00:00',%20'is_anomaly':% ...

# %%
# Trying access via `requests`.
endpoint_url = "http://api.coingecko.com/api/v3/exchanges/binance/tickers/"
response = requests.get(endpoint_url)
data = response.json()
print(data.keys())
data["tickers"][:3]
# Out:
# dict_keys(['name', 'tickers'])
# [{'base': 'BUSD',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 0.9998,
#   'volume': 890045365.9754951,
#   'converted_last': {'btc': 4.352e-05, 'eth': 0.00061209, 'usd': 1.001},
#   'converted_volume': {'btc': 38732, 'eth': 544790, 'usd': 890527365},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.010001,
#   'timestamp': '2023-01-23T21:35:55+00:00',
#   'last_traded_at': '2023-01-23T21:35:55+00:00',
#   'last_fetch_at': '2023-01-23T21:35:55+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BUSD_USDT?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'binance-usd',
#   'target_coin_id': 'tether'},
#  {'base': 'BTC',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 22987.35,
#   'volume': 297903.40566024056,
#   'converted_last': {'btc': 1.000545, 'eth': 14.073866, 'usd': 22986},
#   'converted_volume': {'btc': 298066, 'eth': 4192653, 'usd': 6847596246},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.014178,
#   'timestamp': '2023-01-23T21:34:44+00:00',
#   'last_traded_at': '2023-01-23T21:34:44+00:00',
#   'last_fetch_at': '2023-01-23T21:34:44+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BTC_USDT?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'bitcoin',
#   'target_coin_id': 'tether'},
#  {'base': 'BTC',
#   'target': 'BUSD',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 22989.6,
#   'volume': 180474.6870857792,
#   'converted_last': {'btc': 1.000445, 'eth': 14.067987, 'usd': 23002},
#   'converted_volume': {'btc': 180555, 'eth': 2538916, 'usd': 4151335732},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.016047,
#   'timestamp': '2023-01-23T21:30:39+00:00',
#   'last_traded_at': '2023-01-23T21:30:39+00:00',
#   'last_fetch_at': '2023-01-23T21:30:39+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BTC_BUSD?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'bitcoin',
#   'target_coin_id': 'binance-usd'}]

# %% [markdown]
# ## /indexes

# %%
# Get a list of indexes.
cg.get_indexes()[10:15]
# Out:
# [{'name': 'BingX (Futures) LINA',
#   'id': 'LINA',
#   'market': 'BingX (Futures)',
#   'last': 0.007182,
#   'is_multi_asset_composite': False},
#  {'name': 'BingX (Futures) CEL',
#   'id': 'CEL',
#   'market': 'BingX (Futures)',
#   'last': 0.97023,
#   'is_multi_asset_composite': False},
#  {'name': 'Uniswap Index',
#   'id': 'UNISWAP',
#   'market': 'FTX (Derivatives)',
#   'last': 11475.6335355322,
#   'is_multi_asset_composite': True},
#  {'name': 'Bonfida Token',
#   'id': 'FIDA',
#   'market': 'FTX (Derivatives)',
#   'last': 0.21041141889,
#   'is_multi_asset_composite': None},
#  {'name': 'Holo',
#   'id': 'HOT',
#   'market': 'FTX (Derivatives)',
#   'last': 0.0014578270524,
#   'is_multi_asset_composite': False}]

# %%
# Also returns a `414` error.
# cg.get_indexes_by_market_id_and_index_id(binance_id, "ADA")

# %%
# Get price info on MOB index for FTX Derivatives.
endpoint_url = "http://api.coingecko.com/api/v3/indexes/ftx/MOB/"
response = requests.get(endpoint_url)
print(response)
data = response.json()
data
# Out:
# <Response [200]>
# {'name': 'MobileCoin',
#  'market': 'FTX (Derivatives)',
#  'last': 0.559925,
#  'is_multi_asset_composite': False}

# %% [markdown]
# ## /derivatives

# %%
# Get a list of derivatives with price and other data.
cg.get_derivatives()[:3]
# Out:
# [{'market': 'Deepcoin (Derivatives)',
#   'symbol': 'ETHUSDT',
#   'index_id': 'ETH',
#   'price': '1635.01',
#   'price_percentage_change_24h': 0.5922806499079564,
#   'contract_type': 'perpetual',
#   'index': 1633.4333,
#   'basis': -0.025504177250053554,
#   'spread': 0.01,
#   'funding_rate': -0.009552,
#   'open_interest': 5059197345.77,
#   'volume_24h': 3348964023.9240947,
#   'last_traded_at': 1674510413,
#   'expired_at': None},
#  {'market': 'BingX (Futures)',
#   'symbol': 'BTC-USDT',
#   'index_id': 'BTC',
#   'price': '23011.36',
#   'price_percentage_change_24h': 2.0616497636537137,
#   'contract_type': 'perpetual',
#   'index': 22996.6,
#   'basis': 0.006958034355294629,
#   'spread': 0.01,
#   'funding_rate': 0.0101,
#   'open_interest': 3488279342.63,
#   'volume_24h': 11252874579.41714,
#   'last_traded_at': 1674510411,
#   'expired_at': None},
#  {'market': 'Bitget Futures',
#   'symbol': 'BTCUSDT_UMCBL',
#   'index_id': 'BTC',
#   'price': '22992.69',
#   'price_percentage_change_24h': 1.9165927240461402,
#   'contract_type': 'perpetual',
#   'index': 22975.042448,
#   'basis': 0.013244158105519764,
#   'spread': 0.01,
#   'funding_rate': 0.0091,
#   'open_interest': 2955667290.17,
#   'volume_24h': 4748341795.600462,
#   'last_traded_at': 1674510583,
#   'expired_at': None}]

# %%
kwargs = {"include_tickers": "all"}

derivatives = cg.get_derivatives_exchanges_by_id("bitmex", **kwargs)
print(derivatives.keys())
derivatives["tickers"][:3]
# Out:
# dict_keys(['name', 'open_interest_btc', 'trade_volume_24h_btc', 'number_of_perpetual_pairs', 'number_of_futures_pairs', 'image', 'year_established', 'country', 'description', 'url', 'tickers'])
# [{'symbol': 'ADAUSD',
#   'base': 'ADA',
#   'target': 'USD',
#   'trade_url': 'https://www.bitmex.com/app/trade/ADAUSD',
#   'contract_type': 'perpetual',
#   'last': 0.376,
#   'h24_percentage_change': 0.186,
#   'index': 0.3758,
#   'index_basis_percentage': -0.106,
#   'bid_ask_spread': 0.000797660196756094,
#   'funding_rate': 0.01,
#   'open_interest_usd': 0.0,
#   'h24_volume': 7986241.7715940615,
#   'converted_volume': {'btc': '130.6533942661970361716420274451216982919253280368023',
#    'eth': '1837.64972904531392885814609651046056835568424545300500856831313468',
#    'usd': '3004424.15447368593630000000000000023667220584295564391686073512548'},
#   'converted_last': {'btc': '0.0000163598095328033743771905845119882602',
#    'eth': '0.00023010194051244172193549463211146725549859362509032',
#    'usd': '0.37620000000000000000000000000000002963499135284952'},
#   'last_traded': 1674510452,
#   'expired_at': None},
#  {'symbol': 'ADAUSDT',
#   'base': 'ADA',
#   'target': 'USDT',
#   'trade_url': 'https://www.bitmex.com/app/trade/ADAUSDT',
#   'contract_type': 'perpetual',
#   'last': 0.375,
#   'h24_percentage_change': 0.133,
#   'index': 0.3757,
#   'index_basis_percentage': 0.16,
#   'bid_ask_spread': 0.00239361702127663,
#   'funding_rate': 0.01,
#   'open_interest_usd': 0.0,
#   'h24_volume': 86740.0,
#   'converted_volume': {'btc': '1.41598730596973678426893066616',
#    'eth': '19.915967003852341125881289846128728869625056',
#    'usd': '32561.162979171545908250899224654155523600416'},
#   'converted_last': {'btc': '0.000016324502028703444596137084',
#    'eth': '0.0002296053378355123486958875933378917324144',
#    'usd': '0.3753880906060819219304922668279243200784'},
#   'last_traded': 1674508579,
#   'expired_at': None},
#  {'symbol': 'ADAH23',
#   'base': 'ADA',
#   'target': 'XBT',
#   'trade_url': 'https://www.bitmex.com/app/trade/ADAH23',
#   'contract_type': 'futures',
#   'last': 0.0,
#   'h24_percentage_change': 1.041,
#   'index': 1.635e-05,
#   'index_basis_percentage': -0.909,
#   'bid_ask_spread': 0.0108564535585043,
#   'funding_rate': 0.0,
#   'open_interest_usd': 82051228.58825433,
#   'h24_volume': 360.0,
#   'converted_volume': {'btc': '0.00594',
#    'eth': '0.083546542757927304',
#    'usd': '136.592543789663544'},
#   'converted_last': {'btc': '0.0000165',
#    'eth': '0.0002320737298831314',
#    'usd': '0.3794237327490654'},
#   'last_traded': 1674508580,
#   'expired_at': 1680264000}]

# %% [markdown]
# ## /trending

# %%
# Get 7 most searched coins in the last 24 hours.
cg.get_search_trending()
# Out:
# {'coins': [{'item': {'id': 'lossless',
#     'coin_id': 15917,
#     'name': 'Lossless',
#     'symbol': 'LSS',
#     'market_cap_rank': 780,
#     'thumb': 'https://assets.coingecko.com/coins/images/15917/thumb/Group_57.png?1623046307',
#     'small': 'https://assets.coingecko.com/coins/images/15917/small/Group_57.png?1623046307',
#     'large': 'https://assets.coingecko.com/coins/images/15917/large/Group_57.png?1623046307',
#     'slug': 'lossless',
#     'price_btc': 1.1775900663260454e-05,
#     'score': 0}},
#   {'item': {'id': 'ocean-protocol',
#     'coin_id': 3687,
#     'name': 'Ocean Protocol',
#     'symbol': 'OCEAN',
#     'market_cap_rank': 205,
#     'thumb': 'https://assets.coingecko.com/coins/images/3687/thumb/ocean-protocol-logo.jpg?1547038686',
#     'small': 'https://assets.coingecko.com/coins/images/3687/small/ocean-protocol-logo.jpg?1547038686',
#     'large': 'https://assets.coingecko.com/coins/images/3687/large/ocean-protocol-logo.jpg?1547038686',
#     'slug': 'ocean-protocol',
#     'price_btc': 1.544211230913067e-05,
#     'score': 1}},
#   {'item': {'id': 'optimism',
#     'coin_id': 25244,
#     'name': 'Optimism',
#     'symbol': 'OP',
#     'market_cap_rank': 91,
#     'thumb': 'https://assets.coingecko.com/coins/images/25244/thumb/Optimism.png?1660904599',
#     'small': 'https://assets.coingecko.com/coins/images/25244/small/Optimism.png?1660904599',
#     'large': 'https://assets.coingecko.com/coins/images/25244/large/Optimism.png?1660904599',
#     'slug': 'optimism',
#     'price_btc': 9.407525960659117e-05,
#     'score': 2}},
#   {'item': {'id': 'fetch-ai',
#     'coin_id': 5681,
#     'name': 'Fetch.ai',
#     'symbol': 'FET',
#     'market_cap_rank': 126,
#     'thumb': 'https://assets.coingecko.com/coins/images/5681/thumb/Fetch.jpg?1572098136',
#     'small': 'https://assets.coingecko.com/coins/images/5681/small/Fetch.jpg?1572098136',
#     'large': 'https://assets.coingecko.com/coins/images/5681/large/Fetch.jpg?1572098136',
#     'slug': 'fetch-ai',
#     'price_btc': 1.2518127584997474e-05,
#     'score': 3}},
#   {'item': {'id': 'aptos',
#     'coin_id': 26455,
#     'name': 'Aptos',
#     'symbol': 'APT',
#     'market_cap_rank': 31,
#     'thumb': 'https://assets.coingecko.com/coins/images/26455/thumb/aptos_round.png?1666839629',
#     'small': 'https://assets.coingecko.com/coins/images/26455/small/aptos_round.png?1666839629',
#     'large': 'https://assets.coingecko.com/coins/images/26455/large/aptos_round.png?1666839629',
#     'slug': 'aptos',
#     'price_btc': 0.0005704628148422064,
#     'score': 4}},
#   {'item': {'id': 'magic',
#     'coin_id': 18623,
#     'name': 'Magic',
#     'symbol': 'MAGIC',
#     'market_cap_rank': 143,
#     'thumb': 'https://assets.coingecko.com/coins/images/18623/thumb/magic.png?1656052146',
#     'small': 'https://assets.coingecko.com/coins/images/18623/small/magic.png?1656052146',
#     'large': 'https://assets.coingecko.com/coins/images/18623/large/magic.png?1656052146',
#     'slug': 'magic',
#     'price_btc': 5.395231192786994e-05,
#     'score': 5}},
#   {'item': {'id': 'fantom',
#     'coin_id': 4001,
#     'name': 'Fantom',
#     'symbol': 'FTM',
#     'market_cap_rank': 51,
#     'thumb': 'https://assets.coingecko.com/coins/images/4001/thumb/Fantom_round.png?1669652346',
#     'small': 'https://assets.coingecko.com/coins/images/4001/small/Fantom_round.png?1669652346',
#     'large': 'https://assets.coingecko.com/coins/images/4001/large/Fantom_round.png?1669652346',
#     'slug': 'fantom',
#     'price_btc': 1.7590267655281405e-05,
#     'score': 6}}],
#  'exchanges': []}

# %% [markdown]
# ## /global

# %%
# Get Top 100 Cryptocurrency Global Eecentralized Finance(defi) data.
cg.get_global_decentralized_finance_defi()
# Out:
# {'defi_market_cap': '44677119581.8998751442875403991',
#  'eth_market_cap': '197077803588.0777601942111525836',
#  'defi_to_eth_ratio': '22.6697876516229966709336424078805137557335802963645113216625871',
#  'trading_volume_24h': '3592523458.28162408759983099842',
#  'defi_dominance': '4.1071895718765593814164951148386813128937550521831944768134785',
#  'top_coin_name': 'Lido Staked Ether',
#  'top_coin_defi_dominance': 18.336509067812777}

# %% [markdown]
# ## /companies

# %%
# Get Bitcoin holdings by companies.
public_treasury = cg.get_companies_public_treasury_by_coin_id(bitcoin_id)
print(public_treasury.keys())
public_treasury["companies"][:3]
# Out:
# dict_keys(['total_holdings', 'total_value_usd', 'market_cap_dominance', 'companies'])
# [{'name': 'MicroStrategy Inc.',
#   'symbol': 'NASDAQ:MSTR',
#   'country': 'US',
#   'total_holdings': 129699,
#   'total_entry_value_usd': 3975000000,
#   'total_current_value_usd': 2983298308,
#   'percentage_of_total_supply': 0.618},
#  {'name': 'Marathon Digital Holdings',
#   'symbol': 'NASDAQ:MARA',
#   'country': 'US',
#   'total_holdings': 10054,
#   'total_entry_value_usd': 150000000,
#   'total_current_value_usd': 231277556,
#   'percentage_of_total_supply': 0.048},
#  {'name': 'Coinbase',
#   'symbol': 'NASDAQ: COIN',
#   'country': 'US',
#   'total_holdings': 9000,
#   'total_entry_value_usd': 173700000,
#   'total_current_value_usd': 207015356,
#   'percentage_of_total_supply': 0.043}]
