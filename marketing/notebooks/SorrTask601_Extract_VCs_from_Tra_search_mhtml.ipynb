# %%
import marketing.tra.extract_VCs_from_Tra_search_mhtml as mtevftsmh

# %% [markdown]
# # Workflow before using this library:
#
# 1. Go to a Tra VCs search result page
# 2. Use the browser's `Save As` button to download the webpage as a `Web page, single file`.
#     * Or use any other download method that can fulfill the requirement in step 3.
# 3. If you see the downloaded file format is `.mht` or `.mhtml`, you can process forward.
#     * Otherwise you won't be able to bypass the check layer from the website.
# 4. Call `get_VCs_from_mhtml` method with the `.mhtml` file path.
# 5. Save the returned dataframe to whatever format preferred.

# %% [markdown]
# # Sample usage of the function.

# %%
# Source data file path.
vc_mhtml_path = "../data/Investors _ VC _ Tra.mhtml"
# Destination result file path.
vc_csv_save_path = "../result_csv/Investors _ VC _ Tra.csv"
# Get Dataframe of VCs from HTML page.
vc_df = mtevftsmh.get_VCs_from_mhtml(vc_mhtml_path)
vc_df.to_csv(vc_csv_save_path, sep=",", index=False)
vc_df
# Out:
#                   Investor Name Score #Rounds  \
# 0               Sequoia Capital    15      81
# 1                  Y Combinator    13      70
# 2                         Accel    12      67
# 3   Lightspeed Venture Partners    12      60
# 4               Khosla Ventures    11      63
# 5     New Enterprise Associates    11      58
# 6                          DCVC    11      58
# 7              Insight Partners    10      53
# 8                          a16z     9      52
# 9                 Intel Capital     9      49
# 10          First Round Capital     9      48
# 11              Google Ventures     9      47
# 12             General Catalyst     8      43
# 13    Bessemer Venture Partners     7      40
# 14                          M12     7      40
# 15        Madrona Venture Group     7      38
# 16                Founders Fund     7      37
# 17                     SV Angel     6      35
# 18                    Greycroft     6      35
# 19             Felicis Ventures     6      35
# 20    Plug and Play Tech Center     6      34
# 21                  Lux Capital     6      32
# 22                  GGV Capital     6      32
# 23                True Ventures     6      31
# 24                          CRV     6      31
# 25             Battery Ventures     6      31
# 26                 Global Brain     6      31
# 27           AME Cloud Ventures     5      30
# 28     Norwest Venture Partners     5      30
# 29                   500 Global     5      30
# 30      Tiger Global Management     5      29
# 31                     Greylock     5      29
# 32            Horizons Ventures     5      29
# 33             Peak XV Partners     5      29
# 34            Chiratae Ventures     5      29
# 35             Octopus Ventures     5      29
# 36                  IDG Capital     5      27
# 37         Eight Roads Ventures     5      27
# 38              Sierra Ventures     5      27
# 39                          8VC     5      26
# 40        Bain Capital Ventures     5      26
# 41               Bloomberg Beta     5      26
# 42                     In-Q-Tel     5      26
# 43         Innovation Endeavors     5      25
# 44               Storm Ventures     5      25
# 45       Nexus Venture Partners     5      25
# 46             Blumberg Capital     5      25
# 47               Index Ventures     5      25
# 48              Kleiner Perkins     5      25
# 49           Foundation Capital     4      24
# 50         Wing Venture Capital     4      24
# 51            Redpoint Ventures     4      24
# 52            Gradient Ventures     4      24
# 53              Amadeus Capital     4      23
# 54               Yunqi Partners     4      23
# 55               Craft Ventures     4      22
# 56        Matrix Partners China     4      22
# 57            Qualcomm Ventures     4      22
# 58               Menlo Ventures     4      21
# 59              Sequoia Capital     4      21
#
#                       Portfolio Companies    Investor Location  \
# 0                  Stripe;Bitmain;PicsArt           Menlo Park
# 1                 Replit;Scale;Observe.AI        Mountain View
# 2                Notion;UiPath;Freshworks       Palo Alto [+3]
# 3       Rubrik;ThoughtSpot;Yellow Freight     Menlo Park [+13]
# 4                   Gitlab;Checkr;Upstart           Menlo Park
# 5           FiscalNote;Upstart;Mindtickle      Menlo Park [+3]
# 6                  Airtable;Checkr;Primer       Palo Alto [+1]
# 7            PicsArt;Shutterstock;Acronis        New York City
# 8               Samsara;GitHub;Databricks        New York City
# 9        Segway-Ninebot;Anyscale;MemVerge          Santa Clara
# 10                 Verkada;Planet;Upstart   San Francisco [+2]
# 11         Dialpad;Checkr;Recorded Future        Mountain View
# 12                 Grammarly;Drift;PathAI   San Francisco [+4]
# 13                  Perfios;K Health;Spot    Redwood City [+7]
# 14                Evisort;Zencity;Rescale   San Francisco [+4]
# 15      Highspot;Wonder Workshop;Amperity         Seattle [+1]
# 16                   Canva;Planet;Upstart        San Francisco
# 17             BetterUp;Checkr;HackerRank        San Francisco
# 18                Icertis;Craft;Botkeeper   New York City [+1]
# 19      Matterport;Canva;Pindrop Security      Menlo Park [+1]
# 20               CleverTap;LogiNext;Jerry      Sunnyvale [+41]
# 21         Matterport;Planet;Hugging Face      Menlo Park [+1]
# 22             Otter.ai;Xiaopeng;StarTree           Menlo Park
# 23            StockTwits;TripleLift;ICEYE       Palo Alto [+1]
# 24                 Airtable;Zendesk;Sense       Palo Alto [+1]
# 25                    Sprinklr;Pendo;CHEQ          Boston [+5]
# 26                Plum;Telexistence;CADDi              Shibuya
# 27      Zoom;FiscalNote;Rigetti Computing            Palo Alto
# 28                   Exabeam;Simpplr;Gong      Menlo Park [+3]
# 29               Shiprocket;Otter.ai;Plum  San Francisco [+18]
# 30              InVideo;GreyOrange;Osmind        New York City
# 31               Matterport;Workday;Figma      Menlo Park [+2]
# 32           Otter.ai;Brightseed;DeepMind            Hong Kong
# 33                Appier;CleverTap;GoKwik            Bengaluru
# 34               SquadStack;Blowhorn;Miko       Bengaluru [+2]
# 35      Streetbees;Sprout.ai;Conversocial          London [+1]
# 36  Bitmain;data.ai;Accutar Biotechnology       New York [+11]
# 37                Icertis;Securonix;Neo4j         London [+10]
# 38         Zimperium;Treasure Data;Dasera            San Mateo
# 39                  PathAI;Airbyte;BigHat               Austin
# 40                                                 Boston [+3]
# 41                                          San Francisco [+1]
# 42                                         Washington, DC [+4]
# 43                                                   Palo Alto
# 44                                                  Menlo Park
# 45                                             Menlo Park [+2]
# 46                                          San Francisco [+3]
# 47                                                 London [+4]
# 48                                                  Menlo Park
# 49                                                   Palo Alto
# 50                                                   Palo Alto
# 51                                               Woodside [+1]
# 52                                               Mountain View
# 53                                                 London [+5]
# 54                                                Beijing [+3]
# 55                                          San Francisco [+2]
# 56                                               Chaoyang [+1]
# 57                                              San Diego [+5]
# 58                                             Menlo Park [+1]
# 59                                                Beijing [+3]
#
#                        Stages of Entry  \
# 0       Series A (582);Seed (307)[+13]
# 1       Seed (4289);Series A (107)[+9]
# 2       Series A (373);Seed (300)[+11]
# 3       Series A (270);Seed (190)[+11]
# 4        Series A (242);Seed (161)[+6]
# 5   Series A (334);Series B (231)[+11]
# 6         Seed (109);Series A (98)[+4]
# 7   Series A (210);Series B (194)[+10]
# 8       Seed (336);Series A (311)[+11]
# 9    Series A (253);Series B (208)[+9]
# 10       Seed (233);Series A (164)[+6]
# 11       Series A (200);Seed (197)[+9]
# 12       Series A (219);Seed (199)[+8]
# 13   Series A (238);Series B (151)[+6]
# 14     Series A (50);Series B (40)[+5]
# 15        Series A (100);Seed (77)[+8]
# 16       Series A (189);Seed (171)[+8]
# 17       Seed (421);Series A (187)[+6]
# 18       Series A (197);Seed (136)[+5]
# 19       Seed (128);Series A (109)[+6]
# 20       Seed (590);Series A (110)[+8]
# 21         Series A (92);Seed (80)[+6]
# 22   Series A (130);Series B (98)[+10]
# 23       Seed (173);Series A (133)[+7]
# 24       Series A (137);Seed (104)[+9]
# 25   Series A (155);Series B (90)[+10]
# 26        Series A (105);Seed (80)[+3]
# 27         Series A (68);Seed (60)[+4]
# 28   Series A (154);Series B (112)[+8]
# 29      Seed (1402);Series A (192)[+7]
# 30  Series B (201);Series A (200)[+11]
# 31       Series A (157);Seed (141)[+8]
# 32         Series A (88);Seed (47)[+5]
# 33        Series A (111);Seed (72)[+8]
# 34         Seed (62);Series A (58)[+5]
# 35        Series A (117);Seed (74)[+6]
# 36       Series A (242);Seed (92)[+10]
# 37    Series A (134);Series B (99)[+8]
# 38         Series A (67);Seed (43)[+6]
# 39         Series A (92);Seed (80)[+5]
# 40    Series A (109);Series B (85)[+8]
# 41         Seed (80);Series A (42)[+3]
# 42     Series A (85);Series B (70)[+7]
# 43         Series A (53);Seed (51)[+4]
# 44         Series A (76);Seed (32)[+4]
# 45         Seed (78);Series A (69)[+3]
# 46         Seed (61);Series A (54)[+4]
# 47       Series A (222);Seed (178)[+9]
# 48   Series A (223);Series B (161)[+8]
# 49       Seed (118);Series A (101)[+7]
# 50         Series A (45);Seed (31)[+2]
# 51    Series A (151);Series B (97)[+9]
# 52         Seed (71);Series A (40)[+2]
# 53         Series A (44);Seed (38)[+5]
# 54         Series A (51);Seed (21)[+4]
# 55         Seed (67);Series A (62)[+4]
# 56    Series A (189);Series B (94)[+5]
# 57     Series A (82);Series B (80)[+7]
# 58   Series A (120);Series B (114)[+7]
# 59    Series A (102);Series B (75)[+8]
#
#                                 Sectors of Investment  \
# 0   Enterprise Applications (535);Consumer (363)[+39]
# 1   Enterprise Applications (2154);Consumer (918)[...
# 2   Enterprise Applications (485);Consumer (255)[+37]
# 3   Enterprise Applications (364);Consumer (190)[+37]
# 4   Enterprise Applications (206);High Tech (122)[...
# 5   Enterprise Applications (342);Life Sciences (2...
# 6   Enterprise Applications (179);Enterprise Infra...
# 7   Enterprise Applications (521);Enterprise Infra...
# 8   Enterprise Applications (373);High Tech (208)[...
# 9   Enterprise Applications (279);Enterprise Infra...
# 10  Enterprise Applications (234);Consumer (145)[+35]
# 11  Enterprise Applications (274);Consumer (149)[+34]
# 12  Enterprise Applications (290);Consumer (149)[+35]
# 13  Enterprise Applications (357);Enterprise Infra...
# 14  Enterprise Applications (115);Enterprise Infra...
# 15  Enterprise Applications (135);High Tech (43)[+34]
# 16  Enterprise Applications (188);Consumer (128)[+37]
# 17  Enterprise Applications (321);Consumer (220)[+32]
# 18  Enterprise Applications (193);Consumer (111)[+31]
# 19   Enterprise Applications (196);Consumer (74)[+33]
# 20  Enterprise Applications (665);High Tech (327)[...
# 21   Enterprise Applications (98);High Tech (86)[+31]
# 22  Enterprise Applications (162);Consumer (140)[+35]
# 23   Enterprise Applications (159);Consumer (90)[+31]
# 24  Enterprise Applications (173);Enterprise Infra...
# 25  Enterprise Applications (296);Enterprise Infra...
# 26   Enterprise Applications (117);Consumer (97)[+36]
# 27  Enterprise Applications (131);High Tech (70)[+30]
# 28  Enterprise Applications (224);Enterprise Infra...
# 29  Enterprise Applications (813);Consumer (812)[+37]
# 30  Enterprise Applications (407);Consumer (237)[+36]
# 31  Enterprise Applications (204);Consumer (100)[+32]
# 32   Enterprise Applications (70);High Tech (61)[+30]
# 33    Enterprise Applications (96);Consumer (82)[+35]
# 34    Enterprise Applications (68);Consumer (55)[+28]
# 35   Enterprise Applications (109);Consumer (49)[+33]
# 36  Consumer (156);Enterprise Applications (114)[+37]
# 37  Enterprise Applications (140);Life Sciences (9...
# 38  Enterprise Applications (119);Enterprise Infra...
# 39   Enterprise Applications (134);Consumer (55)[+31]
# 40  Enterprise Applications (220);Enterprise Infra...
# 41   Enterprise Applications (88);High Tech (35)[+21]
# 42  Enterprise Applications (190);High Tech (140)[...
# 43    Enterprise Applications (79);Consumer (33)[+33]
# 44  Enterprise Applications (92);Enterprise Infras...
# 45   Enterprise Applications (101);Consumer (56)[+31]
# 46  Enterprise Applications (103);Enterprise Infra...
# 47  Enterprise Applications (258);Consumer (172)[+33]
# 48  Enterprise Applications (253);Consumer (161)[+36]
# 49    Enterprise Applications (173);FinTech (72)[+33]
# 50  Enterprise Applications (115);Enterprise Infra...
# 51  Enterprise Applications (192);Enterprise Infra...
# 52    Enterprise Applications (101);FinTech (29)[+27]
# 53   Enterprise Applications (55);High Tech (39)[+30]
# 54      Enterprise Applications (36);Retail (22)[+33]
# 55   Enterprise Applications (129);Consumer (53)[+33]
# 56   Consumer (132);Enterprise Applications (91)[+38]
# 57  Enterprise Applications (148);High Tech (114)[...
# 58  Enterprise Applications (175);Enterprise Infra...
# 59   Enterprise Applications (102);Consumer (75)[+37]
#
#                           Locations of Investment  \
# 0            United States (630);China (421)[+44]
# 1           United States (3109);India (215)[+83]
# 2            United States (544);India (214)[+41]
# 3             United States (513);China (64)[+27]
# 4             United States (508);India (15)[+18]
# 5             United States (906);India (44)[+21]
# 6    United States (290);United Kingdom (14)[+18]
# 7            United States (467);Israel (56)[+32]
# 8            United States (761);Canada (17)[+30]
# 9             United States (467);China (83)[+38]
# 10           United States (454);Canada (13)[+13]
# 11   United States (601);United Kingdom (34)[+15]
# 12   United States (525);United Kingdom (26)[+26]
# 13            United States (514);India (61)[+24]
# 14           United States (101);Israel (17)[+13]
# 15            United States (215);Canada (5)[+10]
# 16   United States (427);United Kingdom (12)[+26]
# 17           United States (656);Canada (19)[+21]
# 18   United States (378);United Kingdom (13)[+22]
# 19           United States (324);Canada (10)[+16]
# 20   United States (636);United Kingdom (77)[+48]
# 21            United States (222);Canada (5)[+12]
# 22           United States (211);China (147)[+21]
# 23   United States (298);United Kingdom (11)[+20]
# 24           United States (305);Israel (10)[+13]
# 25           United States (396);Israel (42)[+18]
# 26            Japan (198);United States (68)[+21]
# 27     United States (213);United Kingdom (7)[+8]
# 28            United States (388);India (60)[+17]
# 29          United States (1095);Mexico (73)[+63]
# 30           United States (371);India (130)[+50]
# 31           United States (389);Israel (20)[+15]
# 32   United States (108);United Kingdom (22)[+16]
# 33                India (157);Singapore (38)[+14]
# 34             India (129);United States (27)[+7]
# 35   United Kingdom (193);United States (28)[+21]
# 36            China (417);United States (51)[+18]
# 37            United States (143);China (80)[+17]
# 38             United States (169);China (7)[+11]
# 39           United States (245);Colombia (5)[+9]
# 40            United States (330);Canada (6)[+10]
# 41             United States (126);Canada (4)[+3]
# 42   United States (299);United Kingdom (20)[+12]
# 43            United States (114);Israel (21)[+5]
# 44           United States (133);Germany (4)[+10]
# 45             India (99);United States (82)[+10]
# 46             United States (99);Israel (26)[+8]
# 47  United States (320);United Kingdom (111)[+31]
# 48            United States (563);China (48)[+26]
# 49    United States (309);United Kingdom (9)[+10]
# 50             United States (138);Israel (8)[+4]
# 51            United States (321);China (30)[+15]
# 52            United States (100);Canada (5)[+11]
# 53    United Kingdom (90);United States (20)[+19]
# 54              China (90);United States (10)[+4]
# 55             United States (189);Canada (6)[+7]
# 56             China (414);United States (22)[+6]
# 57            United States (168);China (55)[+17]
# 58            United States (348);Israel (6)[+11]
# 59            China (312);United States (42)[+16]
#
#                                           Company URL
# 0   https://tracxn.com/a/companies/PuyKDxi6s4MDikT...
# 1   https://tracxn.com/a/companies/srAiTt8Aevx0dkP...
# 2   https://tracxn.com/a/companies/asmY3flzarkQxfc...
# 3   https://tracxn.com/a/companies/aqLNsYlO_gpgAgY...
# 4   https://tracxn.com/a/companies/-24Z99iK6UymolR...
# 5   https://tracxn.com/a/companies/ybmB7Tn9E5oeNF4...
# 6   https://tracxn.com/a/companies/v-1lTmv5Tr4vlq9...
# 7   https://tracxn.com/a/companies/IKgQL2XMlT2uBV5...
# 8   https://tracxn.com/a/companies/UPS46sviVk047PS...
# 9   https://tracxn.com/a/companies/xUoGHuWmRTrEN2-...
# 10  https://tracxn.com/a/companies/OnYY4Ad4i6Oih7m...
# 11  https://tracxn.com/a/companies/YkGGYZyeNUNoCMR...
# 12  https://tracxn.com/a/companies/ou595fgJR47OKoZ...
# 13  https://tracxn.com/a/companies/OWFH2mkG8eq9fuj...
# 14  https://tracxn.com/a/companies/TK5rhhc4-01TrNz...
# 15  https://tracxn.com/a/companies/UtVrInDilPhNX-6...
# 16  https://tracxn.com/a/companies/Ga7paPCM_S0I6Tg...
# 17  https://tracxn.com/a/companies/OH8_R4Ci4pB1Rif...
# 18  https://tracxn.com/a/companies/WeOK38Yv11W9rTs...
# 19  https://tracxn.com/a/companies/nNjjoEDpblGOEyw...
# 20  https://tracxn.com/a/companies/FLn81cuWYMAwkC0...
# 21  https://tracxn.com/a/companies/QJ9g7fE7W3gwMFV...
# 22  https://tracxn.com/a/companies/Cl5bO096qZfk1lV...
# 23  https://tracxn.com/a/companies/x4taHfkBxkFGBsX...
# 24  https://tracxn.com/a/companies/SFCT5m6KawYu6AP...
# 25  https://tracxn.com/a/companies/B3ttdnsnUVhXHWl...
# 26  https://tracxn.com/a/companies/DoITDTCw4_J5y55...
# 27  https://tracxn.com/a/companies/TFmrD5a15FORjFz...
# 28  https://tracxn.com/a/companies/pZiMj24jixXoTuc...
# 29  https://tracxn.com/a/companies/runQgYmPnMdNqjV...
# 30  https://tracxn.com/a/companies/LfyJjSFXSdee9IX...
# 31  https://tracxn.com/a/companies/Zwz7kFLlhpRHgd8...
# 32  https://tracxn.com/a/companies/7FWKIhQvFdlbBOa...
# 33  https://tracxn.com/a/companies/cnPxEA6LjLH2Iat...
# 34  https://tracxn.com/a/companies/akyundxJ8XuMoPK...
# 35  https://tracxn.com/a/companies/BJFId88NdBIuSJV...
# 36  https://tracxn.com/a/companies/SBSyJ0zGR-xBWP8...
# 37  https://tracxn.com/a/companies/AnFuql2sxip4Lev...
# 38  https://tracxn.com/a/companies/fTb5hA0nEnNAGuu...
# 39  https://tracxn.com/a/companies/07cpe8LO2ctOg0S...
# 40  https://tracxn.com/a/companies/tK2yBRb2aOkPVLK...
# 41  https://tracxn.com/a/companies/GOnRObghwb9YtaS...
# 42  https://tracxn.com/a/companies/woZ8_Qe88LbiJ1O...
# 43  https://tracxn.com/a/companies/gf-xTkVuWVYmMub...
# 44  https://tracxn.com/a/companies/-RjzFJZG09Nim08...
# 45  https://tracxn.com/a/companies/iY0v_bLCrnh6fpr...
# 46  https://tracxn.com/a/companies/Q_rhhtWTcxyp0iZ...
# 47  https://tracxn.com/a/companies/ENnixzcSP2Nvl3-...
# 48  https://tracxn.com/a/companies/Uwyqb-9GM-knAxG...
# 49  https://tracxn.com/a/companies/hLXgIfbPeBh12zs...
# 50  https://tracxn.com/a/companies/4a3XCTol-Ke2FRD...
# 51  https://tracxn.com/a/companies/Rcp4SB-gkNLuo4k...
# 52  https://tracxn.com/a/companies/VrWcKUbFlZaFeig...
# 53  https://tracxn.com/a/companies/BJFId88NdBIuSJV...
# 54  https://tracxn.com/a/companies/4q5OvcOiY4re1u0...
# 55  https://tracxn.com/a/companies/fhvSW_iOI4z6KET...
# 56  https://tracxn.com/a/companies/W5x9gnCAiT9AkEk...
# 57  https://tracxn.com/a/companies/jN0ldVe3Yfs8WMr...
# 58  https://tracxn.com/a/companies/gf-xTkVuWVYmMub...
# 59  https://tracxn.com/a/companies/6KQKo4KwITC3b7e...
