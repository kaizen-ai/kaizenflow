# %% [markdown]
# # Imports

# %%
import logging

import pandas as pd

import helpers.hdatetime as hdateti
import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hpandas as hpandas
import helpers.hprint as hprint
import im_v2.ccxt.data.extract.extractor as imvcdexex
import im_v2.common.data.client.im_raw_data_client as imvcdcimrdc
import im_v2.common.data.qa.dataset_validator as imvcdqdava
import im_v2.common.data.qa.qa_check as imvcdqqach
import im_v2.common.universe as ivcu
import im_v2.common.universe.universe as imvcounun

# %load_ext autoreload
# %autoreload 2
# Out:
# /app/core/signal_processing/decorrelation.py:12: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
hdbg.init_logger(verbosity=logging.INFO)

_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])

hprint.config_notebook()
# Out:
# INFO: > cmd='/venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-d306cd35-d553-416d-bddc-8d41429fd05b.json'
# WARNING: Running in Jupyter
# -----------------------------------------------------------------------------
# This code is not in sync with the container:
# code_version='1.4.3' != container_version='1.4.0'
# -----------------------------------------------------------------------------
# You need to:
# - merge origin/master into your branch with `invoke git_merge_master`
# - pull the latest container with `invoke docker_pull`
# INFO  # Git
#   branch_name='CmTask4422_Onboard_CCXT_Kraken_periodic_daily_trades_futures'
#   hash='e432ad0ad'
#   # Last commits:
#     * e432ad0ad Sonya Nikiforova CmTask4380: Refactor ccxt methods (#4421)                         (69 minutes ago) Wed May 24 11:35:47 2023  (HEAD -> CmTask4422_Onboard_CCXT_Kraken_periodic_daily_trades_futures, origin/master, origin/HEAD, origin/CmTask4422_Onboard_CCXT_Kraken_periodic_daily_trades_futures, master)
#     * 44549d976 Daniil Tikhomirov Cm task4381 ccxt logs reader tests (#4418)                        (  16 hours ago) Tue May 23 20:31:22 2023
#     * f3efb7607 Daniil Tikhomirov Cm task4363 ccxt broker v2 followup (#4411)                       (    2 days ago) Mon May 22 18:00:59 2023
# # Machine info
#   system=Linux
#   node name=1baf285691d3
#   release=5.15.0-1033-aws
#   version=#37~20.04.1-Ubuntu SMP Fri Mar 17 11:39:30 UTC 2023
#   machine=x86_64
#   processor=x86_64
#   cpu count=8
#   cpu freq=scpufreq(current=2499.998, min=0.0, max=0.0)
#   memory=svmem(total=33292873728, available=29971427328, percent=10.0, used=2860511232, free=10681257984, active=10122436608, inactive=9108746240, buffers=2442313728, cached=17308790784, shared=2027520, slab=3130245120)
#   disk usage=sdiskusage(total=156052275200, used=45461995520, free=110573502464, percent=29.1)
# # Packages
#   python: 3.8.10
#   cvxopt: 1.3.0
#   cvxpy: 1.2.2
#   gluonnlp: ?
#   gluonts: 0.6.7
#   joblib: 1.2.0
#   mxnet: 1.9.1
#   numpy: 1.23.4
#   pandas: 1.5.1
#   pyarrow: 10.0.0
#   scipy: 1.9.3
#   seaborn: 0.12.1
#   sklearn: 1.1.3
#   statsmodels: 0.13.5

# %% [markdown]
# # Bare CCXT extractor test

# %%
since = None

# %%
import ccxt

extractor = ccxt.krakenfutures()

# %%
m = extractor.fetch_markets()

# %%
m_f = [s for s in m if s["info"]["type"] == "flexible_futures"]

# %%
s_f = [s["symbol"] for s in m_f]

# %%
s_f
# Out:
# ['BTC/USD:USD',
#  'ETH/USD:USD',
#  'ADA/USD:USD',
#  'XRP/USD:USD',
#  'SOL/USD:USD',
#  'UNI/USD:USD',
#  'ATOM/USD:USD',
#  'BCH/USD:USD',
#  'DOT/USD:USD',
#  'EOS/USD:USD',
#  'FIL/USD:USD',
#  'LINK/USD:USD',
#  'LTC/USD:USD',
#  'MATIC/USD:USD',
#  'DEFI/USD:USD',
#  'AVAX/USD:USD',
#  'XMR/USD:USD',
#  'GMT/USD:USD',
#  'LUNA2/USD:USD',
#  'OP/USD:USD',
#  'NEAR/USD:USD',
#  'APE/USD:USD',
#  'WAVES/USD:USD',
#  'DOGE/USD:USD',
#  'FTM/USD:USD',
#  'TRX/USD:USD',
#  'MANA/USD:USD',
#  'CRV/USD:USD',
#  'AAVE/USD:USD',
#  'SNX/USD:USD',
#  'XTZ/USD:USD',
#  'XLM/USD:USD',
#  'ALGO/USD:USD',
#  'SAND/USD:USD',
#  'OMG/USD:USD',
#  'ENJ/USD:USD',
#  'COMP/USD:USD',
#  'YFI/USD:USD',
#  'CHZ/USD:USD',
#  'LPT/USD:USD',
#  'BAT/USD:USD',
#  'MKR/USD:USD',
#  'AXS/USD:USD',
#  'GALA/USD:USD',
#  'ETC/USD:USD',
#  'KAVA/USD:USD',
#  'LRC/USD:USD',
#  'KSM/USD:USD',
#  'GRT/USD:USD',
#  'FLOW/USD:USD',
#  'ZEC/USD:USD',
#  'QTUM/USD:USD',
#  'DASH/USD:USD',
#  '1INCH/USD:USD',
#  'KNC/USD:USD',
#  'OGN/USD:USD',
#  'SUSHI/USD:USD',
#  'STORJ/USD:USD',
#  'RUNE/USD:USD',
#  'EGLD/USD:USD',
#  'DYDX/USD:USD',
#  'REN/USD:USD',
#  'ANKR/USD:USD',
#  'ICP/USD:USD',
#  'ETHW/USD:USD',
#  'OCEAN/USD:USD',
#  'BAND/USD:USD',
#  'BAL/USD:USD',
#  'ALICE/USD:USD',
#  'ICX/USD:USD',
#  'ENS/USD:USD',
#  'AUDIO/USD:USD',
#  'ANT/USD:USD',
#  'SC/USD:USD',
#  'MINA/USD:USD',
#  'GLMR/USD:USD',
#  'THETA/USD:USD',
#  'QNT/USD:USD',
#  'IMX/USD:USD',
#  'APT/USD:USD',
#  'FLR/USD:USD',
#  'BLUR/USD:USD',
#  'GMX/USD:USD',
#  'MASK/USD:USD',
#  'LDO/USD:USD',
#  'USDC/USD:USD',
#  'USDT/USD:USD',
#  'ARB/USD:USD',
#  'FET/USD:USD',
#  'STX/USD:USD',
#  'RNDR/USD:USD',
#  'CVX/USD:USD',
#  'WOO/USD:USD',
#  'JASMY/USD:USD',
#  'INJ/USD:USD',
#  'ZRX/USD:USD',
#  'RLC/USD:USD',
#  'GAL/USD:USD',
#  'SUI/USD:USD']

# %%
start_timestamp = pd.Timestamp("2023-05-01T00:00:00+00:00")
start_timestamp = hdateti.convert_timestamp_to_unix_epoch(start_timestamp)
end_timestamp = pd.Timestamp("2023-05-18T01:10:00+00:00")
end_timestamp = hdateti.convert_timestamp_to_unix_epoch(end_timestamp)
# currency_pair = "ETH/USDT"
currency_pair = "BTC/USD:USD"

# %%
end_timestamp
# Out:
# 1684372200000

# %%
data = extractor.fetch_trades(
    currency_pair,
#     since=start_timestamp,
    params={"until": end_timestamp}
)

# %%
data
# Out:
# [{'info': {'time': '2023-05-18T00:45:43.570Z',
#    'trade_id': '100',
#    'price': '27376',
#    'size': '0.0327',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'dc944b39-4d9b-4f6d-9e2e-4ad5904958ab'},
#   'id': 'dc944b39-4d9b-4f6d-9e2e-4ad5904958ab',
#   'timestamp': 1684370743570,
#   'datetime': '2023-05-18T00:45:43.570Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0327,
#   'cost': 895.1952,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:43.572Z',
#    'trade_id': '99',
#    'price': '27376',
#    'size': '0.0011',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'df5d1d57-5ca7-419f-a300-5c1b529f8fa7'},
#   'id': 'df5d1d57-5ca7-419f-a300-5c1b529f8fa7',
#   'timestamp': 1684370743572,
#   'datetime': '2023-05-18T00:45:43.572Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0011,
#   'cost': 30.1136,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:43.573Z',
#    'trade_id': '98',
#    'price': '27376',
#    'size': '0.0111',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'c2fb5a8c-fffb-48f7-8088-96394f932a02'},
#   'id': 'c2fb5a8c-fffb-48f7-8088-96394f932a02',
#   'timestamp': 1684370743573,
#   'datetime': '2023-05-18T00:45:43.573Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0111,
#   'cost': 303.8736,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:43.575Z',
#    'trade_id': '97',
#    'price': '27376',
#    'size': '0.0181',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '922e53db-3b23-4450-912f-5e23b8b85365'},
#   'id': '922e53db-3b23-4450-912f-5e23b8b85365',
#   'timestamp': 1684370743575,
#   'datetime': '2023-05-18T00:45:43.575Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0181,
#   'cost': 495.5056,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:43.576Z',
#    'trade_id': '96',
#    'price': '27376',
#    'size': '0.0035',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'e2595253-9c00-448c-b681-ec2454f1869c'},
#   'id': 'e2595253-9c00-448c-b681-ec2454f1869c',
#   'timestamp': 1684370743576,
#   'datetime': '2023-05-18T00:45:43.576Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0035,
#   'cost': 95.816,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:45.050Z',
#    'trade_id': '95',
#    'price': '27371',
#    'size': '0.0003',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '14f0a8f5-d9b1-4039-ba7a-7af493d9f5e2'},
#   'id': '14f0a8f5-d9b1-4039-ba7a-7af493d9f5e2',
#   'timestamp': 1684370745050,
#   'datetime': '2023-05-18T00:45:45.050Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27371.0,
#   'amount': 0.0003,
#   'cost': 8.2113,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:45:48.055Z',
#    'trade_id': '94',
#    'price': '27371',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '77f1c4e6-d62d-4192-a846-8be3389238c4'},
#   'id': '77f1c4e6-d62d-4192-a846-8be3389238c4',
#   'timestamp': 1684370748055,
#   'datetime': '2023-05-18T00:45:48.055Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27371.0,
#   'amount': 0.0001,
#   'cost': 2.7371,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:00.547Z',
#    'trade_id': '93',
#    'price': '27368',
#    'size': '0.0245',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'ae43985b-fd8d-4b91-a2af-a002a5b3380d'},
#   'id': 'ae43985b-fd8d-4b91-a2af-a002a5b3380d',
#   'timestamp': 1684370760547,
#   'datetime': '2023-05-18T00:46:00.547Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0245,
#   'cost': 670.516,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:16.319Z',
#    'trade_id': '92',
#    'price': '27368',
#    'size': '0.0211',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '0cf87de5-72af-45a3-9a22-d9c9f91af00c'},
#   'id': '0cf87de5-72af-45a3-9a22-d9c9f91af00c',
#   'timestamp': 1684370776319,
#   'datetime': '2023-05-18T00:46:16.319Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0211,
#   'cost': 577.4648,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:16.319Z',
#    'trade_id': '91',
#    'price': '27368',
#    'size': '0.0547',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'f667c85f-b448-4fa3-b386-d56c9d53a19c'},
#   'id': 'f667c85f-b448-4fa3-b386-d56c9d53a19c',
#   'timestamp': 1684370776319,
#   'datetime': '2023-05-18T00:46:16.319Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0547,
#   'cost': 1497.0296,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:25.608Z',
#    'trade_id': '90',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'dfaa87ea-0868-4adb-8475-5dfa3179e02e'},
#   'id': 'dfaa87ea-0868-4adb-8475-5dfa3179e02e',
#   'timestamp': 1684370785608,
#   'datetime': '2023-05-18T00:46:25.608Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:27.169Z',
#    'trade_id': '89',
#    'price': '27367',
#    'size': '0.0002',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '4e6f9def-ebfa-4b96-a208-449f4c41be41'},
#   'id': '4e6f9def-ebfa-4b96-a208-449f4c41be41',
#   'timestamp': 1684370787169,
#   'datetime': '2023-05-18T00:46:27.169Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0002,
#   'cost': 5.4734,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:32.643Z',
#    'trade_id': '88',
#    'price': '27366',
#    'size': '0.0547',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '0853ea03-fcff-490d-a971-2cfaa839f6bc'},
#   'id': '0853ea03-fcff-490d-a971-2cfaa839f6bc',
#   'timestamp': 1684370792643,
#   'datetime': '2023-05-18T00:46:32.643Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27366.0,
#   'amount': 0.0547,
#   'cost': 1496.9202,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:32.727Z',
#    'trade_id': '87',
#    'price': '27365',
#    'size': '0.0089',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'af12ed0d-8708-4352-9ace-50fe3fd66481'},
#   'id': 'af12ed0d-8708-4352-9ace-50fe3fd66481',
#   'timestamp': 1684370792727,
#   'datetime': '2023-05-18T00:46:32.727Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27365.0,
#   'amount': 0.0089,
#   'cost': 243.5485,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:35.398Z',
#    'trade_id': '86',
#    'price': '27365',
#    'size': '0.1421',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '5f5a92dc-804a-4f95-9158-9761a045031f'},
#   'id': '5f5a92dc-804a-4f95-9158-9761a045031f',
#   'timestamp': 1684370795398,
#   'datetime': '2023-05-18T00:46:35.398Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27365.0,
#   'amount': 0.1421,
#   'cost': 3888.5665,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:46:50.896Z',
#    'trade_id': '85',
#    'price': '27366',
#    'size': '0.1423',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '93279424-b17e-4107-841d-fdb76e7460e3'},
#   'id': '93279424-b17e-4107-841d-fdb76e7460e3',
#   'timestamp': 1684370810896,
#   'datetime': '2023-05-18T00:46:50.896Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27366.0,
#   'amount': 0.1423,
#   'cost': 3894.1818,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.007Z',
#    'trade_id': '84',
#    'price': '27365',
#    'size': '0.0548',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '82bb2464-9047-49a2-be03-1884b02e8825'},
#   'id': '82bb2464-9047-49a2-be03-1884b02e8825',
#   'timestamp': 1684370827007,
#   'datetime': '2023-05-18T00:47:07.007Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27365.0,
#   'amount': 0.0548,
#   'cost': 1499.602,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.020Z',
#    'trade_id': '80',
#    'price': '27362',
#    'size': '0.1284',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '35dd35e8-6baf-4d68-baf8-93acd9b8ccd4'},
#   'id': '35dd35e8-6baf-4d68-baf8-93acd9b8ccd4',
#   'timestamp': 1684370827020,
#   'datetime': '2023-05-18T00:47:07.020Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.1284,
#   'cost': 3513.2808,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.020Z',
#    'trade_id': '82',
#    'price': '27364',
#    'size': '0.0133',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '5838c26a-5b3a-4fbb-a49f-a1e75984c557'},
#   'id': '5838c26a-5b3a-4fbb-a49f-a1e75984c557',
#   'timestamp': 1684370827020,
#   'datetime': '2023-05-18T00:47:07.020Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27364.0,
#   'amount': 0.0133,
#   'cost': 363.9412,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.020Z',
#    'trade_id': '81',
#    'price': '27362',
#    'size': '0.0213',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '6af7ac6a-f9de-4e48-9eac-7b0da2409862'},
#   'id': '6af7ac6a-f9de-4e48-9eac-7b0da2409862',
#   'timestamp': 1684370827020,
#   'datetime': '2023-05-18T00:47:07.020Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0213,
#   'cost': 582.8106,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.020Z',
#    'trade_id': '83',
#    'price': '27364',
#    'size': '0.015',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'a7cac048-80ba-465c-9ae7-3ba95fdd93a1'},
#   'id': 'a7cac048-80ba-465c-9ae7-3ba95fdd93a1',
#   'timestamp': 1684370827020,
#   'datetime': '2023-05-18T00:47:07.020Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27364.0,
#   'amount': 0.015,
#   'cost': 410.46,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.140Z',
#    'trade_id': '79',
#    'price': '27362',
#    'size': '0.0424',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '15d121e4-925b-4f05-b7e0-a9ac02c5adca'},
#   'id': '15d121e4-925b-4f05-b7e0-a9ac02c5adca',
#   'timestamp': 1684370827140,
#   'datetime': '2023-05-18T00:47:07.140Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0424,
#   'cost': 1160.1488,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.140Z',
#    'trade_id': '78',
#    'price': '27362',
#    'size': '0.01',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '90cd409f-2e67-4253-897c-405e3fbd4a17'},
#   'id': '90cd409f-2e67-4253-897c-405e3fbd4a17',
#   'timestamp': 1684370827140,
#   'datetime': '2023-05-18T00:47:07.140Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.01,
#   'cost': 273.62,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.209Z',
#    'trade_id': '76',
#    'price': '27362',
#    'size': '0.0547',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '345a42e1-6530-4cbe-8de6-176bd0c25636'},
#   'id': '345a42e1-6530-4cbe-8de6-176bd0c25636',
#   'timestamp': 1684370827209,
#   'datetime': '2023-05-18T00:47:07.209Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0547,
#   'cost': 1496.7014,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.209Z',
#    'trade_id': '77',
#    'price': '27362',
#    'size': '0.0109',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'e31c7107-d925-4c3d-9e7b-918726b30140'},
#   'id': 'e31c7107-d925-4c3d-9e7b-918726b30140',
#   'timestamp': 1684370827209,
#   'datetime': '2023-05-18T00:47:07.209Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0109,
#   'cost': 298.2458,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.226Z',
#    'trade_id': '75',
#    'price': '27362',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'eb674c69-9bb8-46fa-aa7a-a4868fe91b89'},
#   'id': 'eb674c69-9bb8-46fa-aa7a-a4868fe91b89',
#   'timestamp': 1684370827226,
#   'datetime': '2023-05-18T00:47:07.226Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0001,
#   'cost': 2.7362,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.252Z',
#    'trade_id': '74',
#    'price': '27361',
#    'size': '0.0009',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'f5aed65d-29ff-4c7c-ad9b-d9b2427abda4'},
#   'id': 'f5aed65d-29ff-4c7c-ad9b-d9b2427abda4',
#   'timestamp': 1684370827252,
#   'datetime': '2023-05-18T00:47:07.252Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27361.0,
#   'amount': 0.0009,
#   'cost': 24.6249,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:07.440Z',
#    'trade_id': '73',
#    'price': '27361',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '7812468d-8f79-42c9-a284-f51840b852c5'},
#   'id': '7812468d-8f79-42c9-a284-f51840b852c5',
#   'timestamp': 1684370827440,
#   'datetime': '2023-05-18T00:47:07.440Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27361.0,
#   'amount': 0.0001,
#   'cost': 2.7361,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:09.109Z',
#    'trade_id': '72',
#    'price': '27360',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '9e51982a-1161-4c1b-b2c8-bd4a92080f20'},
#   'id': '9e51982a-1161-4c1b-b2c8-bd4a92080f20',
#   'timestamp': 1684370829109,
#   'datetime': '2023-05-18T00:47:09.109Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27360.0,
#   'amount': 0.0001,
#   'cost': 2.736,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:09.167Z',
#    'trade_id': '71',
#    'price': '27360',
#    'size': '0.0003',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '46a59d1f-8a63-4204-bcce-96325e2b95f9'},
#   'id': '46a59d1f-8a63-4204-bcce-96325e2b95f9',
#   'timestamp': 1684370829167,
#   'datetime': '2023-05-18T00:47:09.167Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27360.0,
#   'amount': 0.0003,
#   'cost': 8.208,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:09.344Z',
#    'trade_id': '70',
#    'price': '27358',
#    'size': '0.0548',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '058b59a5-859f-4b65-bf2e-1ad3582946d6'},
#   'id': '058b59a5-859f-4b65-bf2e-1ad3582946d6',
#   'timestamp': 1684370829344,
#   'datetime': '2023-05-18T00:47:09.344Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27358.0,
#   'amount': 0.0548,
#   'cost': 1499.2184,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:09.376Z',
#    'trade_id': '69',
#    'price': '27357',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '3f4c3bf9-89bc-451a-8d40-6341bb628e9c'},
#   'id': '3f4c3bf9-89bc-451a-8d40-6341bb628e9c',
#   'timestamp': 1684370829376,
#   'datetime': '2023-05-18T00:47:09.376Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27357.0,
#   'amount': 0.0001,
#   'cost': 2.7357,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:09.376Z',
#    'trade_id': '68',
#    'price': '27357',
#    'size': '0.02',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '7dcb863a-e276-4f17-b4da-aa0eff3324d9'},
#   'id': '7dcb863a-e276-4f17-b4da-aa0eff3324d9',
#   'timestamp': 1684370829376,
#   'datetime': '2023-05-18T00:47:09.376Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27357.0,
#   'amount': 0.02,
#   'cost': 547.14,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:12.576Z',
#    'trade_id': '67',
#    'price': '27359',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'ce5be28f-d89f-4460-8c1d-8380ca2342c4'},
#   'id': 'ce5be28f-d89f-4460-8c1d-8380ca2342c4',
#   'timestamp': 1684370832576,
#   'datetime': '2023-05-18T00:47:12.576Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27359.0,
#   'amount': 0.0001,
#   'cost': 2.7359,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:43.813Z',
#    'trade_id': '66',
#    'price': '27356',
#    'size': '0.0205',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'eeaf705a-b384-4a60-b0c1-5cdfe62d481e'},
#   'id': 'eeaf705a-b384-4a60-b0c1-5cdfe62d481e',
#   'timestamp': 1684370863813,
#   'datetime': '2023-05-18T00:47:43.813Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27356.0,
#   'amount': 0.0205,
#   'cost': 560.798,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:59.768Z',
#    'trade_id': '64',
#    'price': '27355',
#    'size': '0.0256',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'a0a17e3e-4331-4fb6-8d57-60397a1caf5b'},
#   'id': 'a0a17e3e-4331-4fb6-8d57-60397a1caf5b',
#   'timestamp': 1684370879768,
#   'datetime': '2023-05-18T00:47:59.768Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.0256,
#   'cost': 700.288,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:59.768Z',
#    'trade_id': '65',
#    'price': '27355',
#    'size': '0.0009',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'c2efd9f1-2d05-4900-a8ed-2bf733777bca'},
#   'id': 'c2efd9f1-2d05-4900-a8ed-2bf733777bca',
#   'timestamp': 1684370879768,
#   'datetime': '2023-05-18T00:47:59.768Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.0009,
#   'cost': 24.6195,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:47:59.849Z',
#    'trade_id': '63',
#    'price': '27354',
#    'size': '0.01',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '6ca628c9-7a75-48bd-854a-d036d932f490'},
#   'id': '6ca628c9-7a75-48bd-854a-d036d932f490',
#   'timestamp': 1684370879849,
#   'datetime': '2023-05-18T00:47:59.849Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27354.0,
#   'amount': 0.01,
#   'cost': 273.54,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:02.464Z',
#    'trade_id': '62',
#    'price': '27355',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '657800e2-a32d-4e5c-b20d-34dbed074205'},
#   'id': '657800e2-a32d-4e5c-b20d-34dbed074205',
#   'timestamp': 1684370882464,
#   'datetime': '2023-05-18T00:48:02.464Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.0001,
#   'cost': 2.7355,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:03.994Z',
#    'trade_id': '61',
#    'price': '27355',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '41d9da02-9a14-4ae1-bb9e-99c5538a055b'},
#   'id': '41d9da02-9a14-4ae1-bb9e-99c5538a055b',
#   'timestamp': 1684370883994,
#   'datetime': '2023-05-18T00:48:03.994Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.0001,
#   'cost': 2.7355,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:04.167Z',
#    'trade_id': '60',
#    'price': '27355',
#    'size': '0.1415',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '44ffb76f-7626-4374-9a8f-ccf4da07410f'},
#   'id': '44ffb76f-7626-4374-9a8f-ccf4da07410f',
#   'timestamp': 1684370884167,
#   'datetime': '2023-05-18T00:48:04.167Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.1415,
#   'cost': 3870.7325,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:36.256Z',
#    'trade_id': '59',
#    'price': '27367',
#    'size': '0.1417',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '0e9bfd60-e262-469f-a4f8-ffa1ac9cff1c'},
#   'id': '0e9bfd60-e262-469f-a4f8-ffa1ac9cff1c',
#   'timestamp': 1684370916256,
#   'datetime': '2023-05-18T00:48:36.256Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.1417,
#   'cost': 3877.9039,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:44.392Z',
#    'trade_id': '58',
#    'price': '27369',
#    'size': '0.0003',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '8dbdfbba-137b-4da6-92b0-0b4c5fa25995'},
#   'id': '8dbdfbba-137b-4da6-92b0-0b4c5fa25995',
#   'timestamp': 1684370924392,
#   'datetime': '2023-05-18T00:48:44.392Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0003,
#   'cost': 8.2107,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:47.477Z',
#    'trade_id': '57',
#    'price': '27367',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '30af240c-908c-4a05-b07a-8d2c2abdff97'},
#   'id': '30af240c-908c-4a05-b07a-8d2c2abdff97',
#   'timestamp': 1684370927477,
#   'datetime': '2023-05-18T00:48:47.477Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0002,
#   'cost': 5.4734,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:48.037Z',
#    'trade_id': '56',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '4875b3d4-29df-42be-a8ff-d110ab12c56d'},
#   'id': '4875b3d4-29df-42be-a8ff-d110ab12c56d',
#   'timestamp': 1684370928037,
#   'datetime': '2023-05-18T00:48:48.037Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:48:55.075Z',
#    'trade_id': '55',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '2130638d-7309-46b7-bb59-5646feafc8d8'},
#   'id': '2130638d-7309-46b7-bb59-5646feafc8d8',
#   'timestamp': 1684370935075,
#   'datetime': '2023-05-18T00:48:55.075Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:49:20.960Z',
#    'trade_id': '54',
#    'price': '27373',
#    'size': '0.0222',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'ea3d023a-edf8-4e10-9f55-747afe9e88c7'},
#   'id': 'ea3d023a-edf8-4e10-9f55-747afe9e88c7',
#   'timestamp': 1684370960960,
#   'datetime': '2023-05-18T00:49:20.960Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27373.0,
#   'amount': 0.0222,
#   'cost': 607.6806,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:09.196Z',
#    'trade_id': '53',
#    'price': '27369',
#    'size': '0.0002',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '2a565c20-be16-4c60-91ca-98dc9ef1fd0f'},
#   'id': '2a565c20-be16-4c60-91ca-98dc9ef1fd0f',
#   'timestamp': 1684371009196,
#   'datetime': '2023-05-18T00:50:09.196Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0002,
#   'cost': 5.4738,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:12.530Z',
#    'trade_id': '52',
#    'price': '27369',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '12641ec4-f8c3-4a83-83ee-71a4b4ea0a9f'},
#   'id': '12641ec4-f8c3-4a83-83ee-71a4b4ea0a9f',
#   'timestamp': 1684371012530,
#   'datetime': '2023-05-18T00:50:12.530Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0001,
#   'cost': 2.7369,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:15.330Z',
#    'trade_id': '51',
#    'price': '27372',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '98871c4f-9ebc-4976-8917-7f03c5f7baff'},
#   'id': '98871c4f-9ebc-4976-8917-7f03c5f7baff',
#   'timestamp': 1684371015330,
#   'datetime': '2023-05-18T00:50:15.330Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27372.0,
#   'amount': 0.0001,
#   'cost': 2.7372,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:51.422Z',
#    'trade_id': '50',
#    'price': '27369',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'd2c97f62-a240-4e31-ade4-bc1256b2bd56'},
#   'id': 'd2c97f62-a240-4e31-ade4-bc1256b2bd56',
#   'timestamp': 1684371051422,
#   'datetime': '2023-05-18T00:50:51.422Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0002,
#   'cost': 5.4738,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:58.262Z',
#    'trade_id': '49',
#    'price': '27373',
#    'size': '0.2386',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'ae119b35-3aa7-4f35-aa6d-2c29db070cb3'},
#   'id': 'ae119b35-3aa7-4f35-aa6d-2c29db070cb3',
#   'timestamp': 1684371058262,
#   'datetime': '2023-05-18T00:50:58.262Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27373.0,
#   'amount': 0.2386,
#   'cost': 6531.1978,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:50:59.196Z',
#    'trade_id': '48',
#    'price': '27369',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'f364da1a-78ee-4d70-9699-f2a063967bf0'},
#   'id': 'f364da1a-78ee-4d70-9699-f2a063967bf0',
#   'timestamp': 1684371059196,
#   'datetime': '2023-05-18T00:50:59.196Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0001,
#   'cost': 2.7369,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:51:10.199Z',
#    'trade_id': '47',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'bef0c531-93cf-4233-9e04-203807d6d20f'},
#   'id': 'bef0c531-93cf-4233-9e04-203807d6d20f',
#   'timestamp': 1684371070199,
#   'datetime': '2023-05-18T00:51:10.199Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:51:12.691Z',
#    'trade_id': '46',
#    'price': '27370',
#    'size': '0.0003',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '2f639c55-78bf-412e-a78e-fe0a9520d68b'},
#   'id': '2f639c55-78bf-412e-a78e-fe0a9520d68b',
#   'timestamp': 1684371072691,
#   'datetime': '2023-05-18T00:51:12.691Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0003,
#   'cost': 8.211,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:51:32.217Z',
#    'trade_id': '45',
#    'price': '27368',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '605e3bd8-61ea-474a-82ea-72acc7f91533'},
#   'id': '605e3bd8-61ea-474a-82ea-72acc7f91533',
#   'timestamp': 1684371092217,
#   'datetime': '2023-05-18T00:51:32.217Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0001,
#   'cost': 2.7368,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:51:54.213Z',
#    'trade_id': '44',
#    'price': '27368',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'ffe83085-f3ec-4de1-86af-1f927868174d'},
#   'id': 'ffe83085-f3ec-4de1-86af-1f927868174d',
#   'timestamp': 1684371114213,
#   'datetime': '2023-05-18T00:51:54.213Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0001,
#   'cost': 2.7368,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:51:54.815Z',
#    'trade_id': '43',
#    'price': '27368',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '4187d93f-972a-4253-b90b-259c1f91380e'},
#   'id': '4187d93f-972a-4253-b90b-259c1f91380e',
#   'timestamp': 1684371114815,
#   'datetime': '2023-05-18T00:51:54.815Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0001,
#   'cost': 2.7368,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:52:26.601Z',
#    'trade_id': '42',
#    'price': '27372',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'b8600d7e-7741-4406-b05c-9b5c8cddadf7'},
#   'id': 'b8600d7e-7741-4406-b05c-9b5c8cddadf7',
#   'timestamp': 1684371146601,
#   'datetime': '2023-05-18T00:52:26.601Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27372.0,
#   'amount': 0.0002,
#   'cost': 5.4744,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:52:27.398Z',
#    'trade_id': '41',
#    'price': '27368',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'abbfa24b-5f33-41eb-9572-3abe2384bd77'},
#   'id': 'abbfa24b-5f33-41eb-9572-3abe2384bd77',
#   'timestamp': 1684371147398,
#   'datetime': '2023-05-18T00:52:27.398Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0001,
#   'cost': 2.7368,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:52:28.778Z',
#    'trade_id': '40',
#    'price': '27368',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '63175548-b913-487c-ab5b-8d8a80075e66'},
#   'id': '63175548-b913-487c-ab5b-8d8a80075e66',
#   'timestamp': 1684371148778,
#   'datetime': '2023-05-18T00:52:28.778Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27368.0,
#   'amount': 0.0001,
#   'cost': 2.7368,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:53:00.306Z',
#    'trade_id': '39',
#    'price': '27370',
#    'size': '0.0002',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '641ccfd0-f426-499b-8852-6b8a9226d640'},
#   'id': '641ccfd0-f426-499b-8852-6b8a9226d640',
#   'timestamp': 1684371180306,
#   'datetime': '2023-05-18T00:53:00.306Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0002,
#   'cost': 5.474,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:53:01.125Z',
#    'trade_id': '38',
#    'price': '27370',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'b3fdfde0-1fb9-459c-8aae-29f7fb3706fa'},
#   'id': 'b3fdfde0-1fb9-459c-8aae-29f7fb3706fa',
#   'timestamp': 1684371181125,
#   'datetime': '2023-05-18T00:53:01.125Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0001,
#   'cost': 2.737,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:53:01.280Z',
#    'trade_id': '37',
#    'price': '27370',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'd00f7ee4-1acb-4264-b098-27f331960566'},
#   'id': 'd00f7ee4-1acb-4264-b098-27f331960566',
#   'timestamp': 1684371181280,
#   'datetime': '2023-05-18T00:53:01.280Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0001,
#   'cost': 2.737,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:55:29.482Z',
#    'trade_id': '36',
#    'price': '27364',
#    'size': '0.0013',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '84a00fd3-6dbb-4fd1-ae1e-7af4402dfc61'},
#   'id': '84a00fd3-6dbb-4fd1-ae1e-7af4402dfc61',
#   'timestamp': 1684371329482,
#   'datetime': '2023-05-18T00:55:29.482Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27364.0,
#   'amount': 0.0013,
#   'cost': 35.5732,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:56:19.583Z',
#    'trade_id': '35',
#    'price': '27363',
#    'size': '0.02',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '112d0567-c75a-4f57-b7d3-856ca87812c2'},
#   'id': '112d0567-c75a-4f57-b7d3-856ca87812c2',
#   'timestamp': 1684371379583,
#   'datetime': '2023-05-18T00:56:19.583Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27363.0,
#   'amount': 0.02,
#   'cost': 547.26,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:56:19.733Z',
#    'trade_id': '34',
#    'price': '27361',
#    'size': '0.1095',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '9c74248c-5b1c-4019-93e5-8df63d60003d'},
#   'id': '9c74248c-5b1c-4019-93e5-8df63d60003d',
#   'timestamp': 1684371379733,
#   'datetime': '2023-05-18T00:56:19.733Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27361.0,
#   'amount': 0.1095,
#   'cost': 2996.0295,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:56:39.361Z',
#    'trade_id': '33',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '69e0b1fc-7502-432c-8acf-76333e551d8b'},
#   'id': '69e0b1fc-7502-432c-8acf-76333e551d8b',
#   'timestamp': 1684371399361,
#   'datetime': '2023-05-18T00:56:39.361Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:56:42.784Z',
#    'trade_id': '32',
#    'price': '27363',
#    'size': '0.0002',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'ffa1bfea-a2a2-4752-b268-d2fd8c948b92'},
#   'id': 'ffa1bfea-a2a2-4752-b268-d2fd8c948b92',
#   'timestamp': 1684371402784,
#   'datetime': '2023-05-18T00:56:42.784Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27363.0,
#   'amount': 0.0002,
#   'cost': 5.4726,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:58:37.968Z',
#    'trade_id': '31',
#    'price': '27356',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'c9c8142d-68b5-4d20-b731-65639984d0e3'},
#   'id': 'c9c8142d-68b5-4d20-b731-65639984d0e3',
#   'timestamp': 1684371517968,
#   'datetime': '2023-05-18T00:58:37.968Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27356.0,
#   'amount': 0.0001,
#   'cost': 2.7356,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:58:38.552Z',
#    'trade_id': '30',
#    'price': '27356',
#    'size': '0.0003',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '0e71b0d9-7a48-4a80-a399-3a6684824618'},
#   'id': '0e71b0d9-7a48-4a80-a399-3a6684824618',
#   'timestamp': 1684371518552,
#   'datetime': '2023-05-18T00:58:38.552Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27356.0,
#   'amount': 0.0003,
#   'cost': 8.2068,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:58:38.872Z',
#    'trade_id': '29',
#    'price': '27356',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '8da77c5f-feb9-4256-81eb-29f15b1ba94e'},
#   'id': '8da77c5f-feb9-4256-81eb-29f15b1ba94e',
#   'timestamp': 1684371518872,
#   'datetime': '2023-05-18T00:58:38.872Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27356.0,
#   'amount': 0.0001,
#   'cost': 2.7356,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:58:49.841Z',
#    'trade_id': '28',
#    'price': '27351',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'e0e239de-6775-4113-8939-0f2301ab22ef'},
#   'id': 'e0e239de-6775-4113-8939-0f2301ab22ef',
#   'timestamp': 1684371529841,
#   'datetime': '2023-05-18T00:58:49.841Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27351.0,
#   'amount': 0.0001,
#   'cost': 2.7351,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T00:59:11.107Z',
#    'trade_id': '27',
#    'price': '27353',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '00bae882-9787-4c46-857e-340ca78961ff'},
#   'id': '00bae882-9787-4c46-857e-340ca78961ff',
#   'timestamp': 1684371551107,
#   'datetime': '2023-05-18T00:59:11.107Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27353.0,
#   'amount': 0.0001,
#   'cost': 2.7353,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:14.399Z',
#    'trade_id': '26',
#    'price': '27362',
#    'size': '0.0003',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'e04d6380-d852-406e-a901-1a93a2663784'},
#   'id': 'e04d6380-d852-406e-a901-1a93a2663784',
#   'timestamp': 1684371614399,
#   'datetime': '2023-05-18T01:00:14.399Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0003,
#   'cost': 8.2086,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:18.844Z',
#    'trade_id': '25',
#    'price': '27362',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '5ff52b5e-4dd9-491d-a8bc-c60593409204'},
#   'id': '5ff52b5e-4dd9-491d-a8bc-c60593409204',
#   'timestamp': 1684371618844,
#   'datetime': '2023-05-18T01:00:18.844Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27362.0,
#   'amount': 0.0001,
#   'cost': 2.7362,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:24.748Z',
#    'trade_id': '24',
#    'price': '27367',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '6dc3dbb6-2a32-4ceb-ae1c-b5f22a75e96f'},
#   'id': '6dc3dbb6-2a32-4ceb-ae1c-b5f22a75e96f',
#   'timestamp': 1684371624748,
#   'datetime': '2023-05-18T01:00:24.748Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0001,
#   'cost': 2.7367,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:24.973Z',
#    'trade_id': '23',
#    'price': '27367',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '6141c486-1aa1-4e40-9b3b-689df9ec5d62'},
#   'id': '6141c486-1aa1-4e40-9b3b-689df9ec5d62',
#   'timestamp': 1684371624973,
#   'datetime': '2023-05-18T01:00:24.973Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27367.0,
#   'amount': 0.0002,
#   'cost': 5.4734,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:30.151Z',
#    'trade_id': '22',
#    'price': '27369',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '6e0689d2-1ddd-42d4-a2a8-c2610958a025'},
#   'id': '6e0689d2-1ddd-42d4-a2a8-c2610958a025',
#   'timestamp': 1684371630151,
#   'datetime': '2023-05-18T01:00:30.151Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27369.0,
#   'amount': 0.0001,
#   'cost': 2.7369,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:35.700Z',
#    'trade_id': '21',
#    'price': '27370',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '74a90a7a-51ae-4807-8139-2051cff6b3cf'},
#   'id': '74a90a7a-51ae-4807-8139-2051cff6b3cf',
#   'timestamp': 1684371635700,
#   'datetime': '2023-05-18T01:00:35.700Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0002,
#   'cost': 5.474,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:47.059Z',
#    'trade_id': '20',
#    'price': '27364',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '618a3120-685d-40e6-8c3a-46159766a626'},
#   'id': '618a3120-685d-40e6-8c3a-46159766a626',
#   'timestamp': 1684371647059,
#   'datetime': '2023-05-18T01:00:47.059Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27364.0,
#   'amount': 0.0001,
#   'cost': 2.7364,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:51.978Z',
#    'trade_id': '19',
#    'price': '27365',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'e637172d-9011-4941-b51a-95f16c8f08e9'},
#   'id': 'e637172d-9011-4941-b51a-95f16c8f08e9',
#   'timestamp': 1684371651978,
#   'datetime': '2023-05-18T01:00:51.978Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27365.0,
#   'amount': 0.0001,
#   'cost': 2.7365,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:00:56.738Z',
#    'trade_id': '18',
#    'price': '27370',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '3d18d3a1-24e2-4119-9bb6-9b309fa96d1d'},
#   'id': '3d18d3a1-24e2-4119-9bb6-9b309fa96d1d',
#   'timestamp': 1684371656738,
#   'datetime': '2023-05-18T01:00:56.738Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0001,
#   'cost': 2.737,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:01:03.009Z',
#    'trade_id': '17',
#    'price': '27370',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '8f730fa6-0a67-43e5-b29c-d009a693c97f'},
#   'id': '8f730fa6-0a67-43e5-b29c-d009a693c97f',
#   'timestamp': 1684371663009,
#   'datetime': '2023-05-18T01:01:03.009Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27370.0,
#   'amount': 0.0001,
#   'cost': 2.737,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:02:04.276Z',
#    'trade_id': '16',
#    'price': '27360',
#    'size': '0.1639',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'bfc85e2c-dca3-42c9-8cca-ed6b7fa3918a'},
#   'id': 'bfc85e2c-dca3-42c9-8cca-ed6b7fa3918a',
#   'timestamp': 1684371724276,
#   'datetime': '2023-05-18T01:02:04.276Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27360.0,
#   'amount': 0.1639,
#   'cost': 4484.304,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:02:04.371Z',
#    'trade_id': '15',
#    'price': '27359',
#    'size': '0.0023',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '8d40f968-9708-421d-899f-6b9d341afaaa'},
#   'id': '8d40f968-9708-421d-899f-6b9d341afaaa',
#   'timestamp': 1684371724371,
#   'datetime': '2023-05-18T01:02:04.371Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27359.0,
#   'amount': 0.0023,
#   'cost': 62.9257,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:02:08.657Z',
#    'trade_id': '14',
#    'price': '27358',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '96fdb6be-5626-4280-b256-8c58f0e898ae'},
#   'id': '96fdb6be-5626-4280-b256-8c58f0e898ae',
#   'timestamp': 1684371728657,
#   'datetime': '2023-05-18T01:02:08.657Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27358.0,
#   'amount': 0.0001,
#   'cost': 2.7358,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:02:10.934Z',
#    'trade_id': '13',
#    'price': '27358',
#    'size': '0.0005',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '90dfe87f-6c5f-4d47-9114-b3bf93dc5f85'},
#   'id': '90dfe87f-6c5f-4d47-9114-b3bf93dc5f85',
#   'timestamp': 1684371730934,
#   'datetime': '2023-05-18T01:02:10.934Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27358.0,
#   'amount': 0.0005,
#   'cost': 13.679,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:03:43.491Z',
#    'trade_id': '12',
#    'price': '27354',
#    'size': '0.1415',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'dca84cf4-c5ba-4314-9eaf-4638d9320dce'},
#   'id': 'dca84cf4-c5ba-4314-9eaf-4638d9320dce',
#   'timestamp': 1684371823491,
#   'datetime': '2023-05-18T01:03:43.491Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27354.0,
#   'amount': 0.1415,
#   'cost': 3870.591,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:04:34.624Z',
#    'trade_id': '11',
#    'price': '27355',
#    'size': '0.1341',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '9ffc7b59-ac44-4f03-a93c-9d1e1a00fb35'},
#   'id': '9ffc7b59-ac44-4f03-a93c-9d1e1a00fb35',
#   'timestamp': 1684371874624,
#   'datetime': '2023-05-18T01:04:34.624Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27355.0,
#   'amount': 0.1341,
#   'cost': 3668.3055,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:09.656Z',
#    'trade_id': '10',
#    'price': '27376',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'be4957ae-7364-4e40-b750-8ee006458975'},
#   'id': 'be4957ae-7364-4e40-b750-8ee006458975',
#   'timestamp': 1684371909656,
#   'datetime': '2023-05-18T01:05:09.656Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27376.0,
#   'amount': 0.0002,
#   'cost': 5.4752,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:13.211Z',
#    'trade_id': '9',
#    'price': '27377',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '3f9b6eac-a235-4124-b5e5-2bb9d29c13d1'},
#   'id': '3f9b6eac-a235-4124-b5e5-2bb9d29c13d1',
#   'timestamp': 1684371913211,
#   'datetime': '2023-05-18T01:05:13.211Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27377.0,
#   'amount': 0.0001,
#   'cost': 2.7377,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:13.580Z',
#    'trade_id': '8',
#    'price': '27380',
#    'size': '0.1708',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '71b0fcbc-a4d0-4653-8074-883873ac42f2'},
#   'id': '71b0fcbc-a4d0-4653-8074-883873ac42f2',
#   'timestamp': 1684371913580,
#   'datetime': '2023-05-18T01:05:13.580Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27380.0,
#   'amount': 0.1708,
#   'cost': 4676.504,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:20.374Z',
#    'trade_id': '7',
#    'price': '27378',
#    'size': '0.0003',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '193bfda2-ba7d-4762-a119-13bbf6ceee0e'},
#   'id': '193bfda2-ba7d-4762-a119-13bbf6ceee0e',
#   'timestamp': 1684371920374,
#   'datetime': '2023-05-18T01:05:20.374Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27378.0,
#   'amount': 0.0003,
#   'cost': 8.2134,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:41.204Z',
#    'trade_id': '6',
#    'price': '27378',
#    'size': '0.0001',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': 'c680cf53-07d6-4341-8b0f-7d9be70eea93'},
#   'id': 'c680cf53-07d6-4341-8b0f-7d9be70eea93',
#   'timestamp': 1684371941204,
#   'datetime': '2023-05-18T01:05:41.204Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27378.0,
#   'amount': 0.0001,
#   'cost': 2.7378,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:41.432Z',
#    'trade_id': '5',
#    'price': '27378',
#    'size': '0.0004',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '789f1d2a-0e7b-4651-893e-136435526f7d'},
#   'id': '789f1d2a-0e7b-4651-893e-136435526f7d',
#   'timestamp': 1684371941432,
#   'datetime': '2023-05-18T01:05:41.432Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27378.0,
#   'amount': 0.0004,
#   'cost': 10.9512,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:05:46.062Z',
#    'trade_id': '4',
#    'price': '27377',
#    'size': '0.0002',
#    'side': 'sell',
#    'type': 'fill',
#    'uid': '442e977c-2cbc-40c0-97e9-8d79e44168ac'},
#   'id': '442e977c-2cbc-40c0-97e9-8d79e44168ac',
#   'timestamp': 1684371946062,
#   'datetime': '2023-05-18T01:05:46.062Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 27377.0,
#   'amount': 0.0002,
#   'cost': 5.4754,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:07:06.010Z',
#    'trade_id': '3',
#    'price': '27383',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'da1477c2-3d24-41b1-9dda-5ee5d4fecf6e'},
#   'id': 'da1477c2-3d24-41b1-9dda-5ee5d4fecf6e',
#   'timestamp': 1684372026010,
#   'datetime': '2023-05-18T01:07:06.010Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27383.0,
#   'amount': 0.0001,
#   'cost': 2.7383,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:09:36.770Z',
#    'trade_id': '2',
#    'price': '27383',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': '0e6b3948-39bb-4a47-ae3d-e10dfe5942db'},
#   'id': '0e6b3948-39bb-4a47-ae3d-e10dfe5942db',
#   'timestamp': 1684372176770,
#   'datetime': '2023-05-18T01:09:36.770Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27383.0,
#   'amount': 0.0001,
#   'cost': 2.7383,
#   'fee': None,
#   'fees': []},
#  {'info': {'time': '2023-05-18T01:09:44.457Z',
#    'trade_id': '1',
#    'price': '27382',
#    'size': '0.0001',
#    'side': 'buy',
#    'type': 'fill',
#    'uid': 'aa773dac-e9e4-4092-bc16-801afa478610'},
#   'id': 'aa773dac-e9e4-4092-bc16-801afa478610',
#   'timestamp': 1684372184457,
#   'datetime': '2023-05-18T01:09:44.457Z',
#   'symbol': 'BTC/USD:USD',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 27382.0,
#   'amount': 0.0001,
#   'cost': 2.7382,
#   'fee': None,
#   'fees': []}]

# %%
since = data[-1]["timestamp"]

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#        id order                                               info      timestamp                  datetime    symbol    type side takerOrMaker   price    amount         cost   fee fees
# 0  306690  None  [743.14000, 2.80536389, 1609509956.2953913, b,...  1609509956295  2021-01-01T14:05:56.295Z  ETH/USDT  market  buy         None  743.14  2.805364  2084.778121  None   []
# 1  306691  None  [743.14000, 0.96000000, 1609509956.2967162, b,...  1609509956296  2021-01-01T14:05:56.296Z  ETH/USDT  market  buy         None  743.14  0.960000   713.414400  None   []
# 2  306692  None  [743.15000, 0.70000000, 1609509956.298092, b, ...  1609509956298  2021-01-01T14:05:56.298Z  ETH/USDT  market  buy         None  743.15  0.700000   520.205000  None   []
# 3  306693  None  [743.19000, 0.63267197, 1609509956.2997396, b,...  1609509956299  2021-01-01T14:05:56.299Z  ETH/USDT  market  buy         None  743.19  0.632672   470.195481  None   []
# 4  306694  None  [740.28000, 0.30168360, 1609510398.675571, b, ...  1609510398675  2021-01-01T14:13:18.675Z  ETH/USDT   limit  buy         None  740.28  0.301684   223.330335  None   []

# %%
data.timestamp.agg(["min", "max"]).apply(pd.Timestamp, unit="ms")
# Out:
# min   2021-01-01 14:05:56.295
# max   2021-01-02 08:30:39.047
# Name: timestamp, dtype: datetime64[ns]

# %%
last_data_id = 1609509956295391408

# %%
params = {"fromId": last_data_id}
data = extractor.fetch_trades(currency_pair, since=160950995629539.1408)

# %%
data
# Out:
# []

# %%
since = data[-1]["info"][-1]

# %% [markdown]
# # CCXT extractor test

# %%
import im_v2.ccxt.data.extract.extractor as imvcdexex

exchange_id = "kraken"
contract_type = "spot"
ccxt_extractor = imvcdexex.CcxtExtractor(exchange_id, contract_type)

# %%
data_type = "trades"
currency_pair = "ETH/USDT"
converted_currency_pair = currency_pair
start_timestamp = pd.Timestamp("2021-01-01T00:00:00+00:00")
end_timestamp = pd.Timestamp("2021-01-07T23:59:59+00:00")
data = ccxt_extractor.download_data(
    data_type,
    exchange_id,
    converted_currency_pair,
    start_timestamp=start_timestamp,
    end_timestamp=end_timestamp,
    depth=10,
)

# %%
data.head()
# Out:
#        timestamp    symbol  side   price    amount            end_download_timestamp
# 0  1609459218231  ETH/USDT  sell  735.91  0.035530  2023-04-21 16:41:36.288763+00:00
# 1  1609459326746  ETH/USDT   buy  738.76  0.373670  2023-04-21 16:41:36.288763+00:00
# 2  1609459326749  ETH/USDT   buy  738.76  0.783000  2023-04-21 16:41:36.288763+00:00
# 3  1609459387015  ETH/USDT  sell  737.36  1.015312  2023-04-21 16:41:36.288763+00:00
# 4  1609459387018  ETH/USDT  sell  737.35  1.213466  2023-04-21 16:41:36.288763+00:00

# %%
data["timestamp1"] = data["timestamp"].apply(pd.Timestamp, unit="ms")

# %%
len(data)
# Out:
# 1000

# %%
data.timestamp.agg(["min", "max"]).apply(pd.Timestamp, unit="ms")
# Out:
# min   2021-01-01 00:00:18.231
# max   2021-01-07 23:59:12.423
# Name: timestamp, dtype: datetime64[ns]

# %%
data.isna().any().any()
# Out:
# False

# %% [markdown]
# # Bulk script data download

# %%
# %%bash
# /app/im_v2/common/data/extract/download_bulk.py \
#     --download_mode 'periodic_daily' \
#     --downloading_entity 'airflow' \
#     --action_tag 'downloaded_1min' \
#     --vendor 'ccxt' \
#     --start_timestamp '2023-02-01T00:00:00+00:00' \
#     --end_timestamp '2023-02-20T00:00:00+00:00' \
#     --exchange_id 'kraken' \
#     --incremental \
#     --universe 'v7.4' \
#     --aws_profile 'ck' \
#     --data_type 'trades' \
#     --data_format 'parquet' \
#     --contract_type 'spot' \
#     --s3_path 's3://cryptokaizen-data-test/'
# Out:
# INFO: > cmd='/app/im_v2/common/data/extract/download_bulk.py --download_mode periodic_daily --downloading_entity airflow --action_tag downloaded_1min --vendor ccxt --start_timestamp 2023-02-01T00:00:00+00:00 --end_timestamp 2023-02-20T00:00:00+00:00 --exchange_id kraken --incremental --universe v7.4 --aws_profile ck --data_type trades --data_format parquet --contract_type spot --s3_path s3://cryptokaizen-data-test/'
# report_memory_usage=False report_cpu_usage=False
# INFO: Saving log to file '/app/im_v2/common/data/extract/download_bulk.py.log'
# 14:53:19 - INFO  dataset_schema_utils.py _get_dataset_schema_file_path:39 Loading dataset schema file: /app/data_schema/dataset_schema_versions/dataset_schema_v3.json
# 14:53:19 - INFO  dataset_schema_utils.py get_dataset_schema:74          Loaded dataset schema version v3
# 14:53:20 - INFO  dataset_schema_utils.py _get_dataset_schema_file_path:39 Loading dataset schema file: /app/data_schema/dataset_schema_versions/dataset_schema_v3.json
# 14:53:20 - INFO  dataset_schema_utils.py get_dataset_schema:74          Loaded dataset schema version v3
# 14:53:22 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:23 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:24 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:26 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:27 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:28 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:29 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:30 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:31 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:32 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:33 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:34 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:35 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:36 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:37 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:39 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:39 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:40 - INFO  extract_utils.py download_historical_data:734          Saving the dataset into s3://cryptokaizen-data-test/v3/periodic_daily/airflow/downloaded_1min/parquet/trades/spot/v7_4/ccxt/kraken/v1_0_0
# 14:53:41 - INFO  hcache.py clear_global_cache:292                       Before clear_global_cache: 'global mem' cache: path='/mnt/tmpfs/tmp.cache.mem', size=32.0 KB
# 14:53:41 - WARN  hcache.py clear_global_cache:293                       Resetting 'global mem' cache '/mnt/tmpfs/tmp.cache.mem'
# 14:53:41 - WARN  hcache.py clear_global_cache:303                       Destroying '/mnt/tmpfs/tmp.cache.mem' ...
# 14:53:41 - INFO  hcache.py clear_global_cache:319                       After clear_global_cache: 'global mem' cache: path='/mnt/tmpfs/tmp.cache.mem', size=nan

# %% [markdown]
# # Read and check data by RawReader

# %%
signature = "periodic_daily.airflow.downloaded_1min.parquet.trades.spot.v7_4.ccxt.kraken.v1_0_0"
reader = imvcdcimrdc.RawDataReader(signature, stage="test")
start_timestamp = pd.Timestamp("2023-02-01T00:00:00+00:00")
end_timestamp = pd.Timestamp("2023-02-20T00:00:00+00:00")
trades = reader.read_data(start_timestamp, end_timestamp)
# Out:
# INFO  Loading dataset schema file: /app/data_schema/dataset_schema_versions/dataset_schema_v3.json
# INFO  Loaded dataset schema version v3
# INFO  Loading dataset schema file: /app/data_schema/dataset_schema_versions/dataset_schema_v3.json
# INFO  Loaded dataset schema version v3
# INFO  Loading dataset schema file: /app/data_schema/dataset_schema_versions/dataset_schema_v3.json
# INFO  Loaded dataset schema version v3

# %%
trades
# Out:
#                                       timestamp    symbol  side     price        amount exchange_id              knowledge_timestamp currency_pair  year  month  day
# timestamp
# 2023-02-01 00:11:20.376000+00:00  1675210280376  ADA/USDT   buy  0.389438     15.000000      kraken 2023-04-17 18:53:32.446532+00:00      ADA_USDT  2023      2    1
# 2023-02-01 00:41:59.149000+00:00  1675212119149  ADA/USDT   buy  0.390383     15.000000      kraken 2023-04-17 18:53:32.446532+00:00      ADA_USDT  2023      2    1
# 2023-02-01 00:42:25.063000+00:00  1675212145063  ADA/USDT  sell  0.389947     15.000000      kraken 2023-04-17 18:53:32.446532+00:00      ADA_USDT  2023      2    1
# 2023-02-01 00:42:27.405000+00:00  1675212147405  ADA/USDT   buy  0.390153     15.000000      kraken 2023-04-17 18:53:32.446532+00:00      ADA_USDT  2023      2    1
# 2023-02-01 00:42:51.891000+00:00  1675212171891  ADA/USDT   buy  0.389907     15.000000      kraken 2023-04-17 18:53:32.446532+00:00      ADA_USDT  2023      2    1
# ...                                         ...       ...   ...       ...           ...         ...                              ...           ...   ...    ...  ...
# 2023-02-03 14:51:33.681000+00:00  1675435893681  XRP/USDT   buy  0.411280   2540.150019      kraken 2023-04-17 18:53:28.350857+00:00      XRP_USDT  2023      2    3
# 2023-02-03 14:51:33.681000+00:00  1675435893681  XRP/USDT   buy  0.411290  13042.648019      kraken 2023-04-17 18:53:28.350857+00:00      XRP_USDT  2023      2    3
# 2023-02-03 14:51:33.681000+00:00  1675435893681  XRP/USDT   buy  0.411500   1270.452268      kraken 2023-04-17 18:53:28.350857+00:00      XRP_USDT  2023      2    3
# 2023-02-03 14:52:05.868000+00:00  1675435925868  XRP/USDT  sell  0.410770     88.000000      kraken 2023-04-17 18:53:28.350857+00:00      XRP_USDT  2023      2    3
# 2023-02-03 14:53:33.238000+00:00  1675436013238  XRP/USDT   buy  0.410430    132.652579      kraken 2023-04-17 18:53:28.350857+00:00      XRP_USDT  2023      2    3
#
# [18000 rows x 11 columns]

# %%
trades.isna().any().any()
# Out:
# False

# %%
pd.Series(trades.currency_pair.unique())
# Out:
# 0       ADA_USDT
# 1       APE_USDT
# 2           ATOM
# 3      AVAX_USDT
# 4            BCH
# 5       BTC_USDT
# 6       DAI_USDT
# 7      DOGE_USDT
# 8       DOT_USDT
# 9       ETH_USDT
# 10          LINK
# 11      LTC_USDT
# 12    MATIC_USDT
# 13     SHIB_USDT
# 14      SOL_USDT
# 15     USDC_USDT
# 16           XMR
# 17      XRP_USDT
# dtype: object

# %%
a = [
    "ETH_USDT",
    "BTC_USDT",
    "APE_USDT",
    "MATIC_USDT",
    "DOT_USDT",
    "XRP_USDT",
    "DOGE_USDT",
    "SOL_USDT",
    "USDC_USDT",
    "ADA_USDT",
    "LTC_USDT",
    "SHIB_USDT",
    "AVAX_USDT",
    "DAI_USDT",
    "LINK/USDT",
    "ATOM/USDT",
    "XMR/USDT",
    "BCH/USDT",
]

# %%
unique_currency_pair = pd.Series(trades.currency_pair.unique())

# %%
unique_currency_pair[~unique_currency_pair.isin(a)]
# Out:
# 2     ATOM
# 4      BCH
# 10    LINK
# 16     XMR
# dtype: object

# %% [markdown]
# # QA  exploratory analysis

# %%
mode = "download"
vendor_name = "CCXT"
version = "v7.4"
universe = imvcounun.get_vendor_universe(vendor_name, mode, version=version)
universe_list = universe[exchange_id]
qa_check_list = [
    imvcdqqach.NaNChecks(),
    imvcdqqach.FullUniversePresentCheck(universe_list),
]
dataset_validator1 = imvcdqdava.DataFrameDatasetValidator(qa_check_list)

# %%
dataset_validator1.run_all_checks([trades])
# Out:
# INFO  Running all QA checks:
# INFO  	NaNChecks: PASSED
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [74], line 1
# ----> 1 dataset_validator1.run_all_checks([trades], _LOG)
#
# File /app/im_v2/common/data/qa/dataset_validator.py:26, in DataFrameDatasetValidator.run_all_checks(self, datasets, logger)
#      24 if error_msgs:
#      25     error_msg = "\n".join(error_msgs)
# ---> 26     hdbg.dfatal(error_msg)
#
# File /app/helpers/hdbg.py:71, in dfatal(message, assertion_type)
#      69 if assertion_type is None:
#      70     assertion_type = AssertionError
# ---> 71 raise assertion_type(ret)
#
# AssertionError:
# ################################################################################
# 	FullUniversePresentCheck: FAILED: Found missing symbols in dataset:
# 	{'MATIC_USDT', 'APE_USDT', 'AVAX_USDT', 'SOL_USDT'}
# ################################################################################
