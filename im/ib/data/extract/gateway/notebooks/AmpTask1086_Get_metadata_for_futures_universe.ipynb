# %%
# %load_ext autoreload
# %autoreload 2

import ib_insync

print(ib_insync.__all__)

import im.ib.data.extract.gateway.utils as imidegaut
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['util', 'Event', 'SoftDollarTier', 'PriceIncrement', 'Execution', 'CommissionReport', 'BarList', 'BarDataList', 'RealTimeBarList', 'BarData', 'RealTimeBar', 'HistogramData', 'NewsProvider', 'DepthMktDataDescription', 'ScannerSubscription', 'ScanDataList', 'FundamentalRatios', 'ExecutionFilter', 'PnL', 'PnLSingle', 'AccountValue', 'TickData', 'TickByTickAllLast', 'TickByTickBidAsk', 'TickByTickMidPoint', 'HistoricalTick', 'HistoricalTickBidAsk', 'HistoricalTickLast', 'TickAttrib', 'TickAttribBidAsk', 'TickAttribLast', 'MktDepthData', 'DOMLevel', 'TradeLogEntry', 'FamilyCode', 'SmartComponent', 'PortfolioItem', 'Position', 'Fill', 'OptionComputation', 'OptionChain', 'Dividends', 'NewsArticle', 'HistoricalNews', 'NewsTick', 'NewsBulletin', 'ConnectionStats', 'Contract', 'Stock', 'Option', 'Future', 'ContFuture', 'Forex', 'Index', 'CFD', 'Commodity', 'Bond', 'FuturesOption', 'MutualFund', 'Warrant', 'Bag', 'TagValue', 'ComboLeg', 'DeltaNeutralContract', 'ContractDetails', 'ContractDescription', 'ScanData', 'Trade', 'Order', 'OrderStatus', 'OrderState', 'OrderComboLeg', 'LimitOrder', 'MarketOrder', 'StopOrder', 'StopLimitOrder', 'BracketOrder', 'OrderCondition', 'ExecutionCondition', 'MarginCondition', 'TimeCondition', 'PriceCondition', 'PercentChangeCondition', 'VolumeCondition', 'Ticker', 'IB', 'Client', 'RequestError', 'Wrapper', 'FlexReport', 'FlexError', 'IBC', 'IBController', 'Watchdog']

# %%
ib = imidegaut.ib_connect(client_id=33, is_notebook=True)

# %%
# Look for ES.

# symbol = "ES"
symbol = "NG"
# symbol = "CL"
contract = ib_insync.Future(symbol, includeExpired=True)
df = imidegaut.get_contract_details(ib, contract, simplify_df=False)

display(df)

# cds = ib.reqContractDetails(contract)

# contracts = [cd.contract for cd in cds]

# ib_insync.util.df(contracts)
# Out:
#     secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0       FUT   81596321     NG                     20190327     0.0
# 1       FUT   81596321     NG                     20190327     0.0
# 2       FUT   81596324     NG                     20190426     0.0
# 3       FUT   81596324     NG                     20190426     0.0
# 4       FUT   81596331     NG                     20190529     0.0
# ..      ...        ...    ...                          ...     ...   ...
# 349     FUT  457291606     NG                     20330301     0.0
# 350     FUT  457291609     NG                     20331101     0.0
# 351     FUT  457291609     NG                     20331101     0.0
# 352     FUT  457291612     NG                     20330501     0.0
# 353     FUT  457291612     NG                     20330501     0.0
#
#     multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0        10000    NYMEX                      USD        NGJ9           NG
# 1        10000   QBALGO                      USD        NGJ9           NG
# 2        10000    NYMEX                      USD        NGK9           NG
# 3        10000   QBALGO                      USD        NGK9           NG
# 4        10000    NYMEX                      USD        NGM9           NG
# ..         ...      ...             ...      ...         ...          ...
# 349      10000   QBALGO                      USD       NGH33           NG
# 350      10000    NYMEX                      USD       NGX33           NG
# 351      10000   QBALGO                      USD       NGX33           NG
# 352      10000    NYMEX                      USD       NGK33           NG
# 353      10000   QBALGO                      USD       NGK33           NG
#
#      includeExpired secIdType secId comboLegsDescrip comboLegs  \
# 0             False                                         []
# 1             False                                         []
# 2             False                                         []
# 3             False                                         []
# 4             False                                         []
# ..              ...       ...   ...              ...       ...
# 349           False                                         []
# 350           False                                         []
# 351           False                                         []
# 352           False                                         []
# 353           False                                         []
#
#     deltaNeutralContract
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ..                   ...
# 349                 None
# 350                 None
# 351                 None
# 352                 None
# 353                 None
#
# [354 rows x 18 columns]

# %%
df
# Out:
#     secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0       FUT   81596321     NG                     20190327     0.0
# 1       FUT   81596321     NG                     20190327     0.0
# 2       FUT   81596324     NG                     20190426     0.0
# 3       FUT   81596324     NG                     20190426     0.0
# 4       FUT   81596331     NG                     20190529     0.0
# ..      ...        ...    ...                          ...     ...   ...
# 349     FUT  457291606     NG                     20330301     0.0
# 350     FUT  457291609     NG                     20331101     0.0
# 351     FUT  457291609     NG                     20331101     0.0
# 352     FUT  457291612     NG                     20330501     0.0
# 353     FUT  457291612     NG                     20330501     0.0
#
#     multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0        10000    NYMEX                      USD        NGJ9           NG
# 1        10000   QBALGO                      USD        NGJ9           NG
# 2        10000    NYMEX                      USD        NGK9           NG
# 3        10000   QBALGO                      USD        NGK9           NG
# 4        10000    NYMEX                      USD        NGM9           NG
# ..         ...      ...             ...      ...         ...          ...
# 349      10000   QBALGO                      USD       NGH33           NG
# 350      10000    NYMEX                      USD       NGX33           NG
# 351      10000   QBALGO                      USD       NGX33           NG
# 352      10000    NYMEX                      USD       NGK33           NG
# 353      10000   QBALGO                      USD       NGK33           NG
#
#      includeExpired secIdType secId comboLegsDescrip comboLegs  \
# 0             False                                         []
# 1             False                                         []
# 2             False                                         []
# 3             False                                         []
# 4             False                                         []
# ..              ...       ...   ...              ...       ...
# 349           False                                         []
# 350           False                                         []
# 351           False                                         []
# 352           False                                         []
# 353           False                                         []
#
#     deltaNeutralContract
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ..                   ...
# 349                 None
# 350                 None
# 351                 None
# 352                 None
# 353                 None
#
# [354 rows x 18 columns]
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.

# %%
# df.reset_index(drop=True)
# Out:
#     secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0       FUT   81596321     NG                     20190327     0.0
# 1       FUT   81596321     NG                     20190327     0.0
# 2       FUT   81596324     NG                     20190426     0.0
# 3       FUT   81596324     NG                     20190426     0.0
# 4       FUT   81596331     NG                     20190529     0.0
# ..      ...        ...    ...                          ...     ...   ...
# 349     FUT  457291606     NG                     20330301     0.0
# 350     FUT  457291609     NG                     20331101     0.0
# 351     FUT  457291609     NG                     20331101     0.0
# 352     FUT  457291612     NG                     20330501     0.0
# 353     FUT  457291612     NG                     20330501     0.0
#
#     multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0        10000    NYMEX                      USD        NGJ9           NG
# 1        10000   QBALGO                      USD        NGJ9           NG
# 2        10000    NYMEX                      USD        NGK9           NG
# 3        10000   QBALGO                      USD        NGK9           NG
# 4        10000    NYMEX                      USD        NGM9           NG
# ..         ...      ...             ...      ...         ...          ...
# 349      10000   QBALGO                      USD       NGH33           NG
# 350      10000    NYMEX                      USD       NGX33           NG
# 351      10000   QBALGO                      USD       NGX33           NG
# 352      10000    NYMEX                      USD       NGK33           NG
# 353      10000   QBALGO                      USD       NGK33           NG
#
#      includeExpired secIdType secId comboLegsDescrip comboLegs  \
# 0             False                                         []
# 1             False                                         []
# 2             False                                         []
# 3             False                                         []
# 4             False                                         []
# ..              ...       ...   ...              ...       ...
# 349           False                                         []
# 350           False                                         []
# 351           False                                         []
# 352           False                                         []
# 353           False                                         []
#
#     deltaNeutralContract
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ..                   ...
# 349                 None
# 350                 None
# 351                 None
# 352                 None
# 353                 None
#
# [354 rows x 18 columns]

# %%
import copy

# %%
def create_contracts(ib, contract, symbols):
    contracts = []
    for symbol in symbols:
        contract_tmp = copy.copy(contract)
        contract_tmp.symbol = symbol
        # ib.qualifyContracts(contract_tmp)
        contracts.append(contract_tmp)
    return contracts


contract = ib_insync.Future(symbol, includeExpired=True)
symbols = "ES CL NG".split()
create_contracts(ib, contract, symbols)
# Out:
# [Future(symbol='ES', includeExpired=True),
#  Future(symbol='CL', includeExpired=True),
#  Future(symbol='NG', includeExpired=True)]

# %%
contract2.symbol = "E"

# %%
import im.ib.data.extract.gateway.metadata as imidegame

file_name = "./metadata.csv"
ibmeta = imidegame.IbMetadata()

ibmeta.update(ib, [contract], file_name, reset=True)

# %%
ibmeta.load(file_name)
# Out:
#           secType symbol  lastTradeDateOrContractMonth  strike  right  \
# conId
# 81596321      FUT     NG                      20190327     0.0    NaN
# 81596321      FUT     NG                      20190327     0.0    NaN
# 81596324      FUT     NG                      20190426     0.0    NaN
# 81596324      FUT     NG                      20190426     0.0    NaN
# 81596331      FUT     NG                      20190529     0.0    NaN
# ...           ...    ...                           ...     ...    ...
# 457291606     FUT     NG                      20330301     0.0    NaN
# 457291609     FUT     NG                      20331101     0.0    NaN
# 457291609     FUT     NG                      20331101     0.0    NaN
# 457291612     FUT     NG                      20330501     0.0    NaN
# 457291612     FUT     NG                      20330501     0.0    NaN
#
#            multiplier exchange  primaryExchange currency localSymbol  \
# conId
# 81596321        10000    NYMEX              NaN      USD        NGJ9
# 81596321        10000   QBALGO              NaN      USD        NGJ9
# 81596324        10000    NYMEX              NaN      USD        NGK9
# 81596324        10000   QBALGO              NaN      USD        NGK9
# 81596331        10000    NYMEX              NaN      USD        NGM9
# ...               ...      ...              ...      ...         ...
# 457291606       10000   QBALGO              NaN      USD       NGH33
# 457291609       10000    NYMEX              NaN      USD       NGX33
# 457291609       10000   QBALGO              NaN      USD       NGX33
# 457291612       10000    NYMEX              NaN      USD       NGK33
# 457291612       10000   QBALGO              NaN      USD       NGK33
#
#           tradingClass  includeExpired  secIdType  secId  comboLegsDescrip  \
# conId
# 81596321            NG           False        NaN    NaN               NaN
# 81596321            NG           False        NaN    NaN               NaN
# 81596324            NG           False        NaN    NaN               NaN
# 81596324            NG           False        NaN    NaN               NaN
# 81596331            NG           False        NaN    NaN               NaN
# ...                ...             ...        ...    ...               ...
# 457291606           NG           False        NaN    NaN               NaN
# 457291609           NG           False        NaN    NaN               NaN
# 457291609           NG           False        NaN    NaN               NaN
# 457291612           NG           False        NaN    NaN               NaN
# 457291612           NG           False        NaN    NaN               NaN
#
#           comboLegs  deltaNeutralContract
# conId
# 81596321         []                   NaN
# 81596321         []                   NaN
# 81596324         []                   NaN
# 81596324         []                   NaN
# 81596331         []                   NaN
# ...             ...                   ...
# 457291606        []                   NaN
# 457291609        []                   NaN
# 457291609        []                   NaN
# 457291612        []                   NaN
# 457291612        []                   NaN
#
# [354 rows x 17 columns]
