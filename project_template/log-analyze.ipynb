# %%
# !pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in ./venv/lib/python3.11/site-packages (8.13.0)
# Requirement already satisfied: elastic-transport<9,>=8.13 in ./venv/lib/python3.11/site-packages (from elasticsearch) (8.13.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in ./venv/lib/python3.11/site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2.2.1)
# Requirement already satisfied: certifi in ./venv/lib/python3.11/site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2024.2.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from elasticsearch import Elasticsearch
import pandas as pd
import matplotlib.pyplot as plt

# %%
es = Elasticsearch(
    ['http://localhost:9200'],
    basic_auth=('elastic', 'CpZcVEXMtU04YG515b08')
)

# Define the query to fetch data
response = es.search(
    index="web-logs",
    body={
        "size": 10000,  # Adjust the size according to your needs
        "query": {
            "match_all": {}
        },
        "sort": [
            {"timestamp": "asc"}  # Ensure the logs are sorted by timestamp
        ]
    }
)

# Extract data from response
logs = [hit["_source"] for hit in response['hits']['hits']]

# Convert data to DataFrame
df = pd.DataFrame(logs)

# Convert timestamp from string to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

df
# Out:
#                timestamp               ip  method                  endpoint  \
# 0    2024-04-24 14:44:04   134.75.146.209     GET         explore/blog/blog
# 1    2024-04-24 14:44:04     51.48.23.207  DELETE             posts/explore
# 2    2024-04-24 14:44:04  187.156.203.125    POST           tag/main/search
# 3    2024-04-24 14:44:04   95.218.188.233     GET  list/wp-content/category
# 4    2024-04-24 14:44:04    159.10.167.95     PUT                  list/tag
# ...                  ...              ...     ...                       ...
# 5995 2024-05-01 19:04:54    74.171.77.163  DELETE            tags/tag/posts
# 5996 2024-05-01 19:04:54      174.54.53.6     GET            search/explore
# 5997 2024-05-01 19:04:54   157.120.130.21  DELETE                categories
# 5998 2024-05-01 19:04:54    53.118.165.58    POST                  category
# 5999 2024-05-01 19:04:54    199.166.24.15     PUT                       app
#
#       response_code  response_time
# 0               200            343
# 1               500            923
# 2               404            629
# 3               404            538
# 4               500            665
# ...             ...            ...
# 5995            201            458
# 5996            404            494
# 5997            404            302
# 5998            500            993
# 5999            404            208
#
# [6000 rows x 6 columns]
