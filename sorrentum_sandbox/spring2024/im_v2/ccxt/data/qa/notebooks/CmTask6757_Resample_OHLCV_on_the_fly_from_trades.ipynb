# %%
# adhoc to get latest CCXT version.
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --upgrade ccxt)"
# Out:
# Requirement already up-to-date: ccxt in /venv/lib/python3.9/site-packages (4.2.49)
# Requirement already satisfied, skipping upgrade: aiohttp>=3.8; python_version >= "3.5.2" in /venv/lib/python3.9/site-packages (from ccxt) (3.8.5)
# Requirement already satisfied, skipping upgrade: requests>=2.18.4 in /venv/lib/python3.9/site-packages (from ccxt) (2.31.0)
# Requirement already satisfied, skipping upgrade: aiodns>=1.1.1; python_version >= "3.5.2" in /venv/lib/python3.9/site-packages (from ccxt) (3.0.0)
# Requirement already satisfied, skipping upgrade: yarl>=1.7.2; python_version >= "3.5.2" in /venv/lib/python3.9/site-packages (from ccxt) (1.9.2)
# Requirement already satisfied, skipping upgrade: cryptography>=2.6.1 in /venv/lib/python3.9/site-packages (from ccxt) (3.4.7)
# Requirement already satisfied, skipping upgrade: certifi>=2018.1.18 in /venv/lib/python3.9/site-packages (from ccxt) (2023.7.22)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.4.0 in /venv/lib/python3.9/site-packages (from ccxt) (4.8.0)
# Requirement already satisfied, skipping upgrade: setuptools>=60.9.0 in /venv/lib/python3.9/site-packages (from ccxt) (69.0.3)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (6.0.4)
# Requirement already satisfied, skipping upgrade: frozenlist>=1.1.1 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.4.0)
# Requirement already satisfied, skipping upgrade: aiosignal>=1.1.2 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.3.1)
# Requirement already satisfied, skipping upgrade: async-timeout<5.0,>=4.0.0a3 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (4.0.3)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4.0,>=2.0 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (3.3.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /venv/lib/python3.9/site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (23.1.0)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /venv/lib/python3.9/site-packages (from requests>=2.18.4->ccxt) (1.26.17)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /venv/lib/python3.9/site-packages (from requests>=2.18.4->ccxt) (3.4)
# Requirement already satisfied, skipping upgrade: pycares>=4.0.0 in /venv/lib/python3.9/site-packages (from aiodns>=1.1.1; python_version >= "3.5.2"->ccxt) (4.3.0)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /venv/lib/python3.9/site-packages (from cryptography>=2.6.1->ccxt) (1.16.0)
# Requirement already satisfied, skipping upgrade: pycparser in /venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)

# %%
import ccxt
import pandas as pd

import helpers.hdatetime as hdateti
import im_v2.common.data.client.im_raw_data_client as imvcdcimrdc
import im_v2.common.universe.universe as imvcounun
# Out:
# /app/amp/core/statistics/random_samples.py:12: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# WARNING: No module named 'gluonts'

# %%
ccxt.__version__
# Out:
# '4.2.49'

# %%
ccxt_exchange = ccxt.binance()

# %%
def get_ohlcv_data(symbol, start_time, end_time):
    since = hdateti.convert_timestamp_to_unix_epoch(pd.Timestamp(start_time))
    end = hdateti.convert_timestamp_to_unix_epoch(pd.Timestamp(end_time))
    limit = int((end - since) / 60000) + 1
    ohlcv = pd.DataFrame(
        ccxt_exchange.fetch_ohlcv(symbol, "1m", since=since, limit=limit)
    )
    ohlcv.columns = ["timestamp", "open", "high", "low", "close", "volume"]
    return ohlcv

# %%
def get_trades_data(symbol, since):
    #     since = hdateti.convert_timestamp_to_unix_epoch(pd.Timestamp(start_time))
    trades = []
    last_data_id = None
    while True:
        if last_data_id is None:
            # Start from beginning, get the data from the start timestamp.
            data = ccxt_exchange.fetch_trades(
                symbol,
                since=since,
                limit=1000,
            )
        else:
            params = {"fromId": last_data_id}
            data = ccxt_exchange.fetch_trades(symbol, limit=1000, params=params)
        last_data_id = int(data[-1]["id"]) + 1
        trades.extend(data)
        if data[-1]["timestamp"] > since + 60000:
            break
    return trades

# %%
def get_error(REST_ohlcv, fil_data):
    merged_df = pd.merge(REST_ohlcv, fil_data, on="timestamp")
    merged_df["open_error"] = (
        100 * abs(merged_df["open_x"] - merged_df["open_y"]) / merged_df["open_y"]
    )
    merged_df["high_error"] = (
        100 * abs(merged_df["high_x"] - merged_df["high_y"]) / merged_df["high_y"]
    )
    merged_df["low_error"] = (
        100 * abs(merged_df["low_x"] - merged_df["low_y"]) / merged_df["low_y"]
    )
    merged_df["close_error"] = (
        100
        * abs(merged_df["close_x"] - merged_df["close_y"])
        / merged_df["close_y"]
    )
    merged_df["volume_error"] = (
        100
        * abs(merged_df["volume_x"] - merged_df["volume_y"])
        / merged_df["volume_y"]
    )
    print("Avg Open error  :", merged_df["open_error"].mean().round(2))
    print("Avg Close error :", merged_df["close_error"].mean().round(2))
    print("Avg High error  :", merged_df["high_error"].mean().round(2))
    print("Avg Low error   :", merged_df["low_error"].mean().round(2))
    print("Avg Volume error:", merged_df["volume_error"].mean().round(2))
    diff = merged_df[abs(merged_df["high_x"] - merged_df["high_y"]) > 1e-2]
    print(diff)
    data = fil_data[fil_data["timestamp"].isin(diff["timestamp"])]
    print(data)
    return diff, data


#     import pdb;pdb.set_trace()

# %%
def ohlcv_cross_data_qa(
    start_time,
    end_time,
    symbol,
    *,
    signature="realtime.airflow.downloaded_1min.postgres.ohlcv.futures.v7_4.ccxt.binance.v1_0_0",
    stage="test",
):
    data_reader = imvcdcimrdc.RawDataReader(signature, stage=stage)
    ohlcv_trades_data = data_reader.read_data(
        pd.Timestamp(start_time), pd.Timestamp(end_time)
    )
    filtered_data = ohlcv_trades_data[
        ohlcv_trades_data["currency_pair"] == symbol
    ]
    print(
        (
            filtered_data["knowledge_timestamp"]
            - filtered_data["end_download_timestamp"]
        ).mean()
    )
    symbol_rest = symbol.replace("_", "/") + ":USDT"
    REST_ohlcv = get_ohlcv_data(symbol_rest, start_time, end_time)
    print("Error % for symbol:", symbol)
    #     import pdb;pdb.set_trace()
    print(filtered_data)
    #     import pdb;pdb.set_trace()
    return get_error(REST_ohlcv, filtered_data)

# %%
vendor_name = "CCXT"
mode = "download"
version = "v7.3"
universe = imvcounun.get_vendor_universe(vendor_name, mode, version=version)
universe_list = universe["binance"]
universe_list = ["ETH_USDT"]
len(universe_list)
# Out:
# 1

# %%
start_time = "2024-03-05T10:00:00+00:00"
end_time = "2024-03-05T13:10:00+00:00"
for symbol in universe_list:
    diff, data = ohlcv_cross_data_qa(start_time, end_time, symbol)
# Out:
# /app/amp/helpers/hsql_implementation.py:582: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# 0 days 00:00:00.137496879
# Error % for symbol: ETH_USDT
#           id      timestamp     open     high      low    close     volume  \
# 0   54900187  1709638620000  3733.89  3733.89  3731.38  3732.54   1076.443
# 1   54900188  1709638680000  3732.54  3734.87  3731.00  3734.40   1371.746
# 2   54900189  1709638740000  3734.40  3737.00  3733.75  3736.63   1390.271
# 3   54900190  1709638800000  3736.63  3736.83  3732.21  3734.49   2034.620
# 4   54900191  1709638860000  3734.49  3737.86  3732.92  3732.93    946.462
# 5   54900192  1709638920000  3732.92  3736.22  3732.50  3734.91    973.450
# 6   54900193  1709638980000  3734.90  3737.70  3734.31  3736.67   1082.863
# 7   54900194  1709639040000  3736.68  3737.48  3732.82  3732.83   1693.116
# 8   54900195  1709639100000  3732.82  3738.73  3731.00  3738.73   2437.276
# 9   54900196  1709639160000  3738.72  3743.44  3737.23  3743.26   3590.652
# 10  54900197  1709639220000  3743.25  3745.74  3740.59  3745.74   2060.703
# 11  54900198  1709639280000  3745.74  3750.00  3745.74  3748.32   8104.545
# 12  54900199  1709639340000  3748.32  3748.78  3742.40  3744.24   2582.692
# 13  54900200  1709639400000  3744.24  3747.99  3744.24  3745.57   1258.833
# 14  54900201  1709639460000  3745.57  3749.56  3745.29  3747.88   1753.862
# 15  54900202  1709639520000  3747.89  3748.47  3745.00  3745.30   2042.279
# 16  54900203  1709639580000  3745.30  3745.30  3740.79  3741.57   2746.268
# 17  54900204  1709639640000  3741.57  3747.83  3741.56  3747.26   1858.051
# 18  54900205  1709639700000  3747.26  3747.98  3745.09  3745.57   1674.060
# 19  54900206  1709639760000  3745.56  3745.56  3742.01  3744.81   3803.530
# 20  54900207  1709639820000  3744.81  3744.98  3743.05  3743.66    981.937
# 21  54900208  1709639880000  3743.65  3743.93  3741.56  3742.80   1116.674
# 22  54900209  1709639940000  3742.80  3742.81  3737.95  3737.96   1868.683
# 23  54900210  1709640000000  3737.95  3741.97  3737.06  3739.56   2433.827
# 24  54900211  1709640060000  3739.61  3744.70  3739.61  3744.70   1576.226
# 25  54900212  1709640120000  3744.71  3744.95  3737.57  3738.65   1977.275
# 26  54900213  1709640180000  3738.65  3744.26  3737.75  3744.26   1317.330
# 27  54900214  1709640240000  3744.30  3750.00  3743.24  3749.99   4668.378
# 28  54900215  1709640300000  3750.00  3756.80  3749.28  3754.49  12601.214
# 29  54900216  1709640360000  3754.48  3761.88  3754.48  3757.56  10782.188
# 30  54900217  1709640420000  3757.55  3760.59  3756.47  3759.50   4391.163
# 31  54900218  1709640480000  3759.49  3764.73  3758.79  3761.43   6632.158
# 32  54900219  1709640540000  3761.43  3764.48  3760.00  3763.11   4651.151
# 33  54900220  1709640600000  3763.11  3766.00  3761.72  3765.69   4256.859
# 34  54900221  1709640660000  3765.69  3769.16  3764.57  3769.15   6090.297
# 35  54900222  1709640720000  3769.15  3774.06  3768.57  3769.88   9489.527
# 36  54900223  1709640780000  3769.87  3769.88  3765.30  3767.72   4848.302
# 37  54900224  1709640840000  3767.70  3767.70  3761.69  3762.99   5921.122
# 38  54900225  1709640900000  3763.00  3768.23  3762.91  3767.31   2501.924
# 39  54900226  1709640960000  3767.31  7042.67  3762.46  3764.32   2475.478
# 40  54900227  1709641020000  3764.31  3765.00  3760.64  3761.16   1734.332
# 41  54900228  1709641080000  3761.16  3761.28  3757.00  3758.18   3711.793
# 42  54900229  1709641140000  3758.18  3760.37  3757.00  3759.27   1977.041
# 43  54900230  1709641200000  3759.28  3769.12  3759.27  3768.80   4730.886
# 44  54900231  1709641260000  3768.79  3768.85  3763.04  3767.03   2275.517
# 45  54900232  1709641320000  3767.02  3767.34  3760.13  3760.69   3645.540
# 46  54900233  1709641380000  3760.68  3771.16  3760.41  3769.95   4044.347
# 47  54900234  1709641440000  3769.94  3777.20  3768.85  3775.00   7158.593
# 48  54900235  1709641500000  3775.00  3775.85  3770.85  3775.44   4551.491
# 49  54900236  1709641560000  3775.43  3776.21  3771.69  3772.68   3457.354
# 50  54900237  1709641620000  3772.68  3774.84  3770.88  3771.54   2125.290
# 51  54900238  1709641680000  3771.53  3774.73  3770.74  3774.25   1688.275
# 52  54900239  1709641740000  3774.24  3776.71  3773.05  3775.23   2857.326
# 53  54900240  1709641800000  3775.22  3775.87  3769.12  3769.26   2572.536
# 54  54900241  1709641860000  3769.13  3772.82  3766.17  3772.53   2582.254
# 55  54900242  1709641920000  3772.52  3775.73  3771.45  3772.45   1862.869
# 56  54900243  1709641980000  3772.46  3775.31  3770.94  3772.69   1557.740
# 57  54900244  1709642040000  3772.68  3773.15  3769.39  3770.85   1366.272
#
#    currency_pair exchange_id           end_download_timestamp  \
# 0       ETH_USDT     binance 2024-03-05 11:38:00.153872+00:00
# 1       ETH_USDT     binance 2024-03-05 11:39:00.312402+00:00
# 2       ETH_USDT     binance 2024-03-05 11:40:00.277330+00:00
# 3       ETH_USDT     binance 2024-03-05 11:41:00.240265+00:00
# 4       ETH_USDT     binance 2024-03-05 11:42:00.234533+00:00
# 5       ETH_USDT     binance 2024-03-05 11:43:00.197391+00:00
# 6       ETH_USDT     binance 2024-03-05 11:44:00.308044+00:00
# 7       ETH_USDT     binance 2024-03-05 11:45:00.271603+00:00
# 8       ETH_USDT     binance 2024-03-05 11:46:00.217532+00:00
# 9       ETH_USDT     binance 2024-03-05 11:47:00.192293+00:00
# 10      ETH_USDT     binance 2024-03-05 11:48:00.177275+00:00
# 11      ETH_USDT     binance 2024-03-05 11:49:00.144010+00:00
# 12      ETH_USDT     binance 2024-03-05 11:50:00.297433+00:00
# 13      ETH_USDT     binance 2024-03-05 11:51:00.270465+00:00
# 14      ETH_USDT     binance 2024-03-05 11:52:00.247393+00:00
# 15      ETH_USDT     binance 2024-03-05 11:53:00.225901+00:00
# 16      ETH_USDT     binance 2024-03-05 11:54:00.416069+00:00
# 17      ETH_USDT     binance 2024-03-05 11:55:00.404126+00:00
# 18      ETH_USDT     binance 2024-03-05 11:56:00.170292+00:00
# 19      ETH_USDT     binance 2024-03-05 11:57:00.317142+00:00
# 20      ETH_USDT     binance 2024-03-05 11:58:00.268298+00:00
# 21      ETH_USDT     binance 2024-03-05 11:59:00.193561+00:00
# 22      ETH_USDT     binance 2024-03-05 12:00:00.160546+00:00
# 23      ETH_USDT     binance 2024-03-05 12:01:00.301393+00:00
# 24      ETH_USDT     binance 2024-03-05 12:02:00.458166+00:00
# 25      ETH_USDT     binance 2024-03-05 12:03:00.215311+00:00
# 26      ETH_USDT     binance 2024-03-05 12:04:00.381353+00:00
# 27      ETH_USDT     binance 2024-03-05 12:05:00.334364+00:00
# 28      ETH_USDT     binance 2024-03-05 12:06:00.286769+00:00
# 29      ETH_USDT     binance 2024-03-05 12:07:00.187389+00:00
# 30      ETH_USDT     binance 2024-03-05 12:08:00.141403+00:00
# 31      ETH_USDT     binance 2024-03-05 12:09:00.293206+00:00
# 32      ETH_USDT     binance 2024-03-05 12:10:00.180919+00:00
# 33      ETH_USDT     binance 2024-03-05 12:11:00.264126+00:00
# 34      ETH_USDT     binance 2024-03-05 12:12:00.208514+00:00
# 35      ETH_USDT     binance 2024-03-05 12:13:00.305230+00:00
# 36      ETH_USDT     binance 2024-03-05 12:14:00.264318+00:00
# 37      ETH_USDT     binance 2024-03-05 12:15:00.400516+00:00
# 38      ETH_USDT     binance 2024-03-05 12:16:00.345447+00:00
# 39      ETH_USDT     binance 2024-03-05 12:17:00.303628+00:00
# 40      ETH_USDT     binance 2024-03-05 12:18:00.255087+00:00
# 41      ETH_USDT     binance 2024-03-05 12:19:00.225915+00:00
# 42      ETH_USDT     binance 2024-03-05 12:20:00.182572+00:00
# 43      ETH_USDT     binance 2024-03-05 12:21:00.155772+00:00
# 44      ETH_USDT     binance 2024-03-05 12:22:00.307910+00:00
# 45      ETH_USDT     binance 2024-03-05 12:23:00.270855+00:00
# 46      ETH_USDT     binance 2024-03-05 12:24:00.226993+00:00
# 47      ETH_USDT     binance 2024-03-05 12:25:00.180263+00:00
# 48      ETH_USDT     binance 2024-03-05 12:26:00.331479+00:00
# 49      ETH_USDT     binance 2024-03-05 12:27:00.304221+00:00
# 50      ETH_USDT     binance 2024-03-05 12:28:00.241885+00:00
# 51      ETH_USDT     binance 2024-03-05 12:29:00.410122+00:00
# 52      ETH_USDT     binance 2024-03-05 12:30:00.170726+00:00
# 53      ETH_USDT     binance 2024-03-05 12:31:00.319644+00:00
# 54      ETH_USDT     binance 2024-03-05 12:32:00.298310+00:00
# 55      ETH_USDT     binance 2024-03-05 12:33:00.656770+00:00
# 56      ETH_USDT     binance 2024-03-05 12:34:00.419646+00:00
# 57      ETH_USDT     binance 2024-03-05 12:35:00.374112+00:00
#
#                 knowledge_timestamp
# 0  2024-03-05 11:38:00.186080+00:00
# 1  2024-03-05 11:39:00.342959+00:00
# 2  2024-03-05 11:40:00.310849+00:00
# 3  2024-03-05 11:41:00.277434+00:00
# 4  2024-03-05 11:42:00.273011+00:00
# 5  2024-03-05 11:43:00.237487+00:00
# 6  2024-03-05 11:44:00.355174+00:00
# 7  2024-03-05 11:45:00.318905+00:00
# 8  2024-03-05 11:46:00.277211+00:00
# 9  2024-03-05 11:47:00.267341+00:00
# 10 2024-03-05 11:48:00.259019+00:00
# 11 2024-03-05 11:49:00.268054+00:00
# 12 2024-03-05 11:50:00.411473+00:00
# 13 2024-03-05 11:51:00.381334+00:00
# 14 2024-03-05 11:52:00.373070+00:00
# 15 2024-03-05 11:53:00.355925+00:00
# 16 2024-03-05 11:54:00.562125+00:00
# 17 2024-03-05 11:55:00.557757+00:00
# 18 2024-03-05 11:56:00.320879+00:00
# 19 2024-03-05 11:57:00.471987+00:00
# 20 2024-03-05 11:58:00.421547+00:00
# 21 2024-03-05 11:59:00.339148+00:00
# 22 2024-03-05 12:00:00.306507+00:00
# 23 2024-03-05 12:01:00.454584+00:00
# 24 2024-03-05 12:02:00.608092+00:00
# 25 2024-03-05 12:03:00.368161+00:00
# 26 2024-03-05 12:04:00.565593+00:00
# 27 2024-03-05 12:05:00.497571+00:00
# 28 2024-03-05 12:06:00.469478+00:00
# 29 2024-03-05 12:07:00.388795+00:00
# 30 2024-03-05 12:08:00.323506+00:00
# 31 2024-03-05 12:09:00.463784+00:00
# 32 2024-03-05 12:10:00.358185+00:00
# 33 2024-03-05 12:11:00.429499+00:00
# 34 2024-03-05 12:12:00.380252+00:00
# 35 2024-03-05 12:13:00.497192+00:00
# 36 2024-03-05 12:14:00.452167+00:00
# 37 2024-03-05 12:15:00.570194+00:00
# 38 2024-03-05 12:16:00.507409+00:00
# 39 2024-03-05 12:17:00.462377+00:00
# 40 2024-03-05 12:18:00.411507+00:00
# 41 2024-03-05 12:19:00.382105+00:00
# 42 2024-03-05 12:20:00.341326+00:00
# 43 2024-03-05 12:21:00.313437+00:00
# 44 2024-03-05 12:22:00.471836+00:00
# 45 2024-03-05 12:23:00.426243+00:00
# 46 2024-03-05 12:24:00.386074+00:00
# 47 2024-03-05 12:25:00.351175+00:00
# 48 2024-03-05 12:26:00.519625+00:00
# 49 2024-03-05 12:27:00.467146+00:00
# 50 2024-03-05 12:28:00.395084+00:00
# 51 2024-03-05 12:29:00.561999+00:00
# 52 2024-03-05 12:30:00.324374+00:00
# 53 2024-03-05 12:31:00.473660+00:00
# 54 2024-03-05 12:32:00.457922+00:00
# 55 2024-03-05 12:33:00.821161+00:00
# 56 2024-03-05 12:34:00.575931+00:00
# 57 2024-03-05 12:35:00.524209+00:00
# Avg Open error  : 0.0
# Avg Close error : 0.0
# Avg High error  : 0.8
# Avg Low error   : 0.0
# Avg Volume error: 0.0
#         timestamp   open_x   high_x    low_x  close_x  volume_x        id  \
# 39  1709640960000  3767.31  3767.52  3762.46  3764.32  2475.476  54900226
#
#      open_y   high_y    low_y  ...  volume_y  currency_pair exchange_id  \
# 39  3767.31  7042.67  3762.46  ...  2475.478       ETH_USDT     binance
#
#              end_download_timestamp              knowledge_timestamp  \
# 39 2024-03-05 12:17:00.303628+00:00 2024-03-05 12:17:00.462377+00:00
#
#    open_error  high_error  low_error  close_error  volume_error
# 39        0.0    46.50438        0.0          0.0      0.000081
#
# [1 rows x 21 columns]
#           id      timestamp     open     high      low    close    volume  \
# 39  54900226  1709640960000  3767.31  7042.67  3762.46  3764.32  2475.478
#
#    currency_pair exchange_id           end_download_timestamp  \
# 39      ETH_USDT     binance 2024-03-05 12:17:00.303628+00:00
#
#                 knowledge_timestamp
# 39 2024-03-05 12:17:00.462377+00:00

# %%
diff[
    [
        "timestamp",
        "open_x",
        "high_x",
        "low_x",
        "close_x",
        "volume_x",
        "open_y",
        "high_y",
        "low_y",
        "close_y",
        "volume_y",
    ]
].tail(10)
# Out:
#          timestamp   open_x   high_x    low_x  close_x   volume_x   open_y  \
# 364  1708975320000  3160.76  3171.10  3160.26  3166.01   6895.600  3160.76
# 373  1708975860000  3172.45  3184.31  3171.97  3175.59  22162.776  3172.45
# 407  1708977960000  3196.38  3199.00  3193.41  3197.42   9839.710  3196.38
# 503  1708983780000  3189.32  3191.16  3189.32  3190.36    374.400  3189.32
# 740  1708998240000  3191.17  3198.95  3190.39  3195.69  13163.738  3191.17
# 744  1708999560000  3229.74  3254.12  3226.24  3250.80  37318.839  3229.74
# 745  1708999620000  3250.80  3268.10  3242.85  3261.63  38242.711  3250.80
# 746  1709003160000  3243.45  3244.60  3240.75  3242.99   1504.349  3243.45
# 747  1709003220000  3243.00  3243.33  3239.98  3241.42   1675.083  3243.00
# 750  1709003400000  3243.81  3244.80  3242.61  3242.61   1026.923  3243.81
#
#       high_y    low_y  close_y   volume_y
# 364  3171.10  3159.69  3166.01   6910.636
# 373  3226.87  3171.97  3175.59  22162.837
# 407  3199.00  3192.26  3197.42   9839.748
# 503  3362.43  3189.32  3190.36    375.400
# 740  3198.95  3176.43  3195.69  13164.719
# 744  3274.20  3205.17  3250.80  37352.693
# 745  3325.71  3206.89  3261.63  38386.637
# 746  3244.60     0.00  3242.99   1504.360
# 747  3243.33  3199.68  3241.42   1675.483
# 750  3244.80  3239.74  3242.61   1027.013

# %%
data
# Out:
#              id      timestamp     open      high       low    close  \
# 4570   54867416  1708963920000  53425.0  54093.25  53425.00  53633.0
# 10291  54873137  1708977960000  54838.4  55126.63  54763.20  54916.7
# 20442  54883288  1709003160000  56543.8  56553.50  35778.96  56511.0
# 21616  54884462  1709005980000  56013.1  56017.70  55814.00  55876.1
#
#          volume currency_pair exchange_id           end_download_timestamp  \
# 4570   5369.103      BTC_USDT     binance 2024-02-26 16:13:01.763486+00:00
# 10291  2721.079      BTC_USDT     binance 2024-02-26 20:07:05.947698+00:00
# 20442   365.982      BTC_USDT     binance 2024-02-27 03:07:01.351579+00:00
# 21616  2521.857      BTC_USDT     binance 2024-02-27 03:54:02.196273+00:00
#
#                    knowledge_timestamp
# 4570  2024-02-26 16:13:03.387947+00:00
# 10291 2024-02-26 20:07:06.915714+00:00
# 20442 2024-02-27 03:07:01.906345+00:00
# 21616 2024-02-27 03:54:04.912489+00:00

# %%
trades = get_trades_data("ETH/USDT:USDT", 1709480580000)

# %%
len(trades)
# Out:
# 1000

# %%
trades[29]
# Out:
# {'info': {'a': '1520833751',
#   'p': '3431.98',
#   'q': '0.114',
#   'f': '3691724447',
#   'l': '3691724451',
#   'T': '1709480589228',
#   'm': True},
#  'timestamp': 1709480589228,
#  'datetime': '2024-03-03T15:43:09.228Z',
#  'symbol': 'ETH/USDT:USDT',
#  'id': '1520833751',
#  'order': None,
#  'type': None,
#  'side': 'sell',
#  'takerOrMaker': None,
#  'price': 3431.98,
#  'amount': 0.114,
#  'cost': 391.24572,
#  'fee': None,
#  'fees': []}

# %%
ccxt_exchange.build_ohlcvc(trades)
# Out:
# [[1709480580000, 3431.98, 3432.13, 3430.68, 3431.93, 536.5779999999986, 304],
#  [1709480640000, 3431.93, 3433.8, 3431.93, 3432.23, 1021.104999999999, 468],
#  [1709480700000, 3432.24, 3432.72, 3431.47, 3432.13, 451.972, 228]]

# %%
import im_v2.ccxt.data.extract.extractor as imvcdexex

extractor = imvcdexex.CcxtExtractor("binance", "futures")

# %%
trades_df = extractor._fetch_trades(
    "ETH_USDT",
    start_timestamp="2024-02-29T11:31:00+00:00",
    end_timestamp="2024-02-29T11:33:00+00:00",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 trades_df = extractor._fetch_trades("ETH_USDT", start_timestamp="2024-02-29T11:31:00+00:00", end_timestamp="2024-02-29T11:33:00+00:00")
#
# File /app/amp/im_v2/ccxt/data/extract/extractor.py:729, in CcxtExtractor._fetch_trades(self, currency_pair, start_timestamp, end_timestamp, sleep_time_in_secs, limit)
#     727 # Prepare parameters.
#     728 columns = ["id", "timestamp", "symbol", "side", "price", "amount"]
# --> 729 start_timestamp = hdateti.convert_timestamp_to_unix_epoch(start_timestamp)
#     730 end_timestamp = hdateti.convert_timestamp_to_unix_epoch(end_timestamp)
#     731 trades = []
#
# File /app/amp/helpers/hdatetime.py:858, in convert_timestamp_to_unix_epoch(timestamp, unit)
#     849 """
#     850 Convert timestamp to Unix epoch.
#     851
#    (...)
#     854 :return: Unix time epoch
#     855 """
#     856 # Make timestamp tz-naive if it is not. Converted to UTC tz before becoming
#     857 # naive automatically.
# --> 858 if timestamp.tz:
#     859     timestamp = timestamp.tz_convert(None)
#     860 # Convert to epoch.
#
# AttributeError: 'str' object has no attribute 'tz'

# %%
import pickle

trades = pickle.load(open("../../../../../../trades.pkl", "rb"))

# %%
len(trades)
# Out:
# 909460665

# %%
ccxt_exchange.build_ohlcvc(trades, since=1709231580000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 ccxt_exchange.build_ohlcvc(trades, since=1709231580000)
#
# File /venv/lib/python3.9/site-packages/ccxt/base/exchange.py:3558, in Exchange.build_ohlcvc(self, trades, timeframe, since, limit)
#    3556 ohlcv_length = len(ohlcvs)
#    3557 candle = ohlcv_length - 1
# -> 3558 if (candle == -1) or (openingTime >= self.sum(ohlcvs[candle][i_timestamp], ms)):
#    3559     # moved to a new timeframe -> create a new candle from opening trade
#    3560     ohlcvs.append([
#    3561         openingTime,  # timestamp
#    3562         trade['price'],  # O
#    (...)
#    3567         1,  # count
#    3568     ])
#    3569 else:
#    3570     # still processing the same timeframe -> update opening trade
#
# File /venv/lib/python3.9/site-packages/ccxt/base/exchange.py:1116, in Exchange.sum(*args)
#    1114 @staticmethod
#    1115 def sum(*args):
# -> 1116     return sum([arg for arg in args if isinstance(arg, (float, int))])
#
# File /venv/lib/python3.9/site-packages/ccxt/base/exchange.py:1116, in <listcomp>(.0)
#    1114 @staticmethod
#    1115 def sum(*args):
# -> 1116     return sum([arg for arg in args if isinstance(arg, (float, int))])
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm

my_trades = []
for trade in tqdm(trades):
    if (
        trade["timestamp"] >= 1709231580000
        and trade["timestamp"] <= 1709231580000 + 60100
    ):
        my_trades.append(trade)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 909460665/909460665 [06:19<00:00, 2399296.89it/s]

# %%
len(my_trades)
# Out:
# 27006200

# %%
my_trades[0]
# Out:
# {'info': {'e': 'trade',
#   'E': 1709231580003,
#   'T': 1709231580003,
#   's': 'ETHUSDT',
#   't': 3681469088,
#   'p': '3388.75',
#   'q': '0.021',
#   'X': 'MARKET',
#   'm': True},
#  'timestamp': 1709231580003,
#  'datetime': '2024-02-29T18:33:00.003Z',
#  'symbol': 'ETH/USDT:USDT',
#  'id': '3681469088',
#  'order': None,
#  'type': None,
#  'side': 'sell',
#  'takerOrMaker': None,
#  'price': 3388.75,
#  'amount': 0.021,
#  'cost': 71.16375,
#  'fee': None,
#  'fees': []}

# %%
df = pd.DataFrame(my_trades)

# %%
df = df[
    ["timestamp", "datetime", "symbol", "id", "side", "price", "amount", "cost"]
]
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 15246

# %%
trades_ts = df.to_dict(orient="records")

# %%
ccxt_exchange.build_ohlcvc(trades_ts)
# Out:
# [[1709231580000, 3388.75, 3388.76, 3368.06, 3376.2, 15710.068999999085, 15235],
#  [1709231640000, 3376.2, 3376.2, 3376.2, 3376.2, 2.1529999999999996, 11]]

# %%
trades_ts[:20]
# Out:
# [{'timestamp': 1709231580003,
#   'datetime': '2024-02-29T18:33:00.003Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469088',
#   'side': 'sell',
#   'price': 3388.75,
#   'amount': 0.021,
#   'cost': 71.16375},
#  {'timestamp': 1709231580019,
#   'datetime': '2024-02-29T18:33:00.019Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469089',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 12.01,
#   'cost': 40699.0076},
#  {'timestamp': 1709231580033,
#   'datetime': '2024-02-29T18:33:00.033Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469090',
#   'side': 'sell',
#   'price': 3388.75,
#   'amount': 0.017,
#   'cost': 57.60875},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469091',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.542,
#   'cost': 1836.70792},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469092',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 1.5,
#   'cost': 5083.14},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469093',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.894,
#   'cost': 3029.55144},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469094',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.606,
#   'cost': 2053.58856},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469095',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 2.114,
#   'cost': 7163.83864},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469096',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.306,
#   'cost': 1036.96056},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469097',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 2.194,
#   'cost': 7434.93944},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469098',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.761,
#   'cost': 2578.84636},
#  {'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469099',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 3.093,
#   'cost': 10481.43468},
#  {'timestamp': 1709231580058,
#   'datetime': '2024-02-29T18:33:00.058Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469100',
#   'side': 'sell',
#   'price': 3388.75,
#   'amount': 0.029,
#   'cost': 98.27375},
#  {'timestamp': 1709231580068,
#   'datetime': '2024-02-29T18:33:00.068Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469101',
#   'side': 'sell',
#   'price': 3388.75,
#   'amount': 0.937,
#   'cost': 3175.25875},
#  {'timestamp': 1709231580092,
#   'datetime': '2024-02-29T18:33:00.092Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469102',
#   'side': 'sell',
#   'price': 3388.75,
#   'amount': 0.025,
#   'cost': 84.71875},
#  {'timestamp': 1709231580098,
#   'datetime': '2024-02-29T18:33:00.098Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469103',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.006,
#   'cost': 20.33256},
#  {'timestamp': 1709231580099,
#   'datetime': '2024-02-29T18:33:00.099Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469104',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.018,
#   'cost': 60.99768},
#  {'timestamp': 1709231580099,
#   'datetime': '2024-02-29T18:33:00.099Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469105',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.006,
#   'cost': 20.33256},
#  {'timestamp': 1709231580099,
#   'datetime': '2024-02-29T18:33:00.099Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469106',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.006,
#   'cost': 20.33256},
#  {'timestamp': 1709231580099,
#   'datetime': '2024-02-29T18:33:00.099Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681469107',
#   'side': 'buy',
#   'price': 3388.76,
#   'amount': 0.006,
#   'cost': 20.33256}]

# %%
trades[:10]
# Out:
# [{'info': {'a': '1517803116',
#    'p': '3388.76',
#    'q': '12.010',
#    'f': '3681469089',
#    'l': '3681469089',
#    'T': '1709231580019',
#    'm': False},
#   'timestamp': 1709231580019,
#   'datetime': '2024-02-29T18:33:00.019Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803116',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3388.76,
#   'amount': 12.01,
#   'cost': 40699.0076,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803117',
#    'p': '3388.75',
#    'q': '0.017',
#    'f': '3681469090',
#    'l': '3681469090',
#    'T': '1709231580033',
#    'm': True},
#   'timestamp': 1709231580033,
#   'datetime': '2024-02-29T18:33:00.033Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803117',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3388.75,
#   'amount': 0.017,
#   'cost': 57.60875,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803118',
#    'p': '3388.76',
#    'q': '12.010',
#    'f': '3681469091',
#    'l': '3681469099',
#    'T': '1709231580037',
#    'm': False},
#   'timestamp': 1709231580037,
#   'datetime': '2024-02-29T18:33:00.037Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803118',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3388.76,
#   'amount': 12.01,
#   'cost': 40699.0076,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803119',
#    'p': '3388.75',
#    'q': '0.991',
#    'f': '3681469100',
#    'l': '3681469102',
#    'T': '1709231580058',
#    'm': True},
#   'timestamp': 1709231580058,
#   'datetime': '2024-02-29T18:33:00.058Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803119',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3388.75,
#   'amount': 0.991,
#   'cost': 3358.25125,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803120',
#    'p': '3388.76',
#    'q': '0.150',
#    'f': '3681469103',
#    'l': '3681469123',
#    'T': '1709231580098',
#    'm': False},
#   'timestamp': 1709231580098,
#   'datetime': '2024-02-29T18:33:00.098Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803120',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3388.76,
#   'amount': 0.15,
#   'cost': 508.314,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803121',
#    'p': '3388.75',
#    'q': '0.046',
#    'f': '3681469124',
#    'l': '3681469125',
#    'T': '1709231580110',
#    'm': True},
#   'timestamp': 1709231580110,
#   'datetime': '2024-02-29T18:33:00.110Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803121',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3388.75,
#   'amount': 0.046,
#   'cost': 155.8825,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803122',
#    'p': '3388.76',
#    'q': '0.229',
#    'f': '3681469126',
#    'l': '3681469146',
#    'T': '1709231580120',
#    'm': False},
#   'timestamp': 1709231580120,
#   'datetime': '2024-02-29T18:33:00.120Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803122',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3388.76,
#   'amount': 0.229,
#   'cost': 776.02604,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803123',
#    'p': '3388.75',
#    'q': '0.036',
#    'f': '3681469147',
#    'l': '3681469147',
#    'T': '1709231580133',
#    'm': True},
#   'timestamp': 1709231580133,
#   'datetime': '2024-02-29T18:33:00.133Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803123',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3388.75,
#   'amount': 0.036,
#   'cost': 121.995,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803124',
#    'p': '3388.76',
#    'q': '0.358',
#    'f': '3681469148',
#    'l': '3681469169',
#    'T': '1709231580133',
#    'm': False},
#   'timestamp': 1709231580133,
#   'datetime': '2024-02-29T18:33:00.133Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803124',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3388.76,
#   'amount': 0.358,
#   'cost': 1213.17608,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517803125',
#    'p': '3388.75',
#    'q': '0.015',
#    'f': '3681469170',
#    'l': '3681469170',
#    'T': '1709231580138',
#    'm': True},
#   'timestamp': 1709231580138,
#   'datetime': '2024-02-29T18:33:00.138Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517803125',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3388.75,
#   'amount': 0.015,
#   'cost': 50.83125,
#   'fee': None,
#   'fees': []}]

# %%
trades[-530:-510]
# Out:
# [{'info': {'a': '1517808586',
#    'p': '3376.52',
#    'q': '0.295',
#    'f': '3681484250',
#    'l': '3681484252',
#    'T': '1709231639221',
#    'm': False},
#   'timestamp': 1709231639221,
#   'datetime': '2024-02-29T18:33:59.221Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808586',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3376.52,
#   'amount': 0.295,
#   'cost': 996.0734,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808587',
#    'p': '3376.53',
#    'q': '0.006',
#    'f': '3681484253',
#    'l': '3681484253',
#    'T': '1709231639223',
#    'm': False},
#   'timestamp': 1709231639223,
#   'datetime': '2024-02-29T18:33:59.223Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808587',
#   'order': None,
#   'type': None,
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 3376.53,
#   'amount': 0.006,
#   'cost': 20.25918,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808588',
#    'p': '3376.61',
#    'q': '8.120',
#    'f': '3681484254',
#    'l': '3681484294',
#    'T': '1709231639692',
#    'm': True},
#   'timestamp': 1709231639692,
#   'datetime': '2024-02-29T18:33:59.692Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808588',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.61,
#   'amount': 8.12,
#   'cost': 27418.0732,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808589',
#    'p': '3376.60',
#    'q': '0.006',
#    'f': '3681484295',
#    'l': '3681484295',
#    'T': '1709231639692',
#    'm': True},
#   'timestamp': 1709231639692,
#   'datetime': '2024-02-29T18:33:59.692Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808589',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.6,
#   'amount': 0.006,
#   'cost': 20.2596,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808590',
#    'p': '3376.54',
#    'q': '0.065',
#    'f': '3681484296',
#    'l': '3681484296',
#    'T': '1709231639692',
#    'm': True},
#   'timestamp': 1709231639692,
#   'datetime': '2024-02-29T18:33:59.692Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808590',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.54,
#   'amount': 0.065,
#   'cost': 219.4751,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808591',
#    'p': '3376.52',
#    'q': '1.000',
#    'f': '3681484297',
#    'l': '3681484298',
#    'T': '1709231639692',
#    'm': True},
#   'timestamp': 1709231639692,
#   'datetime': '2024-02-29T18:33:59.692Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808591',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.52,
#   'amount': 1.0,
#   'cost': 3376.52,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808592',
#    'p': '3376.50',
#    'q': '1.000',
#    'f': '3681484299',
#    'l': '3681484300',
#    'T': '1709231639692',
#    'm': True},
#   'timestamp': 1709231639692,
#   'datetime': '2024-02-29T18:33:59.692Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808592',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.5,
#   'amount': 1.0,
#   'cost': 3376.5,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808593',
#    'p': '3376.46',
#    'q': '0.295',
#    'f': '3681484301',
#    'l': '3681484301',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808593',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.46,
#   'amount': 0.295,
#   'cost': 996.0557,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808594',
#    'p': '3376.43',
#    'q': '1.553',
#    'f': '3681484302',
#    'l': '3681484303',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808594',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.43,
#   'amount': 1.553,
#   'cost': 5243.59579,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808595',
#    'p': '3376.42',
#    'q': '2.620',
#    'f': '3681484304',
#    'l': '3681484305',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808595',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.42,
#   'amount': 2.62,
#   'cost': 8846.2204,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808596',
#    'p': '3376.39',
#    'q': '0.007',
#    'f': '3681484306',
#    'l': '3681484306',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808596',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.39,
#   'amount': 0.007,
#   'cost': 23.63473,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808597',
#    'p': '3376.36',
#    'q': '0.295',
#    'f': '3681484307',
#    'l': '3681484307',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808597',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.36,
#   'amount': 0.295,
#   'cost': 996.0262,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808598',
#    'p': '3376.34',
#    'q': '0.158',
#    'f': '3681484308',
#    'l': '3681484308',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808598',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.34,
#   'amount': 0.158,
#   'cost': 533.46172,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808599',
#    'p': '3376.32',
#    'q': '2.620',
#    'f': '3681484309',
#    'l': '3681484310',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808599',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.32,
#   'amount': 2.62,
#   'cost': 8845.9584,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808600',
#    'p': '3376.30',
#    'q': '0.295',
#    'f': '3681484311',
#    'l': '3681484311',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808600',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.3,
#   'amount': 0.295,
#   'cost': 996.0085,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808601',
#    'p': '3376.28',
#    'q': '0.039',
#    'f': '3681484312',
#    'l': '3681484312',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808601',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.28,
#   'amount': 0.039,
#   'cost': 131.67492,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808602',
#    'p': '3376.27',
#    'q': '1.668',
#    'f': '3681484313',
#    'l': '3681484314',
#    'T': '1709231639693',
#    'm': True},
#   'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808602',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.27,
#   'amount': 1.668,
#   'cost': 5631.61836,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808603',
#    'p': '3376.26',
#    'q': '0.356',
#    'f': '3681484315',
#    'l': '3681484315',
#    'T': '1709231639695',
#    'm': True},
#   'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808603',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.26,
#   'amount': 0.356,
#   'cost': 1201.94856,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808604',
#    'p': '3376.20',
#    'q': '7.098',
#    'f': '3681484316',
#    'l': '3681484319',
#    'T': '1709231639695',
#    'm': True},
#   'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808604',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.2,
#   'amount': 7.098,
#   'cost': 23964.2676,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '1517808605',
#    'p': '3376.19',
#    'q': '0.373',
#    'f': '3681484320',
#    'l': '3681484321',
#    'T': '1709231639695',
#    'm': True},
#   'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '1517808605',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 3376.19,
#   'amount': 0.373,
#   'cost': 1259.31887,
#   'fee': None,
#   'fees': []}]

# %%
trades_ts[-32:-12]
# Out:
# [{'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484302',
#   'side': 'sell',
#   'price': 3376.43,
#   'amount': 0.616,
#   'cost': 2079.88088},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484303',
#   'side': 'sell',
#   'price': 3376.43,
#   'amount': 0.937,
#   'cost': 3163.71491},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484304',
#   'side': 'sell',
#   'price': 3376.42,
#   'amount': 1.0,
#   'cost': 3376.42},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484305',
#   'side': 'sell',
#   'price': 3376.42,
#   'amount': 1.62,
#   'cost': 5469.8004},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484306',
#   'side': 'sell',
#   'price': 3376.39,
#   'amount': 0.007,
#   'cost': 23.63473},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484307',
#   'side': 'sell',
#   'price': 3376.36,
#   'amount': 0.295,
#   'cost': 996.0262},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484308',
#   'side': 'sell',
#   'price': 3376.34,
#   'amount': 0.158,
#   'cost': 533.46172},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484309',
#   'side': 'sell',
#   'price': 3376.32,
#   'amount': 1.62,
#   'cost': 5469.6384},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484310',
#   'side': 'sell',
#   'price': 3376.32,
#   'amount': 1.0,
#   'cost': 3376.32},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484311',
#   'side': 'sell',
#   'price': 3376.3,
#   'amount': 0.295,
#   'cost': 996.0085},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484312',
#   'side': 'sell',
#   'price': 3376.28,
#   'amount': 0.039,
#   'cost': 131.67492},
#  {'timestamp': 1709231639693,
#   'datetime': '2024-02-29T18:33:59.693Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484313',
#   'side': 'sell',
#   'price': 3376.27,
#   'amount': 0.309,
#   'cost': 1043.26743},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484314',
#   'side': 'sell',
#   'price': 3376.27,
#   'amount': 1.359,
#   'cost': 4588.35093},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484315',
#   'side': 'sell',
#   'price': 3376.26,
#   'amount': 0.356,
#   'cost': 1201.94856},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484316',
#   'side': 'sell',
#   'price': 3376.2,
#   'amount': 1.457,
#   'cost': 4919.1234},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484317',
#   'side': 'sell',
#   'price': 3376.2,
#   'amount': 1.62,
#   'cost': 5469.444},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484318',
#   'side': 'sell',
#   'price': 3376.2,
#   'amount': 0.295,
#   'cost': 995.979},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484319',
#   'side': 'sell',
#   'price': 3376.2,
#   'amount': 3.726,
#   'cost': 12579.7212},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484320',
#   'side': 'sell',
#   'price': 3376.19,
#   'amount': 0.296,
#   'cost': 999.35224},
#  {'timestamp': 1709231639695,
#   'datetime': '2024-02-29T18:33:59.695Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3681484321',
#   'side': 'sell',
#   'price': 3376.19,
#   'amount': 0.077,
#   'cost': 259.96663}]

# %%
import requests


def fetch_all_trades(symbol, start_time, end_time):
    limit = 1000  # Maximum number of trades per request
    all_trades = []  # List to store all trades

    while True:
        url = f"https://fapi.binance.com/fapi/v1/aggTrades?symbol={symbol}&startTime={start_time}&endTime={end_time}&limit={limit}"
        response = requests.get(url)

        if response.status_code == 200:
            trades_data = response.json()
            all_trades.extend(trades_data)

            # Check if all trades are fetched
            if len(trades_data) < limit:
                break  # Exit loop if fewer trades than limit are returned

            # Update start_time for next request
            start_time = trades_data[-1]["T"]

        else:
            print(
                f"Failed to fetch trades data. Status code: {response.status_code}"
            )
            return None

    all_trades = pd.DataFrame(all_trades)
    all_trades = all_trades.drop_duplicates()
    all_trades = all_trades.to_dict(orient="records")
    return all_trades

# %%
trades_api = fetch_all_trades("ETHUSDT", 1709480580000, 1709480580000 + 60000)

# %%
len(trades_api)
# Out:
# 304

# %%
trades_api[-1]
# Out:
# {'a': 1517808606,
#  'p': '3376.20',
#  'q': '0.491',
#  'f': 3681484322,
#  'l': 3681484322,
#  'T': 1709231639840,
#  'm': False}

# %%
trades[5490]
# Out:
# {'info': {'a': '1517808606',
#   'p': '3376.20',
#   'q': '0.491',
#   'f': '3681484322',
#   'l': '3681484322',
#   'T': '1709231639840',
#   'm': False},
#  'timestamp': 1709231639840,
#  'datetime': '2024-02-29T18:33:59.840Z',
#  'symbol': 'ETH/USDT:USDT',
#  'id': '1517808606',
#  'order': None,
#  'type': None,
#  'side': 'buy',
#  'takerOrMaker': None,
#  'price': 3376.2,
#  'amount': 0.491,
#  'cost': 1657.7142,
#  'fee': None,
#  'fees': []}

# %%
import pickle

trades_ccxt_ws = pickle.load(open("../../../../../../trades_ccxt.pkl", "rb"))

# %%
len(trades_ccxt_ws)
# Out:
# 888170974

# %%
trades_ccxt_ws[0]
# Out:
# {'info': {'e': 'trade',
#   'E': 1709638563141,
#   'T': 1709638563141,
#   's': 'ETHUSDT',
#   't': 3701863556,
#   'p': '3733.67',
#   'q': '0.406',
#   'X': 'MARKET',
#   'm': False},
#  'timestamp': 1709638563141,
#  'datetime': '2024-03-05T11:36:03.141Z',
#  'symbol': 'ETH/USDT:USDT',
#  'id': '3701863556',
#  'order': None,
#  'type': None,
#  'side': 'buy',
#  'takerOrMaker': None,
#  'price': 3733.67,
#  'amount': 0.406,
#  'cost': 1515.87002,
#  'fee': None,
#  'fees': []}

# %%
from tqdm import tqdm

my_trades = []
for trade in tqdm(trades_ccxt_ws):
    if (
        trade["timestamp"] >= 1709640960000
        and trade["timestamp"] <= 1709640960000 + 60000
    ):
        my_trades.append(trade)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 888170974/888170974 [06:06<00:00, 2420443.65it/s]

# %%
len(my_trades)
# Out:
# 17945332

# %%
df = pd.DataFrame(my_trades)

# %%
df = df[
    ["timestamp", "datetime", "symbol", "id", "side", "price", "amount", "cost"]
]
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 4648

# %%
trades_ws_ccxt = df.to_dict(orient="records")

# %%
trades_ws_ccxt
# Out:
# [{'timestamp': 1709640960021,
#   'datetime': '2024-03-05T12:16:00.021Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038934',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.141,
#   'cost': 531.19071},
#  {'timestamp': 1709640960054,
#   'datetime': '2024-03-05T12:16:00.054Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038935',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.042,
#   'cost': 158.22702},
#  {'timestamp': 1709640960054,
#   'datetime': '2024-03-05T12:16:00.054Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038936',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.036,
#   'cost': 135.62316},
#  {'timestamp': 1709640960054,
#   'datetime': '2024-03-05T12:16:00.054Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038937',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.026,
#   'cost': 97.95006},
#  {'timestamp': 1709640960054,
#   'datetime': '2024-03-05T12:16:00.054Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038938',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.037,
#   'cost': 139.39047},
#  {'timestamp': 1709640960074,
#   'datetime': '2024-03-05T12:16:00.074Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038939',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.335,
#   'cost': 1262.04885},
#  {'timestamp': 1709640960105,
#   'datetime': '2024-03-05T12:16:00.105Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038940',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.4,
#   'cost': 1506.928},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038941',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.088,
#   'cost': 331.52416},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038942',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.325,
#   'cost': 1224.379},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038943',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 3.253,
#   'cost': 12255.09196},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038944',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.464,
#   'cost': 1748.03648},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038945',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.007,
#   'cost': 26.37124},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038946',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.087,
#   'cost': 327.75684},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038947',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.104,
#   'cost': 391.80128},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038948',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.055,
#   'cost': 207.2026},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038949',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.771,
#   'cost': 2904.60372},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038950',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 2.0,
#   'cost': 7534.64},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038951',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.65,
#   'cost': 2448.758},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038952',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.033,
#   'cost': 124.32156},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038953',
#   'side': 'buy',
#   'price': 3767.32,
#   'amount': 0.266,
#   'cost': 1002.10712},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038954',
#   'side': 'buy',
#   'price': 3767.33,
#   'amount': 2.0,
#   'cost': 7534.66},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038955',
#   'side': 'buy',
#   'price': 3767.33,
#   'amount': 0.006,
#   'cost': 22.60398},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038956',
#   'side': 'buy',
#   'price': 3767.33,
#   'amount': 0.3,
#   'cost': 1130.199},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038957',
#   'side': 'buy',
#   'price': 3767.33,
#   'amount': 0.61,
#   'cost': 2298.0713},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038958',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.37,
#   'cost': 1393.9158},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038959',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.34,
#   'cost': 1280.8956},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038960',
#   'side': 'buy',
#   'price': 3767.35,
#   'amount': 0.266,
#   'cost': 1002.1151},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038961',
#   'side': 'buy',
#   'price': 3767.35,
#   'amount': 0.33,
#   'cost': 1243.2255},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038962',
#   'side': 'buy',
#   'price': 3767.36,
#   'amount': 0.31,
#   'cost': 1167.8816},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038963',
#   'side': 'buy',
#   'price': 3767.4,
#   'amount': 0.266,
#   'cost': 1002.1284},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038964',
#   'side': 'buy',
#   'price': 3767.43,
#   'amount': 0.266,
#   'cost': 1002.13638},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038965',
#   'side': 'buy',
#   'price': 3767.45,
#   'amount': 0.399,
#   'cost': 1503.21255},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038966',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.266,
#   'cost': 1002.14968},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038967',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 4.092,
#   'cost': 15416.52816},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038968',
#   'side': 'buy',
#   'price': 3767.49,
#   'amount': 2.0,
#   'cost': 7534.98},
#  {'timestamp': 1709640960125,
#   'datetime': '2024-03-05T12:16:00.125Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038969',
#   'side': 'buy',
#   'price': 3767.51,
#   'amount': 0.076,
#   'cost': 286.33076},
#  {'timestamp': 1709640960211,
#   'datetime': '2024-03-05T12:16:00.211Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038970',
#   'side': 'buy',
#   'price': 3767.51,
#   'amount': 0.132,
#   'cost': 497.31132},
#  {'timestamp': 1709640960298,
#   'datetime': '2024-03-05T12:16:00.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038971',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.308,
#   'cost': 1160.39},
#  {'timestamp': 1709640960448,
#   'datetime': '2024-03-05T12:16:00.448Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038972',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.05,
#   'cost': 188.375},
#  {'timestamp': 1709640960457,
#   'datetime': '2024-03-05T12:16:00.457Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038973',
#   'side': 'buy',
#   'price': 3767.51,
#   'amount': 0.058,
#   'cost': 218.51558},
#  {'timestamp': 1709640960457,
#   'datetime': '2024-03-05T12:16:00.457Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038974',
#   'side': 'buy',
#   'price': 3767.51,
#   'amount': 1.988,
#   'cost': 7489.80988},
#  {'timestamp': 1709640960518,
#   'datetime': '2024-03-05T12:16:00.518Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038975',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.808,
#   'cost': 3044.14},
#  {'timestamp': 1709640960518,
#   'datetime': '2024-03-05T12:16:00.518Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038976',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.007,
#   'cost': 26.3725},
#  {'timestamp': 1709640960518,
#   'datetime': '2024-03-05T12:16:00.518Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038977',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.585,
#   'cost': 2203.9875},
#  {'timestamp': 1709640960527,
#   'datetime': '2024-03-05T12:16:00.527Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038978',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.205,
#   'cost': 772.3375},
#  {'timestamp': 1709640960527,
#   'datetime': '2024-03-05T12:16:00.527Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038979',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.006,
#   'cost': 22.605},
#  {'timestamp': 1709640960527,
#   'datetime': '2024-03-05T12:16:00.527Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038980',
#   'side': 'sell',
#   'price': 3767.5,
#   'amount': 0.021,
#   'cost': 79.1175},
#  {'timestamp': 1709640960527,
#   'datetime': '2024-03-05T12:16:00.527Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038981',
#   'side': 'sell',
#   'price': 3767.49,
#   'amount': 0.006,
#   'cost': 22.60494},
#  {'timestamp': 1709640960527,
#   'datetime': '2024-03-05T12:16:00.527Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038982',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.01,
#   'cost': 37.6737},
#  {'timestamp': 1709640960668,
#   'datetime': '2024-03-05T12:16:00.668Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038983',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.007,
#   'cost': 26.37159},
#  {'timestamp': 1709640960668,
#   'datetime': '2024-03-05T12:16:00.668Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038984',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.093,
#   'cost': 350.36541},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038985',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.405,
#   'cost': 1525.78485},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038986',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.013,
#   'cost': 48.97581},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038987',
#   'side': 'sell',
#   'price': 3767.37,
#   'amount': 0.12,
#   'cost': 452.0844},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038988',
#   'side': 'sell',
#   'price': 3767.36,
#   'amount': 0.007,
#   'cost': 26.37152},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038989',
#   'side': 'sell',
#   'price': 3767.36,
#   'amount': 0.006,
#   'cost': 22.60416},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038990',
#   'side': 'sell',
#   'price': 3767.34,
#   'amount': 1.759,
#   'cost': 6626.75106},
#  {'timestamp': 1709640960763,
#   'datetime': '2024-03-05T12:16:00.763Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038991',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.01,
#   'cost': 37.6733},
#  {'timestamp': 1709640960766,
#   'datetime': '2024-03-05T12:16:00.766Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038992',
#   'side': 'buy',
#   'price': 3767.33,
#   'amount': 2.5,
#   'cost': 9418.325},
#  {'timestamp': 1709640960766,
#   'datetime': '2024-03-05T12:16:00.766Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038993',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.5,
#   'cost': 1883.67},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038994',
#   'side': 'sell',
#   'price': 3767.32,
#   'amount': 0.022,
#   'cost': 82.88104},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038995',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 1.599,
#   'cost': 6023.92869},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038996',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.08,
#   'cost': 301.3848},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038997',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.342,
#   'cost': 1288.42002},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038998',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.018,
#   'cost': 67.81158},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702038999',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.08,
#   'cost': 301.3848},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039000',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.08,
#   'cost': 301.3848},
#  {'timestamp': 1709640960767,
#   'datetime': '2024-03-05T12:16:00.767Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039001',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.095,
#   'cost': 357.89445},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039002',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 1.768,
#   'cost': 6660.60408},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039003',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 2.593,
#   'cost': 9768.63483},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039004',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 2.371,
#   'cost': 8932.29201},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039005',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.023,
#   'cost': 86.64813},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039006',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.007,
#   'cost': 26.37117},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039007',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.007,
#   'cost': 26.37117},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039008',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 2.6,
#   'cost': 9795.006},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039009',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 7.118,
#   'cost': 26815.71258},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039010',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.022,
#   'cost': 82.88082},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039011',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.013,
#   'cost': 48.97503},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039012',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.066,
#   'cost': 248.64246},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039013',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.013,
#   'cost': 48.97503},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039014',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.008,
#   'cost': 30.13848},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039015',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.777,
#   'cost': 2927.19987},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039016',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 1.063,
#   'cost': 4004.65053},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039017',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.222,
#   'cost': 836.34282},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039018',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.024,
#   'cost': 90.41544},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039019',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.007,
#   'cost': 26.37117},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039020',
#   'side': 'sell',
#   'price': 3767.31,
#   'amount': 0.185,
#   'cost': 696.95235},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039021',
#   'side': 'sell',
#   'price': 3767.3,
#   'amount': 0.011,
#   'cost': 41.4403},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039022',
#   'side': 'sell',
#   'price': 3767.29,
#   'amount': 2.0,
#   'cost': 7534.58},
#  {'timestamp': 1709640960768,
#   'datetime': '2024-03-05T12:16:00.768Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039023',
#   'side': 'sell',
#   'price': 3767.29,
#   'amount': 0.01,
#   'cost': 37.6729},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039024',
#   'side': 'sell',
#   'price': 3767.29,
#   'amount': 1.73,
#   'cost': 6517.4117},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039025',
#   'side': 'sell',
#   'price': 3767.29,
#   'amount': 0.007,
#   'cost': 26.37103},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039026',
#   'side': 'sell',
#   'price': 3767.28,
#   'amount': 0.006,
#   'cost': 22.60368},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039027',
#   'side': 'sell',
#   'price': 3767.26,
#   'amount': 0.434,
#   'cost': 1634.99084},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039028',
#   'side': 'sell',
#   'price': 3767.25,
#   'amount': 0.006,
#   'cost': 22.6035},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039029',
#   'side': 'sell',
#   'price': 3767.23,
#   'amount': 0.007,
#   'cost': 26.37061},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039030',
#   'side': 'sell',
#   'price': 3767.22,
#   'amount': 0.006,
#   'cost': 22.60332},
#  {'timestamp': 1709640960771,
#   'datetime': '2024-03-05T12:16:00.771Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039031',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 1.804,
#   'cost': 6796.0288},
#  {'timestamp': 1709640960773,
#   'datetime': '2024-03-05T12:16:00.773Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039032',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 19.0,
#   'cost': 71576.8},
#  {'timestamp': 1709640960776,
#   'datetime': '2024-03-05T12:16:00.776Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039033',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 2.183,
#   'cost': 8223.7976},
#  {'timestamp': 1709640960776,
#   'datetime': '2024-03-05T12:16:00.776Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039034',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 1.19,
#   'cost': 4482.968},
#  {'timestamp': 1709640960777,
#   'datetime': '2024-03-05T12:16:00.777Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039035',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 0.823,
#   'cost': 3100.4056},
#  {'timestamp': 1709640960777,
#   'datetime': '2024-03-05T12:16:00.777Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039036',
#   'side': 'sell',
#   'price': 3767.2,
#   'amount': 0.007,
#   'cost': 26.3704},
#  {'timestamp': 1709640960783,
#   'datetime': '2024-03-05T12:16:00.783Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039037',
#   'side': 'sell',
#   'price': 3767.09,
#   'amount': 0.337,
#   'cost': 1269.50933},
#  {'timestamp': 1709640960783,
#   'datetime': '2024-03-05T12:16:00.783Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039038',
#   'side': 'sell',
#   'price': 3767.09,
#   'amount': 0.007,
#   'cost': 26.36963},
#  {'timestamp': 1709640960783,
#   'datetime': '2024-03-05T12:16:00.783Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039039',
#   'side': 'sell',
#   'price': 3767.08,
#   'amount': 0.11,
#   'cost': 414.3788},
#  {'timestamp': 1709640960804,
#   'datetime': '2024-03-05T12:16:00.804Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039040',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 17.02,
#   'cost': 64115.5314},
#  {'timestamp': 1709640960804,
#   'datetime': '2024-03-05T12:16:00.804Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039041',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.007,
#   'cost': 26.36949},
#  {'timestamp': 1709640960810,
#   'datetime': '2024-03-05T12:16:00.810Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039042',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.17,
#   'cost': 640.4019},
#  {'timestamp': 1709640960821,
#   'datetime': '2024-03-05T12:16:00.821Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039043',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.7,
#   'cost': 2636.949},
#  {'timestamp': 1709640960824,
#   'datetime': '2024-03-05T12:16:00.824Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039044',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 2.0,
#   'cost': 7534.14},
#  {'timestamp': 1709640960987,
#   'datetime': '2024-03-05T12:16:00.987Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039045',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 2.553,
#   'cost': 9617.35524},
#  {'timestamp': 1709640960987,
#   'datetime': '2024-03-05T12:16:00.987Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039046',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 1.816,
#   'cost': 6841.01728},
#  {'timestamp': 1709640961259,
#   'datetime': '2024-03-05T12:16:01.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039047',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.4,
#   'cost': 1506.828},
#  {'timestamp': 1709640961263,
#   'datetime': '2024-03-05T12:16:01.263Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039048',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 1.8,
#   'cost': 6780.726},
#  {'timestamp': 1709640961264,
#   'datetime': '2024-03-05T12:16:01.264Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039049',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.001,
#   'cost': 3.76707},
#  {'timestamp': 1709640961309,
#   'datetime': '2024-03-05T12:16:01.309Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039050',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.007,
#   'cost': 26.36956},
#  {'timestamp': 1709640961309,
#   'datetime': '2024-03-05T12:16:01.309Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039051',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.464,
#   'cost': 1747.92512},
#  {'timestamp': 1709640961309,
#   'datetime': '2024-03-05T12:16:01.309Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039052',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.191,
#   'cost': 719.51228},
#  {'timestamp': 1709640961394,
#   'datetime': '2024-03-05T12:16:01.394Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039053',
#   'side': 'sell',
#   'price': 3767.07,
#   'amount': 0.004,
#   'cost': 15.06828},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039054',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 2.768,
#   'cost': 10427.27744},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039055',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.02,
#   'cost': 75.3416},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039056',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.488,
#   'cost': 1838.33504},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039057',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.134,
#   'cost': 504.78872},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039058',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.017,
#   'cost': 64.04036},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039059',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.163,
#   'cost': 614.03404},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039060',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.006,
#   'cost': 22.60248},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039061',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.315,
#   'cost': 1186.6302},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039062',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.084,
#   'cost': 316.43472},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039063',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.885,
#   'cost': 3333.8658},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039064',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.043,
#   'cost': 161.98444},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039065',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.464,
#   'cost': 1747.92512},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039066',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.007,
#   'cost': 26.36956},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039067',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 0.514,
#   'cost': 1936.27912},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039068',
#   'side': 'buy',
#   'price': 3767.08,
#   'amount': 2.0,
#   'cost': 7534.16},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039069',
#   'side': 'buy',
#   'price': 3767.09,
#   'amount': 0.846,
#   'cost': 3186.95814},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039070',
#   'side': 'buy',
#   'price': 3767.09,
#   'amount': 0.006,
#   'cost': 22.60254},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039071',
#   'side': 'buy',
#   'price': 3767.16,
#   'amount': 0.266,
#   'cost': 1002.06456},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039072',
#   'side': 'buy',
#   'price': 3767.24,
#   'amount': 0.266,
#   'cost': 1002.08584},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039073',
#   'side': 'buy',
#   'price': 3767.26,
#   'amount': 4.843,
#   'cost': 18244.84018},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039074',
#   'side': 'buy',
#   'price': 3767.27,
#   'amount': 4.5,
#   'cost': 16952.715},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039075',
#   'side': 'buy',
#   'price': 3767.27,
#   'amount': 4.5,
#   'cost': 16952.715},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039076',
#   'side': 'buy',
#   'price': 3767.27,
#   'amount': 4.5,
#   'cost': 16952.715},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039077',
#   'side': 'buy',
#   'price': 3767.29,
#   'amount': 0.006,
#   'cost': 22.60374},
#  {'timestamp': 1709640961517,
#   'datetime': '2024-03-05T12:16:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039078',
#   'side': 'buy',
#   'price': 3767.31,
#   'amount': 1.0,
#   'cost': 3767.31},
#  {'timestamp': 1709640961528,
#   'datetime': '2024-03-05T12:16:01.528Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039079',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.047,
#   'cost': 177.06498},
#  {'timestamp': 1709640961528,
#   'datetime': '2024-03-05T12:16:01.528Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039080',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.01,
#   'cost': 37.6734},
#  {'timestamp': 1709640961539,
#   'datetime': '2024-03-05T12:16:01.539Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039081',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 1.061,
#   'cost': 3997.14774},
#  {'timestamp': 1709640961586,
#   'datetime': '2024-03-05T12:16:01.586Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039082',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.882,
#   'cost': 3322.79388},
#  {'timestamp': 1709640961586,
#   'datetime': '2024-03-05T12:16:01.586Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039083',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.007,
#   'cost': 26.37138},
#  {'timestamp': 1709640961586,
#   'datetime': '2024-03-05T12:16:01.586Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039084',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.488,
#   'cost': 1838.46192},
#  {'timestamp': 1709640961586,
#   'datetime': '2024-03-05T12:16:01.586Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039085',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.464,
#   'cost': 1748.04576},
#  {'timestamp': 1709640961586,
#   'datetime': '2024-03-05T12:16:01.586Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039086',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.113,
#   'cost': 425.70942},
#  {'timestamp': 1709640961597,
#   'datetime': '2024-03-05T12:16:01.597Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039087',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.4,
#   'cost': 1506.932},
#  {'timestamp': 1709640961597,
#   'datetime': '2024-03-05T12:16:01.597Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039088',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.4,
#   'cost': 1506.932},
#  {'timestamp': 1709640961691,
#   'datetime': '2024-03-05T12:16:01.691Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039089',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.4,
#   'cost': 1506.932},
#  {'timestamp': 1709640961913,
#   'datetime': '2024-03-05T12:16:01.913Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039090',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.019,
#   'cost': 71.57946},
#  {'timestamp': 1709640962049,
#   'datetime': '2024-03-05T12:16:02.049Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039091',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.181,
#   'cost': 681.88854},
#  {'timestamp': 1709640962085,
#   'datetime': '2024-03-05T12:16:02.085Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039092',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.007,
#   'cost': 26.37131},
#  {'timestamp': 1709640962085,
#   'datetime': '2024-03-05T12:16:02.085Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039093',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.019,
#   'cost': 71.57927},
#  {'timestamp': 1709640962202,
#   'datetime': '2024-03-05T12:16:02.202Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039094',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.077,
#   'cost': 290.08518},
#  {'timestamp': 1709640962322,
#   'datetime': '2024-03-05T12:16:02.322Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039095',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 1.981,
#   'cost': 7463.08073},
#  {'timestamp': 1709640962322,
#   'datetime': '2024-03-05T12:16:02.322Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039096',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.019,
#   'cost': 71.57927},
#  {'timestamp': 1709640962351,
#   'datetime': '2024-03-05T12:16:02.351Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039097',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.343,
#   'cost': 1292.19762},
#  {'timestamp': 1709640962433,
#   'datetime': '2024-03-05T12:16:02.433Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039098',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.017,
#   'cost': 64.04461},
#  {'timestamp': 1709640962550,
#   'datetime': '2024-03-05T12:16:02.550Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039099',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 1.267,
#   'cost': 4773.21978},
#  {'timestamp': 1709640962550,
#   'datetime': '2024-03-05T12:16:02.550Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039100',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.464,
#   'cost': 1748.04576},
#  {'timestamp': 1709640962550,
#   'datetime': '2024-03-05T12:16:02.550Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039101',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.488,
#   'cost': 1838.46192},
#  {'timestamp': 1709640962550,
#   'datetime': '2024-03-05T12:16:02.550Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039102',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.057,
#   'cost': 214.73838},
#  {'timestamp': 1709640962558,
#   'datetime': '2024-03-05T12:16:02.558Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039103',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.265,
#   'cost': 998.34245},
#  {'timestamp': 1709640962562,
#   'datetime': '2024-03-05T12:16:02.562Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039104',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.5,
#   'cost': 1883.665},
#  {'timestamp': 1709640962598,
#   'datetime': '2024-03-05T12:16:02.598Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039105',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 1.187,
#   'cost': 4471.82071},
#  {'timestamp': 1709640962598,
#   'datetime': '2024-03-05T12:16:02.598Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039106',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 2.0,
#   'cost': 7534.66},
#  {'timestamp': 1709640962598,
#   'datetime': '2024-03-05T12:16:02.598Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039107',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 1.813,
#   'cost': 6830.16929},
#  {'timestamp': 1709640962798,
#   'datetime': '2024-03-05T12:16:02.798Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039108',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.187,
#   'cost': 704.49071},
#  {'timestamp': 1709640962798,
#   'datetime': '2024-03-05T12:16:02.798Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039109',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.006,
#   'cost': 22.60398},
#  {'timestamp': 1709640962798,
#   'datetime': '2024-03-05T12:16:02.798Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039110',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.164,
#   'cost': 617.84212},
#  {'timestamp': 1709640962798,
#   'datetime': '2024-03-05T12:16:02.798Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039111',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.023,
#   'cost': 86.64859},
#  {'timestamp': 1709640962798,
#   'datetime': '2024-03-05T12:16:02.798Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039112',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.12,
#   'cost': 452.0796},
#  {'timestamp': 1709640962823,
#   'datetime': '2024-03-05T12:16:02.823Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039113',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.139,
#   'cost': 523.65887},
#  {'timestamp': 1709640962847,
#   'datetime': '2024-03-05T12:16:02.847Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039114',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.349,
#   'cost': 1314.79817},
#  {'timestamp': 1709640962961,
#   'datetime': '2024-03-05T12:16:02.961Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039115',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.143,
#   'cost': 538.72819},
#  {'timestamp': 1709640962961,
#   'datetime': '2024-03-05T12:16:02.961Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039116',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.133,
#   'cost': 501.05489},
#  {'timestamp': 1709640963015,
#   'datetime': '2024-03-05T12:16:03.015Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039117',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.01,
#   'cost': 37.6733},
#  {'timestamp': 1709640963026,
#   'datetime': '2024-03-05T12:16:03.026Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039118',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.299,
#   'cost': 1126.43167},
#  {'timestamp': 1709640963057,
#   'datetime': '2024-03-05T12:16:03.057Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039119',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.104,
#   'cost': 391.80232},
#  {'timestamp': 1709640963166,
#   'datetime': '2024-03-05T12:16:03.166Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039120',
#   'side': 'sell',
#   'price': 3767.33,
#   'amount': 0.108,
#   'cost': 406.87164},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039121',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.464,
#   'cost': 1748.04576},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039122',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.488,
#   'cost': 1838.46192},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039123',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 2.0,
#   'cost': 7534.68},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039124',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.136,
#   'cost': 512.35824},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039125',
#   'side': 'buy',
#   'price': 3767.34,
#   'amount': 0.067,
#   'cost': 252.41178},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039126',
#   'side': 'buy',
#   'price': 3767.35,
#   'amount': 0.006,
#   'cost': 22.6041},
#  {'timestamp': 1709640963216,
#   'datetime': '2024-03-05T12:16:03.216Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039127',
#   'side': 'buy',
#   'price': 3767.36,
#   'amount': 0.01,
#   'cost': 37.6736},
#  {'timestamp': 1709640963218,
#   'datetime': '2024-03-05T12:16:03.218Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039128',
#   'side': 'buy',
#   'price': 3767.36,
#   'amount': 0.021,
#   'cost': 79.11456},
#  {'timestamp': 1709640963218,
#   'datetime': '2024-03-05T12:16:03.218Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039129',
#   'side': 'buy',
#   'price': 3767.39,
#   'amount': 0.027,
#   'cost': 101.71953},
#  {'timestamp': 1709640963219,
#   'datetime': '2024-03-05T12:16:03.219Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039130',
#   'side': 'buy',
#   'price': 3767.43,
#   'amount': 0.007,
#   'cost': 26.37201},
#  {'timestamp': 1709640963219,
#   'datetime': '2024-03-05T12:16:03.219Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039131',
#   'side': 'buy',
#   'price': 3767.43,
#   'amount': 1.211,
#   'cost': 4562.35773},
#  {'timestamp': 1709640963219,
#   'datetime': '2024-03-05T12:16:03.219Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039132',
#   'side': 'buy',
#   'price': 3767.44,
#   'amount': 0.399,
#   'cost': 1503.20856},
#  {'timestamp': 1709640963219,
#   'datetime': '2024-03-05T12:16:03.219Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039133',
#   'side': 'buy',
#   'price': 3767.45,
#   'amount': 0.006,
#   'cost': 22.6047},
#  {'timestamp': 1709640963219,
#   'datetime': '2024-03-05T12:16:03.219Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039134',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.053,
#   'cost': 199.67644},
#  {'timestamp': 1709640963287,
#   'datetime': '2024-03-05T12:16:03.287Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039135',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.05,
#   'cost': 188.3735},
#  {'timestamp': 1709640963397,
#   'datetime': '2024-03-05T12:16:03.397Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039136',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.007,
#   'cost': 26.37236},
#  {'timestamp': 1709640963397,
#   'datetime': '2024-03-05T12:16:03.397Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039137',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.993,
#   'cost': 3741.10764},
#  {'timestamp': 1709640963510,
#   'datetime': '2024-03-05T12:16:03.510Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039138',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.362,
#   'cost': 1363.82414},
#  {'timestamp': 1709640963547,
#   'datetime': '2024-03-05T12:16:03.547Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039139',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.026,
#   'cost': 97.95422},
#  {'timestamp': 1709640963609,
#   'datetime': '2024-03-05T12:16:03.609Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039140',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.1,
#   'cost': 376.747},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039141',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.007,
#   'cost': 26.37236},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039142',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.464,
#   'cost': 1748.11072},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039143',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.488,
#   'cost': 1838.53024},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039144',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.266,
#   'cost': 1002.14968},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039145',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.052,
#   'cost': 195.90896},
#  {'timestamp': 1709640963993,
#   'datetime': '2024-03-05T12:16:03.993Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039146',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.942,
#   'cost': 3548.96616},
#  {'timestamp': 1709640964237,
#   'datetime': '2024-03-05T12:16:04.237Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039147',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.305,
#   'cost': 1149.0814},
#  {'timestamp': 1709640964331,
#   'datetime': '2024-03-05T12:16:04.331Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039148',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.213,
#   'cost': 802.47111},
#  {'timestamp': 1709640964434,
#   'datetime': '2024-03-05T12:16:04.434Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039149',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.007,
#   'cost': 26.37236},
#  {'timestamp': 1709640964549,
#   'datetime': '2024-03-05T12:16:04.549Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039150',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.002,
#   'cost': 7.53494},
#  {'timestamp': 1709640964748,
#   'datetime': '2024-03-05T12:16:04.748Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039151',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 1.781,
#   'cost': 6709.88188},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039152',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 2.327,
#   'cost': 8766.90269},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039153',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 1.559,
#   'cost': 5873.48573},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039154',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.007,
#   'cost': 26.37229},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039155',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.007,
#   'cost': 26.37229},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039156',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.055,
#   'cost': 207.21085},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039157',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.08,
#   'cost': 301.3976},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039158',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.08,
#   'cost': 301.3976},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039159',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.08,
#   'cost': 301.3976},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039160',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.08,
#   'cost': 301.3976},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039161',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 2.0,
#   'cost': 7534.94},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039162',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 2.0,
#   'cost': 7534.94},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039163',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 2.0,
#   'cost': 7534.94},
#  {'timestamp': 1709640964752,
#   'datetime': '2024-03-05T12:16:04.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039164',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 1.144,
#   'cost': 4309.98568},
#  {'timestamp': 1709640964761,
#   'datetime': '2024-03-05T12:16:04.761Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039165',
#   'side': 'sell',
#   'price': 3767.47,
#   'amount': 0.079,
#   'cost': 297.63013},
#  {'timestamp': 1709640964894,
#   'datetime': '2024-03-05T12:16:04.894Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039166',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.032,
#   'cost': 120.55936},
#  {'timestamp': 1709640965091,
#   'datetime': '2024-03-05T12:16:05.091Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039167',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.03,
#   'cost': 113.0244},
#  {'timestamp': 1709640965184,
#   'datetime': '2024-03-05T12:16:05.184Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039168',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 2.636,
#   'cost': 9931.07728},
#  {'timestamp': 1709640965184,
#   'datetime': '2024-03-05T12:16:05.184Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039169',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.009,
#   'cost': 33.90732},
#  {'timestamp': 1709640965184,
#   'datetime': '2024-03-05T12:16:05.184Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039170',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.021,
#   'cost': 79.11708},
#  {'timestamp': 1709640965184,
#   'datetime': '2024-03-05T12:16:05.184Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039171',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.12,
#   'cost': 452.0976},
#  {'timestamp': 1709640965184,
#   'datetime': '2024-03-05T12:16:05.184Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039172',
#   'side': 'buy',
#   'price': 3767.48,
#   'amount': 0.057,
#   'cost': 214.74636},
# ...
#   'id': '3702039854',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.797,
#   'cost': 3001.94832},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039855',
#   'side': 'sell',
#   'price': 3766.55,
#   'amount': 0.266,
#   'cost': 1001.9023},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039856',
#   'side': 'sell',
#   'price': 3766.54,
#   'amount': 0.149,
#   'cost': 561.21446},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039857',
#   'side': 'sell',
#   'price': 3766.54,
#   'amount': 0.048,
#   'cost': 180.79392},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039858',
#   'side': 'sell',
#   'price': 3766.54,
#   'amount': 0.069,
#   'cost': 259.89126},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039859',
#   'side': 'sell',
#   'price': 3766.54,
#   'amount': 1.17,
#   'cost': 4406.8518},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039860',
#   'side': 'sell',
#   'price': 3766.53,
#   'amount': 0.266,
#   'cost': 1001.89698},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039861',
#   'side': 'sell',
#   'price': 3766.53,
#   'amount': 0.531,
#   'cost': 2000.02743},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039862',
#   'side': 'sell',
#   'price': 3766.53,
#   'amount': 0.531,
#   'cost': 2000.02743},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039863',
#   'side': 'sell',
#   'price': 3766.52,
#   'amount': 2.123,
#   'cost': 7996.32196},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039864',
#   'side': 'sell',
#   'price': 3766.51,
#   'amount': 0.407,
#   'cost': 1532.96957},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039865',
#   'side': 'sell',
#   'price': 3766.5,
#   'amount': 0.006,
#   'cost': 22.599},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039866',
#   'side': 'sell',
#   'price': 3766.5,
#   'amount': 0.006,
#   'cost': 22.599},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039867',
#   'side': 'sell',
#   'price': 3766.5,
#   'amount': 0.796,
#   'cost': 2998.134},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039868',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.006,
#   'cost': 22.59888},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039869',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 3.986,
#   'cost': 15013.18928},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039870',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 1.028,
#   'cost': 3871.94144},
#  {'timestamp': 1709640975298,
#   'datetime': '2024-03-05T12:16:15.298Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039871',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.499,
#   'cost': 1879.47352},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039872',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.076,
#   'cost': 286.25248},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039873',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 1.292,
#   'cost': 4866.29216},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039874',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.494,
#   'cost': 1860.64112},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039875',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.098,
#   'cost': 369.11504},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039876',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.025,
#   'cost': 94.162},
#  {'timestamp': 1709640975299,
#   'datetime': '2024-03-05T12:16:15.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039877',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.148,
#   'cost': 557.43904},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039878',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.115,
#   'cost': 433.1452},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039879',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.115,
#   'cost': 433.1452},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039880',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.166,
#   'cost': 625.23568},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039881',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 1.979,
#   'cost': 7453.86392},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039882',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.115,
#   'cost': 433.1452},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039883',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.494,
#   'cost': 1860.64112},
#  {'timestamp': 1709640975300,
#   'datetime': '2024-03-05T12:16:15.300Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039884',
#   'side': 'sell',
#   'price': 3766.48,
#   'amount': 0.112,
#   'cost': 421.84576},
#  {'timestamp': 1709640975306,
#   'datetime': '2024-03-05T12:16:15.306Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039885',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.008,
#   'cost': 30.1316},
#  {'timestamp': 1709640975366,
#   'datetime': '2024-03-05T12:16:15.366Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039886',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.007,
#   'cost': 26.36515},
#  {'timestamp': 1709640975366,
#   'datetime': '2024-03-05T12:16:15.366Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039887',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.258,
#   'cost': 971.7441},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039888',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.007,
#   'cost': 26.36515},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039889',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.02,
#   'cost': 75.329},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039890',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.544,
#   'cost': 2048.9488},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039891',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.006,
#   'cost': 22.5987},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039892',
#   'side': 'buy',
#   'price': 3766.66,
#   'amount': 0.266,
#   'cost': 1001.93156},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039893',
#   'side': 'buy',
#   'price': 3766.7,
#   'amount': 0.006,
#   'cost': 22.6002},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039894',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 1.13,
#   'cost': 4256.3936},
#  {'timestamp': 1709640975419,
#   'datetime': '2024-03-05T12:16:15.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039895',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 0.01,
#   'cost': 37.6672},
#  {'timestamp': 1709640975598,
#   'datetime': '2024-03-05T12:16:15.598Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039896',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 0.296,
#   'cost': 1114.94912},
#  {'timestamp': 1709640975630,
#   'datetime': '2024-03-05T12:16:15.630Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039897',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 0.564,
#   'cost': 2124.43008},
#  {'timestamp': 1709640975630,
#   'datetime': '2024-03-05T12:16:15.630Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039898',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 1.304,
#   'cost': 4911.80288},
#  {'timestamp': 1709640975752,
#   'datetime': '2024-03-05T12:16:15.752Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039899',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.358,
#   'cost': 1348.48218},
#  {'timestamp': 1709640975911,
#   'datetime': '2024-03-05T12:16:15.911Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039900',
#   'side': 'buy',
#   'price': 3766.72,
#   'amount': 0.302,
#   'cost': 1137.54944},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039901',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.007,
#   'cost': 26.36697},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039902',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.053,
#   'cost': 199.63563},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039903',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.025,
#   'cost': 94.16775},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039904',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.052,
#   'cost': 195.86892},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039905',
#   'side': 'sell',
#   'price': 3766.71,
#   'amount': 0.065,
#   'cost': 244.83615},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039906',
#   'side': 'sell',
#   'price': 3766.7,
#   'amount': 0.006,
#   'cost': 22.6002},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039907',
#   'side': 'sell',
#   'price': 3766.68,
#   'amount': 0.006,
#   'cost': 22.60008},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039908',
#   'side': 'sell',
#   'price': 3766.6,
#   'amount': 0.133,
#   'cost': 500.9578},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039909',
#   'side': 'sell',
#   'price': 3766.57,
#   'amount': 0.649,
#   'cost': 2444.50393},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039910',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.804,
#   'cost': 3028.31424},
#  {'timestamp': 1709640976208,
#   'datetime': '2024-03-05T12:16:16.208Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039911',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.01,
#   'cost': 37.6656},
#  {'timestamp': 1709640976209,
#   'datetime': '2024-03-05T12:16:16.209Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039912',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 0.182,
#   'cost': 685.51574},
#  {'timestamp': 1709640976209,
#   'datetime': '2024-03-05T12:16:16.209Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039913',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 1.126,
#   'cost': 4241.15782},
#  {'timestamp': 1709640976212,
#   'datetime': '2024-03-05T12:16:16.212Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039914',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 0.156,
#   'cost': 587.58492},
#  {'timestamp': 1709640976214,
#   'datetime': '2024-03-05T12:16:16.214Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039915',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 0.013,
#   'cost': 48.96541},
#  {'timestamp': 1709640976246,
#   'datetime': '2024-03-05T12:16:16.246Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039916',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 0.013,
#   'cost': 48.96541},
#  {'timestamp': 1709640976299,
#   'datetime': '2024-03-05T12:16:16.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039917',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.007,
#   'cost': 26.36592},
#  {'timestamp': 1709640976299,
#   'datetime': '2024-03-05T12:16:16.299Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039918',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.013,
#   'cost': 48.96528},
#  {'timestamp': 1709640976305,
#   'datetime': '2024-03-05T12:16:16.305Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039919',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.007,
#   'cost': 26.36592},
#  {'timestamp': 1709640976317,
#   'datetime': '2024-03-05T12:16:16.317Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039920',
#   'side': 'buy',
#   'price': 3766.57,
#   'amount': 0.006,
#   'cost': 22.59942},
#  {'timestamp': 1709640976358,
#   'datetime': '2024-03-05T12:16:16.358Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039921',
#   'side': 'sell',
#   'price': 3766.56,
#   'amount': 0.007,
#   'cost': 26.36592},
#  {'timestamp': 1709640976358,
#   'datetime': '2024-03-05T12:16:16.358Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039922',
#   'side': 'sell',
#   'price': 3766.55,
#   'amount': 0.006,
#   'cost': 22.5993},
#  {'timestamp': 1709640976358,
#   'datetime': '2024-03-05T12:16:16.358Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039923',
#   'side': 'sell',
#   'price': 3766.5,
#   'amount': 0.01,
#   'cost': 37.665},
#  {'timestamp': 1709640976358,
#   'datetime': '2024-03-05T12:16:16.358Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039924',
#   'side': 'sell',
#   'price': 3766.5,
#   'amount': 0.006,
#   'cost': 22.599},
#  {'timestamp': 1709640976358,
#   'datetime': '2024-03-05T12:16:16.358Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039925',
#   'side': 'sell',
#   'price': 3766.46,
#   'amount': 0.241,
#   'cost': 907.71686},
#  {'timestamp': 1709640976360,
#   'datetime': '2024-03-05T12:16:16.360Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039926',
#   'side': 'buy',
#   'price': 3766.46,
#   'amount': 0.038,
#   'cost': 143.12548},
#  {'timestamp': 1709640976365,
#   'datetime': '2024-03-05T12:16:16.365Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039927',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 2.279,
#   'cost': 8583.73955},
#  {'timestamp': 1709640976366,
#   'datetime': '2024-03-05T12:16:16.366Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039928',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.02,
#   'cost': 75.329},
#  {'timestamp': 1709640976419,
#   'datetime': '2024-03-05T12:16:16.419Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039929',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.414,
#   'cost': 1559.3103},
#  {'timestamp': 1709640976430,
#   'datetime': '2024-03-05T12:16:16.430Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039930',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.007,
#   'cost': 26.36515},
#  {'timestamp': 1709640976507,
#   'datetime': '2024-03-05T12:16:16.507Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039931',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 2.039,
#   'cost': 7679.79155},
#  {'timestamp': 1709640976510,
#   'datetime': '2024-03-05T12:16:16.510Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039932',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.215,
#   'cost': 809.78675},
#  {'timestamp': 1709640976525,
#   'datetime': '2024-03-05T12:16:16.525Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3702039933',
#   'side': 'buy',
#   'price': 3766.45,
#   'amount': 0.815,
#   'cost': 3069.65675},
#  ...]

# %%
df_full = pd.read_csv("../../../../../../trades_data_ws_binance.csv")

# %%
df_full
# Out:
#         Unnamed: 0      e              E              T        s           t  \
# 0                0  trade  1709638481972  1709638481971  ETHUSDT  3701858304
# 1                1  trade  1709638481972  1709638481972  ETHUSDT  3701858305
# 2                2  trade  1709638481974  1709638481973  ETHUSDT  3701858306
# 3                3  trade  1709638481974  1709638481973  ETHUSDT  3701858307
# 4                4  trade  1709638481974  1709638481973  ETHUSDT  3701858308
# ...            ...    ...            ...            ...      ...         ...
# 286701      286701  trade  1709642486413  1709642486412  ETHUSDT  3702145005
# 286702      286702  trade  1709642486490  1709642486490  ETHUSDT  3702145006
# 286703      286703  trade  1709642486646  1709642486646  ETHUSDT  3702145007
# 286704      286704  trade  1709642486646  1709642486646  ETHUSDT  3702145008
# 286705      286705  trade  1709642486671  1709642486670  ETHUSDT  3702145009
#
#               p      q       X      m
# 0       3735.58  1.550  MARKET  False
# 1       3735.57  0.010  MARKET   True
# 2       3735.57  0.049  MARKET   True
# 3       3735.57  0.007  MARKET   True
# 4       3735.57  0.007  MARKET   True
# ...         ...    ...     ...    ...
# 286701  3761.14  0.946  MARKET   True
# 286702  3761.15  1.000  MARKET  False
# 286703  3761.15  0.007  MARKET  False
# 286704  3761.15  1.473  MARKET  False
# 286705  3761.14  0.027  MARKET   True
#
# [286706 rows x 10 columns]

# %%
df = df_full[
    ((df_full["T"] >= 1709640960000) & (df_full["T"] <= (1709640960000 + 60000)))
]

# %%
len(df)
# Out:
# 4648

# %%
df["timestamp"] = df["T"]
df["id"] = df["t"]
df["price"] = df["p"]
df["amount"] = df["q"]

# %%
trades_ws_binance = df.to_dict(orient="records")

# %%
ccxt_exchange.build_ohlcvc(trades_ws_binance)
# Out:
# [[1709640960000, 3767.31, 7042.67, 3762.46, 3764.32, 2475.4780000000233, 4648]]

# %%
ccxt_exchange.build_ohlcvc(trades_ws_ccxt)
# Out:
# [[1709640960000, 3767.31, 7042.67, 3762.46, 3764.32, 2475.4780000000233, 4648]]

# %%
for trade in trades_ws_ccxt:
    if trade["price"] == 7042.67:
        print(trade)
# Out:
# {'timestamp': 1709640988575, 'datetime': '2024-03-05T12:16:28.575Z', 'symbol': 'ETH/USDT:USDT', 'id': '3702041010', 'side': 'sell', 'price': 7042.67, 'amount': 0.002, 'cost': 14.08534}

# %%
536.6359999999945 - 536.5779999999986
# Out:
# 0.0579999999959

# %%
def found_trade_id(id):
    for trade in trades_ws_binance:
        if trade["l"] >= id and trade["f"] <= id:
            return True
    return False

# %%
for id in range(3691724382, 3691725689 + 1):
    if not found_trade_id(id):
        print(id)
# Out:
# 3691725522

# %%
trades_ws_ccxt
# Out:
# [{'timestamp': 1709480580478,
#   'datetime': '2024-03-03T15:43:00.478Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724382',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 3.455,
#   'cost': 11857.4909},
#  {'timestamp': 1709480580702,
#   'datetime': '2024-03-03T15:43:00.702Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724383',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.016,
#   'cost': 54.91168},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724384',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 3.496,
#   'cost': 11998.20208},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724385',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 5.0,
#   'cost': 17159.9},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724386',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.732,
#   'cost': 2512.20936},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724387',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 1.819,
#   'cost': 6242.77162},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724388',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.437,
#   'cost': 1499.77526},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724389',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 2.0,
#   'cost': 6863.96},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724390',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 17.28,
#   'cost': 59304.6144},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724391',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 6.0,
#   'cost': 20591.88},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724392',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 5.832,
#   'cost': 20015.30736},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724393',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 20.478,
#   'cost': 70280.08644},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724394',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 4.429,
#   'cost': 15200.23942},
#  {'timestamp': 1709480580712,
#   'datetime': '2024-03-03T15:43:00.712Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724395',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.492,
#   'cost': 1688.53416},
#  {'timestamp': 1709480580803,
#   'datetime': '2024-03-03T15:43:00.803Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724396',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.021,
#   'cost': 72.07158},
#  {'timestamp': 1709480580912,
#   'datetime': '2024-03-03T15:43:00.912Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724397',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.007,
#   'cost': 24.02386},
#  {'timestamp': 1709480580914,
#   'datetime': '2024-03-03T15:43:00.914Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724398',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.06,
#   'cost': 205.9188},
#  {'timestamp': 1709480581012,
#   'datetime': '2024-03-03T15:43:01.012Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724399',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.01,
#   'cost': 34.3198},
#  {'timestamp': 1709480581013,
#   'datetime': '2024-03-03T15:43:01.013Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724400',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.039,
#   'cost': 133.84722},
#  {'timestamp': 1709480581014,
#   'datetime': '2024-03-03T15:43:01.014Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724401',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.007,
#   'cost': 24.02386},
#  {'timestamp': 1709480581243,
#   'datetime': '2024-03-03T15:43:01.243Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724402',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 1.57,
#   'cost': 5388.2243},
#  {'timestamp': 1709480581517,
#   'datetime': '2024-03-03T15:43:01.517Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724403',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.011,
#   'cost': 37.75178},
#  {'timestamp': 1709480581797,
#   'datetime': '2024-03-03T15:43:01.797Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724404',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 3.713,
#   'cost': 12742.94174},
#  {'timestamp': 1709480581797,
#   'datetime': '2024-03-03T15:43:01.797Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724405',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.616,
#   'cost': 2114.09968},
#  {'timestamp': 1709480582211,
#   'datetime': '2024-03-03T15:43:02.211Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724406',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.291,
#   'cost': 998.70618},
#  {'timestamp': 1709480582412,
#   'datetime': '2024-03-03T15:43:02.412Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724407',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.088,
#   'cost': 302.01512},
#  {'timestamp': 1709480582772,
#   'datetime': '2024-03-03T15:43:02.772Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724408',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.016,
#   'cost': 54.91168},
#  {'timestamp': 1709480582872,
#   'datetime': '2024-03-03T15:43:02.872Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724409',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.022,
#   'cost': 75.50356},
#  {'timestamp': 1709480582975,
#   'datetime': '2024-03-03T15:43:02.975Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724410',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.04,
#   'cost': 137.2792},
#  {'timestamp': 1709480582975,
#   'datetime': '2024-03-03T15:43:02.975Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724411',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.056,
#   'cost': 192.19088},
#  {'timestamp': 1709480582976,
#   'datetime': '2024-03-03T15:43:02.976Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724412',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.009,
#   'cost': 30.88782},
#  {'timestamp': 1709480583459,
#   'datetime': '2024-03-03T15:43:03.459Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724413',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.5,
#   'cost': 1715.995},
#  {'timestamp': 1709480583588,
#   'datetime': '2024-03-03T15:43:03.588Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724414',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.01,
#   'cost': 34.3198},
#  {'timestamp': 1709480584378,
#   'datetime': '2024-03-03T15:43:04.378Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724415',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.179,
#   'cost': 614.32442},
#  {'timestamp': 1709480584720,
#   'datetime': '2024-03-03T15:43:04.720Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724416',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.015,
#   'cost': 51.4797},
#  {'timestamp': 1709480584786,
#   'datetime': '2024-03-03T15:43:04.786Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724417',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.495,
#   'cost': 1698.8301},
#  {'timestamp': 1709480584827,
#   'datetime': '2024-03-03T15:43:04.827Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724418',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.022,
#   'cost': 75.50356},
#  {'timestamp': 1709480584916,
#   'datetime': '2024-03-03T15:43:04.916Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724419',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 1.048,
#   'cost': 3596.71504},
#  {'timestamp': 1709480584927,
#   'datetime': '2024-03-03T15:43:04.927Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724420',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.036,
#   'cost': 123.55128},
#  {'timestamp': 1709480584927,
#   'datetime': '2024-03-03T15:43:04.927Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724421',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.058,
#   'cost': 199.05484},
#  {'timestamp': 1709480585031,
#   'datetime': '2024-03-03T15:43:05.031Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724422',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.009,
#   'cost': 30.88782},
#  {'timestamp': 1709480585056,
#   'datetime': '2024-03-03T15:43:05.056Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724423',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.006,
#   'cost': 20.59194},
#  {'timestamp': 1709480585089,
#   'datetime': '2024-03-03T15:43:05.089Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724424',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.552,
#   'cost': 1894.45296},
#  {'timestamp': 1709480585391,
#   'datetime': '2024-03-03T15:43:05.391Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724425',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.086,
#   'cost': 295.15028},
#  {'timestamp': 1709480585546,
#   'datetime': '2024-03-03T15:43:05.546Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724426',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.01,
#   'cost': 34.3198},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724427',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.277,
#   'cost': 950.65846},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724428',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.092,
#   'cost': 315.74216},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724429',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.509,
#   'cost': 1746.87782},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724430',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.012,
#   'cost': 41.18376},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724431',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.09,
#   'cost': 308.8782},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724432',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.291,
#   'cost': 998.70618},
#  {'timestamp': 1709480585715,
#   'datetime': '2024-03-03T15:43:05.715Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724433',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 6.942,
#   'cost': 23824.80516},
#  {'timestamp': 1709480586458,
#   'datetime': '2024-03-03T15:43:06.458Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724434',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.322,
#   'cost': 1105.09756},
#  {'timestamp': 1709480586731,
#   'datetime': '2024-03-03T15:43:06.731Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724435',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.016,
#   'cost': 54.91168},
#  {'timestamp': 1709480586882,
#   'datetime': '2024-03-03T15:43:06.882Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724436',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.059,
#   'cost': 202.48682},
#  {'timestamp': 1709480586883,
#   'datetime': '2024-03-03T15:43:06.883Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724437',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.022,
#   'cost': 75.50356},
#  {'timestamp': 1709480586992,
#   'datetime': '2024-03-03T15:43:06.992Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724438',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.008,
#   'cost': 27.45584},
#  {'timestamp': 1709480586995,
#   'datetime': '2024-03-03T15:43:06.995Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724439',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.009,
#   'cost': 30.88782},
#  {'timestamp': 1709480586999,
#   'datetime': '2024-03-03T15:43:06.999Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724440',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.037,
#   'cost': 126.98326},
#  {'timestamp': 1709480587220,
#   'datetime': '2024-03-03T15:43:07.220Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724441',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.127,
#   'cost': 435.86146},
#  {'timestamp': 1709480589039,
#   'datetime': '2024-03-03T15:43:09.039Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724442',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.011,
#   'cost': 37.75178},
#  {'timestamp': 1709480589047,
#   'datetime': '2024-03-03T15:43:09.047Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724443',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.021,
#   'cost': 72.07158},
#  {'timestamp': 1709480589047,
#   'datetime': '2024-03-03T15:43:09.047Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724444',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.021,
#   'cost': 72.07158},
#  {'timestamp': 1709480589077,
#   'datetime': '2024-03-03T15:43:09.077Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724445',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.004,
#   'cost': 13.72792},
#  {'timestamp': 1709480589077,
#   'datetime': '2024-03-03T15:43:09.077Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724446',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.05,
#   'cost': 171.599},
#  {'timestamp': 1709480589228,
#   'datetime': '2024-03-03T15:43:09.228Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724447',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.009,
#   'cost': 30.88782},
#  {'timestamp': 1709480589230,
#   'datetime': '2024-03-03T15:43:09.230Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724448',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.005,
#   'cost': 17.1599},
#  {'timestamp': 1709480589230,
#   'datetime': '2024-03-03T15:43:09.230Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724449',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.032,
#   'cost': 109.82336},
#  {'timestamp': 1709480589260,
#   'datetime': '2024-03-03T15:43:09.260Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724450',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.008,
#   'cost': 27.45584},
#  {'timestamp': 1709480589277,
#   'datetime': '2024-03-03T15:43:09.277Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724451',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.06,
#   'cost': 205.9188},
#  {'timestamp': 1709480589350,
#   'datetime': '2024-03-03T15:43:09.350Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724452',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.437,
#   'cost': 1499.77963},
#  {'timestamp': 1709480589430,
#   'datetime': '2024-03-03T15:43:09.430Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724453',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.037,
#   'cost': 126.98326},
#  {'timestamp': 1709480589432,
#   'datetime': '2024-03-03T15:43:09.432Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724454',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.009,
#   'cost': 30.88782},
#  {'timestamp': 1709480589479,
#   'datetime': '2024-03-03T15:43:09.479Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724455',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.055,
#   'cost': 188.7589},
#  {'timestamp': 1709480589490,
#   'datetime': '2024-03-03T15:43:09.490Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724456',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 3.835,
#   'cost': 13161.68165},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724457',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 19.927,
#   'cost': 68389.26473},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724458',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.01,
#   'cost': 34.3199},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724459',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.016,
#   'cost': 54.91184},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724460',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.023,
#   'cost': 78.93577},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724461',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 2.208,
#   'cost': 7577.83392},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724462',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.026,
#   'cost': 89.23174},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724463',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.01,
#   'cost': 34.3199},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724464',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.35,
#   'cost': 1201.1965},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724465',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.022,
#   'cost': 75.50378},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724466',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.016,
#   'cost': 54.91184},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724467',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.011,
#   'cost': 37.75189},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724468',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 11.666,
#   'cost': 40037.59534},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724469',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.013,
#   'cost': 44.61587},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724470',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.023,
#   'cost': 78.93577},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724471',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.017,
#   'cost': 58.34383},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724472',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.262,
#   'cost': 899.18138},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724473',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.01,
#   'cost': 34.3199},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724474',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.023,
#   'cost': 78.93577},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724475',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.016,
#   'cost': 54.91184},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724476',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.011,
#   'cost': 37.75189},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724477',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.311,
#   'cost': 1067.34889},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724478',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.038,
#   'cost': 130.41562},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724479',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.211,
#   'cost': 724.14989},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724480',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.02,
#   'cost': 68.6398},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724481',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.017,
#   'cost': 58.34383},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724482',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.021,
#   'cost': 72.07179},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724483',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.175,
#   'cost': 600.59825},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724484',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.024,
#   'cost': 82.36776},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724485',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.011,
#   'cost': 37.75189},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724486',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.049,
#   'cost': 168.16751},
#  {'timestamp': 1709480589555,
#   'datetime': '2024-03-03T15:43:09.555Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724487',
#   'side': 'buy',
#   'price': 3431.99,
#   'amount': 0.373,
#   'cost': 1280.13227},
#  {'timestamp': 1709480589559,
#   'datetime': '2024-03-03T15:43:09.559Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724488',
#   'side': 'buy',
#   'price': 3432.0,
#   'amount': 0.006,
#   'cost': 20.592},
#  {'timestamp': 1709480589559,
#   'datetime': '2024-03-03T15:43:09.559Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724489',
#   'side': 'buy',
#   'price': 3432.0,
#   'amount': 0.058,
#   'cost': 199.056},
#  {'timestamp': 1709480589559,
#   'datetime': '2024-03-03T15:43:09.559Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724490',
#   'side': 'buy',
#   'price': 3432.0,
#   'amount': 0.5,
#   'cost': 1716.0},
#  {'timestamp': 1709480589559,
#   'datetime': '2024-03-03T15:43:09.559Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724491',
#   'side': 'buy',
#   'price': 3432.0,
#   'amount': 0.334,
#   'cost': 1146.288},
#  {'timestamp': 1709480589559,
#   'datetime': '2024-03-03T15:43:09.559Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724492',
#   'side': 'buy',
#   'price': 3432.0,
#   'amount': 5.0,
#   'cost': 17160.0},
#  {'timestamp': 1709480589560,
#   'datetime': '2024-03-03T15:43:09.560Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724493',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.736,
#   'cost': 2525.95936},
#  {'timestamp': 1709480589560,
#   'datetime': '2024-03-03T15:43:09.560Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724494',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.181,
#   'cost': 621.19381},
#  {'timestamp': 1709480589560,
#   'datetime': '2024-03-03T15:43:09.560Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724495',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.225,
#   'cost': 772.20225},
#  {'timestamp': 1709480589560,
#   'datetime': '2024-03-03T15:43:09.560Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724496',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.221,
#   'cost': 758.47421},
#  {'timestamp': 1709480589560,
#   'datetime': '2024-03-03T15:43:09.560Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724497',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 5.885,
#   'cost': 20197.37885},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724498',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.291,
#   'cost': 998.71491},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724499',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.316,
#   'cost': 1084.51516},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724500',
#   'side': 'buy',
#   'price': 3432.01,
#   'amount': 0.007,
#   'cost': 24.02407},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724501',
#   'side': 'buy',
#   'price': 3432.09,
#   'amount': 0.008,
#   'cost': 27.45672},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724502',
#   'side': 'buy',
#   'price': 3432.11,
#   'amount': 0.002,
#   'cost': 6.86422},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724503',
#   'side': 'buy',
#   'price': 3432.11,
#   'amount': 0.009,
#   'cost': 30.88899},
#  {'timestamp': 1709480589561,
#   'datetime': '2024-03-03T15:43:09.561Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724504',
#   'side': 'buy',
#   'price': 3432.11,
#   'amount': 0.328,
#   'cost': 1125.73208},
#  {'timestamp': 1709480589629,
#   'datetime': '2024-03-03T15:43:09.629Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724505',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.009,
#   'cost': 30.88908},
#  {'timestamp': 1709480589631,
#   'datetime': '2024-03-03T15:43:09.631Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724506',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.036,
#   'cost': 123.55632},
#  {'timestamp': 1709480589677,
#   'datetime': '2024-03-03T15:43:09.677Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724507',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.057,
#   'cost': 195.63084},
#  {'timestamp': 1709480590342,
#   'datetime': '2024-03-03T15:43:10.342Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724508',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.102,
#   'cost': 350.07624},
#  {'timestamp': 1709480590551,
#   'datetime': '2024-03-03T15:43:10.551Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724509',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.306,
#   'cost': 1050.23178},
#  {'timestamp': 1709480590832,
#   'datetime': '2024-03-03T15:43:10.832Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724510',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.15,
#   'cost': 514.8195},
#  {'timestamp': 1709480590832,
#   'datetime': '2024-03-03T15:43:10.832Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724511',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 5.884,
#   'cost': 20194.65292},
#  {'timestamp': 1709480590832,
#   'datetime': '2024-03-03T15:43:10.832Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724512',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 1.966,
#   'cost': 6747.56758},
#  {'timestamp': 1709480590834,
#   'datetime': '2024-03-03T15:43:10.834Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724513',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.006,
#   'cost': 20.59278},
#  {'timestamp': 1709480590878,
#   'datetime': '2024-03-03T15:43:10.878Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724514',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.028,
#   'cost': 96.09964},
#  {'timestamp': 1709480590878,
#   'datetime': '2024-03-03T15:43:10.878Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724515',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 1.972,
#   'cost': 6768.16036},
#  {'timestamp': 1709480591132,
#   'datetime': '2024-03-03T15:43:11.132Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724516',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.009,
#   'cost': 30.88917},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724517',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 1.611,
#   'cost': 5529.16143},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724518',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 3.847,
#   'cost': 13203.40411},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724519',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.509,
#   'cost': 1746.95417},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724520',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 11.847,
#   'cost': 40660.44411},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724521',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.029,
#   'cost': 99.53177},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724522',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.319,
#   'cost': 1094.84947},
#  {'timestamp': 1709480591259,
#   'datetime': '2024-03-03T15:43:11.259Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724523',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 2.83,
#   'cost': 9712.9279},
#  {'timestamp': 1709480591504,
#   'datetime': '2024-03-03T15:43:11.504Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724524',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.006,
#   'cost': 20.59278},
#  {'timestamp': 1709480591935,
#   'datetime': '2024-03-03T15:43:11.935Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724525',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.007,
#   'cost': 24.02484},
#  {'timestamp': 1709480592553,
#   'datetime': '2024-03-03T15:43:12.553Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724526',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 1.456,
#   'cost': 4997.16672},
#  {'timestamp': 1709480593143,
#   'datetime': '2024-03-03T15:43:13.143Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724527',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 3.048,
#   'cost': 10461.13224},
#  {'timestamp': 1709480593143,
#   'datetime': '2024-03-03T15:43:13.143Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724528',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.167,
#   'cost': 573.16571},
#  {'timestamp': 1709480593143,
#   'datetime': '2024-03-03T15:43:13.143Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724529',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 3.847,
#   'cost': 13203.40411},
#  {'timestamp': 1709480593143,
#   'datetime': '2024-03-03T15:43:13.143Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724530',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.029,
#   'cost': 99.53177},
#  {'timestamp': 1709480593143,
#   'datetime': '2024-03-03T15:43:13.143Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724531',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.749,
#   'cost': 2570.66537},
#  {'timestamp': 1709480593462,
#   'datetime': '2024-03-03T15:43:13.462Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724532',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.036,
#   'cost': 123.55668},
#  {'timestamp': 1709480593932,
#   'datetime': '2024-03-03T15:43:13.932Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724533',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.006,
#   'cost': 20.59272},
#  {'timestamp': 1709480594471,
#   'datetime': '2024-03-03T15:43:14.471Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724534',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.01,
#   'cost': 34.3213},
#  {'timestamp': 1709480594796,
#   'datetime': '2024-03-03T15:43:14.796Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724535',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 1.205,
#   'cost': 4135.71665},
#  {'timestamp': 1709480594796,
#   'datetime': '2024-03-03T15:43:14.796Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724536',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.89,
#   'cost': 3054.5957},
#  {'timestamp': 1709480594801,
#   'datetime': '2024-03-03T15:43:14.801Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724537',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 1.456,
#   'cost': 4997.16672},
#  {'timestamp': 1709480595295,
#   'datetime': '2024-03-03T15:43:15.295Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724538',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.026,
#   'cost': 89.23538},
#  {'timestamp': 1709480596124,
#   'datetime': '2024-03-03T15:43:16.124Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724539',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.288,
#   'cost': 988.45056},
#  {'timestamp': 1709480596369,
#   'datetime': '2024-03-03T15:43:16.369Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724540',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.026,
#   'cost': 89.23512},
#  {'timestamp': 1709480596452,
#   'datetime': '2024-03-03T15:43:16.452Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724541',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.009,
#   'cost': 30.88908},
#  {'timestamp': 1709480597177,
#   'datetime': '2024-03-03T15:43:17.177Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724542',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.193,
#   'cost': 662.40109},
#  {'timestamp': 1709480597663,
#   'datetime': '2024-03-03T15:43:17.663Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724543',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.029,
#   'cost': 99.53177},
#  {'timestamp': 1709480597855,
#   'datetime': '2024-03-03T15:43:17.855Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724544',
#   'side': 'buy',
#   'price': 3432.13,
#   'amount': 0.312,
#   'cost': 1070.82456},
#  {'timestamp': 1709480598187,
#   'datetime': '2024-03-03T15:43:18.187Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724545',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.007,
#   'cost': 24.02484},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724546',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 1.134,
#   'cost': 3892.02408},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724547',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 10.489,
#   'cost': 35999.50668},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724548',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.007,
#   'cost': 24.02484},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724549',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.1,
#   'cost': 343.212},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724550',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 1.212,
#   'cost': 4159.72944},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724551',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.142,
#   'cost': 487.36104},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724552',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.101,
#   'cost': 346.64412},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724553',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.088,
#   'cost': 302.02656},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724554',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.088,
#   'cost': 302.02656},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724555',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.088,
#   'cost': 302.02656},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724556',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.088,
#   'cost': 302.02656},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724557',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.087,
#   'cost': 298.59444},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724558',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.087,
#   'cost': 298.59444},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724559',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.087,
#   'cost': 298.59444},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724560',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.087,
#   'cost': 298.59444},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724561',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.088,
#   'cost': 302.02656},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724562',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.087,
#   'cost': 298.59444},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724563',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.027,
#   'cost': 92.66724},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724564',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.008,
#   'cost': 27.45696},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724565',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.025,
#   'cost': 85.803},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724566',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.484,
#   'cost': 1661.14608},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724567',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.966,
#   'cost': 3315.42792},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724568',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.733,
#   'cost': 2515.74396},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724569',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724570',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724571',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724572',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724573',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724574',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724575',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724576',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724577',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724578',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724579',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724580',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724581',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724582',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724583',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724584',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724585',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724586',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724587',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724588',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724589',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724590',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724591',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724592',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724593',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724594',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724595',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724596',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724597',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724598',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724599',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724600',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724601',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724602',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724603',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724604',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.05,
#   'cost': 171.606},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724605',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.509,
#   'cost': 1746.94908},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724606',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.421,
#   'cost': 1444.92252},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724607',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.265,
#   'cost': 909.5118},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724608',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.863,
#   'cost': 2961.91956},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724609',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 1.428,
#   'cost': 4901.06736},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724610',
#   'side': 'sell',
#   'price': 3432.12,
#   'amount': 0.319,
#   'cost': 1094.84628},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724611',
#   'side': 'sell',
#   'price': 3432.11,
#   'amount': 0.006,
#   'cost': 20.59266},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724612',
#   'side': 'sell',
#   'price': 3432.11,
#   'amount': 0.5,
#   'cost': 1716.055},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724613',
#   'side': 'sell',
#   'price': 3432.08,
#   'amount': 0.015,
#   'cost': 51.4812},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724614',
#   'side': 'sell',
#   'price': 3432.08,
#   'amount': 0.1,
#   'cost': 343.208},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724615',
#   'side': 'sell',
#   'price': 3432.04,
#   'amount': 0.01,
#   'cost': 34.3204},
#  {'timestamp': 1709480598347,
#   'datetime': '2024-03-03T15:43:18.347Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724616',
#   'side': 'sell',
#   'price': 3432.04,
#   'amount': 0.005,
#   'cost': 17.1602},
#  {'timestamp': 1709480598376,
#   'datetime': '2024-03-03T15:43:18.376Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724617',
#   'side': 'sell',
#   'price': 3432.0,
#   'amount': 0.015,
#   'cost': 51.48},
#  {'timestamp': 1709480598376,
#   'datetime': '2024-03-03T15:43:18.376Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724618',
#   'side': 'sell',
#   'price': 3432.0,
#   'amount': 0.058,
#   'cost': 199.056},
#  {'timestamp': 1709480598376,
#   'datetime': '2024-03-03T15:43:18.376Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724619',
#   'side': 'sell',
#   'price': 3431.98,
#   'amount': 0.119,
#   'cost': 408.40562},
#  {'timestamp': 1709480598376,
#   'datetime': '2024-03-03T15:43:18.376Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691724620',
#   'side': 'sell',
#   'price': 3431.97,
#   'amount': 0.04,
#   'cost': 137.2788},
# ...
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725302',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725303',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 2.0,
#   'cost': 6863.26},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725304',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725305',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725306',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725307',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725308',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725309',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725310',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725311',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725312',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725313',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725314',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725315',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725316',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725317',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725318',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725319',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725320',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725321',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725322',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725323',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725324',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725325',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725326',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725327',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725328',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725329',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725330',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725331',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725332',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725333',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725334',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725335',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725336',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.352,
#   'cost': 1207.93376},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725337',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725338',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725339',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725340',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725341',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725342',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725343',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725344',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725345',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725346',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725347',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725348',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725349',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.01,
#   'cost': 34.3163},
#  {'timestamp': 1709480622746,
#   'datetime': '2024-03-03T15:43:42.746Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725350',
#   'side': 'sell',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480622855,
#   'datetime': '2024-03-03T15:43:42.855Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725351',
#   'side': 'buy',
#   'price': 3431.63,
#   'amount': 0.05,
#   'cost': 171.5815},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725352',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725353',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.913,
#   'cost': 3133.06906},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725354',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725355',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725356',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.008,
#   'cost': 27.45296},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725357',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.103,
#   'cost': 353.45686},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725358',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725359',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725360',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725361',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725362',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.104,
#   'cost': 356.88848},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725363',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.103,
#   'cost': 353.45686},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725364',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.691,
#   'cost': 2371.24942},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725365',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.311,
#   'cost': 1067.23382},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725366',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.258,
#   'cost': 885.35796},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725367',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.19,
#   'cost': 652.0078},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725368',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.007,
#   'cost': 24.02134},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725369',
#   'side': 'sell',
#   'price': 3431.62,
#   'amount': 0.213,
#   'cost': 730.93506},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725370',
#   'side': 'sell',
#   'price': 3431.61,
#   'amount': 0.006,
#   'cost': 20.58966},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725371',
#   'side': 'sell',
#   'price': 3431.43,
#   'amount': 0.007,
#   'cost': 24.02001},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725372',
#   'side': 'sell',
#   'price': 3431.43,
#   'amount': 0.003,
#   'cost': 10.29429},
#  {'timestamp': 1709480623086,
#   'datetime': '2024-03-03T15:43:43.086Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725373',
#   'side': 'sell',
#   'price': 3431.43,
#   'amount': 0.003,
#   'cost': 10.29429},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725374',
#   'side': 'sell',
#   'price': 3431.34,
#   'amount': 0.006,
#   'cost': 20.58804},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725375',
#   'side': 'sell',
#   'price': 3431.34,
#   'amount': 0.02,
#   'cost': 68.6268},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725376',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.001,
#   'cost': 3.43128},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725377',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.001,
#   'cost': 3.43128},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725378',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.001,
#   'cost': 3.43128},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725379',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.009,
#   'cost': 30.88152},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725380',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.006,
#   'cost': 20.58768},
#  {'timestamp': 1709480623147,
#   'datetime': '2024-03-03T15:43:43.147Z',
#   'symbol': 'ETH/USDT:USDT',
#   'id': '3691725381',
#   'side': 'sell',
#   'price': 3431.28,
#   'amount': 0.002,
#   'cost': 6.86256},
#  ...]

# %%
trades_error = {"binance": trades_ws_binance, "ccxt": trades_ws_ccxt}
pickle.dump(trades_error, open("trades_error_1709640960000.pkl", "wb"))

# %%
df_agg_trade = pd.read_csv("trades_data_ws_binance_agg_trade.csv")
df_trade = pd.read_csv("trades_data_ws_binance_trade.csv")

# %%
df_agg_trade.head()
# Out:
#    Unnamed: 0         e              E           a        s        p      q  \
# 0           0  aggTrade  1709699443548  1527349983  ETHUSDT  3555.07  1.406
# 1           1  aggTrade  1709699443681  1527349984  ETHUSDT  3555.07  1.406
# 2           2  aggTrade  1709699443827  1527349985  ETHUSDT  3555.07  0.703
# 3           3  aggTrade  1709699443937  1527349986  ETHUSDT  3555.07  1.406
# 4           4  aggTrade  1709699444054  1527349987  ETHUSDT  3555.07  1.406
#
#             f           l              T     m
# 0  3709345386  3709345396  1709699443427  True
# 1  3709345397  3709345401  1709699443546  True
# 2  3709345402  3709345402  1709699443679  True
# 3  3709345403  3709345404  1709699443825  True
# 4  3709345405  3709345410  1709699443936  True

# %%
df_trade.head()
# Out:
#    Unnamed: 0      e              E              T        s           t  \
# 0           0  trade  1709699594705  1709699594705  ETHUSDT  3709350188
# 1           1  trade  1709699594705  1709699594705  ETHUSDT  3709350189
# 2           2  trade  1709699594717  1709699594716  ETHUSDT  3709350190
# 3           3  trade  1709699594717  1709699594716  ETHUSDT  3709350191
# 4           4  trade  1709699594717  1709699594716  ETHUSDT  3709350192
#
#          p      q       X     m
# 0  3560.63  0.007  MARKET  True
# 1  3560.63  0.193  MARKET  True
# 2  3560.63  0.124  MARKET  True
# 3  3560.63  0.037  MARKET  True
# 4  3560.63  2.500  MARKET  True

# %%
df_agg_trade["timestamp"] = df_agg_trade["T"]
df_agg_trade["id"] = df_agg_trade["l"]
df_agg_trade["price"] = df_agg_trade["p"]
df_agg_trade["amount"] = df_agg_trade["q"]
agg_trades_binance = df_agg_trade.to_dict(orient="records")

# %%
df_trade["timestamp"] = df_trade["T"]
df_trade["id"] = df_trade["t"]
df_trade["price"] = df_trade["p"]
df_trade["amount"] = df_trade["q"]
trades_binance = df_trade.to_dict(orient="records")

# %%
ohlcv_agg_trade = pd.DataFrame(
    ccxt_exchange.build_ohlcvc(agg_trades_binance),
    columns=["timestamp", "open", "high", "low", "close", "volume", "count"],
)
ohlcv_trade = pd.DataFrame(
    ccxt_exchange.build_ohlcvc(trades_binance),
    columns=["timestamp", "open", "high", "low", "close", "volume", "count"],
)

# %%
ohlcv_agg_trade
# Out:
#         timestamp     open     high      low    close     volume  count
# 0   1709699400000  3555.07  3555.07  3552.84  3552.84    299.446    193
# 1   1709699460000  3552.84  3556.80  3552.47  3555.88   1384.329    846
# 2   1709699520000  3555.89  3557.94  3555.00  3557.93    657.172    568
# 3   1709699580000  3557.75  3560.64  3556.36  3557.51    930.879    786
# 4   1709699640000  3557.51  3562.38  3557.23  3562.38   1235.291    932
# ..            ...      ...      ...      ...      ...        ...    ...
# 63  1709703180000  3748.94  3753.79  3746.00  3746.00   5251.909   2764
# 64  1709703240000  3746.00  3746.87  3732.65  3734.38  12570.065   4486
# 65  1709703300000  3734.37  3741.98  3731.77  3739.09   7006.102   2894
# 66  1709703360000  3739.08  3754.99  3738.30  3753.18   7577.095   3272
# 67  1709703420000  3753.19  3754.99  3747.58  3754.21   3696.520   1746
#
# [68 rows x 7 columns]

# %%
ohlcv_trade
# Out:
#         timestamp     open     high      low    close     volume  count
# 0   1709699580000  3560.63  3560.63  3556.36  3557.51    744.456   1225
# 1   1709699640000  3557.51  3562.38  3557.23  3562.38   1235.291   2287
# 2   1709699700000  3562.37  3564.89  3561.83  3564.73    628.905   1341
# 3   1709699760000  3564.73  3570.00  3564.49  3570.00   8023.223   5501
# 4   1709699820000  3569.99  3572.08  3564.49  3564.52   3378.039   3868
# ..            ...      ...      ...      ...      ...        ...    ...
# 62  1709703300000  3734.37  3741.98  3731.77  3739.09   7005.799   7410
# 63  1709703360000  3739.09  3754.99  3738.30  3753.18   7577.398   7915
# 64  1709703420000  3753.19  3758.49  3747.58  3756.73   9320.037   9931
# 65  1709703480000  3756.73  3756.73  3745.38  3746.85   5992.732   9286
# 66  1709703540000  3746.85  3749.23  3734.47  3738.27  10840.810  10464
#
# [67 rows x 7 columns]

# %%
get_error(ohlcv_agg_trade, ohlcv_trade)
# Out:
# Avg Open error  : 0.0
# Avg Close error : 0.0
# Avg High error  : 0.0
# Avg Low error   : 0.0
# Avg Volume error: 1.36
#         timestamp   open_x   high_x    low_x  close_x  volume_x  count_x  \
# 28  1709701260000  3668.73  3668.78  3654.68  3656.69  8676.335     3655
# 57  1709703000000  3747.81  3758.97  3746.70  3754.19  9832.262     4909
# 64  1709703420000  3753.19  3754.99  3747.58  3754.21  3696.520     1746
#
#      open_y   high_y    low_y  close_y  volume_y  count_y  open_error  \
# 28  3668.84  3668.84  3654.68  3656.69  8684.978     8959    0.002998
# 57  3747.81  3762.74  3746.70  3754.19  9832.304    11454    0.000000
# 64  3753.19  3758.49  3747.58  3756.73  9320.037     9931    0.000000
#
#     high_error  low_error  close_error  volume_error
# 28    0.001635        0.0      0.00000      0.099517
# 57    0.100193        0.0      0.00000      0.000427
# 64    0.093123        0.0      0.06708     60.337926
#         timestamp     open     high      low    close    volume  count
# 28  1709701260000  3668.84  3668.84  3654.68  3656.69  8684.978   8959
# 57  1709703000000  3747.81  3762.74  3746.70  3754.19  9832.304  11454
# 64  1709703420000  3753.19  3758.49  3747.58  3756.73  9320.037   9931
# (        timestamp   open_x   high_x    low_x  close_x  volume_x  count_x  \
#  28  1709701260000  3668.73  3668.78  3654.68  3656.69  8676.335     3655
#  57  1709703000000  3747.81  3758.97  3746.70  3754.19  9832.262     4909
#  64  1709703420000  3753.19  3754.99  3747.58  3754.21  3696.520     1746
#
#       open_y   high_y    low_y  close_y  volume_y  count_y  open_error  \
#  28  3668.84  3668.84  3654.68  3656.69  8684.978     8959    0.002998
#  57  3747.81  3762.74  3746.70  3754.19  9832.304    11454    0.000000
#  64  3753.19  3758.49  3747.58  3756.73  9320.037     9931    0.000000
#
#      high_error  low_error  close_error  volume_error
#  28    0.001635        0.0      0.00000      0.099517
#  57    0.100193        0.0      0.00000      0.000427
#  64    0.093123        0.0      0.06708     60.337926  ,
#          timestamp     open     high      low    close    volume  count
#  28  1709701260000  3668.84  3668.84  3654.68  3656.69  8684.978   8959
#  57  1709703000000  3747.81  3762.74  3746.70  3754.19  9832.304  11454
#  64  1709703420000  3753.19  3758.49  3747.58  3756.73  9320.037   9931)

# %%
df_trade.tail()
# Out:
#         Unnamed: 0      e              E              T        s           t  \
# 601274      601274  trade  1709703594615  1709703594614  ETHUSDT  3709951462
# 601275      601275  trade  1709703594633  1709703594633  ETHUSDT  3709951463
# 601276      601276  trade  1709703594684  1709703594684  ETHUSDT  3709951464
# 601277      601277  trade  1709703594695  1709703594695  ETHUSDT  3709951465
# 601278      601278  trade  1709703594712  1709703594712  ETHUSDT  3709951466
#
#               p      q       X      m      timestamp          id    price  \
# 601274  3738.24  3.599  MARKET  False  1709703594614  3709951462  3738.24
# 601275  3738.24  0.034  MARKET  False  1709703594633  3709951463  3738.24
# 601276  3738.27  0.170  MARKET   True  1709703594684  3709951464  3738.27
# 601277  3738.27  0.180  MARKET   True  1709703594695  3709951465  3738.27
# 601278  3738.27  0.008  MARKET   True  1709703594712  3709951466  3738.27
#
#         amount
# 601274   3.599
# 601275   0.034
# 601276   0.170
# 601277   0.180
# 601278   0.008

# %%
df_agg_trade.tail()
# Out:
#         Unnamed: 0         e              E           a        s        p  \
# 230474      230474  aggTrade  1709703443546  1527580457  ETHUSDT  3754.35
# 230475      230475  aggTrade  1709703443563  1527580458  ETHUSDT  3754.34
# 230476      230476  aggTrade  1709703443563  1527580459  ETHUSDT  3754.33
# 230477      230477  aggTrade  1709703443563  1527580460  ETHUSDT  3754.30
# 230478      230478  aggTrade  1709703443563  1527580461  ETHUSDT  3754.21
#
#             q           f           l              T      m      timestamp  \
# 230474  0.137  3709925788  3709925788  1709703443393  False  1709703443393
# 230475  5.337  3709925789  3709925796  1709703443560   True  1709703443560
# 230476  0.006  3709925797  3709925797  1709703443560   True  1709703443560
# 230477  1.658  3709925798  3709925799  1709703443560   True  1709703443560
# 230478  0.875  3709925800  3709925800  1709703443561   True  1709703443561
#
#                 id    price  amount
# 230474  3709925788  3754.35   0.137
# 230475  3709925796  3754.34   5.337
# 230476  3709925797  3754.33   0.006
# 230477  3709925799  3754.30   1.658
# 230478  3709925800  3754.21   0.875
