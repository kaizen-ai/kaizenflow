# %% [markdown]
# # Description

# %% [markdown]
# This notebook contains examples of CCXT functionality.

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import logging
import pprint

import ccxt

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint
import helpers.hsecrets as hsecret
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
display(HTML("""
<style>
/* Jupyter cell is in normal mode when code mirror */
.edit_mode .cell.selected .CodeMirror-focused.cm-fat-cursor {
  /* background-color: #F5F6EB; */
  background-color: rgba(128, 0, 0, 0.1); 
}
/* Jupyter cell is in insert mode when code mirror */
.edit_mode .cell.selected .CodeMirror-focused:not(.cm-fat-cursor) {
  /* background-color: #F6EBF1; */
  background-color: rgba(0, 128, 0, 0.2); 
}
</style>
"""))
# Out:
# <style>
# /* Jupyter cell is in normal mode when code mirror */
# .edit_mode .cell.selected .CodeMirror-focused.cm-fat-cursor {
#   /* background-color: #F5F6EB; */
#   background-color: rgba(128, 0, 0, 0.1);
# }
# /* Jupyter cell is in insert mode when code mirror */
# .edit_mode .cell.selected .CodeMirror-focused:not(.cm-fat-cursor) {
#   /* background-color: #F6EBF1; */
#   background-color: rgba(0, 128, 0, 0.2);
# }
# </style>

# %%
display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
hdbg.init_logger(verbosity=logging.INFO)

_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])

hprint.config_notebook()
# Out:
# INFO: > cmd='/venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-4dccc445-39d6-441c-a178-0ebbf342cb3f.json'
# WARNING: Running in Jupyter
# -----------------------------------------------------------------------------
# This code is not in sync with the container:
# code_version='1.4.3' != container_version='1.4.0'
# -----------------------------------------------------------------------------
# You need to:
# - merge origin/master into your branch with `invoke git_merge_master`
# - pull the latest container with `invoke docker_pull`
# INFO  # Git
#   branch_name='gp_scratch'
#   hash='26de62867'
#   # Last commits:
#     *   26de62867 saggese  Merge branch 'master' into gp_scratch                             (20 minutes ago) Thu Jul 13 08:31:45 2023  (HEAD -> gp_scratch, origin/gp_scratch)
#     |\
#     * | 4b839e702 saggese  Update                                                            (  15 hours ago) Wed Jul 12 17:34:03 2023
#     | * 0256f5fca Vlad     CmampTask4631_Create_random_workload_for_broker_run (#4666)       (  17 hours ago) Wed Jul 12 16:15:32 2023  (origin/master, origin/HEAD, master)
# # Machine info
#   system=Linux
#   node name=975188e300cd
#   release=5.15.0-1039-aws
#   version=#44~20.04.1-Ubuntu SMP Thu Jun 22 12:21:12 UTC 2023
#   machine=x86_64
#   processor=x86_64
#   cpu count=8
#   cpu freq=scpufreq(current=2499.9959999999996, min=0.0, max=0.0)
#   memory=svmem(total=33280286720, available=27717611520, percent=16.7, used=5095030784, free=19034648576, active=4720021504, inactive=7740043264, buffers=1832693760, cached=7317913600, shared=2236416, slab=1509797888)
#   disk usage=sdiskusage(total=156052275200, used=39971991552, free=116063506432, percent=25.6)
# # Packages
#   python: 3.8.10
#   cvxopt: 1.3.0
#   cvxpy: 1.2.2
#   gluonnlp: ?
#   gluonts: 0.6.7
#   joblib: 1.2.0
#   mxnet: 1.9.1
#   numpy: 1.23.4
#   pandas: 1.5.1
#   pyarrow: 10.0.0
#   scipy: 1.9.3
#   seaborn: 0.12.1
#   sklearn: 1.1.3
#   statsmodels: 0.13.5

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install sagemath)"

# %%
from typing import Any, Dict, List

def subset_dict(dict_: Dict, keys: List[Any], *, keep_order: bool = True) -> Dict:
    res = {}
    if keep_order:
        for k, v in dict_.items():
            if k in keys:
                res[k] = v
    else:
        for k in keys:
            res[k] = dict_[k]
    return res

# %% [markdown]
# # CCXT
#
# ## Resources
# - https://github.com/ccxt/ccxt
# - https://docs.ccxt.com/#/README
# - https://github.com/ccxt/ccxt#readme
# - https://ccxt.readthedocs.io/en/latest/index.html
# - https://ccxt.readthedocs.io/en/latest/manual.html
#
# ## Intro
#
# - CCXT = CryptoCurrency eXchange Trading library
#
# - Connect with cryptocurrency exchanges and trade
# - Connect with payment processing services
# - Access to market data
# - Algorithmic trading
# - Strategy backtesting
# - Bot programming
#
# - Normalized API for cross-exchange analytics and arbitrage
#
# - There is an async mode using asyncio
#   ```
#   import ccxt.async_support as ccxt
#   ```
#
# - Proxy: in case Cloudflare or your country / IP is rejected
#   - Of course an intermediary adds latency
#   - Server that acts as an intermediary between the client requesting a resource and the server
#
# ## Usage
#
# // https://github.com/ccxt/ccxt#usage
#
# - Public API
#   - Unrestricted access to public information for exchanges without account or
#     API key
#   - E.g.,
#     - Market data
#     - Order books
#     - Price feeds
#     - Trade history
#
# - Private API
#   - Obtain an API key from exchange website by signing up
#     - You might need personal info and verification
#   - Manage personal account info
#   - Query account balance
#   - Query orders
#   - Trade
#   - Deposit and withdraw fiat and crypto funds
#
# - CCXT supports REST APIs for all exchanges
# - CCXT Pro supports WebSocket and FIX

# %% [markdown]
# # Exchanges

# %% [markdown]
# From https://docs.ccxt.com/#/README?id=exchanges
#
# - Each class implements the public and private API for a particular crypto
#   exchange
# - The `Exchange` class shares a set of common methods
#
# - Some exchanges offer:
#   - Margin trading (i.e., leverage)
#   - Derivatives (e.g., futures and options)
#   - Dark pools, OTC trading
#   - Merchant APIs
#
# - Testnets and mainnets envs
#     - Some exchanges offer a separated API for:
#       - Testing purposes (aka "sandboxes", "staging environments", "testnets")
#       - Trading with real assets (aka "mainnets", "production environments")
#     - Typically the sandbox has the same API as the production API but with a
#       different URL (and maybe different market)
#
# - Exchange structure
#     - Every exchange has properties that can be overridden in the constructor
#
#     - `id`: default id for identification purposes (typically a lower case string)
#     - `name`: human-readable exchange name
#     - `countries`: where the exchange is operating from
#     - `urls`: URLs for private and public APIs, main website, documentation
#     - `version`: version of the current exchange API
#     - `api`: API endpoints exposed by a crypto exchange
#     - `has`: array of exchange capabilities
#     - `timeframes`: frequency of available bars (e.g., minutes)
#     - `rateLimit`: minimum delay between two consecutive requests
#     - `markets`: dictionary of markets indexed by symbols
#     - `symbols`: list of symbols available with an exchange
#     - `currencies`: array of currencies available
#
# - Exchange metadata
#     - Each exchange has a `has` with flags about the exchange capabilities
#
# - Rate limit
#     - Exchanges track your user / IP address to throttle querying the API too
#       frequently
#     - You need to stay under the rate limit to avoid being banned
#       - Typical limits are 1 or 2 requests per second
#     - CCXT has an experimental rate-limiter that throttles in background
#       ```
#       exchange.enableRateLimit = True
#       ```
#       - The state is inside the class instance so one should have a single class

# %%
# Print all exchanges.
print(len(ccxt.exchanges), ccxt.exchanges)
# Out:
# 117 ['aax', 'alpaca', 'ascendex', 'bequant', 'bibox', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitforex', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitstamp1', 'bittrex', 'bitvavo', 'bkex', 'bl3p', 'blockchaincom', 'btcalpha', 'btcbox', 'btcex', 'btcmarkets', 'btctradeua', 'btcturk', 'buda', 'bw', 'bybit', 'bytetrade', 'cex', 'coinbase', 'coinbaseprime', 'coinbasepro', 'coincheck', 'coinex', 'coinfalcon', 'coinmate', 'coinone', 'coinspot', 'crex24', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'flowbtc', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'huobi', 'huobijp', 'huobipro', 'idex', 'independentreserve', 'indodax', 'itbit', 'kraken', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'lbank2', 'liquid', 'luno', 'lykke', 'mercado', 'mexc', 'mexc3', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okex', 'okex5', 'okx', 'paymium', 'phemex', 'poloniex', 'probit', 'qtrade', 'ripio', 'stex', 'therock', 'tidex', 'timex', 'tokocrypto', 'upbit', 'wavesexchange', 'wazirx', 'whitebit', 'woo', 'yobit', 'zaif', 'zb', 'zipmex', 'zonda']

# %%
# Create Binance exchange.
exchange_id = "binance"
mode = "test"
contract_type = "futures"

# Select credentials for provided exchange.
if mode == "test":
    secrets_id = exchange_id + "_sandbox"
else:
    secrets_id = exchange_id
exchange_params = hsecret.get_secret(secrets_id)

# Enable rate limit.
exchange_params["rateLimit"] = True

# Log into futures/spot market.
if contract_type == "futures":
    exchange_params["options"] = {"defaultType": "future"}

# Create a CCXT Exchange class object.
ccxt_exchange = getattr(ccxt, exchange_id)
print(hprint.to_str("ccxt_exchange"))
exchange = ccxt_exchange(exchange_params)
print(hprint.to_str("exchange"))
if mode == "test":
    exchange.set_sandbox_mode(True)
    _LOG.warning("Running in sandbox mode")
hdbg.dassert(
    exchange.checkRequiredCredentials(),
    msg="Required credentials not passed",
)
# Out:
# ccxt_exchange=<class 'ccxt.binance.binance'>
# exchange=ccxt.binance()
# WARNING Running in sandbox mode

# %% [markdown]
# ## Exchange properties

# %%
print("exchange=", exchange, type(exchange))
# Out:
# exchange= Binance <class 'ccxt.binance.binance'>

# %%
# # Print some properties of the exchange.
# var_names = ["exchange.id", 
#              "exchange.name",
#              "exchange.countries",
#              #"exchange.urls",
#              "exchange.version",
#              "exchange.timeframes",
#              "exchange.timeout",
#              "exchange.rateLimit",
#              "exchange.symbols",
#              "exchange.currencies"]
# for var_name in var_names:
#     print(hprint.to_str(var_name, mode="pprint_color"))

# %%
# Name in user-land to identify the exchange.
hprint.pprint_color(exchange.id)
# Out:
# 'binance'

# %%
# Human readable name.
hprint.pprint_color(exchange.name)
# Out:
# 'Binance'

# %%
# Which countries the exchange is operating from.
hprint.pprint_color(exchange.countries)
# Out:
# ['JP', 'MT']

# %%
# Version identifier for exchange API.
hprint.pprint_color(exchange.version)
# Out:
# None

# %%
# timeframes for fetchOHLCV().
# TODO(gp): It seems that it has 1s resolution.
hprint.pprint_color(exchange.timeframes)
# Out:
# {'12h': '12h',
#  '15m': '15m',
#  '1M': '1M',
#  '1d': '1d',
#  '1h': '1h',
#  '1m': '1m',
#  '1s': '1s',
#  '1w': '1w',
#  '2h': '2h',
#  '30m': '30m',
#  '3d': '3d',
#  '3m': '3m',
#  '4h': '4h',
#  '5m': '5m',
#  '6h': '6h',
#  '8h': '8h'}

# %%
# Binance doesn't have this method.
#hprint.pprint_color(exchange.requiredCredentialsCredentials)

# %%
# Exchange decimal precision.
hprint.pprint_color(exchange.precisionMode)
# Out:
# 2

# %%
hprint.pprint_color(exchange.urls)
# Out:
# {'api': {'dapiPrivate': 'https://testnet.binancefuture.com/dapi/v1',
#          'dapiPublic': 'https://testnet.binancefuture.com/dapi/v1',
#          'eapiPrivate': 'https://testnet.binanceops.com/eapi/v1',
#          'eapiPublic': 'https://testnet.binanceops.com/eapi/v1',
#          'fapiPrivate': 'https://testnet.binancefuture.com/fapi/v1',
#          'fapiPrivateV2': 'https://testnet.binancefuture.com/fapi/v2',
#          'fapiPublic': 'https://testnet.binancefuture.com/fapi/v1',
#          'private': 'https://testnet.binance.vision/api/v3',
#          'public': 'https://testnet.binance.vision/api/v3',
#          'v1': 'https://testnet.binance.vision/api/v1'},
#  'apiBackup': {'dapiData': 'https://dapi.binance.com/futures/data',
#                'dapiPrivate': 'https://dapi.binance.com/dapi/v1',
#                'dapiPrivateV2': 'https://dapi.binance.com/dapi/v2',
#                'dapiPublic': 'https://dapi.binance.com/dapi/v1',
#                'eapiPrivate': 'https://eapi.binance.com/eapi/v1',
#                'eapiPublic': 'https://eapi.binance.com/eapi/v1',
#                'fapiData': 'https://fapi.binance.com/futures/data',
#                'fapiPrivate': 'https://fapi.binance.com/fapi/v1',
#                'fapiPrivateV2': 'https://fapi.binance.com/fapi/v2',
#                'fapiPublic': 'https://fapi.binance.com/fapi/v1',
#                'private': 'https://api.binance.com/api/v3',
#                'public': 'https://api.binance.com/api/v3',
#                'sapi': 'https://api.binance.com/sapi/v1',
#                'sapiV3': 'https://api.binance.com/sapi/v3',
#                'v1': 'https://api.binance.com/api/v1',
#                'wapi': 'https://api.binance.com/wapi/v3'},
#  'api_management': 'https://www.binance.com/en/usercenter/settings/api-management',
#  'doc': ['https://binance-docs.github.io/apidocs/spot/en'],
#  'fees': 'https://www.binance.com/en/fee/schedule',
#  'logo': 'https://user-images.githubusercontent.com/1294454/29604020-d5483cdc-87ee-11e7-94c7-d1a8d9169293.jpg',
#  'referral': {'discount': 0.1,
#               'url': 'https://accounts.binance.com/en/register?ref=D7YA7CLY'},
#  'test': {'dapiPrivate': 'https://testnet.binancefuture.com/dapi/v1',
#           'dapiPublic': 'https://testnet.binancefuture.com/dapi/v1',
#           'eapiPrivate': 'https://testnet.binanceops.com/eapi/v1',
#           'eapiPublic': 'https://testnet.binanceops.com/eapi/v1',
#           'fapiPrivate': 'https://testnet.binancefuture.com/fapi/v1',
#           'fapiPrivateV2': 'https://testnet.binancefuture.com/fapi/v2',
#           'fapiPublic': 'https://testnet.binancefuture.com/fapi/v1',
#           'private': 'https://testnet.binance.vision/api/v3',
#           'public': 'https://testnet.binance.vision/api/v3',
#           'v1': 'https://testnet.binance.vision/api/v1'},
#  'www': 'https://www.binance.com'}

# %%
hprint.pprint_color(exchange.api)
# Out:
# {'dapiData': {'get': {'basis': 1,
#                       'globalLongShortAccountRatio': 1,
#                       'openInterestHist': 1,
#                       'takerBuySellVol': 1,
#                       'topLongShortAccountRatio': 1,
#                       'topLongShortPositionRatio': 1}},
#  'dapiPrivate': {'delete': {'allOpenOrders': 1,
#                             'batchOrders': 5,
#                             'listenKey': 1,
#                             'order': 1},
#                  'get': {'account': 5,
#                          'adlQuantile': 5,
#                          'allOrders': {'cost': 20, 'noSymbol': 40},
#                          'balance': 1,
#                          'forceOrders': {'cost': 20, 'noSymbol': 50},
#                          'income': 20,
#                          'leverageBracket': 1,
#                          'openOrder': 1,
#                          'openOrders': {'cost': 1, 'noSymbol': 5},
#                          'order': 1,
#                          'orderAmendment': 1,
#                          'pmAccountInfo': 5,
#                          'positionMargin/history': 1,
#                          'positionRisk': 1,
#                          'positionSide/dual': 30,
#                          'userTrades': {'cost': 20, 'noSymbol': 40}},
#                  'post': {'batchOrders': 5,
#                           'countdownCancelAll': 10,
#                           'leverage': 1,
#                           'listenKey': 1,
#                           'marginType': 1,
#                           'order': 4,
#                           'positionMargin': 1,
#                           'positionSide/dual': 1},
#                  'put': {'batchOrders': 5, 'listenKey': 1, 'order': 1}},
#  'dapiPrivateV2': {'get': {'leverageBracket': 1}},
#  'dapiPublic': {'get': {'aggTrades': 20,
#                         'continuousKlines': {'byLimit': [[99, 1],
#                                                          [499, 2],
#                                                          [1000, 5],
#                                                          [10000, 10]],
#                                              'cost': 1},
#                         'depth': {'byLimit': [[50, 2],
#                                               [100, 5],
#                                               [500, 10],
#                                               [1000, 20]],
#                                   'cost': 2},
#                         'exchangeInfo': 1,
#                         'fundingRate': 1,
#                         'historicalTrades': 20,
#                         'indexPriceKlines': {'byLimit': [[99, 1],
#                                                          [499, 2],
#                                                          [1000, 5],
#                                                          [10000, 10]],
#                                              'cost': 1},
#                         'klines': {'byLimit': [[99, 1],
#                                                [499, 2],
#                                                [1000, 5],
#                                                [10000, 10]],
#                                    'cost': 1},
#                         'markPriceKlines': {'byLimit': [[99, 1],
#                                                         [499, 2],
#                                                         [1000, 5],
#                                                         [10000, 10]],
#                                             'cost': 1},
#                         'openInterest': 1,
#                         'ping': 1,
#                         'pmExchangeInfo': 1,
#                         'premiumIndex': 10,
#                         'ticker/24hr': {'cost': 1, 'noSymbol': 40},
#                         'ticker/bookTicker': {'cost': 1, 'noSymbol': 2},
#                         'ticker/price': {'cost': 1, 'noSymbol': 2},
#                         'time': 1,
#                         'trades': 5}},
#  'eapiPrivate': {'delete': {'allOpenOrders': 1,
#                             'allOpenOrdersByUnderlying': 1,
#                             'batchOrders': 1,
#                             'listenKey': 1,
#                             'order': 1},
#                  'get': {'account': 3,
#                          'bill': 1,
#                          'countdownCancelAll': 1,
#                          'exerciseRecord': 5,
#                          'historyOrders': 3,
#                          'marginAccount': 3,
#                          'mmp': 1,
#                          'openOrders': {'cost': 1, 'noSymbol': 40},
#                          'position': 5,
#                          'userTrades': 5},
#                  'post': {'batchOrders': 5,
#                           'countdownCancelAll': 1,
#                           'countdownCancelAllHeartBeat': 10,
#                           'listenKey': 1,
#                           'mmpReset': 1,
#                           'mmpSet': 1,
#                           'order': 1,
#                           'transfer': 1},
#                  'put': {'listenKey': 1}},
#  'eapiPublic': {'get': {'depth': 1,
#                         'exchangeInfo': 1,
#                         'exerciseHistory': 3,
#                         'historicalTrades': 20,
#                         'index': 1,
#                         'klines': 1,
#                         'mark': 5,
#                         'ping': 1,
#                         'ticker': 5,
#                         'time': 1,
#                         'trades': 5}},
#  'fapiData': {'get': {'globalLongShortAccountRatio': 1,
#                       'openInterestHist': 1,
#                       'takerlongshortRatio': 1,
#                       'topLongShortAccountRatio': 1,
#                       'topLongShortPositionRatio': 1}},
#  'fapiPrivate': {'delete': {'allOpenOrders': 1,
#                             'batchOrders': 1,
#                             'listenKey': 1,
#                             'order': 1},
#                  'get': {'account': 5,
#                          'adlQuantile': 5,
#                          'allOrders': 5,
#                          'apiReferral/customization': 1,
#                          'apiReferral/ifNewUser': 1,
#                          'apiReferral/overview': 1,
#                          'apiReferral/rebateVol': 1,
#                          'apiReferral/tradeVol': 1,
#                          'apiReferral/traderNum': 1,
#                          'apiReferral/traderSummary': 1,
#                          'apiReferral/userCustomization': 1,
#                          'apiTradingStatus': 1,
#                          'balance': 5,
#                          'commissionRate': 20,
#                          'forceOrders': {'cost': 20, 'noSymbol': 50},
#                          'income': 30,
#                          'leverageBracket': 1,
#                          'multiAssetsMargin': 30,
#                          'openOrder': 1,
#                          'openOrders': 1,
#                          'order': 1,
#                          'pmAccountInfo': 5,
#                          'positionMargin/history': 1,
#                          'positionRisk': 5,
#                          'positionSide/dual': 30,
#                          'userTrades': 5},
#                  'post': {'apiReferral/customization': 1,
#                           'apiReferral/userCustomization': 1,
#                           'batchOrders': 5,
#                           'countdownCancelAll': 10,
#                           'leverage': 1,
#                           'listenKey': 1,
#                           'marginType': 1,
#                           'multiAssetsMargin': 1,
#                           'order': 4,
#                           'positionMargin': 1,
#                           'positionSide/dual': 1},
#                  'put': {'listenKey': 1}},
#  'fapiPrivateV2': {'get': {'account': 1, 'balance': 1, 'positionRisk': 1}},
#  'fapiPublic': {'get': {'aggTrades': 20,
#                         'apiTradingStatus': {'cost': 1, 'noSymbol': 10},
#                         'continuousKlines': {'byLimit': [[99, 1],
#                                                          [499, 2],
#                                                          [1000, 5],
#                                                          [10000, 10]],
#                                              'cost': 1},
#                         'depth': {'byLimit': [[50, 2],
#                                               [100, 5],
#                                               [500, 10],
#                                               [1000, 20]],
#                                   'cost': 2},
#                         'exchangeInfo': 1,
#                         'fundingRate': 1,
#                         'historicalTrades': 20,
#                         'indexInfo': 1,
#                         'indexPriceKlines': {'byLimit': [[99, 1],
#                                                          [499, 2],
#                                                          [1000, 5],
#                                                          [10000, 10]],
#                                              'cost': 1},
#                         'klines': {'byLimit': [[99, 1],
#                                                [499, 2],
#                                                [1000, 5],
#                                                [10000, 10]],
#                                    'cost': 1},
#                         'lvtKlines': 1,
#                         'markPriceKlines': {'byLimit': [[99, 1],
#                                                         [499, 2],
#                                                         [1000, 5],
#                                                         [10000, 10]],
#                                             'cost': 1},
#                         'openInterest': 1,
#                         'ping': 1,
#                         'pmExchangeInfo': 1,
#                         'premiumIndex': 1,
#                         'ticker/24hr': {'cost': 1, 'noSymbol': 40},
#                         'ticker/bookTicker': {'cost': 1, 'noSymbol': 2},
#                         'ticker/price': {'cost': 1, 'noSymbol': 2},
#                         'time': 1,
#                         'trades': 5}},
#  'private': {'delete': {'openOrders': 1, 'order': 1, 'orderList': 1},
#              'get': {'account': 10,
#                      'allOrderList': 10,
#                      'allOrders': 10,
#                      'myTrades': 10,
#                      'openOrderList': 3,
#                      'openOrders': {'cost': 3, 'noSymbol': 40},
#                      'order': 2,
#                      'orderList': 2,
#                      'rateLimit/order': 20},
#              'post': {'order': 1, 'order/oco': 1, 'order/test': 1}},
#  'public': {'delete': {'userDataStream': 1},
#             'get': {'aggTrades': 1,
#                     'depth': {'byLimit': [[100, 1],
#                                           [500, 5],
#                                           [1000, 10],
#                                           [5000, 50]],
#                               'cost': 1},
#                     'exchangeInfo': 10,
#                     'historicalTrades': 5,
#                     'klines': 1,
#                     'ping': 1,
#                     'ticker/24hr': {'cost': 1, 'noSymbol': 40},
#                     'ticker/bookTicker': {'cost': 1, 'noSymbol': 2},
#                     'ticker/price': {'cost': 1, 'noSymbol': 2},
#                     'time': 1,
#                     'trades': 1},
#             'post': {'userDataStream': 1},
#             'put': {'userDataStream': 1}},
#  'sapi': {'delete': {'algo/futures/order': 0.1,
#                      'broker/subAccountApi': 1,
#                      'broker/subAccountApi/ipRestriction/ipList': 1,
#                      'margin/isolated/account': 2.0001,
#                      'margin/openOrders': 0.1,
#                      'margin/order': 0.0066667,
#                      'margin/orderList': 0.0066667,
#                      'userDataStream': 0.1,
#                      'userDataStream/isolated': 0.1},
#           'get': {'account/apiRestrictions': 0.1,
#                   'account/apiRestrictions/ipRestriction': 0.1,
#                   'account/apiTradingStatus': 0.1,
#                   'account/status': 0.1,
#                   'accountSnapshot': 240,
#                   'algo/futures/historicalOrders': 0.1,
#                   'algo/futures/openOrders': 0.1,
#                   'algo/futures/subOrders': 0.1,
#                   'apiReferral/customization': 1,
#                   'apiReferral/ifNewUser': 1,
#                   'apiReferral/kickback/historicalRecord': 1,
#                   'apiReferral/kickback/recentRecord': 1,
#                   'apiReferral/rebate/historicalRecord': 1,
#                   'apiReferral/rebate/recentRecord': 1,
#                   'apiReferral/userCustomization': 1,
#                   'asset/assetDetail': 0.1,
#                   'asset/assetDividend': 1,
#                   'asset/dribblet': 0.1,
#                   'asset/tradeFee': 0.1,
#                   'asset/transfer': 0.1,
#                   'blvt/redeem/record': 0.1,
#                   'blvt/subscribe/record': 0.1,
#                   'blvt/tokenInfo': 0.1,
#                   'blvt/userLimit': 0.1,
#                   'bnbBurn': 0.1,
#                   'broker/info': 1,
#                   'broker/rebate/futures/recentRecord': 1,
#                   'broker/rebate/historicalRecord': 1,
#                   'broker/rebate/recentRecord': 1,
#                   'broker/subAccount': 1,
#                   'broker/subAccount/bnbBurn/status': 1,
#                   'broker/subAccount/depositHist': 1,
#                   'broker/subAccount/futuresSummary': 1,
#                   'broker/subAccount/marginSummary': 1,
#                   'broker/subAccount/spotSummary': 1,
#                   'broker/subAccountApi': 1,
#                   'broker/subAccountApi/commission/coinFutures': 1,
#                   'broker/subAccountApi/commission/futures': 1,
#                   'broker/subAccountApi/ipRestriction': 1,
#                   'broker/transfer': 1,
#                   'broker/transfer/futures': 1,
#                   'broker/universalTransfer': 1,
#                   'bswap/addLiquidityPreview': 1.00005,
#                   'bswap/claimedHistory': 6.667,
#                   'bswap/liquidity': {'cost': 0.1, 'noPoolId': 1},
#                   'bswap/liquidityOps': 20.001,
#                   'bswap/poolConfigure': 1.00005,
#                   'bswap/pools': 0.1,
#                   'bswap/quote': 1.00005,
#                   'bswap/removeLiquidityPreview': 1.00005,
#                   'bswap/swap': 20.001,
#                   'bswap/unclaimedRewards': 6.667,
#                   'c2c/orderMatch/listUserOrderHistory': 0.1,
#                   'capital/config/getall': 1,
#                   'capital/deposit/address': 1,
#                   'capital/deposit/hisrec': 0.1,
#                   'capital/deposit/subAddress': 0.1,
#                   'capital/deposit/subHisrec': 0.1,
#                   'capital/withdraw/history': 0.1,
#                   'convert/tradeFlow': 0.6667,
#                   'fiat/orders': 600.03,
#                   'fiat/payments': 0.1,
#                   'futures/loan/adjustCollateral/history': 1,
#                   'futures/loan/borrow/history': 1,
#                   'futures/loan/liquidationHistory': 1,
#                   'futures/loan/repay/history': 1,
#                   'futures/loan/wallet': 1,
#                   'futures/transfer': 1,
#                   'giftcard/buyCode/token-limit': 0.1,
#                   'giftcard/cryptography/rsa-public-key': 0.1,
#                   'giftcard/verify': 0.1,
#                   'lending/daily/product/list': 0.1,
#                   'lending/daily/token/position': 0.1,
#                   'lending/daily/userLeftQuota': 0.1,
#                   'lending/daily/userRedemptionQuota': 0.1,
#                   'lending/project/list': 0.1,
#                   'lending/project/position/list': 0.1,
#                   'lending/union/account': 0.1,
#                   'lending/union/interestHistory': 0.1,
#                   'lending/union/purchaseRecord': 0.1,
#                   'lending/union/redemptionRecord': 0.1,
#                   'loan/borrow/history': 40,
#                   'loan/collateral/data': 40,
#                   'loan/income': 40,
#                   'loan/loanable/data': 40,
#                   'loan/ltv/adjustment/history': 40,
#                   'loan/ongoing/orders': 40,
#                   'loan/repay/collateral/rate': 600,
#                   'loan/repay/history': 40,
#                   'managed-subaccount/accountSnapshot': 240,
#                   'managed-subaccount/asset': 0.1,
#                   'margin/account': 1,
#                   'margin/allAssets': 0.1,
#                   'margin/allOrderList': 20,
#                   'margin/allOrders': 20,
#                   'margin/allPairs': 0.1,
#                   'margin/asset': 1,
#                   'margin/crossMarginData': {'cost': 0.1, 'noCoin': 0.5},
#                   'margin/dribblet': 0.1,
#                   'margin/forceLiquidationRec': 0.1,
#                   'margin/interestHistory': 0.1,
#                   'margin/interestRateHistory': 0.1,
#                   'margin/isolated/account': 1,
#                   'margin/isolated/accountLimit': 0.1,
#                   'margin/isolated/allPairs': 1,
#                   'margin/isolated/pair': 1,
#                   'margin/isolated/transfer': 0.1,
#                   'margin/isolatedMarginData': {'cost': 0.1, 'noCoin': 1},
#                   'margin/isolatedMarginTier': 0.1,
#                   'margin/loan': 1,
#                   'margin/maxBorrowable': 5,
#                   'margin/maxTransferable': 5,
#                   'margin/myTrades': 1,
#                   'margin/openOrderList': 1,
#                   'margin/openOrders': 1,
#                   'margin/order': 1,
#                   'margin/orderList': 1,
#                   'margin/pair': 1,
#                   'margin/priceIndex': 1,
#                   'margin/rateLimit/order': 2,
#                   'margin/repay': 1,
#                   'margin/tradeCoeff': 1,
#                   'margin/transfer': 0.1,
#                   'mining/payment/list': 0.5,
#                   'mining/payment/uid': 0.5,
#                   'mining/pub/algoList': 0.1,
#                   'mining/pub/coinList': 0.1,
#                   'mining/statistics/user/list': 0.5,
#                   'mining/statistics/user/status': 0.5,
#                   'mining/worker/detail': 0.5,
#                   'mining/worker/list': 0.5,
#                   'nft/history/deposit': 20.001,
#                   'nft/history/transactions': 20.001,
#                   'nft/history/withdraw': 20.001,
#                   'nft/user/getAsset': 20.001,
#                   'pay/transactions': 20.001,
#                   'portfolio/account': 0.1,
#                   'portfolio/collateralRate': 5,
#                   'portfolio/pmLoan': 3.3335,
#                   'rebate/taxQuery': 20.001,
#                   'staking/personalLeftQuota': 0.1,
#                   'staking/position': 0.1,
#                   'staking/productList': 0.1,
#                   'staking/stakingRecord': 0.1,
#                   'sub-account/futures/account': 1,
#                   'sub-account/futures/accountSummary': 0.1,
#                   'sub-account/futures/internalTransfer': 0.1,
#                   'sub-account/futures/positionRisk': 1,
#                   'sub-account/list': 0.1,
#                   'sub-account/margin/account': 1,
#                   'sub-account/margin/accountSummary': 1,
#                   'sub-account/spotSummary': 0.1,
#                   'sub-account/status': 1,
#                   'sub-account/sub/transfer/history': 0.1,
#                   'sub-account/transfer/subUserHistory': 0.1,
#                   'sub-account/universalTransfer': 0.1,
#                   'system/status': 0.1},
#           'post': {'account/disableFastWithdrawSwitch': 0.1,
#                    'account/enableFastWithdrawSwitch': 0.1,
#                    'algo/futures/newOrderTwap': 20.001,
#                    'algo/futures/newOrderVp': 20.001,
#                    'apiReferral/customization': 1,
#                    'apiReferral/kickback/historicalRecord': 1,
#                    'apiReferral/rebate/historicalRecord': 1,
#                    'apiReferral/userCustomization': 1,
#                    'asset/convert-transfer': 0.033335,
#                    'asset/convert-transfer/queryByPage': 0.033335,
#                    'asset/dust': 1,
#                    'asset/dust-btc': 0.1,
#                    'asset/get-funding-asset': 0.1,
#                    'asset/transfer': 0.1,
#                    'blvt/redeem': 0.1,
#                    'blvt/subscribe': 0.1,
#                    'bnbBurn': 0.1,
#                    'broker/rebate/historicalRecord': 1,
#                    'broker/subAccount': 1,
#                    'broker/subAccount/blvt': 1,
#                    'broker/subAccount/bnbBurn/marginInterest': 1,
#                    'broker/subAccount/bnbBurn/spot': 1,
#                    'broker/subAccount/futures': 1,
#                    'broker/subAccount/margin': 1,
#                    'broker/subAccountApi': 1,
#                    'broker/subAccountApi/commission': 1,
#                    'broker/subAccountApi/commission/coinFutures': 1,
#                    'broker/subAccountApi/commission/futures': 1,
#                    'broker/subAccountApi/ipRestriction': 1,
#                    'broker/subAccountApi/ipRestriction/ipList': 1,
#                    'broker/subAccountApi/permission': 1,
#                    'broker/subAccountApi/permission/universalTransfer': 1,
#                    'broker/subAccountApi/permission/vanillaOptions': 1,
#                    'broker/transfer': 1,
#                    'broker/transfer/futures': 1,
#                    'broker/universalTransfer': 1,
#                    'bswap/claimRewards': 6.667,
#                    'bswap/liquidityAdd': 60,
#                    'bswap/liquidityRemove': 60,
#                    'bswap/swap': 60,
#                    'capital/withdraw/apply': 4.0002,
#                    'futures/transfer': 0.1,
#                    'giftcard/buyCode': 0.1,
#                    'giftcard/createCode': 0.1,
#                    'giftcard/redeemCode': 0.1,
#                    'lending/customizedFixed/purchase': 0.1,
#                    'lending/daily/purchase': 0.1,
#                    'lending/daily/redeem': 0.1,
#                    'loan/adjust/ltv': 40,
#                    'loan/borrow': 40,
#                    'loan/customize/margin_call': 40,
#                    'loan/repay': 40,
#                    'managed-subaccount/deposit': 0.1,
#                    'managed-subaccount/withdraw': 0.1,
#                    'margin/isolated/account': 2.0001,
#                    'margin/isolated/transfer': 4.0002,
#                    'margin/loan': 20.001,
#                    'margin/order': 0.040002,
#                    'margin/order/oco': 0.040002,
#                    'margin/repay': 20.001,
#                    'margin/transfer': 1,
#                    'portfolio/repay': 20.001,
#                    'staking/purchase': 0.1,
#                    'staking/redeem': 0.1,
#                    'staking/setAutoStaking': 0.1,
#                    'sub-account/futures/enable': 0.1,
#                    'sub-account/futures/internalTransfer': 0.1,
#                    'sub-account/futures/transfer': 0.1,
#                    'sub-account/margin/enable': 0.1,
#                    'sub-account/margin/transfer': 4.0002,
#                    'sub-account/transfer/subToMaster': 0.1,
#                    'sub-account/transfer/subToSub': 0.1,
#                    'sub-account/universalTransfer': 0.1,
#                    'sub-account/virtualSubAccount': 0.1,
#                    'userDataStream': 0.1,
#                    'userDataStream/isolated': 0.1},
#           'put': {'userDataStream': 0.1, 'userDataStream/isolated': 0.1}},
#  'sapiV3': {'get': {'sub-account/assets': 1},
#             'post': {'asset/getUserAsset': 0.5}},
#  'wapi': {'get': {'accountStatus': 1,
#                   'apiTradingStatus': 1,
#                   'assetDetail': 1,
#                   'depositAddress': 1,
#                   'depositHistory': 1,
#                   'sub-account/assets': 1,
#                   'sub-account/list': 1,
#                   'sub-account/transfer/history': 1,
#                   'systemStatus': 1,
#                   'tradeFee': 1,
#                   'userAssetDribbletLog': 1,
#                   'withdrawHistory': 1},
#           'post': {'sub-account/transfer': 1, 'withdraw': 1}}}

# %%
exchange.loadMarkets()
print(hprint.list_to_str(exchange.markets.keys(), tag="market_list"))
# Out:
# market_list: (227) BTC/USDT ETH/USDT BCH/USDT XRP/USDT EOS/USDT LTC/USDT TRX/USDT ETC/USDT LINK/USDT XLM/USDT ADA/USDT DASH/USDT ZEC/USDT XTZ/USDT BNB/USDT ATOM/USDT ONT/USDT IOTA/USDT BAT/USDT VET/USDT NEOUSDT QTUM/USDT IOST/USDT THETA/USDT ALGO/USDT ZIL/USDT KNC/USDT ZRX/USDT COMP/USDT OMG/USDT DOGE/USDT SXP/USDT KAVA/USDT BAND/USDT RLC/USDT WAVES/USDT MKR/USDT SNX/USDT DOT/USDT DEFI/USDT YFI/USDT BAL/USDT CRV/USDT TRBUSDT RUNE/USDT SUSHI/USDT SRMUSDT EGLD/USDT SOL/USDT ICXUSDT STORJ/USDT UNI/USDT AVAX/USDT FTM/USDT HNT/USDT ENJ/USDT FLM/USDT TOMO/USDT REN/USDT KSM/USDT NEAR/USDT AAVE/USDT FIL/USDT RSRUSDT LRC/USDT MATIC/USDT OCEAN/USDT BELUSDT CTKUSDT AXS/USDT ALPHAUSDT ZEN/USDT SKL/USDT GRT/USDT BNTUSDT 1INCH/USDT UNFI/USDT BTC/BUSD CHZ/USDT SAND/USDT ANKR/USDT LIT/USDT REEF/USDT RVNUSDT SFPUSDT XEMUSDT BTCSTUSDT COTI/USDT CHR/USDT MANA/USDT ALICE/USDT HBARUSDT ONE/USDT LINA/USDT STMX/USDT DENT/USDT CELR/USDT HOT/USDT MTL/USDT OGN/USDT NKNUSDT DGBUSDT 1000SHIB/USDT BAKEUSDT GTCUSDT ETH/BUSD BTCDOM/USDT MASK/USDT BNB/BUSD ADA/BUSD DOGEBUSD XRPBUSD IOTX/USDT AUDIO/USDT C98/USDT ATA/USDT SOL/BUSD DYDX/USDT 1000XEC/USDT GALA/USDT CELO/USDT AR/USDT KLAY/USDT ARPA/USDT CTSIUSDT LPTUSDT ENS/USDT PEOPLE/USDT ANT/USDT ROSE/USDT DUSK/USDT FLOW/USDT IMX/USDT API3/USDT GMT/USDT APE/USDT WOO/USDT JASMY/USDT DAR/USDT GAL/USDT TRX/BUSD GALA/BUSD FTM/BUSD GAL/BUSD ANC/BUSD 1000LUNC/BUSD LUNA2/BUSD OP/USDT DOT/BUSD ICP/BUSD WAVEBUSD LINK/BUSD WAVES/BUSD XMR/USDT LTC/BUSD SAND/BUSD MATIC/BUSD LEVER/BUSD 1000SHIB/BUSD LDO/BUSD UNI/BUSD AUCTION/BUSD INJ/USDT STG/USDT SPELL/USDT 1000LUNC/USDT LUNA2/USDT AMB/BUSD LDO/USDT CVX/USDT ICP2USDT FOOTBALL/USDT APT/USDT QNT/USDT APT/BUSD BLUEBIRD/USDT AGIX/BUSD FXS/USDT HOOK/USDT MAGIC/USDT T/USDT RNDR/USDT HIGH/USDT MINA/USDT ASTR/USDT PHB/USDT AGIX/USDT FET/USDT GMX/USDT CFX/USDT STX/USDT BNX/USDT ACH/USDT SSV/USDT CKB/USDT PERP/USDT LQTY/USDT USDC/USDT ARB/USDT ID/USDT ID/BUSD ARB/BUSD JOE/USDT AMB AMB/USDT LEVER/USDT TRU/USDT RDNT/USDT ETH/BTC HFT/USDT XVS/USDT BLUR/USDT EDU/USDT IDEX/USDT 1000PEPE/USDT 1000FLOKIUSDT RAD/USDT UMA/USDT KEY/USDT COMBO/USDT SUI/USDT NMR/USDT BTCUSDT_230929 ETHUSDT_230929 MAV/USDT MDT/USDT XVG/USDT

# %%
print(hprint.list_to_str(exchange.currencies, tag="currencies"))
# Out:
# currencies: (197) 1000FLOKI 1000LUNC 1000PEPE 1000SHIB 1000XEC 1INCH AAVE ACH ADA AGIX ALGO ALICE ALPHA AMB ANC ANKR ANT APE API3 APT AR ARB ARPA ASTR ATA ATOM AUCTION AUDIO AVAX AXS BAKE BAL BAND BAT BCH BEL BLUEBIRD BLUR BNB BNT BNX BTC BTCDOM BTCST BUSD C98 CELO CELR CFX CHR CHZ CKB COMBO COMP COTI CRV CTK CTSI CVX DAR DASH DEFI DENT DGB DOGE DOT DUSK DYDX EDU EGLD ENJ ENS EOS ETC ETH FET FIL FLM FLOW FOOTBALL FTM FXS GAL GALA GMT GMX GRT GTC HBAR HFT HIGH HNT HOOK HOT ICP ICP2 ICX ID IDEX IMX INJ IOST IOTA IOTX JASMY JOE KAVA KEY KLAY KNC KSM LDO LEVER LINA LINK LIT LPT LQTY LRC LTC LUNA2 MAGIC MANA MASK MATIC MAV MDT MINA MKR MTL NEAR NEO NKN NMR OCEAN OGN OMG ONE ONT OP PEOPLE PERP PHB QNT QTUM RAD RDNT REEF REN RLC RNDR ROSE RSR RUNE RVN SAND SFP SKL SNX SOL SPELL SRM SSV STG STMX STORJ STX SUI SUSHI SXP T THETA TOMO TRB TRU TRX UMA UNFI UNI USDC USDT VET WAVE WAVES WOO XEM XLM XMR XRP XTZ XVG XVS YFI ZEC ZEN ZIL ZRX

# %%
hprint.pprint_color(exchange.commonCurrencies)
# Out:
# {'BCC': 'BCC', 'BCHABC': 'BCH', 'BCHSV': 'BSV', 'XBT': 'BTC', 'YOYO': 'YOYOW'}

# %% [markdown]
# ## Exchange metadata

# %%
# Flags for exchange capabilities (true, false, emulated).
# CORS = cross-origin resource sharing.
hprint.pprint_color(exchange.has)
# Out:
# {'CORS': None,
#  'addMargin': True,
#  'borrowMargin': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': None,
#  'createDepositAddress': False,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'createPostOnlyOrder': None,
#  'createReduceOnlyOrder': True,
#  'createStopLimitOrder': True,
#  'createStopMarketOrder': False,
#  'createStopOrder': True,
#  'editOrder': 'emulated',
#  'fetchAccounts': None,
#  'fetchBalance': True,
#  'fetchBidsAsks': True,
#  'fetchBorrowInterest': True,
#  'fetchBorrowRate': True,
#  'fetchBorrowRateHistories': False,
#  'fetchBorrowRateHistory': True,
#  'fetchBorrowRates': False,
#  'fetchBorrowRatesPerSymbol': False,
#  'fetchCanceledOrders': False,
#  'fetchClosedOrder': False,
#  'fetchClosedOrders': 'emulated',
#  'fetchCurrencies': True,
#  'fetchDeposit': False,
#  'fetchDepositAddress': True,
#  'fetchDepositAddresses': False,
#  'fetchDepositAddressesByNetwork': False,
#  'fetchDeposits': True,
#  'fetchFundingFee': None,
#  'fetchFundingFees': None,
#  'fetchFundingHistory': True,
#  'fetchFundingRate': True,
#  'fetchFundingRateHistory': True,
#  'fetchFundingRates': True,
#  'fetchIndexOHLCV': True,
#  'fetchL2OrderBook': True,
#  'fetchL3OrderBook': False,
#  'fetchLedger': None,
#  'fetchLedgerEntry': None,
#  'fetchLeverage': False,
#  'fetchLeverageTiers': True,
#  'fetchMarkOHLCV': True,
#  'fetchMarketLeverageTiers': 'emulated',
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenInterestHistory': True,
#  'fetchOpenOrder': False,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrderTrades': True,
#  'fetchOrders': True,
#  'fetchPermissions': None,
#  'fetchPosition': None,
#  'fetchPositions': True,
#  'fetchPositionsRisk': True,
#  'fetchPremiumIndexOHLCV': False,
#  'fetchStatus': True,
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchTradingLimits': None,
#  'fetchTransactionFee': None,
#  'fetchTransactionFees': True,
#  'fetchTransactions': False,
#  'fetchTransfers': True,
#  'fetchWithdrawal': False,
#  'fetchWithdrawalWhitelist': False,
#  'fetchWithdrawals': True,
#  'future': True,
#  'margin': True,
#  'option': None,
#  'privateAPI': True,
#  'publxicAPI': True,
#  'reduceMargin': True,
#  'repayMargin': True,
#  'setLeverage': True,
#  'setMargin': False,
#  'setMarginMode': True,
#  'setPositionMode': True,
#  'signIn': False,
#  'spot': True,
#  'swap': True,
#  'transfer': True,
#  'withdraw': True}

# %% [markdown]
# ## Rate limit

# %% [markdown]
# # Markets
#
# - Valuables
#     - Valuables are exchanged at each market
#       - E.g.,
#         - instruments
#         - symbols
#         - assets
#         - trading pairs
#         - currencies
#         - tokens
#         - contract
#
# - Exchange and Market
#     - Every Exchange offers multiple Markets
#     - A Market is usually a pair of currencies (e.g., crypto, fiat)

# %% [markdown]
# ## Currency structure
#
# - Each currency has an associated dictionary
#     - `id`: currency id within the exchange
#     - `code`: `cctx` representation of the currency
#     - `name`: human readable currency name
#     - `fee`: withdrawal fee
#     - `active`: indicates whether trading and funding this currency is possible
#     - `info`: dictionary of non-common market properties
#     - `precision`
#     - `limits`: min and max for withdrawals

# %% [markdown]
# ## Market structure
#
# - `id` string representing the instrument within the exchange (e.g., `btcusd`)
# - `baseId` (e.g., `btc`), `quoteId` (e.g., `usd`) are exchange-specific ids
# - `symbol` string code representing the trading pair
#   - E.g., typically `BaseCurrency/QuoteCurrency` (e.g., `BTC/USD`)
#   - This is standard in `ccxt`
# - `base` (e.g., `BTC`) / `quote` (`USD`) standardized currency code
# - `active`: indicates whether trading this market is possible
#   - The cache of the markets should be refreshed periodically
# - `maker`: maker fees paid when you provide liquidity to the exchange
#   - E.g., you make an order and someone else fills it
#   - A negative fee means a rebate
# - `taker`: taker fees paid when you take liquidity from the exchange (i.e., you
#   fill someone else's order)
# - `tierBased`: whether the fee depends on your trading tier (e.g., amount of
#   trading done over a period of time)
# - `info`: non-common market properties
# - `precision`: precision used for price, amount, and cost
#   - E.g., decimal places, significant digits, tick size

# %%
# A market is an associative array.

#market_id = exchange.markets_by_id["1000FLOKIUSDT"]
market_id = exchange.markets_by_id["ETHUSDT"]
print(type(market_id))
hprint.pprint_color(market_id)
# Out:
# <class 'dict'>
# {'active': True,
#  'base': 'ETH',
#  'baseId': 'ETH',
#  'contract': True,
#  'contractSize': 1.0,
#  'delivery': False,
#  'expiry': None,
#  'expiryDatetime': None,
#  'future': True,
#  'id': 'ETHUSDT',
#  'info': {'baseAsset': 'ETH',
#           'baseAssetPrecision': '8',
#           'contractType': 'PERPETUAL',
#           'deliveryDate': '4133404800000',
#           'filters': [{'filterType': 'PRICE_FILTER',
#                        'maxPrice': '95000.02',
#                        'minPrice': '18.62',
#                        'tickSize': '0.01'},
#                       {'filterType': 'LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MARKET_LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MAX_NUM_ORDERS', 'limit': '200'},
#                       {'filterType': 'MAX_NUM_ALGO_ORDERS', 'limit': '10'},
#                       {'filterType': 'MIN_NOTIONAL', 'notional': '5.0'},
#                       {'filterType': 'PERCENT_PRICE',
#                        'multiplierDecimal': '4',
#                        'multiplierDown': '0.9000',
#                        'multiplierUp': '1.1000'}],
#           'liquidationFee': '0.020000',
#           'maintMarginPercent': '2.5000',
#           'marginAsset': 'USDT',
#           'marketTakeBound': '0.10',
#           'maxMoveOrderLimit': '10000',
#           'onboardDate': '1569398400000',
#           'orderTypes': ['LIMIT',
#                          'MARKET',
#                          'STOP',
#                          'STOP_MARKET',
#                          'TAKE_PROFIT',
#                          'TAKE_PROFIT_MARKET',
#                          'TRAILING_STOP_MARKET'],
#           'pair': 'ETHUSDT',
#           'pricePrecision': '2',
#           'quantityPrecision': '3',
#           'quoteAsset': 'USDT',
#           'quotePrecision': '8',
#           'requiredMarginPercent': '5.0000',
#           'settlePlan': '0',
#           'status': 'TRADING',
#           'symbol': 'ETHUSDT',
#           'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX'],
#           'triggerProtect': '0.0500',
#           'underlyingSubType': [],
#           'underlyingType': 'COIN'},
#  'inverse': False,
#  'limits': {'amount': {'max': 10000.0, 'min': 0.001},
#             'cost': {'max': None, 'min': 5.0},
#             'leverage': {'max': None, 'min': None},
#             'market': {'max': 10000.0, 'min': 0.001},
#             'price': {'max': 95000.02, 'min': 18.62}},
#  'linear': True,
#  'lowercaseId': 'ethusdt',
#  'maker': 0.0002,
#  'margin': False,
#  'option': False,
#  'optionType': None,
#  'precision': {'amount': 3, 'base': 8, 'price': 2, 'quote': 8},
#  'quote': 'USDT',
#  'quoteId': 'USDT',
#  'settle': 'USDT',
#  'settleId': 'USDT',
#  'spot': False,
#  'strike': None,
#  'swap': True,
#  'symbol': 'ETH/USDT',
#  'taker': 0.0004,
#  'type': 'future'}

# %%
# Trade instrument within the exchange. This is the internal representation of each exchange.
market = exchange.markets["ETH/USDT"]
print(market["id"])
# Out:
# ETHUSDT

# %%
# Trade instrument in CCXT user-land (unified). Typically referrend as "base/quote".
print(market["symbol"])
# Out:
# ETH/USDT

# %%
# Market ids (unified)
print(market["base"], market["quote"])
# Out:
# ETH USDT

# %%
# Symbol ids (not unified).
print(market["baseId"], market["quoteId"])
# Out:
# ETH USDT

# %%
print(hprint.to_str('market["active"] market["maker"] market["taker"] market["percentage"]'))
# Out:
# market["active"]=True, market["maker"]=0.0002, market["taker"]=0.0004, market["percentage"]=True

# %%
# Market-specific properties.
hprint.pprint_color(market["info"])
# Out:
# {'baseAsset': 'ETH',
#  'baseAssetPrecision': '8',
#  'contractType': 'PERPETUAL',
#  'deliveryDate': '4133404800000',
#  'filters': [{'filterType': 'PRICE_FILTER',
#               'maxPrice': '95000.02',
#               'minPrice': '18.62',
#               'tickSize': '0.01'},
#              {'filterType': 'LOT_SIZE',
#               'maxQty': '10000',
#               'minQty': '0.001',
#               'stepSize': '0.001'},
#              {'filterType': 'MARKET_LOT_SIZE',
#               'maxQty': '10000',
#               'minQty': '0.001',
#               'stepSize': '0.001'},
#              {'filterType': 'MAX_NUM_ORDERS', 'limit': '200'},
#              {'filterType': 'MAX_NUM_ALGO_ORDERS', 'limit': '10'},
#              {'filterType': 'MIN_NOTIONAL', 'notional': '5.0'},
#              {'filterType': 'PERCENT_PRICE',
#               'multiplierDecimal': '4',
#               'multiplierDown': '0.9000',
#               'multiplierUp': '1.1000'}],
#  'liquidationFee': '0.020000',
#  'maintMarginPercent': '2.5000',
#  'marginAsset': 'USDT',
#  'marketTakeBound': '0.10',
#  'maxMoveOrderLimit': '10000',
#  'onboardDate': '1569398400000',
#  'orderTypes': ['LIMIT',
#                 'MARKET',
#                 'STOP',
#                 'STOP_MARKET',
#                 'TAKE_PROFIT',
#                 'TAKE_PROFIT_MARKET',
#                 'TRAILING_STOP_MARKET'],
#  'pair': 'ETHUSDT',
#  'pricePrecision': '2',
#  'quantityPrecision': '3',
#  'quoteAsset': 'USDT',
#  'quotePrecision': '8',
#  'requiredMarginPercent': '5.0000',
#  'settlePlan': '0',
#  'status': 'TRADING',
#  'symbol': 'ETHUSDT',
#  'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX'],
#  'triggerProtect': '0.0500',
#  'underlyingSubType': [],
#  'underlyingType': 'COIN'}

# %% [markdown]
# ## Network structure

# %% [markdown]
# ## Precision and limits

# %%
# limits = min, max for prices / amounts (aka volumes) / costs (= price * amount)
# precision = precision for prices / amounts / costs accepted in order values when placing orders
# They are not related.

hprint.pprint_color(market["limits"], tag="limits", sep="\n")
hprint.pprint_color(market["precision"], tag="precision", sep="\n")
# Out:
# limits=
# {'amount': {'max': 10000.0, 'min': 0.001},
#  'cost': {'max': None, 'min': 5.0},
#  'leverage': {'max': None, 'min': None},
#  'market': {'max': 10000.0, 'min': 0.001},
#  'price': {'max': 95000.02, 'min': 18.62}}
# precision=
# {'amount': 3, 'base': 8, 'price': 2, 'quote': 8}

# %%
# Min / max amount (i.e., volume) for an order.
print(market["limits"]["amount"])
# Out:
# {'min': 0.001, 'max': 10000.0}

# %%
# How many decimal digits.

# %%
# Each exchange has their own way of rounding and truncating.

# %%
exchange.precisionMode
# Out:
# 2

# %%
ccxt.TICK_SIZE
# Out:
# 4

# %%
ccxt.SIGNIFICANT_DIGITS
# Out:
# 3

# %%
ccxt.DECIMAL_PLACES
# Out:
# 2

# %%
# From https://docs.ccxt.com/#/README?id=formatting-to-precision
#ccxt.base.decimal_to_precision.amount_to_precision(symbol, amount)

# %% [markdown]
# ## Loading markets

# %%
markets = exchange.load_markets()

# %% [markdown]
# ## Symbols and Market Ids
#
# ### Symbols and market ids
#
# * Currency code
# - = a code of 3 to 5 uppercase letters
# - E.g., `BTC`, `ETH`, `USD`, `XRP`
#
# * Symbol
# - = a pair of currencies separated by a slash
#   - E.g., `BTC/USD`
# - The first currency is called the "base currency"
# - The second currency is called the "quote currency"
#   - BASE / QUOTE
#
# * Market Ids
# - Market ids are unique per exchange and are used in REST request-response
#   - E.g., the same BTC/USD pair can be called in different ways on different
#     markets (e.g., `BTCUSD`, `btc/usd`)
# - `CCTX` abstracts market ids into standardized symbols
#
# * Market symbol vs market ids
# - "Market symbols" are the abstract representation
# - "Market ids" are specific of each market
#
# ### Methods for markets and currencies
#
# // notebook
#
# ### Naming consistency
#
# * Products
# - Some exchanges call markets as "pairs" or "products"
# - `CCXT` considers each exchange as having one or more "trading markets"
#   - Each market has an `id` and a `symbol`
#   - Most symbols are typically a currency pair
#
# * Exchange -> Markets -> Symbols -> Currencies
# - The logic is:
#   - Exchange (name of the exchange, e.g., Binance)
#   - Markets (a "product" that is traded, e.g., the pair `BTC/USD`)
#   - Symbols (a pair of traded currencies separated by slash)
#   - Currencies (the currency code, e.g., `BTC` and `USD`)
#
# - The same currency:
#   - can have different names on different exchanges
#   - has changed name over time (e.g., `XBT` -> `BTC`, `USD` = `USDT`)
#
# * Expiring / perpetual futures
# - Aka "swaps"
# - Futures market symbol have:
#   - Underlying currency
#   - Quoting currency
#   - Settlement currency
#   - Identifier for a settlement date (typically as YYMMDD)
#
# - E.g., `BTC/USDT:BTC-211225`
#   - BTC/USDT futures contract settled in BTC (inverse) on 2021-12-25
# - E.g., `BTC/USDT:USDT-211225`
#   - BTC/USDT futures contract settled in USDT (linear, vanilla)
#
# * Perpetual futures
# - Aka "perpetual swaps"
# - E.g., `BTC/USDT:BTC`

# %%
exchange.load_markets();

# %%
# Get the market structure.
market = exchange.markets["ETH/USDT"]
hprint.pprint_color(market)
# Out:
# {'active': True,
#  'base': 'ETH',
#  'baseId': 'ETH',
#  'contract': True,
#  'contractSize': 1.0,
#  'delivery': False,
#  'expiry': None,
#  'expiryDatetime': None,
#  'feeSide': 'get',
#  'future': True,
#  'id': 'ETHUSDT',
#  'info': {'baseAsset': 'ETH',
#           'baseAssetPrecision': '8',
#           'contractType': 'PERPETUAL',
#           'deliveryDate': '4133404800000',
#           'filters': [{'filterType': 'PRICE_FILTER',
#                        'maxPrice': '306177',
#                        'minPrice': '39.86',
#                        'tickSize': '0.01'},
#                       {'filterType': 'LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MARKET_LOT_SIZE',
#                        'maxQty': '2000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MAX_NUM_ORDERS', 'limit': '200'},
#                       {'filterType': 'MAX_NUM_ALGO_ORDERS', 'limit': '10'},
#                       {'filterType': 'MIN_NOTIONAL', 'notional': '5.0'},
#                       {'filterType': 'PERCENT_PRICE',
#                        'multiplierDecimal': '4',
#                        'multiplierDown': '0.9500',
#                        'multiplierUp': '1.0500'}],
#           'liquidationFee': '0.012500',
#           'maintMarginPercent': '2.5000',
#           'marginAsset': 'USDT',
#           'marketTakeBound': '0.05',
#           'maxMoveOrderLimit': '10000',
#           'onboardDate': '1569398400000',
#           'orderTypes': ['LIMIT',
#                          'MARKET',
#                          'STOP',
#                          'STOP_MARKET',
#                          'TAKE_PROFIT',
#                          'TAKE_PROFIT_MARKET',
#                          'TRAILING_STOP_MARKET'],
#           'pair': 'ETHUSDT',
#           'pricePrecision': '2',
#           'quantityPrecision': '3',
#           'quoteAsset': 'USDT',
#           'quotePrecision': '8',
#           'requiredMarginPercent': '5.0000',
#           'settlePlan': '0',
#           'status': 'TRADING',
#           'symbol': 'ETHUSDT',
#           'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX'],
#           'triggerProtect': '0.0500',
#           'underlyingSubType': ['Layer-1'],
#           'underlyingType': 'COIN'},
#  'inverse': False,
#  'limits': {'amount': {'max': 10000.0, 'min': 0.001},
#             'cost': {'max': None, 'min': 5.0},
#             'leverage': {'max': None, 'min': None},
#             'market': {'max': 2000.0, 'min': 0.001},
#             'price': {'max': 306177.0, 'min': 39.86}},
#  'linear': True,
#  'lowercaseId': 'ethusdt',
#  'maker': 0.0002,
#  'margin': False,
#  'option': False,
#  'optionType': None,
#  'percentage': True,
#  'precision': {'amount': 3, 'base': 8, 'price': 2, 'quote': 8},
#  'quote': 'USDT',
#  'quoteId': 'USDT',
#  'settle': 'USDT',
#  'settleId': 'USDT',
#  'spot': False,
#  'strike': None,
#  'swap': True,
#  'symbol': 'ETH/USDT',
#  'taker': 0.0004,
#  'tierBased': False,
#  'type': 'future'}

# %%
# Print a subset of interesting values for Market structure.
var_names = [
    "id",
    "symbol",
    "base",
    "quote",
    "baseId",
    "quoteId",
    "active",
    "maker",
    "taker",
    "tierBased",
    "info",
    "precision",
    "limits",
]
# for var_name in var_names:
#     print(f"--> {var_name}=", hprint.pprint_pformat(market[var_name]))
hprint.pprint_color(
    subset_dict(market, var_names))
# Out:
# {'active': True,
#  'base': 'ETH',
#  'baseId': 'ETH',
#  'id': 'ETHUSDT',
#  'info': {'baseAsset': 'ETH',
#           'baseAssetPrecision': '8',
#           'contractType': 'PERPETUAL',
#           'deliveryDate': '4133404800000',
#           'filters': [{'filterType': 'PRICE_FILTER',
#                        'maxPrice': '306177',
#                        'minPrice': '39.86',
#                        'tickSize': '0.01'},
#                       {'filterType': 'LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MARKET_LOT_SIZE',
#                        'maxQty': '2000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MAX_NUM_ORDERS', 'limit': '200'},
#                       {'filterType': 'MAX_NUM_ALGO_ORDERS', 'limit': '10'},
#                       {'filterType': 'MIN_NOTIONAL', 'notional': '5.0'},
#                       {'filterType': 'PERCENT_PRICE',
#                        'multiplierDecimal': '4',
#                        'multiplierDown': '0.9500',
#                        'multiplierUp': '1.0500'}],
#           'liquidationFee': '0.012500',
#           'maintMarginPercent': '2.5000',
#           'marginAsset': 'USDT',
#           'marketTakeBound': '0.05',
#           'maxMoveOrderLimit': '10000',
#           'onboardDate': '1569398400000',
#           'orderTypes': ['LIMIT',
#                          'MARKET',
#                          'STOP',
#                          'STOP_MARKET',
#                          'TAKE_PROFIT',
#                          'TAKE_PROFIT_MARKET',
#                          'TRAILING_STOP_MARKET'],
#           'pair': 'ETHUSDT',
#           'pricePrecision': '2',
#           'quantityPrecision': '3',
#           'quoteAsset': 'USDT',
#           'quotePrecision': '8',
#           'requiredMarginPercent': '5.0000',
#           'settlePlan': '0',
#           'status': 'TRADING',
#           'symbol': 'ETHUSDT',
#           'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX'],
#           'triggerProtect': '0.0500',
#           'underlyingSubType': ['Layer-1'],
#           'underlyingType': 'COIN'},
#  'limits': {'amount': {'max': 10000.0, 'min': 0.001},
#             'cost': {'max': None, 'min': 5.0},
#             'leverage': {'max': None, 'min': None},
#             'market': {'max': 2000.0, 'min': 0.001},
#             'price': {'max': 306177.0, 'min': 39.86}},
#  'maker': 0.0002,
#  'precision': {'amount': 3, 'base': 8, 'price': 2, 'quote': 8},
#  'quote': 'USDT',
#  'quoteId': 'USDT',
#  'symbol': 'ETH/USDT',
#  'taker': 0.0004,
#  'tierBased': False}

# %%
# Print all the symbols in one exchange.
symbols = exchange.symbols
print(symbols)
# Out:
# ['1000FLOKIUSDT', '1000LUNC/BUSD', '1000LUNC/USDT', '1000PEPE/USDT', '1000SHIB/BUSD', '1000SHIB/USDT', '1000XEC/USDT', '1INCH/USDT', 'AAVE/USDT', 'ACH/USDT', 'ADA/BUSD', 'ADA/USDT', 'AGIX/BUSD', 'AGIX/USDT', 'ALGO/USDT', 'ALICE/USDT', 'ALPHAUSDT', 'AMB', 'AMB/BUSD', 'AMB/USDT', 'ANC/BUSD', 'ANKR/USDT', 'ANT/USDT', 'APE/USDT', 'API3/USDT', 'APT/BUSD', 'APT/USDT', 'AR/USDT', 'ARB/BUSD', 'ARB/USDT', 'ARPA/USDT', 'ASTR/USDT', 'ATA/USDT', 'ATOM/USDT', 'AUCTION/BUSD', 'AUDIO/USDT', 'AVAX/USDT', 'AXS/USDT', 'BAKEUSDT', 'BAL/USDT', 'BAND/USDT', 'BAT/USDT', 'BCH/USDT', 'BELUSDT', 'BLUEBIRD/USDT', 'BLUR/USDT', 'BNB/BUSD', 'BNB/USDT', 'BNTUSDT', 'BNX/USDT', 'BTC/BUSD', 'BTC/USDT', 'BTCDOM/USDT', 'BTCSTUSDT', 'BTCUSDT_230929', 'C98/USDT', 'CELO/USDT', 'CELR/USDT', 'CFX/USDT', 'CHR/USDT', 'CHZ/USDT', 'CKB/USDT', 'COMBO/USDT', 'COMP/USDT', 'COTI/USDT', 'CRV/USDT', 'CTKUSDT', 'CTSIUSDT', 'CVX/USDT', 'DAR/USDT', 'DASH/USDT', 'DEFI/USDT', 'DENT/USDT', 'DGBUSDT', 'DOGE/USDT', 'DOGEBUSD', 'DOT/BUSD', 'DOT/USDT', 'DUSK/USDT', 'DYDX/USDT', 'EDU/USDT', 'EGLD/USDT', 'ENJ/USDT', 'ENS/USDT', 'EOS/USDT', 'ETC/USDT', 'ETH/BTC', 'ETH/BUSD', 'ETH/USDT', 'ETHUSDT_230929', 'FET/USDT', 'FIL/USDT', 'FLM/USDT', 'FLOW/USDT', 'FOOTBALL/USDT', 'FTM/BUSD', 'FTM/USDT', 'FXS/USDT', 'GAL/BUSD', 'GAL/USDT', 'GALA/BUSD', 'GALA/USDT', 'GMT/USDT', 'GMX/USDT', 'GRT/USDT', 'GTCUSDT', 'HBARUSDT', 'HFT/USDT', 'HIGH/USDT', 'HNT/USDT', 'HOOK/USDT', 'HOT/USDT', 'ICP/BUSD', 'ICP2USDT', 'ICXUSDT', 'ID/BUSD', 'ID/USDT', 'IDEX/USDT', 'IMX/USDT', 'INJ/USDT', 'IOST/USDT', 'IOTA/USDT', 'IOTX/USDT', 'JASMY/USDT', 'JOE/USDT', 'KAVA/USDT', 'KEY/USDT', 'KLAY/USDT', 'KNC/USDT', 'KSM/USDT', 'LDO/BUSD', 'LDO/USDT', 'LEVER/BUSD', 'LEVER/USDT', 'LINA/USDT', 'LINK/BUSD', 'LINK/USDT', 'LIT/USDT', 'LPTUSDT', 'LQTY/USDT', 'LRC/USDT', 'LTC/BUSD', 'LTC/USDT', 'LUNA2/BUSD', 'LUNA2/USDT', 'MAGIC/USDT', 'MANA/USDT', 'MASK/USDT', 'MATIC/BUSD', 'MATIC/USDT', 'MAV/USDT', 'MDT/USDT', 'MINA/USDT', 'MKR/USDT', 'MTL/USDT', 'NEAR/USDT', 'NEOUSDT', 'NKNUSDT', 'NMR/USDT', 'OCEAN/USDT', 'OGN/USDT', 'OMG/USDT', 'ONE/USDT', 'ONT/USDT', 'OP/USDT', 'PEOPLE/USDT', 'PERP/USDT', 'PHB/USDT', 'QNT/USDT', 'QTUM/USDT', 'RAD/USDT', 'RDNT/USDT', 'REEF/USDT', 'REN/USDT', 'RLC/USDT', 'RNDR/USDT', 'ROSE/USDT', 'RSRUSDT', 'RUNE/USDT', 'RVNUSDT', 'SAND/BUSD', 'SAND/USDT', 'SFPUSDT', 'SKL/USDT', 'SNX/USDT', 'SOL/BUSD', 'SOL/USDT', 'SPELL/USDT', 'SRMUSDT', 'SSV/USDT', 'STG/USDT', 'STMX/USDT', 'STORJ/USDT', 'STX/USDT', 'SUI/USDT', 'SUSHI/USDT', 'SXP/USDT', 'T/USDT', 'THETA/USDT', 'TOMO/USDT', 'TRBUSDT', 'TRU/USDT', 'TRX/BUSD', 'TRX/USDT', 'UMA/USDT', 'UNFI/USDT', 'UNI/BUSD', 'UNI/USDT', 'USDC/USDT', 'VET/USDT', 'WAVEBUSD', 'WAVES/BUSD', 'WAVES/USDT', 'WOO/USDT', 'XEMUSDT', 'XLM/USDT', 'XMR/USDT', 'XRP/USDT', 'XRPBUSD', 'XTZ/USDT', 'XVG/USDT', 'XVS/USDT', 'YFI/USDT', 'ZEC/USDT', 'ZEN/USDT', 'ZIL/USDT', 'ZRX/USDT']

# %%
# Print a dictionary of all currencies.
currencies = exchange.currencies
hprint.pprint_color(currencies)
# Out:
# {'1000FLOKI': {'code': '1000FLOKI',
#                'id': '1000FLOKI',
#                'numericId': None,
#                'precision': 8},
#  '1000LUNC': {'code': '1000LUNC',
#               'id': '1000LUNC',
#               'numericId': None,
#               'precision': 8},
#  '1000PEPE': {'code': '1000PEPE',
#               'id': '1000PEPE',
#               'numericId': None,
#               'precision': 8},
#  '1000SHIB': {'code': '1000SHIB',
#               'id': '1000SHIB',
#               'numericId': None,
#               'precision': 8},
#  '1000XEC': {'code': '1000XEC',
#              'id': '1000XEC',
#              'numericId': None,
#              'precision': 8},
#  '1INCH': {'code': '1INCH', 'id': '1INCH', 'numericId': None, 'precision': 8},
#  'AAVE': {'code': 'AAVE', 'id': 'AAVE', 'numericId': None, 'precision': 8},
#  'ACH': {'code': 'ACH', 'id': 'ACH', 'numericId': None, 'precision': 8},
#  'ADA': {'code': 'ADA', 'id': 'ADA', 'numericId': None, 'precision': 8},
#  'AGIX': {'code': 'AGIX', 'id': 'AGIX', 'numericId': None, 'precision': 8},
#  'ALGO': {'code': 'ALGO', 'id': 'ALGO', 'numericId': None, 'precision': 8},
#  'ALICE': {'code': 'ALICE', 'id': 'ALICE', 'numericId': None, 'precision': 8},
#  'ALPHA': {'code': 'ALPHA', 'id': 'ALPHA', 'numericId': None, 'precision': 8},
#  'AMB': {'code': 'AMB', 'id': 'AMB', 'numericId': None, 'precision': 8},
#  'ANC': {'code': 'ANC', 'id': 'ANC', 'numericId': None, 'precision': 8},
#  'ANKR': {'code': 'ANKR', 'id': 'ANKR', 'numericId': None, 'precision': 8},
#  'ANT': {'code': 'ANT', 'id': 'ANT', 'numericId': None, 'precision': 8},
#  'APE': {'code': 'APE', 'id': 'APE', 'numericId': None, 'precision': 8},
#  'API3': {'code': 'API3', 'id': 'API3', 'numericId': None, 'precision': 8},
#  'APT': {'code': 'APT', 'id': 'APT', 'numericId': None, 'precision': 8},
#  'AR': {'code': 'AR', 'id': 'AR', 'numericId': None, 'precision': 8},
#  'ARB': {'code': 'ARB', 'id': 'ARB', 'numericId': None, 'precision': 8},
#  'ARPA': {'code': 'ARPA', 'id': 'ARPA', 'numericId': None, 'precision': 8},
#  'ASTR': {'code': 'ASTR', 'id': 'ASTR', 'numericId': None, 'precision': 8},
#  'ATA': {'code': 'ATA', 'id': 'ATA', 'numericId': None, 'precision': 8},
#  'ATOM': {'code': 'ATOM', 'id': 'ATOM', 'numericId': None, 'precision': 8},
#  'AUCTION': {'code': 'AUCTION',
#              'id': 'AUCTION',
#              'numericId': None,
#              'precision': 8},
#  'AUDIO': {'code': 'AUDIO', 'id': 'AUDIO', 'numericId': None, 'precision': 8},
#  'AVAX': {'code': 'AVAX', 'id': 'AVAX', 'numericId': None, 'precision': 8},
#  'AXS': {'code': 'AXS', 'id': 'AXS', 'numericId': None, 'precision': 8},
#  'BAKE': {'code': 'BAKE', 'id': 'BAKE', 'numericId': None, 'precision': 8},
#  'BAL': {'code': 'BAL', 'id': 'BAL', 'numericId': None, 'precision': 8},
#  'BAND': {'code': 'BAND', 'id': 'BAND', 'numericId': None, 'precision': 8},
#  'BAT': {'code': 'BAT', 'id': 'BAT', 'numericId': None, 'precision': 8},
#  'BCH': {'code': 'BCH', 'id': 'BCH', 'numericId': None, 'precision': 8},
#  'BEL': {'code': 'BEL', 'id': 'BEL', 'numericId': None, 'precision': 8},
#  'BLUEBIRD': {'code': 'BLUEBIRD',
#               'id': 'BLUEBIRD',
#               'numericId': None,
#               'precision': 8},
#  'BLUR': {'code': 'BLUR', 'id': 'BLUR', 'numericId': None, 'precision': 8},
#  'BNB': {'code': 'BNB', 'id': 'BNB', 'numericId': None, 'precision': 8},
#  'BNT': {'code': 'BNT', 'id': 'BNT', 'numericId': None, 'precision': 8},
#  'BNX': {'code': 'BNX', 'id': 'BNX', 'numericId': None, 'precision': 8},
#  'BTC': {'code': 'BTC', 'id': 'BTC', 'numericId': None, 'precision': 8},
#  'BTCDOM': {'code': 'BTCDOM',
#             'id': 'BTCDOM',
#             'numericId': None,
#             'precision': 8},
#  'BTCST': {'code': 'BTCST', 'id': 'BTCST', 'numericId': None, 'precision': 8},
#  'BUSD': {'code': 'BUSD', 'id': 'BUSD', 'numericId': None, 'precision': 8},
#  'C98': {'code': 'C98', 'id': 'C98', 'numericId': None, 'precision': 8},
#  'CELO': {'code': 'CELO', 'id': 'CELO', 'numericId': None, 'precision': 8},
#  'CELR': {'code': 'CELR', 'id': 'CELR', 'numericId': None, 'precision': 8},
#  'CFX': {'code': 'CFX', 'id': 'CFX', 'numericId': None, 'precision': 8},
#  'CHR': {'code': 'CHR', 'id': 'CHR', 'numericId': None, 'precision': 8},
#  'CHZ': {'code': 'CHZ', 'id': 'CHZ', 'numericId': None, 'precision': 8},
#  'CKB': {'code': 'CKB', 'id': 'CKB', 'numericId': None, 'precision': 8},
#  'COMBO': {'code': 'COMBO', 'id': 'COMBO', 'numericId': None, 'precision': 8},
#  'COMP': {'code': 'COMP', 'id': 'COMP', 'numericId': None, 'precision': 8},
#  'COTI': {'code': 'COTI', 'id': 'COTI', 'numericId': None, 'precision': 8},
#  'CRV': {'code': 'CRV', 'id': 'CRV', 'numericId': None, 'precision': 8},
#  'CTK': {'code': 'CTK', 'id': 'CTK', 'numericId': None, 'precision': 8},
#  'CTSI': {'code': 'CTSI', 'id': 'CTSI', 'numericId': None, 'precision': 8},
#  'CVX': {'code': 'CVX', 'id': 'CVX', 'numericId': None, 'precision': 8},
#  'DAR': {'code': 'DAR', 'id': 'DAR', 'numericId': None, 'precision': 8},
#  'DASH': {'code': 'DASH', 'id': 'DASH', 'numericId': None, 'precision': 8},
#  'DEFI': {'code': 'DEFI', 'id': 'DEFI', 'numericId': None, 'precision': 8},
#  'DENT': {'code': 'DENT', 'id': 'DENT', 'numericId': None, 'precision': 8},
#  'DGB': {'code': 'DGB', 'id': 'DGB', 'numericId': None, 'precision': 8},
#  'DOGE': {'code': 'DOGE', 'id': 'DOGE', 'numericId': None, 'precision': 8},
#  'DOT': {'code': 'DOT', 'id': 'DOT', 'numericId': None, 'precision': 8},
#  'DUSK': {'code': 'DUSK', 'id': 'DUSK', 'numericId': None, 'precision': 8},
#  'DYDX': {'code': 'DYDX', 'id': 'DYDX', 'numericId': None, 'precision': 8},
#  'EDU': {'code': 'EDU', 'id': 'EDU', 'numericId': None, 'precision': 8},
#  'EGLD': {'code': 'EGLD', 'id': 'EGLD', 'numericId': None, 'precision': 8},
#  'ENJ': {'code': 'ENJ', 'id': 'ENJ', 'numericId': None, 'precision': 8},
#  'ENS': {'code': 'ENS', 'id': 'ENS', 'numericId': None, 'precision': 8},
#  'EOS': {'code': 'EOS', 'id': 'EOS', 'numericId': None, 'precision': 8},
#  'ETC': {'code': 'ETC', 'id': 'ETC', 'numericId': None, 'precision': 8},
#  'ETH': {'code': 'ETH', 'id': 'ETH', 'numericId': None, 'precision': 8},
#  'FET': {'code': 'FET', 'id': 'FET', 'numericId': None, 'precision': 8},
#  'FIL': {'code': 'FIL', 'id': 'FIL', 'numericId': None, 'precision': 8},
#  'FLM': {'code': 'FLM', 'id': 'FLM', 'numericId': None, 'precision': 8},
#  'FLOW': {'code': 'FLOW', 'id': 'FLOW', 'numericId': None, 'precision': 8},
#  'FOOTBALL': {'code': 'FOOTBALL',
#               'id': 'FOOTBALL',
#               'numericId': None,
#               'precision': 8},
#  'FTM': {'code': 'FTM', 'id': 'FTM', 'numericId': None, 'precision': 8},
#  'FXS': {'code': 'FXS', 'id': 'FXS', 'numericId': None, 'precision': 8},
#  'GAL': {'code': 'GAL', 'id': 'GAL', 'numericId': None, 'precision': 8},
#  'GALA': {'code': 'GALA', 'id': 'GALA', 'numericId': None, 'precision': 8},
#  'GMT': {'code': 'GMT', 'id': 'GMT', 'numericId': None, 'precision': 8},
#  'GMX': {'code': 'GMX', 'id': 'GMX', 'numericId': None, 'precision': 8},
#  'GRT': {'code': 'GRT', 'id': 'GRT', 'numericId': None, 'precision': 8},
#  'GTC': {'code': 'GTC', 'id': 'GTC', 'numericId': None, 'precision': 8},
#  'HBAR': {'code': 'HBAR', 'id': 'HBAR', 'numericId': None, 'precision': 8},
#  'HFT': {'code': 'HFT', 'id': 'HFT', 'numericId': None, 'precision': 8},
#  'HIGH': {'code': 'HIGH', 'id': 'HIGH', 'numericId': None, 'precision': 8},
#  'HNT': {'code': 'HNT', 'id': 'HNT', 'numericId': None, 'precision': 8},
#  'HOOK': {'code': 'HOOK', 'id': 'HOOK', 'numericId': None, 'precision': 8},
#  'HOT': {'code': 'HOT', 'id': 'HOT', 'numericId': None, 'precision': 8},
#  'ICP': {'code': 'ICP', 'id': 'ICP', 'numericId': None, 'precision': 8},
#  'ICP2': {'code': 'ICP2', 'id': 'ICP2', 'numericId': None, 'precision': 8},
#  'ICX': {'code': 'ICX', 'id': 'ICX', 'numericId': None, 'precision': 8},
#  'ID': {'code': 'ID', 'id': 'ID', 'numericId': None, 'precision': 8},
#  'IDEX': {'code': 'IDEX', 'id': 'IDEX', 'numericId': None, 'precision': 8},
#  'IMX': {'code': 'IMX', 'id': 'IMX', 'numericId': None, 'precision': 8},
#  'INJ': {'code': 'INJ', 'id': 'INJ', 'numericId': None, 'precision': 8},
#  'IOST': {'code': 'IOST', 'id': 'IOST', 'numericId': None, 'precision': 8},
#  'IOTA': {'code': 'IOTA', 'id': 'IOTA', 'numericId': None, 'precision': 8},
#  'IOTX': {'code': 'IOTX', 'id': 'IOTX', 'numericId': None, 'precision': 8},
#  'JASMY': {'code': 'JASMY', 'id': 'JASMY', 'numericId': None, 'precision': 8},
#  'JOE': {'code': 'JOE', 'id': 'JOE', 'numericId': None, 'precision': 8},
#  'KAVA': {'code': 'KAVA', 'id': 'KAVA', 'numericId': None, 'precision': 8},
#  'KEY': {'code': 'KEY', 'id': 'KEY', 'numericId': None, 'precision': 8},
#  'KLAY': {'code': 'KLAY', 'id': 'KLAY', 'numericId': None, 'precision': 8},
#  'KNC': {'code': 'KNC', 'id': 'KNC', 'numericId': None, 'precision': 8},
#  'KSM': {'code': 'KSM', 'id': 'KSM', 'numericId': None, 'precision': 8},
#  'LDO': {'code': 'LDO', 'id': 'LDO', 'numericId': None, 'precision': 8},
#  'LEVER': {'code': 'LEVER', 'id': 'LEVER', 'numericId': None, 'precision': 8},
#  'LINA': {'code': 'LINA', 'id': 'LINA', 'numericId': None, 'precision': 8},
#  'LINK': {'code': 'LINK', 'id': 'LINK', 'numericId': None, 'precision': 8},
#  'LIT': {'code': 'LIT', 'id': 'LIT', 'numericId': None, 'precision': 8},
#  'LPT': {'code': 'LPT', 'id': 'LPT', 'numericId': None, 'precision': 8},
#  'LQTY': {'code': 'LQTY', 'id': 'LQTY', 'numericId': None, 'precision': 8},
#  'LRC': {'code': 'LRC', 'id': 'LRC', 'numericId': None, 'precision': 8},
#  'LTC': {'code': 'LTC', 'id': 'LTC', 'numericId': None, 'precision': 8},
#  'LUNA2': {'code': 'LUNA2', 'id': 'LUNA2', 'numericId': None, 'precision': 8},
#  'MAGIC': {'code': 'MAGIC', 'id': 'MAGIC', 'numericId': None, 'precision': 8},
#  'MANA': {'code': 'MANA', 'id': 'MANA', 'numericId': None, 'precision': 8},
#  'MASK': {'code': 'MASK', 'id': 'MASK', 'numericId': None, 'precision': 8},
#  'MATIC': {'code': 'MATIC', 'id': 'MATIC', 'numericId': None, 'precision': 8},
#  'MAV': {'code': 'MAV', 'id': 'MAV', 'numericId': None, 'precision': 8},
#  'MDT': {'code': 'MDT', 'id': 'MDT', 'numericId': None, 'precision': 8},
#  'MINA': {'code': 'MINA', 'id': 'MINA', 'numericId': None, 'precision': 8},
#  'MKR': {'code': 'MKR', 'id': 'MKR', 'numericId': None, 'precision': 8},
#  'MTL': {'code': 'MTL', 'id': 'MTL', 'numericId': None, 'precision': 8},
#  'NEAR': {'code': 'NEAR', 'id': 'NEAR', 'numericId': None, 'precision': 8},
#  'NEO': {'code': 'NEO', 'id': 'NEO', 'numericId': None, 'precision': 8},
#  'NKN': {'code': 'NKN', 'id': 'NKN', 'numericId': None, 'precision': 8},
#  'NMR': {'code': 'NMR', 'id': 'NMR', 'numericId': None, 'precision': 8},
#  'OCEAN': {'code': 'OCEAN', 'id': 'OCEAN', 'numericId': None, 'precision': 8},
#  'OGN': {'code': 'OGN', 'id': 'OGN', 'numericId': None, 'precision': 8},
#  'OMG': {'code': 'OMG', 'id': 'OMG', 'numericId': None, 'precision': 8},
#  'ONE': {'code': 'ONE', 'id': 'ONE', 'numericId': None, 'precision': 8},
#  'ONT': {'code': 'ONT', 'id': 'ONT', 'numericId': None, 'precision': 8},
#  'OP': {'code': 'OP', 'id': 'OP', 'numericId': None, 'precision': 8},
#  'PEOPLE': {'code': 'PEOPLE',
#             'id': 'PEOPLE',
#             'numericId': None,
#             'precision': 8},
#  'PERP': {'code': 'PERP', 'id': 'PERP', 'numericId': None, 'precision': 8},
#  'PHB': {'code': 'PHB', 'id': 'PHB', 'numericId': None, 'precision': 8},
#  'QNT': {'code': 'QNT', 'id': 'QNT', 'numericId': None, 'precision': 8},
#  'QTUM': {'code': 'QTUM', 'id': 'QTUM', 'numericId': None, 'precision': 8},
#  'RAD': {'code': 'RAD', 'id': 'RAD', 'numericId': None, 'precision': 8},
#  'RDNT': {'code': 'RDNT', 'id': 'RDNT', 'numericId': None, 'precision': 8},
#  'REEF': {'code': 'REEF', 'id': 'REEF', 'numericId': None, 'precision': 8},
#  'REN': {'code': 'REN', 'id': 'REN', 'numericId': None, 'precision': 8},
#  'RLC': {'code': 'RLC', 'id': 'RLC', 'numericId': None, 'precision': 8},
#  'RNDR': {'code': 'RNDR', 'id': 'RNDR', 'numericId': None, 'precision': 8},
#  'ROSE': {'code': 'ROSE', 'id': 'ROSE', 'numericId': None, 'precision': 8},
#  'RSR': {'code': 'RSR', 'id': 'RSR', 'numericId': None, 'precision': 8},
#  'RUNE': {'code': 'RUNE', 'id': 'RUNE', 'numericId': None, 'precision': 8},
#  'RVN': {'code': 'RVN', 'id': 'RVN', 'numericId': None, 'precision': 8},
#  'SAND': {'code': 'SAND', 'id': 'SAND', 'numericId': None, 'precision': 8},
#  'SFP': {'code': 'SFP', 'id': 'SFP', 'numericId': None, 'precision': 8},
#  'SKL': {'code': 'SKL', 'id': 'SKL', 'numericId': None, 'precision': 8},
#  'SNX': {'code': 'SNX', 'id': 'SNX', 'numericId': None, 'precision': 8},
#  'SOL': {'code': 'SOL', 'id': 'SOL', 'numericId': None, 'precision': 8},
#  'SPELL': {'code': 'SPELL', 'id': 'SPELL', 'numericId': None, 'precision': 8},
#  'SRM': {'code': 'SRM', 'id': 'SRM', 'numericId': None, 'precision': 8},
#  'SSV': {'code': 'SSV', 'id': 'SSV', 'numericId': None, 'precision': 8},
#  'STG': {'code': 'STG', 'id': 'STG', 'numericId': None, 'precision': 8},
#  'STMX': {'code': 'STMX', 'id': 'STMX', 'numericId': None, 'precision': 8},
#  'STORJ': {'code': 'STORJ', 'id': 'STORJ', 'numericId': None, 'precision': 8},
#  'STX': {'code': 'STX', 'id': 'STX', 'numericId': None, 'precision': 8},
#  'SUI': {'code': 'SUI', 'id': 'SUI', 'numericId': None, 'precision': 8},
#  'SUSHI': {'code': 'SUSHI', 'id': 'SUSHI', 'numericId': None, 'precision': 8},
#  'SXP': {'code': 'SXP', 'id': 'SXP', 'numericId': None, 'precision': 8},
#  'T': {'code': 'T', 'id': 'T', 'numericId': None, 'precision': 8},
#  'THETA': {'code': 'THETA', 'id': 'THETA', 'numericId': None, 'precision': 8},
#  'TOMO': {'code': 'TOMO', 'id': 'TOMO', 'numericId': None, 'precision': 8},
#  'TRB': {'code': 'TRB', 'id': 'TRB', 'numericId': None, 'precision': 8},
#  'TRU': {'code': 'TRU', 'id': 'TRU', 'numericId': None, 'precision': 8},
#  'TRX': {'code': 'TRX', 'id': 'TRX', 'numericId': None, 'precision': 8},
#  'UMA': {'code': 'UMA', 'id': 'UMA', 'numericId': None, 'precision': 8},
#  'UNFI': {'code': 'UNFI', 'id': 'UNFI', 'numericId': None, 'precision': 8},
#  'UNI': {'code': 'UNI', 'id': 'UNI', 'numericId': None, 'precision': 8},
#  'USDC': {'code': 'USDC', 'id': 'USDC', 'numericId': None, 'precision': 8},
#  'USDT': {'code': 'USDT', 'id': 'USDT', 'numericId': None, 'precision': 8},
#  'VET': {'code': 'VET', 'id': 'VET', 'numericId': None, 'precision': 8},
#  'WAVE': {'code': 'WAVE', 'id': 'WAVE', 'numericId': None, 'precision': 8},
#  'WAVES': {'code': 'WAVES', 'id': 'WAVES', 'numericId': None, 'precision': 8},
#  'WOO': {'code': 'WOO', 'id': 'WOO', 'numericId': None, 'precision': 8},
#  'XEM': {'code': 'XEM', 'id': 'XEM', 'numericId': None, 'precision': 8},
#  'XLM': {'code': 'XLM', 'id': 'XLM', 'numericId': None, 'precision': 8},
#  'XMR': {'code': 'XMR', 'id': 'XMR', 'numericId': None, 'precision': 8},
#  'XRP': {'code': 'XRP', 'id': 'XRP', 'numericId': None, 'precision': 8},
#  'XTZ': {'code': 'XTZ', 'id': 'XTZ', 'numericId': None, 'precision': 8},
#  'XVG': {'code': 'XVG', 'id': 'XVG', 'numericId': None, 'precision': 8},
#  'XVS': {'code': 'XVS', 'id': 'XVS', 'numericId': None, 'precision': 8},
#  'YFI': {'code': 'YFI', 'id': 'YFI', 'numericId': None, 'precision': 8},
#  'ZEC': {'code': 'ZEC', 'id': 'ZEC', 'numericId': None, 'precision': 8},
#  'ZEN': {'code': 'ZEN', 'id': 'ZEN', 'numericId': None, 'precision': 8},
#  'ZIL': {'code': 'ZIL', 'id': 'ZIL', 'numericId': None, 'precision': 8},
#  'ZRX': {'code': 'ZRX', 'id': 'ZRX', 'numericId': None, 'precision': 8}}

# %%
#market_id = exchange.markets_by_id["1000FLOKIUSDT"]
market_id = exchange.markets_by_id["ETHUSDT"]
print(type(market_id))
hprint.pprint_color(market_id)
# Out:
# <class 'dict'>
# {'active': True,
#  'base': 'ETH',
#  'baseId': 'ETH',
#  'contract': True,
#  'contractSize': 1.0,
#  'delivery': False,
#  'expiry': None,
#  'expiryDatetime': None,
#  'future': True,
#  'id': 'ETHUSDT',
#  'info': {'baseAsset': 'ETH',
#           'baseAssetPrecision': '8',
#           'contractType': 'PERPETUAL',
#           'deliveryDate': '4133404800000',
#           'filters': [{'filterType': 'PRICE_FILTER',
#                        'maxPrice': '95000.02',
#                        'minPrice': '18.62',
#                        'tickSize': '0.01'},
#                       {'filterType': 'LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MARKET_LOT_SIZE',
#                        'maxQty': '10000',
#                        'minQty': '0.001',
#                        'stepSize': '0.001'},
#                       {'filterType': 'MAX_NUM_ORDERS', 'limit': '200'},
#                       {'filterType': 'MAX_NUM_ALGO_ORDERS', 'limit': '10'},
#                       {'filterType': 'MIN_NOTIONAL', 'notional': '5.0'},
#                       {'filterType': 'PERCENT_PRICE',
#                        'multiplierDecimal': '4',
#                        'multiplierDown': '0.9000',
#                        'multiplierUp': '1.1000'}],
#           'liquidationFee': '0.020000',
#           'maintMarginPercent': '2.5000',
#           'marginAsset': 'USDT',
#           'marketTakeBound': '0.10',
#           'maxMoveOrderLimit': '10000',
#           'onboardDate': '1569398400000',
#           'orderTypes': ['LIMIT',
#                          'MARKET',
#                          'STOP',
#                          'STOP_MARKET',
#                          'TAKE_PROFIT',
#                          'TAKE_PROFIT_MARKET',
#                          'TRAILING_STOP_MARKET'],
#           'pair': 'ETHUSDT',
#           'pricePrecision': '2',
#           'quantityPrecision': '3',
#           'quoteAsset': 'USDT',
#           'quotePrecision': '8',
#           'requiredMarginPercent': '5.0000',
#           'settlePlan': '0',
#           'status': 'TRADING',
#           'symbol': 'ETHUSDT',
#           'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX'],
#           'triggerProtect': '0.0500',
#           'underlyingSubType': [],
#           'underlyingType': 'COIN'},
#  'inverse': False,
#  'limits': {'amount': {'max': 10000.0, 'min': 0.001},
#             'cost': {'max': None, 'min': 5.0},
#             'leverage': {'max': None, 'min': None},
#             'market': {'max': 10000.0, 'min': 0.001},
#             'price': {'max': 95000.02, 'min': 18.62}},
#  'linear': True,
#  'lowercaseId': 'ethusdt',
#  'maker': 0.0002,
#  'margin': False,
#  'option': False,
#  'optionType': None,
#  'precision': {'amount': 3, 'base': 8, 'price': 2, 'quote': 8},
#  'quote': 'USDT',
#  'quoteId': 'USDT',
#  'settle': 'USDT',
#  'settleId': 'USDT',
#  'spot': False,
#  'strike': None,
#  'swap': True,
#  'symbol': 'ETH/USDT',
#  'taker': 0.0004,
#  'type': 'future'}

# %%
market_id["symbol"]
# Out:
# 'ETH/USDT'

# %% [markdown]
# ## Market cache force reload

# %% [markdown]
# # Implicit API methods

# %% [markdown]
# ## API methods / endpoints
#
# - API methods / endpoints
#     - Each exchange offers a set of API methods (aka "endpoints") that are HTTP URLs
#       for querying various types of information
#     - All endpoints return JSON responses
#
# - E.g., an endpoint for:
#   - getting a list of markets from an exchange
#   - retrieving an order book
#   - retrieving trade history
#   - cancelling orders
#
# - Endpoints are defined in `api` property of an exchange
#
# ## Implicit API methods
#
# - In practice each API method is mapped on callable Python function
# - Each function can be called with a dictionary of parameters and return an
#   unparsed JSON from the exchange API
# - The method is available in both camelCase and under_score notation
#
# ## Public / private / unified
#
# - Each `Exchange` implements:
#   - a public / private API for all endpoints
#   - a unified API supporting a subset of common methods
#
# - One should:
#   - use unified methods
#   - use the private method as fallback
#
# ## Public / Private API
#
# - Public API doesn't require authentication
#     - Aka "market data", "basic api", "market api", "mapi"
#     - E.g.,
#         - Allow to access market data
#         - Price feeds
#         - Order books
#         - Trade history
#         - Bars
#
# - Private API requires authentication
#     - Aka "trading api", "tapi"
#     - E.g.,
#         - Manage personal account info
#         - Query account balances
#         - Trade
#         - Create deposit
#         - Request withdrawal
#         - Query orders
#
# - Some exchanges also expose a "merchant API" to accept crypto and fiat as payments
#     - Aka "merchant", "wallet", "ecapi" (for e-commerce)
#
# * Synch vs async calls
# - `CCXT` supports asyncio
# - The same methods are available but decorated with `asyncio` keyword
#
# * Returned objects
# - Public and private APIs return raw JSON objects (representing the response from
#   the exchange)
# - Unified APIs return a JSON object in a common format across all exchanges

# %%
# Print a list of all the methods in an exchange.
print(dir(ccxt.binance()))
# Out:
# ['__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'account', 'accounts', 'addMargin', 'add_margin', 'aggregate', 'aiohttpProxy', 'aiohttpTrustEnv', 'aiohttp_proxy', 'aiohttp_trust_env', 'alias', 'amountToPrecision', 'amount_to_precision', 'api', 'apiKey', 'arrayConcat', 'array_concat', 'asyncioLoop', 'asyncio_loop', 'balance', 'base16ToBinary', 'base16_to_binary', 'base58Alphabet', 'base58Decoder', 'base58Encoder', 'base58ToBinary', 'base58_alphabet', 'base58_decoder', 'base58_encoder', 'base58_to_binary', 'base64ToBinary', 'base64ToString', 'base64_to_binary', 'base64_to_string', 'base64urlencode', 'baseCurrencies', 'base_currencies', 'binaryConcat', 'binaryConcatArray', 'binaryToBase16', 'binaryToBase58', 'binaryToBase64', 'binary_concat', 'binary_concat_array', 'binary_to_base16', 'binary_to_base58', 'binary_to_base64', 'borrowMargin', 'borrow_margin', 'buildOhlcvc', 'build_ohlcvc', 'calculateFee', 'calculateRateLimiterCost', 'calculate_fee', 'calculate_rate_limiter_cost', 'cancelAllOrders', 'cancelOrder', 'cancelUnifiedOrder', 'cancel_all_orders', 'cancel_order', 'cancel_unified_order', 'capitalize', 'certified', 'checkAddress', 'checkOrderArguments', 'checkRequiredArgument', 'checkRequiredCredentials', 'checkRequiredDependencies', 'checkRequiredSymbol', 'checkRequiredVersion', 'check_address', 'check_order_arguments', 'check_required_argument', 'check_required_credentials', 'check_required_dependencies', 'check_required_symbol', 'check_required_version', 'codes', 'commonCurrencies', 'commonCurrencyCode', 'common_currency_code', 'convertOHLCVToTradingView', 'convertTradingViewToOHLCV', 'convertTypeToAccount', 'convert_ohlcv_to_trading_view', 'convert_trading_view_to_ohlcv', 'convert_type_to_account', 'costToPrecision', 'cost_to_precision', 'countries', 'crc32', 'createGiftCode', 'createLimitBuyOrder', 'createLimitOrder', 'createLimitSellOrder', 'createMarketBuyOrder', 'createMarketOrder', 'createMarketSellOrder', 'createOrder', 'createPostOnlyOrder', 'createReduceOnlyOrder', 'createStopLimitOrder', 'createStopMarketOrder', 'createStopOrder', 'create_gift_code', 'create_limit_buy_order', 'create_limit_order', 'create_limit_sell_order', 'create_market_buy_order', 'create_market_order', 'create_market_sell_order', 'create_order', 'create_post_only_order', 'create_reduce_only_order', 'create_stop_limit_order', 'create_stop_market_order', 'create_stop_order', 'currencies', 'currenciesById', 'currencies_by_id', 'currency', 'currencyToPrecision', 'currency_to_precision', 'dapiDataGetBasis', 'dapiDataGetGlobalLongShortAccountRatio', 'dapiDataGetGloballongshortaccountratio', 'dapiDataGetOpenInterestHist', 'dapiDataGetOpeninteresthist', 'dapiDataGetTakerBuySellVol', 'dapiDataGetTakerbuysellvol', 'dapiDataGetTopLongShortAccountRatio', 'dapiDataGetTopLongShortPositionRatio', 'dapiDataGetToplongshortaccountratio', 'dapiDataGetToplongshortpositionratio', 'dapiData_get_basis', 'dapiData_get_globallongshortaccountratio', 'dapiData_get_openinteresthist', 'dapiData_get_takerbuysellvol', 'dapiData_get_toplongshortaccountratio', 'dapiData_get_toplongshortpositionratio', 'dapiPrivateDeleteAllOpenOrders', 'dapiPrivateDeleteAllopenorders', 'dapiPrivateDeleteBatchOrders', 'dapiPrivateDeleteBatchorders', 'dapiPrivateDeleteListenKey', 'dapiPrivateDeleteListenkey', 'dapiPrivateDeleteOrder', 'dapiPrivateGetAccount', 'dapiPrivateGetAdlQuantile', 'dapiPrivateGetAdlquantile', 'dapiPrivateGetAllOrders', 'dapiPrivateGetAllorders', 'dapiPrivateGetBalance', 'dapiPrivateGetForceOrders', 'dapiPrivateGetForceorders', 'dapiPrivateGetIncome', 'dapiPrivateGetLeverageBracket', 'dapiPrivateGetLeveragebracket', 'dapiPrivateGetOpenOrder', 'dapiPrivateGetOpenOrders',  ...

# %% [markdown]
# ## Synchronous vs asynchronous
#
# - CCXT supports async concurrency mode with async/await
# - Use `asyncio` and `aiohttp`
# - The methods are the same but they are decorated with `async`
#
# ```
# import asyncio
# import ccx.async_support as ccxt
#
# ...
# ```

# %% [markdown]
# ## API parameters
#
# - Public / private API endpoints differ from exchange to exchange
#     - Most methods accept an array of key-value params
# - Return a raw JSON object
#
# - Unified API return JSON in a common format uniform across all exchanges

# %% [markdown]
# # Unified API
#
# - fetch...
#   - Markets
#   - Currencies
#   - OrderBook
#   - Status
#   - Trades
#   - Ticker
#   - Balance
# - create...
#   - Order
#   - LimitBuyOrder / LimitSellOrder
#   - MarketBuyOrder / MarketSellOrder
#   - CancelOrder
# - fetch orders
#   - Open
#   - Canceled
#   - Closed
# - fetch
#     - my trades
#     - open interest
#     - transactions
#     - deposit
#     - withdrawals
#
# - A `param` argument is a dictionary of exchange-specific params you want override
#
# ## Pagination
# - Most exchange APIs return a certain number of the most recent objects
# - You can't get all the objects in one call
#   - You need to paginate, i.e., fetch portions of data one by one
#   - Pagination can be performed based on id, time, or page number

# %% [markdown]
# # Public API
#
# https://docs.ccxt.com/#/README?id=public-api

# %%
exchange.fetchMarkets()
# Out:
# [{'id': 'BTCUSDT',
#   'lowercaseId': 'btcusdt',
#   'symbol': 'BTC/USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 1, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 1000.0},
#    'price': {'min': 302.1, 'max': 936574.4},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 1000.0}},
#   'info': {'symbol': 'BTCUSDT',
#    'pair': 'BTCUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404802000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'BTC',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.30',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '302.10',
#      'maxPrice': '936574.40',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.10'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.5454',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ETHUSDT',
#   'lowercaseId': 'ethusdt',
#   'symbol': 'ETH/USDT',
#   'base': 'ETH',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ETH',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 18.62, 'max': 95000.02},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 10000.0}},
#   'info': {'symbol': 'ETHUSDT',
#    'pair': 'ETHUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ETH',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '18.62',
#      'maxPrice': '95000.02',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'BCHUSDT',
#   'lowercaseId': 'bchusdt',
#   'symbol': 'BCH/USDT',
#   'base': 'BCH',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'BCH',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 7.84, 'max': 13076.5},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 10000.0}},
#   'info': {'symbol': 'BCHUSDT',
#    'pair': 'BCHUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'BCH',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '7.84',
#      'maxPrice': '13076.50',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'XRPUSDT',
#   'lowercaseId': 'xrpusdt',
#   'symbol': 'XRP/USDT',
#   'base': 'XRP',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'XRP',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.0117, 'max': 19.605},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 1000000.0}},
#   'info': {'symbol': 'XRPUSDT',
#    'pair': 'XRPUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'XRP',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '4',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0117',
#      'maxPrice': '19.6050',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'EOSUSDT',
#   'lowercaseId': 'eosusdt',
#   'symbol': 'EOS/USDT',
#   'base': 'EOS',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'EOS',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.021, 'max': 36.05},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 10000000.0}},
#   'info': {'symbol': 'EOSUSDT',
#    'pair': 'EOSUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'EOS',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.021',
#      'maxPrice': '36.050',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'LTCUSDT',
#   'lowercaseId': 'ltcusdt',
#   'symbol': 'LTC/USDT',
#   'base': 'LTC',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'LTC',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 2.8, 'max': 4672.32},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 10000.0}},
#   'info': {'symbol': 'LTCUSDT',
#    'pair': 'LTCUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'LTC',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '2.80',
#      'maxPrice': '4672.32',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'TRXUSDT',
#   'lowercaseId': 'trxusdt',
#   'symbol': 'TRX/USDT',
#   'base': 'TRX',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'TRX',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 5, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 10000000.0},
#    'price': {'min': 0.00212, 'max': 3.53444},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 10000000.0}},
#   'info': {'symbol': 'TRXUSDT',
#    'pair': 'TRXUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'TRX',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '5',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.025000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.00212',
#      'maxPrice': '3.53444',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.00001'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ETCUSDT',
#   'lowercaseId': 'etcusdt',
#   'symbol': 'ETC/USDT',
#   'base': 'ETC',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ETC',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 2, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 0.566, 'max': 944.673},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.01, 'max': 100000.0}},
#   'info': {'symbol': 'ETCUSDT',
#    'pair': 'ETCUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ETC',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '2',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0800',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.566',
#      'maxPrice': '944.673',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.01',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'stepSize': '0.01',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'LINKUSDT',
#   'lowercaseId': 'linkusdt',
#   'symbol': 'LINK/USDT',
#   'base': 'LINK',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'LINK',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 2, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 0.233, 'max': 389.118},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.01, 'max': 100000.0}},
#   'info': {'symbol': 'LINKUSDT',
#    'pair': 'LINKUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'LINK',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '2',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': ['DEFI', 'HOT'],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.233',
#      'maxPrice': '389.118',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.01',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'stepSize': '0.01',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'XLMUSDT',
#   'lowercaseId': 'xlmusdt',
#   'symbol': 'XLM/USDT',
#   'base': 'XLM',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'XLM',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 5, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 10000000.0},
#    'price': {'min': 0.00284, 'max': 4.7445},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 10000000.0}},
#   'info': {'symbol': 'XLMUSDT',
#    'pair': 'XLMUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'XLM',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '5',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.00284',
#      'maxPrice': '4.74450',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.00001'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ADAUSDT',
#   'lowercaseId': 'adausdt',
#   'symbol': 'ADA/USDT',
#   'base': 'ADA',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ADA',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 10000000.0},
#    'price': {'min': 0.0085, 'max': 14.28},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 10000000.0}},
#   'info': {'symbol': 'ADAUSDT',
#    'pair': 'ADAUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ADA',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '5',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': ['HOT'],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.00850',
#      'maxPrice': '14.28000',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.00010'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'DASHUSDT',
#   'lowercaseId': 'dashusdt',
#   'symbol': 'DASH/USDT',
#   'base': 'DASH',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'DASH',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 1.0, 'max': 1680.36},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 850000.0}},
#   'info': {'symbol': 'DASHUSDT',
#    'pair': 'DASHUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'DASH',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0005',
#    'liquidationFee': '0.007000',
#    'marketTakeBound': '0.35',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '1',
#      'maxPrice': '1680.36',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '850000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.5000',
#      'multiplierUp': '1.5000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ZECUSDT',
#   'lowercaseId': 'zecusdt',
#   'symbol': 'ZEC/USDT',
#   'base': 'ZEC',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ZEC',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 1.46, 'max': 2445.24},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 10000.0}},
#   'info': {'symbol': 'ZECUSDT',
#    'pair': 'ZECUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ZEC',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.5000',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '1.46',
#      'maxPrice': '2445.24',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'XTZUSDT',
#   'lowercaseId': 'xtzusdt',
#   'symbol': 'XTZ/USDT',
#   'base': 'XTZ',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'XTZ',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 10000.0},
#    'price': {'min': 0.037, 'max': 62.15},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 1000000.0}},
#   'info': {'symbol': 'XTZUSDT',
#    'pair': 'XTZUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'XTZ',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.037',
#      'maxPrice': '62.150',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'BNBUSDT',
#   'lowercaseId': 'bnbusdt',
#   'symbol': 'BNB/USDT',
#   'base': 'BNB',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'BNB',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 2, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.01, 'max': 10000.0},
#    'price': {'min': 7.033, 'max': 11723.052},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.01, 'max': 100000.0}},
#   'info': {'symbol': 'BNBUSDT',
#    'pair': 'BNBUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'BNB',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '2',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': ['BSC', 'HOT'],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '7.033',
#      'maxPrice': '11723.052',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.01',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.01'},
#     {'stepSize': '0.01',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ATOMUSDT',
#   'lowercaseId': 'atomusdt',
#   'symbol': 'ATOM/USDT',
#   'base': 'ATOM',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ATOM',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 2, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.01, 'max': 10000.0},
#    'price': {'min': 0.276, 'max': 460.335},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.01, 'max': 100000.0}},
#   'info': {'symbol': 'ATOMUSDT',
#    'pair': 'ATOMUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ATOM',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '2',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.020000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.276',
#      'maxPrice': '460.335',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.001'},
#     {'stepSize': '0.01',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.01'},
#     {'stepSize': '0.01',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '0.01'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ONTUSDT',
#   'lowercaseId': 'ontusdt',
#   'symbol': 'ONT/USDT',
#   'base': 'ONT',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ONT',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.0083, 'max': 13.8978},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 1000000.0}},
#   'info': {'symbol': 'ONTUSDT',
#    'pair': 'ONTUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ONT',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '4',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': ['BSC'],
#    'settlePlan': '0',
#    'triggerProtect': '0.0005',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0083',
#      'maxPrice': '13.8978',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'IOTAUSDT',
#   'lowercaseId': 'iotausdt',
#   'symbol': 'IOTA/USDT',
#   'base': 'IOTA',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'IOTA',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.0077, 'max': 12.8692},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 1000000.0}},
#   'info': {'symbol': 'IOTAUSDT',
#    'pair': 'IOTAUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'IOTA',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '4',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0005',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0077',
#      'maxPrice': '12.8692',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'BATUSDT',
#   'lowercaseId': 'batusdt',
#   'symbol': 'BAT/USDT',
#   'base': 'BAT',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'BAT',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.0055, 'max': 9.185},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 1000000.0}},
#   'info': {'symbol': 'BATUSDT',
#    'pair': 'BATUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'BAT',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '4',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0005',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0055',
#      'maxPrice': '9.1850',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0001'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'VETUSDT',
#   'lowercaseId': 'vetusdt',
#   'symbol': 'VET/USDT',
#   'base': 'VET',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'VET',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 5, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 10000000.0},
#    'price': {'min': 0.00092, 'max': 1.53872},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 10000000.0}},
#   'info': {'symbol': 'VETUSDT',
#    'pair': 'VETUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'VET',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '6',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.000920',
#      'maxPrice': '1.538720',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.000010'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9000',
#      'multiplierUp': '1.1000',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'NEOUSDT',
#   'lowercaseId': 'neousdt',
#   'symbol': 'NEOUSDT',
#   'base': 'NEO',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'NEO',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': False,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': 4133404800000,
#   'expiryDatetime': '2100-12-25T08:00:00.000Z',
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 2, 'price': 3, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 0.732, 'max': 1220.435},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.01, 'max': 100000.0}},
#   'info': {'symbol': 'NEOUSDT',
#    'pair': 'NEOUSDT',
#    'contractType': '',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
#    'status': 'PENDING_TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'NEO',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '3',
#    'quantityPrecision': '2',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0005',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.10',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.732',
#      'maxPrice': '1220.435',
#      'filterType': 'PRICE_FILTER',
# ...
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 10000000.0},
#    'price': {'min': 0.0001, 'max': 2000.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 10000000.0}},
#   'info': {'symbol': 'SUIUSDT',
#    'pair': 'SUIUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1683072000000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'SUI',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '6',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.1500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.15',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.000100',
#      'maxPrice': '2000',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.000100'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.8500',
#      'multiplierUp': '1.1500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'NMRUSDT',
#   'lowercaseId': 'nmrusdt',
#   'symbol': 'NMR/USDT',
#   'base': 'NMR',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'NMR',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.1, 'max': 1000000.0},
#    'price': {'min': 0.01, 'max': 2000.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.1, 'max': 10000.0}},
#   'info': {'symbol': 'NMRUSDT',
#    'pair': 'NMRUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1687435200000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'NMR',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '6',
#    'quantityPrecision': '1',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.1500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.15',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.010000',
#      'maxPrice': '2000',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.010000'},
#     {'stepSize': '0.1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '0.1'},
#     {'stepSize': '0.1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.8500',
#      'multiplierUp': '1.1500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'BTCUSDT_230929',
#   'lowercaseId': 'btcusdt_230929',
#   'symbol': 'BTCUSDT_230929',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': 1695974400000,
#   'expiryDatetime': '2023-09-29T08:00:00.000Z',
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 1, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 500.0},
#    'price': {'min': 1020.4, 'max': 1700680.6},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 500.0}},
#   'info': {'symbol': 'BTCUSDT_230929',
#    'pair': 'BTCUSDT',
#    'contractType': 'CURRENT_QUARTER',
#    'deliveryDate': '1695974400000',
#    'onboardDate': '1687696200000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'BTC',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '1',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.05',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '1020.4',
#      'maxPrice': '1700680.6',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.1'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '500',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '500',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9500',
#      'multiplierUp': '1.0500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'ETHUSDT_230929',
#   'lowercaseId': 'ethusdt_230929',
#   'symbol': 'ETHUSDT_230929',
#   'base': 'ETH',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'ETH',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': 1695974400000,
#   'expiryDatetime': '2023-09-29T08:00:00.000Z',
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 0.001, 'max': 10000.0},
#    'price': {'min': 51.24, 'max': 85407.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 0.001, 'max': 10000.0}},
#   'info': {'symbol': 'ETHUSDT_230929',
#    'pair': 'ETHUSDT',
#    'contractType': 'CURRENT_QUARTER',
#    'deliveryDate': '1695974400000',
#    'onboardDate': '1687696200000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'ETH',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '2',
#    'quantityPrecision': '3',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.0500',
#    'liquidationFee': '0.010000',
#    'marketTakeBound': '0.05',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '51.24',
#      'maxPrice': '85407',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.01'},
#     {'stepSize': '0.001',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'stepSize': '0.001',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000',
#      'minQty': '0.001'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.9500',
#      'multiplierUp': '1.0500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'MAVUSDT',
#   'lowercaseId': 'mavusdt',
#   'symbol': 'MAV/USDT',
#   'base': 'MAV',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'MAV',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 4, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 10000000.0},
#    'price': {'min': 0.0001, 'max': 200.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 100000.0}},
#   'info': {'symbol': 'MAVUSDT',
#    'pair': 'MAVUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1688040000000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'MAV',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '7',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.1500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.15',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0001000',
#      'maxPrice': '200',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0001000'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '100000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.8500',
#      'multiplierUp': '1.1500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'MDTUSDT',
#   'lowercaseId': 'mdtusdt',
#   'symbol': 'MDT/USDT',
#   'base': 'MDT',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'MDT',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 5, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': 200.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 1000000.0}},
#   'info': {'symbol': 'MDTUSDT',
#    'pair': 'MDTUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1688126400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'MDT',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '7',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.1500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.15',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0000100',
#      'maxPrice': '200',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0000100'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '100000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '1000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.8500',
#      'multiplierUp': '1.1500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}},
#  {'id': 'XVGUSDT',
#   'lowercaseId': 'xvgusdt',
#   'symbol': 'XVG/USDT',
#   'base': 'XVG',
#   'quote': 'USDT',
#   'settle': 'USDT',
#   'baseId': 'XVG',
#   'quoteId': 'USDT',
#   'settleId': 'USDT',
#   'type': 'future',
#   'spot': False,
#   'margin': False,
#   'swap': True,
#   'future': True,
#   'delivery': False,
#   'option': False,
#   'active': True,
#   'contract': True,
#   'linear': True,
#   'inverse': False,
#   'taker': 0.0004,
#   'maker': 0.0002,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 0, 'price': 6, 'base': 8, 'quote': 8},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': 200.0},
#    'cost': {'min': 5.0, 'max': None},
#    'market': {'min': 1.0, 'max': 10000000.0}},
#   'info': {'symbol': 'XVGUSDT',
#    'pair': 'XVGUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1688558400000',
#    'status': 'TRADING',
#    'maintMarginPercent': '2.5000',
#    'requiredMarginPercent': '5.0000',
#    'baseAsset': 'XVG',
#    'quoteAsset': 'USDT',
#    'marginAsset': 'USDT',
#    'pricePrecision': '7',
#    'quantityPrecision': '0',
#    'baseAssetPrecision': '8',
#    'quotePrecision': '8',
#    'underlyingType': 'COIN',
#    'underlyingSubType': [],
#    'settlePlan': '0',
#    'triggerProtect': '0.1500',
#    'liquidationFee': '0.015000',
#    'marketTakeBound': '0.15',
#    'maxMoveOrderLimit': '10000',
#    'filters': [{'minPrice': '0.0000010',
#      'maxPrice': '200',
#      'filterType': 'PRICE_FILTER',
#      'tickSize': '0.0000010'},
#     {'stepSize': '1',
#      'filterType': 'LOT_SIZE',
#      'maxQty': '100000000',
#      'minQty': '1'},
#     {'stepSize': '1',
#      'filterType': 'MARKET_LOT_SIZE',
#      'maxQty': '10000000',
#      'minQty': '1'},
#     {'limit': '200', 'filterType': 'MAX_NUM_ORDERS'},
#     {'limit': '10', 'filterType': 'MAX_NUM_ALGO_ORDERS'},
#     {'notional': '5.0', 'filterType': 'MIN_NOTIONAL'},
#     {'multiplierDown': '0.8500',
#      'multiplierUp': '1.1500',
#      'multiplierDecimal': '4',
#      'filterType': 'PERCENT_PRICE'}],
#    'orderTypes': ['LIMIT',
#     'MARKET',
#     'STOP',
#     'STOP_MARKET',
#     'TAKE_PROFIT',
#     'TAKE_PROFIT_MARKET',
#     'TRAILING_STOP_MARKET'],
#    'timeInForce': ['GTC', 'IOC', 'FOK', 'GTX']}}]

# %%
exchange.fetchCurrencies()

# %%
# Not supported for Binance
# exchange.fetchStatus()

# %%
symbol = "BTC/USDT"
data = exchange.fetchOrderBook(symbol)
#data = exchange.fetchL2OrderBook(symbol)
print("keys=", data.keys())

key_names = ["symbol", "timestamp", "datetime", "nonce", "bids"]
hprint.pprint_color(
    subset_dict(data, key_names))
# Out:
# keys= dict_keys(['symbol', 'bids', 'asks', 'timestamp', 'datetime', 'nonce'])
# # symbol
# 'BTC/USDT'
# # timestamp
# 1689243005611
# # datetime
# '2023-07-13T10:10:05.611Z'
# # nonce
# 3054457027505
# # bids
# [[30545.4, 41.911],
#  [30545.3, 5.795],
#  [30545.2, 0.021],
#  [30545.1, 1.487],
#  [30545.0, 0.004],
#  [30544.9, 0.023],
#  [30544.8, 0.001],
#  [30544.7, 0.05],
#  [30544.6, 0.164],
#  [30544.5, 0.35],
#  [30544.4, 0.015],
#  [30544.3, 0.001],
#  [30544.2, 0.008],
#  [30544.1, 0.351],
#  [30544.0, 0.28],
#  [30543.9, 0.083],
#  [30543.8, 0.14],
#  [30543.7, 0.015],
#  [30543.6, 0.041],
#  [30543.5, 0.012],
#  [30543.4, 0.037],
#  [30543.3, 0.096],
#  [30543.2, 0.155],
#  [30543.1, 0.053],
#  [30543.0, 0.162],
#  [30542.9, 4.959],
#  [30542.8, 0.001],
#  [30542.7, 0.601],
#  [30542.6, 0.011],
#  [30542.5, 0.991],
#  [30542.4, 0.214],
#  [30542.3, 0.051],
#  [30542.2, 0.882],
#  [30542.1, 0.165],
#  [30542.0, 2.449],
#  [30541.9, 1.998],
#  [30541.8, 0.854],
#  [30541.7, 0.067],
#  [30541.6, 1.71],
#  [30541.5, 0.192],
#  [30541.4, 0.997],
#  [30541.2, 0.021],
#  [30541.1, 0.327],
#  [30541.0, 0.028],
#  [30540.9, 0.011],
#  [30540.8, 0.274],
#  [30540.7, 1.121],
#  [30540.6, 0.822],
#  [30540.5, 0.984],
#  [30540.4, 0.013],
#  [30540.3, 0.02],
#  [30540.2, 0.665],
#  [30540.1, 2.11],
#  [30540.0, 1.037],
#  [30539.9, 0.403],
#  [30539.8, 0.845],
#  [30539.7, 0.983],
#  [30539.6, 0.01],
#  [30539.5, 0.013],
#  [30539.4, 0.194],
#  [30539.3, 0.579],
#  [30539.2, 0.146],
#  [30539.1, 1.487],
#  [30539.0, 0.121],
#  [30538.9, 0.224],
#  [30538.8, 1.024],
#  [30538.7, 3.479],
#  [30538.6, 6.321],
#  [30538.5, 0.087],
#  [30538.4, 0.1],
#  [30538.3, 0.001],
#  [30538.2, 0.598],
#  [30538.1, 0.478],
#  [30538.0, 0.289],
#  [30537.9, 0.408],
#  [30537.8, 1.392],
#  [30537.7, 0.078],
#  [30537.6, 1.493],
#  [30537.5, 0.007],
#  [30537.4, 0.343],
#  [30537.3, 0.78],
#  [30537.2, 2.001],
#  [30537.1, 0.371],
#  [30537.0, 4.26],
#  [30536.9, 4.566],
#  [30536.8, 3.401],
#  [30536.7, 0.001],
#  [30536.6, 0.337],
#  [30536.5, 8.56],
#  [30536.4, 1.544],
#  [30536.3, 0.311],
#  [30536.2, 1.364],
#  [30536.1, 12.706],
#  [30536.0, 0.447],
#  [30535.9, 0.122],
#  [30535.8, 0.251],
#  [30535.7, 0.396],
#  [30535.6, 1.965],
#  [30535.5, 0.041],
#  [30535.4, 0.009],
#  [30535.3, 0.331],
#  [30535.2, 0.49],
#  [30535.1, 0.033],
#  [30535.0, 1.498],
#  [30534.9, 0.687],
#  [30534.8, 0.08],
#  [30534.7, 1.981],
#  [30534.5, 0.032],
#  [30534.4, 1.981],
#  [30534.3, 8.876],
#  [30534.2, 0.08],
#  [30534.1, 0.484],
#  [30534.0, 7.277],
#  [30533.9, 1.723],
#  [30533.8, 15.232],
#  [30533.7, 0.855],
#  [30533.5, 2.077],
#  [30533.4, 0.003],
#  [30533.3, 1.509],
#  [30533.2, 0.308],
#  [30533.1, 0.026],
#  [30533.0, 2.733],
#  [30532.9, 1.055],
#  [30532.7, 0.042],
#  [30532.6, 0.756],
#  [30532.5, 0.003],
#  [30532.4, 0.05],
#  [30532.3, 5.242],
#  [30532.2, 2.466],
#  [30532.1, 0.453],
#  [30532.0, 0.195],
#  [30531.9, 0.002],
#  [30531.8, 0.001],
#  [30531.7, 8.788],
#  [30531.6, 0.75],
#  [30531.5, 0.373],
#  [30531.4, 0.849],
#  [30531.3, 0.003],
#  [30531.2, 0.001],
#  [30531.1, 1.247],
#  [30531.0, 0.995],
#  [30530.9, 0.053],
#  [30530.8, 1.475],
#  [30530.7, 0.02],
#  [30530.6, 0.011],
#  [30530.5, 0.83],
#  [30530.4, 0.65],
#  [30530.3, 0.117],
#  [30530.2, 0.061],
#  [30530.1, 9.336],
#  [30530.0, 1.761],
#  [30529.9, 0.034],
#  [30529.8, 3.049],
#  [30529.7, 0.655],
#  [30529.6, 0.05],
#  [30529.5, 11.394],
#  [30529.4, 0.05],
#  [30529.3, 0.003],
#  [30529.2, 0.051],
#  [30529.1, 0.218],
#  [30528.9, 0.13],
#  [30528.8, 0.004],
#  [30528.7, 0.036],
#  [30528.6, 0.094],
#  [30528.5, 0.52],
#  [30528.4, 0.018],
#  [30528.3, 0.035],
#  [30528.2, 0.212],
#  [30528.1, 0.343],
#  [30528.0, 0.808],
#  [30527.9, 0.314],
#  [30527.8, 0.105],
#  [30527.7, 0.063],
#  [30527.6, 0.202],
#  [30527.5, 0.362],
#  [30527.4, 1.529],
#  [30527.3, 0.003],
#  [30527.2, 0.051],
#  [30527.1, 0.094],
#  [30526.9, 0.066],
#  [30526.8, 0.083],
#  [30526.7, 0.011],
#  [30526.6, 0.035],
#  [30526.5, 2.827],
#  [30526.4, 0.036],
#  [30526.3, 4.277],
#  [30526.1, 0.891],
#  [30526.0, 12.087],
#  [30525.9, 2.285],
#  [30525.8, 0.012],
#  [30525.7, 0.101],
#  [30525.4, 1.199],
#  [30525.2, 0.024],
#  [30525.0, 0.93],
#  [30524.9, 0.657],
#  [30524.8, 0.066],
#  [30524.7, 0.182],
#  [30524.6, 0.062],
#  [30524.5, 1.727],
#  [30524.4, 0.01],
#  [30524.2, 1.808],
#  [30524.1, 3.604],
#  [30524.0, 0.319],
#  [30523.9, 0.092],
#  [30523.8, 0.016],
#  [30523.7, 0.004],
#  [30523.6, 0.011],
#  [30523.5, 3.77],
#  [30523.4, 11.267],
#  [30523.3, 0.001],
#  [30523.1, 0.029],
#  [30523.0, 0.004],
#  [30522.9, 7.095],
#  [30522.8, 0.021],
#  [30522.6, 7.811],
#  [30522.5, 0.594],
#  [30522.3, 0.074],
#  [30522.2, 0.001],
#  [30522.1, 0.013],
#  [30522.0, 17.356],
#  [30521.9, 0.011],
#  [30521.8, 0.653],
#  [30521.7, 0.001],
#  [30521.6, 1.67],
#  [30521.5, 3.252],
#  [30521.4, 9.026],
#  [30521.3, 0.07],
#  [30521.2, 0.019],
#  [30521.1, 0.066],
#  [30521.0, 6.102],
#  [30520.9, 1.904],
#  [30520.8, 0.341],
#  [30520.7, 0.452],
#  [30520.6, 0.212],
#  [30520.5, 0.753],
#  [30520.4, 1.235],
#  [30520.3, 2.066],
#  [30520.2, 0.63],
#  [30520.1, 0.001],
#  [30520.0, 0.536],
#  [30519.8, 0.634],
#  [30519.7, 0.01],
#  [30519.6, 0.374],
#  [30519.3, 0.01],
#  [30519.2, 0.002],
#  [30519.0, 0.015],
#  [30518.7, 1.103],
#  [30518.6, 1.561],
#  [30518.5, 0.1],
#  [30518.4, 0.011],
#  [30518.3, 0.097],
#  [30518.2, 0.116],
#  [30518.1, 2.572],
#  [30518.0, 0.222],
#  [30517.9, 2.462],
#  [30517.8, 1.158],
#  [30517.7, 5.572],
#  [30517.6, 0.05],
#  [30517.5, 0.125],
#  [30517.3, 0.205],
#  [30517.2, 1.152],
#  [30517.1, 1.13],
#  [30517.0, 0.763],
#  [30516.9, 0.01],
#  [30516.8, 0.001],
#  [30516.7, 2.553],
#  [30516.6, 1.56],
#  [30516.5, 1.25],
#  [30516.4, 0.051],
#  [30516.3, 0.067],
#  [30516.1, 0.012],
#  [30516.0, 0.178],
#  [30515.9, 0.055],
#  [30515.8, 0.067],
#  [30515.7, 0.004],
#  [30515.6, 0.006],
#  [30515.5, 0.06],
#  [30515.3, 0.103],
#  [30515.2, 0.01],
#  [30515.1, 1.355],
#  [30515.0, 0.285],
#  [30514.9, 0.321],
#  [30514.8, 0.527],
#  [30514.7, 0.054],
#  [30514.6, 3.001],
#  [30514.5, 0.034],
#  [30514.4, 0.213],
#  [30514.3, 3.007],
#  [30514.2, 0.003],
#  [30514.1, 0.001],
#  [30514.0, 0.01],
#  [30513.7, 2.244],
#  [30513.6, 0.064],
#  [30513.5, 0.022],
#  [30513.4, 0.072],
#  [30513.3, 1.449],
#  [30513.2, 0.001],
#  [30513.1, 4.574],
#  [30513.0, 0.025],
#  [30512.9, 3.47],
#  [30512.8, 0.173],
#  [30512.7, 3.024],
#  [30512.5, 0.01],
#  [30512.4, 0.324],
#  [30512.3, 2.54],
#  [30512.2, 3.5],
#  [30512.1, 1.116],
#  [30512.0, 0.013],
#  [30511.9, 0.05],
#  [30511.8, 5.513],
#  [30511.7, 0.608],
#  [30511.6, 0.668],
#  [30511.5, 0.002],
#  [30511.4, 3.24],
#  [30511.3, 0.017],
#  [30511.2, 0.078],
#  [30511.1, 0.988],
#  [30510.8, 3.799],
#  [30510.7, 0.021],
#  [30510.4, 7.387],
#  [30510.3, 1.25],
#  [30510.2, 1.042],
#  [30510.1, 0.088],
#  [30510.0, 1.253],
#  [30509.9, 0.085],
#  [30509.8, 1.551],
#  [30509.6, 0.596],
#  [30509.5, 0.065],
#  [30509.4, 0.001],
#  [30509.3, 0.001],
#  [30509.2, 3.081],
#  [30509.1, 3.966],
#  [30509.0, 0.054],
#  [30508.9, 3.076],
#  [30508.8, 3.287],
#  [30508.7, 0.075],
#  [30508.6, 0.003],
#  [30508.5, 8.787],
#  [30508.4, 0.001],
#  [30508.3, 0.051],
#  [30508.2, 7.539],
#  [30508.1, 2.887],
#  [30508.0, 3.965],
#  [30507.9, 1.078],
#  [30507.8, 1.694],
#  [30507.6, 6.402],
#  [30507.5, 2.554],
#  [30507.4, 1.16],
#  [30507.3, 3.4],
#  [30507.1, 0.162],
#  [30507.0, 6.949],
#  [30506.9, 1.204],
#  [30506.8, 3.03],
#  [30506.7, 0.837],
#  [30506.6, 0.019],
#  [30506.5, 1.656],
#  [30506.4, 9.173],
#  [30506.3, 0.136],
#  [30506.2, 0.787],
#  [30506.1, 0.119],
#  [30506.0, 0.386],
#  [30505.9, 0.012],
#  [30505.8, 0.233],
#  [30505.7, 0.062],
#  [30505.6, 0.205],
#  [30505.5, 1.9],
#  [30505.4, 3.863],
#  [30505.3, 0.47],
#  [30505.2, 0.163],
#  [30505.1, 0.002],
#  [30505.0, 2.234],
#  [30504.9, 0.068],
#  [30504.8, 0.058],
#  [30504.7, 0.026],
#  [30504.6, 0.384],
#  [30504.5, 0.024],
#  [30504.4, 2.888],
#  [30504.3, 0.12],
#  [30504.2, 0.07],
#  [30504.1, 1.002],
#  [30504.0, 0.517],
#  [30503.9, 0.093],
#  [30503.7, 1.074],
#  [30503.6, 1.029],
#  [30503.5, 0.247],
#  [30503.4, 2.718],
#  [30503.3, 1.138],
#  [30503.2, 2.711],
#  [30503.1, 0.051],
#  [30503.0, 2.438],
#  [30502.9, 0.103],
#  [30502.8, 5.987],
#  [30502.7, 0.507],
#  [30502.6, 1.676],
#  [30502.5, 0.082],
#  [30502.4, 2.017],
#  [30502.2, 4.521],
#  [30502.1, 2.287],
#  [30502.0, 0.444],
#  [30501.9, 0.415],
#  [30501.8, 1.661],
#  [30501.6, 0.968],
#  [30501.4, 0.1],
#  [30501.3, 0.141],
#  [30501.2, 2.875],
#  [30501.1, 1.526],
#  [30501.0, 1.29],
#  [30500.9, 0.085],
#  [30500.8, 0.397],
#  [30500.7, 3.131],
#  [30500.6, 13.639],
#  [30500.5, 0.119],
#  [30500.4, 1.366],
#  [30500.3, 1.342],
#  [30500.2, 0.246],
#  [30500.1, 22.575],
#  [30500.0, 46.366],
#  [30499.9, 0.459],
#  [30499.8, 0.485],
#  [30499.7, 6.975],
#  [30499.6, 0.122],
#  [30499.5, 1.53],
#  [30499.4, 0.7],
#  [30499.3, 0.62],
#  [30499.2, 0.66],
#  [30499.1, 2.685],
#  [30499.0, 0.489],
#  [30498.9, 0.05],
#  [30498.8, 0.602],
#  [30498.7, 0.282],
#  [30498.6, 0.095],
#  [30498.5, 0.028],
#  [30498.4, 2.7],
#  [30498.3, 0.136],
#  [30498.1, 0.076],
#  [30498.0, 1.414],
#  [30497.9, 0.991],
#  [30497.8, 0.278],
#  [30497.7, 0.595],
#  [30497.6, 0.49],
#  [30497.5, 0.488],
#  [30497.4, 1.016],
#  [30497.3, 0.24],
#  [30497.2, 0.141],
#  [30497.1, 1.545],
#  [30497.0, 0.793],
#  [30496.9, 1.303],
#  [30496.8, 0.414],
#  [30496.7, 0.193],
#  [30496.6, 0.08],
#  [30496.5, 2.313],
#  [30496.4, 0.744],
#  [30496.3, 3.746],
#  [30496.2, 0.134],
#  [30496.1, 0.321],
#  [30496.0, 4.509],
#  [30495.9, 0.529],
#  [30495.8, 1.624],
#  [30495.7, 1.19],
#  [30495.6, 11.166],
#  [30495.5, 0.941],
#  [30495.4, 1.158],
#  [30495.3, 1.024],
#  [30495.2, 0.067],
#  [30495.1, 6.01],
#  [30495.0, 2.197],
#  [30494.9, 0.168],
#  [30494.8, 0.781],
#  [30494.7, 3.766],
#  [30494.6, 0.066],
#  [30494.5, 1.871],
#  [30494.4, 1.104],
#  [30494.3, 3.774],
#  [30494.2, 1.372],
#  [30494.1, 0.88],
#  [30494.0, 1.136],
#  [30493.9, 1.721],
#  [30493.8, 0.03],
#  [30493.7, 8.119],
#  [30493.6, 0.069],
#  [30493.5, 0.478],
#  [30493.4, 0.084],
#  [30493.3, 2.332],
#  [30493.2, 3.497],
#  [30493.1, 3.909],
#  [30493.0, 0.825],
#  [30492.9, 0.609],
#  [30492.8, 0.591],
#  [30492.7, 1.275],
#  [30492.6, 0.112],
#  [30492.5, 0.136],
#  [30492.4, 0.001],
#  [30492.3, 0.171],
#  [30492.2, 1.013],
#  [30492.1, 0.798],
#  [30492.0, 0.636],
#  [30491.9, 2.827],
#  [30491.8, 7.135],
#  [30491.7, 0.328],
#  [30491.6, 14.888]]

# %%
data = exchange.fetchTrades(symbol)
hprint.pprint_color(data[:2])
# Out:
# [{'amount': 0.1,
#   'cost': 3016.24,
#   'datetime': '2023-07-10T09:20:21.381Z',
#   'fee': None,
#   'fees': [],
#   'id': '152760771',
#   'info': {'T': '1688980821381',
#            'a': '152760771',
#            'f': '263456596',
#            'l': '263456596',
#            'm': True,
#            'p': '30162.40',
#            'q': '0.100'},
#   'order': None,
#   'price': 30162.4,
#   'side': 'sell',
#   'symbol': 'BTC/USDT',
#   'takerOrMaker': 'taker',
#   'timestamp': 1688980821381,
#   'type': None},
#  {'amount': 5.103,
#   'cost': 153918.7272,
#   'datetime': '2023-07-10T09:20:22.509Z',
#   'fee': None,
#   'fees': [],
#   'id': '152760772',
#   'info': {'T': '1688980822509',
#            'a': '152760772',
#            'f': '263456597',
#            'l': '263456597',
#            'm': True,
#            'p': '30162.40',
#            'q': '5.103'},
#   'order': None,
#   'price': 30162.4,
#   'side': 'sell',
#   'symbol': 'BTC/USDT',
#   'takerOrMaker': 'taker',
#   'timestamp': 1688980822509,
#   'type': None}]

# %%
symbol = "BTC/USDT"
data = exchange.fetchTicker(symbol)
hprint.pprint_color(data)
# Out:
# {'ask': None,
#  'askVolume': None,
#  'average': 30272.85,
#  'baseVolume': 102545.049,
#  'bid': None,
#  'bidVolume': None,
#  'change': 54.1,
#  'close': 30299.9,
#  'datetime': '2023-07-10T09:40:54.188Z',
#  'high': 30479.0,
#  'info': {'closeTime': '1688982054188',
#           'count': '103078',
#           'firstId': '263354172',
#           'highPrice': '30479.00',
#           'lastId': '263457255',
#           'lastPrice': '30299.90',
#           'lastQty': '0.001',
#           'lowPrice': '29941.50',
#           'openPrice': '30245.80',
#           'openTime': '1688895600000',
#           'priceChange': '54.10',
#           'priceChangePercent': '0.179',
#           'quoteVolume': '3105934785.56',
#           'symbol': 'BTCUSDT',
#           'volume': '102545.049',
#           'weightedAvgPrice': '30288.49'},
#  'last': 30299.9,
#  'low': 29941.5,
#  'open': 30245.8,
#  'percentage': 0.179,
#  'previousClose': None,
#  'quoteVolume': 3105934785.56,
#  'symbol': 'BTC/USDT',
#  'timestamp': 1688982054188,
#  'vwap': 30288.49}

# %% [markdown]
# ## FetchBalance

# %%
symbol = "BTC/USDT"
data = exchange.fetchBalance()
hprint.pprint_color(data)
# Out:
# {'BNB': {'free': 8.8774531, 'total': 2.45657689, 'used': 0.0},
#  'BTC': {'free': 0.06883463, 'total': 0.0, 'used': 0.0},
#  'BUSD': {'free': 2135.53177178, 'total': 1000.20004, 'used': 0.0},
#  'ETH': {'free': 1.1146111, 'total': 0.0, 'used': 0.0},
#  'USDC': {'free': 2135.07405103, 'total': 0.0, 'used': 0.0},
#  'USDT': {'free': 2177.5013884, 'total': 4601.17963671, 'used': 3981.28813729},
#  'datetime': None,
#  'free': {'BNB': 8.8774531,
#           'BTC': 0.06883463,
#           'BUSD': 2135.53177178,
#           'ETH': 1.1146111,
#           'USDC': 2135.07405103,
#           'USDT': 2177.5013884},
#  'info': {'assets': [{'asset': 'BTC',
#                       'availableBalance': '0.06883463',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'BNB',
#                       'availableBalance': '8.87745310',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '2.45657689',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '2.45657689',
#                       'maxWithdrawAmount': '2.45657689',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '1672741447205',
#                       'walletBalance': '2.45657689'},
#                      {'asset': 'ETH',
#                       'availableBalance': '1.11461110',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'USDT',
#                       'availableBalance': '2177.50138840',
#                       'crossUnPnl': '-921.49970997',
#                       'crossWalletBalance': '5522.67934668',
#                       'initialMargin': '3981.28813729',
#                       'maintMargin': '16.29601094',
#                       'marginAvailable': True,
#                       'marginBalance': '4601.17963671',
#                       'maxWithdrawAmount': '2177.50138840',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '3981.28813729',
#                       'unrealizedProfit': '-921.49970997',
#                       'updateTime': '1680653726118',
#                       'walletBalance': '5522.67934668'},
#                      {'asset': 'USDC',
#                       'availableBalance': '2135.07405103',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'BUSD',
#                       'availableBalance': '2135.53177178',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '1000.20004000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '1000.20004000',
#                       'maxWithdrawAmount': '1000.20004000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '1672741447205',
#                       'walletBalance': '1000.20004000'}],
#           'availableBalance': '2177.75123491',
#           'canDeposit': True,
#           'canTrade': True,
#           'canWithdraw': True,
#           'feeTier': '0',
#           'maxWithdrawAmount': '2177.75123491',
#           'multiAssetsMargin': True,
#           'positions': [{'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SUSHIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'INJUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNTUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TRXBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'RDNTUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ZRXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HIGHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '50000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'WAVESUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SPELLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '50000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XTZUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '250000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '1672741447205'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DARUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HNTUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'JOEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ETCUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XMRUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ALICEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HOOKUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'REEFUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BATUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '900000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOGEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '1680653726118'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '90000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TRXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'STORJUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SNXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOTBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '250000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XLMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'IOTXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'UMAUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DASHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'KAVAUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'RUNEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'APEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BLUEBIRDUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '600000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'OPUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'KEYUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DGBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SKLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'FOOTBALLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '50000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TOMOUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'MTLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '250000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LTCUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ETHBTC',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'KSMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'WAVESBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '100000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNBBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TRBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '150000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'MANAUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'FLOWUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CHRUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'GALUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '900000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'USDCUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
# ...
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LEVERUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000FLOKIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'FTMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000SHIBBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AMBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AMBBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '100000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOGEBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SXPUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XEMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000LUNCBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ZILUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '600000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AXSUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DYDXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'OCEANUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LEVERBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CHZUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DUSKUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CTSIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ACHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'}],
#           'totalCrossUnPnl': '-921.42114290',
#           'totalCrossWalletBalance': '7081.18027675',
#           'totalInitialMargin': '3981.74495029',
#           'totalMaintMargin': '16.29788074',
#           'totalMarginBalance': '6159.75913385',
#           'totalOpenOrderInitialMargin': '0.00000000',
#           'totalPositionInitialMargin': '3981.74495029',
#           'totalUnrealizedProfit': '-921.42114290',
#           'totalWalletBalance': '7081.18027675',
#           'updateTime': '0'},
#  'timestamp': None,
#  'total': {'BNB': 2.45657689,
#            'BTC': 0.0,
#            'BUSD': 1000.20004,
#            'ETH': 0.0,
#            'USDC': 0.0,
#            'USDT': 4601.17963671},
#  'used': {'BNB': 0.0,
#           'BTC': 0.0,
#           'BUSD': 0.0,
#           'ETH': 0.0,
#           'USDC': 0.0,
#           'USDT': 3981.28813729}}

# %% [markdown]
# - L1: market price only
# - L2: order volume aggregated by price
# - L3: each order is kept separated

# %% [markdown]
# ## Market price

# %%
#symbol = exchange.symbols[0]
symbol = "BTC/USDT"
print(symbol)
orderbook = exchange.fetch_order_book(symbol)
bid = orderbook["bids"][0][0] if len(orderbook["bids"]) > 0 else None
ask = orderbook["asks"][0][0] if len(orderbook["asks"]) > 0 else None
spread = (ask - bid) if (bid and ask) else None
print(exchange.id, {"bid": bid, "ask": ask, "spread": spread})
# Out:
# BTC/USDT
# binance {'bid': 30134.0, 'ask': 30275.1, 'spread': 141.09999999999854}

# %% [markdown]
# ## FetchTicker()

# %%
symbol = "BTC/USDT"
data = exchange.fetchTicker(symbol)
hprint.pprint_color(data)
# Out:
# {'ask': None,
#  'askVolume': None,
#  'average': 30204.45,
#  'baseVolume': 102529.415,
#  'bid': None,
#  'bidVolume': None,
#  'change': -140.9,
#  'close': 30134.0,
#  'datetime': '2023-07-10T09:41:03.201Z',
#  'high': 30479.0,
#  'info': {'closeTime': '1688982063201',
#           'count': '103023',
#           'firstId': '263354229',
#           'highPrice': '30479.00',
#           'lastId': '263457257',
#           'lastPrice': '30134.00',
#           'lastQty': '0.219',
#           'lowPrice': '29941.50',
#           'openPrice': '30274.90',
#           'openTime': '1688895660000',
#           'priceChange': '-140.90',
#           'priceChangePercent': '-0.465',
#           'quoteVolume': '3105461266.15',
#           'symbol': 'BTCUSDT',
#           'volume': '102529.415',
#           'weightedAvgPrice': '30288.49'},
#  'last': 30134.0,
#  'low': 29941.5,
#  'open': 30274.9,
#  'percentage': -0.465,
#  'previousClose': None,
#  'quoteVolume': 3105461266.15,
#  'symbol': 'BTC/USDT',
#  'timestamp': 1688982063201,
#  'vwap': 30288.49}

# %% [markdown]
# ## OHLCV bars

# %%
symbol = "BTC/USDT"
data = exchange.fetchOHLCV(symbol)
# O, H, L, C, V
hprint.pprint_color(data[:5])
# Out:
# [[1688952120000, 30090.9, 30282.0, 30090.0, 30282.0, 48.604],
#  [1688952180000, 30282.0, 30282.0, 30090.0, 30120.0, 61.407],
#  [1688952240000, 30093.0, 30282.0, 30090.0, 30090.0, 96.284],
#  [1688952300000, 30090.0, 30282.0, 30090.0, 30200.0, 115.67],
#  [1688952360000, 30090.9, 30282.0, 30090.0, 30090.0, 47.743]]

# %% [markdown]
# - The info from the current candle may be incomplete until the candle is closed
#
# - Exchanges provide
#     - (fast) primary data (e.g., order books, trades, fills)
#         - WebSockets might be faster than REST API
#     - (slow) secondary data calculated from primary data (e.g., OHLCV bars)
#         - It might be faster to compute data locally

# %% [markdown]
# ## Public trades

# %%
symbol = "BTC/USDT"
data = exchange.fetch_trades(symbol)
hprint.pprint_color(data[:2])
# Out:
# [{'amount': 0.375,
#   'cost': 11362.4625,
#   'datetime': '2023-07-10T09:20:26.438Z',
#   'fee': None,
#   'fees': [],
#   'id': '152760775',
#   'info': {'T': '1688980826438',
#            'a': '152760775',
#            'f': '263456600',
#            'l': '263456600',
#            'm': False,
#            'p': '30299.90',
#            'q': '0.375'},
#   'order': None,
#   'price': 30299.9,
#   'side': 'buy',
#   'symbol': 'BTC/USDT',
#   'takerOrMaker': 'taker',
#   'timestamp': 1688980826438,
#   'type': None},
#  {'amount': 0.211,
#   'cost': 6364.2664,
#   'datetime': '2023-07-10T09:20:28.179Z',
#   'fee': None,
#   'fees': [],
#   'id': '152760776',
#   'info': {'T': '1688980828179',
#            'a': '152760776',
#            'f': '263456601',
#            'l': '263456601',
#            'm': True,
#            'p': '30162.40',
#            'q': '0.211'},
#   'order': None,
#   'price': 30162.4,
#   'side': 'sell',
#   'symbol': 'BTC/USDT',
#   'takerOrMaker': 'taker',
#   'timestamp': 1688980828179,
#   'type': None}]

# %% [markdown]
# ## Borrow rates

# %% [markdown]
# - When short trading or trading with leverage on a spot market, currency must be
#   borrowed

# %%
# Binance doesn't support this.
#exchange.fetchBorrowRatesPerSymbol(symbol)

# %% [markdown]
# ## Leverage tiers

# %%
symbol = "BTC/USDT"
data =  exchange.fetchMarketLeverageTiers(symbol)
hprint.pprint_color(data[0])
hprint.pprint_color(data[-1])
# Out:
# {'currency': 'USDT',
#  'info': {'bracket': '1',
#           'cum': '0.0',
#           'initialLeverage': '125',
#           'maintMarginRatio': '0.004',
#           'notionalCap': '50000',
#           'notionalFloor': '0'},
#  'maintenanceMarginRate': 0.004,
#  'maxLeverage': 125.0,
#  'maxNotional': 50000.0,
#  'minNotional': 0.0,
#  'tier': 1.0}
# {'currency': 'USDT',
#  'info': {'bracket': '10',
#           'cum': '1.014213E8',
#           'initialLeverage': '1',
#           'maintMarginRatio': '0.5',
#           'notionalCap': '500000000',
#           'notionalFloor': '300000000'},
#  'maintenanceMarginRate': 0.5,
#  'maxLeverage': 1.0,
#  'maxNotional': 500000000.0,
#  'minNotional': 300000000.0,
#  'tier': 10.0}

# %% [markdown]
# ## Funding rate

# %%
data = exchange.fetchFundingRate(symbol)
hprint.pprint_color(data)
# Out:
# {'datetime': '2023-07-10T09:41:17.000Z',
#  'estimatedSettlePrice': 30102.08968791,
#  'fundingDatetime': '2023-07-10T16:00:00.000Z',
#  'fundingRate': 0.00015788,
#  'fundingTimestamp': 1689004800000,
#  'indexPrice': 30131.55186813,
#  'info': {'estimatedSettlePrice': '30102.08968791',
#           'indexPrice': '30131.55186813',
#           'interestRate': '0.00010000',
#           'lastFundingRate': '0.00015788',
#           'markPrice': '30135.01004989',
#           'nextFundingTime': '1689004800000',
#           'symbol': 'BTCUSDT',
#           'time': '1688982077000'},
#  'interestRate': 0.0001,
#  'markPrice': 30135.01004989,
#  'nextFundingDatetime': None,
#  'nextFundingRate': None,
#  'nextFundingTimestamp': None,
#  'previousFundingDatetime': None,
#  'previousFundingRate': None,
#  'previousFundingTimestamp': None,
#  'symbol': 'BTC/USDT',
#  'timestamp': 1688982077000}

# %%
data = exchange.fetchFundingRateHistory(symbol)
hprint.pprint_color(data[:3])
# Out:
# [{'datetime': '2023-06-07T08:00:00.000Z',
#   'fundingRate': 0.0001,
#   'info': {'fundingRate': '0.00010000',
#            'fundingTime': '1686124800000',
#            'symbol': 'BTCUSDT'},
#   'symbol': 'BTC/USDT',
#   'timestamp': 1686124800000},
#  {'datetime': '2023-06-07T16:00:00.000Z',
#   'fundingRate': 0.003,
#   'info': {'fundingRate': '0.00300000',
#            'fundingTime': '1686153600000',
#            'symbol': 'BTCUSDT'},
#   'symbol': 'BTC/USDT',
#   'timestamp': 1686153600000},
#  {'datetime': '2023-06-08T00:00:00.000Z',
#   'fundingRate': 0.003,
#   'info': {'fundingRate': '0.00300000',
#            'fundingTime': '1686182400000',
#            'symbol': 'BTCUSDT'},
#   'symbol': 'BTC/USDT',
#   'timestamp': 1686182400000}]

# %% [markdown]
# ## Open interest

# %%
# Binance doesn't support this.
# data = exchange.fetchOpenInterest(symbol)
# hprint.pprint_color(data[:3])

# %% [markdown]
# # Private API
#
# https://docs.ccxt.com/#/README?id=private-api
#
# - `fetchBalance`
# - `createOrder`, `cancelOrder`
# - `fetchOrder`, `fetchOpenOrder`, `fetchCanceledOrder`, `fetchClosedOrder`
# - `fetchMyTrades`
# - `fetchPositions`
# - `fetchTransactions`
# - `fetchLedger`
#
# ## Authentication
# - Handled automatically if API key provided
# - Generate nonce (integer and increasing, e.g., 32-bit Unix Timestamp in seconds)
# - Append public API key and nonce to the endpoint params, serialize, sign
# - Append signature to HTTP headers
#
# - `apiKey`
#     - non-secret
#     - sent over HTTPS
# - `secret`
#     - private key
#     - used to sign requests locally
#     - used together with the nonce
#     - signature sent with public key to authenticate
# - `uid`
#     - some exchanges generate a user id
# - `password`
#     - some exchanges use also password for trading

# %%
import oms.hsecrets.secret_identifier as ohsseide

exchange_id = "binance"
#account_type = "sandbox"
account_type = "trading"
stage = "preprod"
#secret_id = "4"
secret_id = 4

secret_identifier = ohsseide.SecretIdentifier(
    exchange_id, stage, account_type, secret_id
    )
print(secret_identifier)

# Prepare exchange params.
exchange_params = hsecret.get_secret(str(secret_identifier))
#print(exchange_params)
exchange_params["rateLimit"] = False
exchange_params["options"] = {"defaultType": "future"}

# Build the exchange object.
ccxt_exchange = getattr(ccxt, exchange_id)
exchange = ccxt_exchange(exchange_params)

exchange.options["adjustForTimeDifference"] = True
# Out:
# /app/core/signal_processing/decorrelation.py:12: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# binance.preprod.trading.4

# %%
# Check what type of authentication an exchange needs.
hprint.pprint_color(exchange.requiredCredentials)
# Out:
# {'apiKey': True,
#  'login': False,
#  'password': False,
#  'privateKey': False,
#  'secret': True,
#  'token': False,
#  'twofa': False,
#  'uid': False,
#  'walletAddress': False}

# %%
# Check that the credentials work.
# It throws an `AuthenticationError` if login fails.
exchange.check_required_credentials()
# Out:
# True

# %% [markdown]
# ## Overriding the nonce

# %% [markdown]
# ## Accounts
#
# * `fetchAccounts()`
# - Return accounts and sub-accounts in a dict.

# %%
# Binance doesn't have.
# exchange.fetchAccounts()

# %% [markdown]
# ## Account balance
#
# * `fetchBalance()`
# - Query for balance and get the amount of funds available

# %%
balance = exchange.fetchBalance()

# %%
hprint.pprint_color(balance)
# Out:
# {'ADA': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'BNB': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'BTC': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'BUSD': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'DOT': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'ETH': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'TUSD': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'USDC': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'USDP': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'USDT': {'free': 716.27859396, 'total': 741.50646893, 'used': 25.12769435},
#  'XRP': {'free': 0.0, 'total': 0.0, 'used': 0.0},
#  'datetime': None,
#  'free': {'ADA': 0.0,
#           'BNB': 0.0,
#           'BTC': 0.0,
#           'BUSD': 0.0,
#           'DOT': 0.0,
#           'ETH': 0.0,
#           'TUSD': 0.0,
#           'USDC': 0.0,
#           'USDP': 0.0,
#           'USDT': 716.27859396,
#           'XRP': 0.0},
#  'info': {'assets': [{'asset': 'BTC',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'ADA',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'XRP',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'TUSD',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'DOT',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'BNB',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'ETH',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'USDT',
#                       'availableBalance': '716.27859396',
#                       'crossUnPnl': '0.38660012',
#                       'crossWalletBalance': '741.11986881',
#                       'initialMargin': '25.12769435',
#                       'maintMargin': '9.43887851',
#                       'marginAvailable': True,
#                       'marginBalance': '741.50646893',
#                       'maxWithdrawAmount': '716.27859396',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '25.12769435',
#                       'unrealizedProfit': '0.38660012',
#                       'updateTime': '1689237994638',
#                       'walletBalance': '741.11986881'},
#                      {'asset': 'USDP',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'USDC',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'},
#                      {'asset': 'BUSD',
#                       'availableBalance': '0.00000000',
#                       'crossUnPnl': '0.00000000',
#                       'crossWalletBalance': '0.00000000',
#                       'initialMargin': '0.00000000',
#                       'maintMargin': '0.00000000',
#                       'marginAvailable': True,
#                       'marginBalance': '0.00000000',
#                       'maxWithdrawAmount': '0.00000000',
#                       'openOrderInitialMargin': '0.00000000',
#                       'positionInitialMargin': '0.00000000',
#                       'unrealizedProfit': '0.00000000',
#                       'updateTime': '0',
#                       'walletBalance': '0.00000000'}],
#           'availableBalance': '716.27859396',
#           'canDeposit': True,
#           'canTrade': True,
#           'canWithdraw': True,
#           'feeTier': '0',
#           'maxWithdrawAmount': '716.27859396',
#           'multiAssetsMargin': False,
#           'positions': [{'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SUSHIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BTSUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'INJUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TRXBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'RDNTUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ZRXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HIGHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '1.98622519685',
#                          'initialMargin': '1.00862030',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '25',
#                          'maintMargin': '0.50431015',
#                          'maxNotional': '5000',
#                          'notional': '-25.21550760',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-12.7',
#                          'positionInitialMargin': '1.00862030',
#                          'positionSide': 'BOTH',
#                          'symbol': 'WAVESUSDT',
#                          'unrealizedProfit': '0.00955230',
#                          'updateTime': '1689237936422'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SPELLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '50000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XTZUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '245.174',
#                          'initialMargin': '0.49024024',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '75',
#                          'maintMargin': '0.18384000',
#                          'maxNotional': '5000',
#                          'notional': '-36.76800000',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-0.15',
#                          'positionInitialMargin': '0.49024024',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNBUSDT',
#                          'unrealizedProfit': '0.00810000',
#                          'updateTime': '1689237927104'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DARUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HNTUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'JOEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ETCUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '250000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XMRUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ALICEUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'HOOKUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'REEFUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BATUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.06494',
#                          'initialMargin': '0.69457864',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '75',
#                          'maintMargin': '0.26046686',
#                          'maxNotional': '5000',
#                          'notional': '-52.09337266',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-802',
#                          'positionInitialMargin': '0.69457864',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOGEUSDT',
#                          'unrealizedProfit': '-0.01149266',
#                          'updateTime': '1689237929179'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '645000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TRXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.3118',
#                          'initialMargin': '0.13388785',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '21',
#                          'maintMargin': '0.05623289',
#                          'maxNotional': '5000',
#                          'notional': '-2.81164491',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-9',
#                          'positionInitialMargin': '0.13388785',
#                          'positionSide': 'BOTH',
#                          'symbol': 'STORJUSDT',
#                          'unrealizedProfit': '-0.00544491',
#                          'updateTime': '1689237935398'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SNXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOTBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'NEARBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '250000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XLMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'APEBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'IOTXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DASHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'UMAUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '10000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'KAVAUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.987',
#                          'initialMargin': '2.20906096',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '25',
#                          'maintMargin': '0.55226524',
#                          'maxNotional': '5000',
#                          'notional': '-55.22652408',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-56',
#                          'positionInitialMargin': '2.20906096',
#                          'positionSide': 'BOTH',
#                          'symbol': 'RUNEUSDT',
#                          'unrealizedProfit': '0.04547592',
#                          'updateTime': '1689237933849'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '1.854',
#                          'initialMargin': '0.14856000',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '50',
#                          'maintMargin': '0.04828200',
#                          'maxNotional': '5000',
#                          'notional': '7.42800000',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '4',
#                          'positionInitialMargin': '0.14856000',
#                          'positionSide': 'BOTH',
#                          'symbol': 'APEUSDT',
#                          'unrealizedProfit': '0.01200000',
#                          'updateTime': '1689237025303'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BLUEBIRDUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'BNXUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CVXBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '600000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'OPUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'KEYUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DGBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SKLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'FOOTBALLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '50000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'TOMOUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'MTLUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '500000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.000',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LTCUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DODOBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '400',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.00',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ETHBTC',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
# ...
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LEVERUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000FLOKIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.2774',
#                          'initialMargin': '0.16655999',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '50',
#                          'maintMargin': '0.04996800',
#                          'maxNotional': '5000',
#                          'notional': '8.32800000',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '30',
#                          'positionInitialMargin': '0.16655999',
#                          'positionSide': 'BOTH',
#                          'symbol': 'FTMUSDT',
#                          'unrealizedProfit': '0.00600000',
#                          'updateTime': '1689237031080'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000SHIBBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AMBUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AMBBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '100000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DOGEBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0.0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'SXPUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'XEMUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': '1000LUNCBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ZILUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '50',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'AXSUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '1689072057201'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '1.86',
#                          'initialMargin': '0.22323412',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '50',
#                          'maintMargin': '0.11161706',
#                          'maxNotional': '5000',
#                          'notional': '-11.16170634',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '-6.0',
#                          'positionInitialMargin': '0.22323412',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DYDXUSDT',
#                          'unrealizedProfit': '-0.00170634',
#                          'updateTime': '1689237930212'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'OCEANUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '0',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'LEVERBUSD',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CHZUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'DUSKUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '25000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'CTSIUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'},
#                         {'askNotional': '0',
#                          'bidNotional': '0',
#                          'entryPrice': '0.0',
#                          'initialMargin': '0',
#                          'isolated': False,
#                          'isolatedWallet': '0',
#                          'leverage': '20',
#                          'maintMargin': '0',
#                          'maxNotional': '5000',
#                          'notional': '0',
#                          'openOrderInitialMargin': '0',
#                          'positionAmt': '0',
#                          'positionInitialMargin': '0',
#                          'positionSide': 'BOTH',
#                          'symbol': 'ACHUSDT',
#                          'unrealizedProfit': '0.00000000',
#                          'updateTime': '0'}],
#           'totalCrossUnPnl': '0.38660012',
#           'totalCrossWalletBalance': '741.11986881',
#           'totalInitialMargin': '25.12769435',
#           'totalMaintMargin': '9.43887851',
#           'totalMarginBalance': '741.50646893',
#           'totalOpenOrderInitialMargin': '0.00000000',
#           'totalPositionInitialMargin': '25.12769435',
#           'totalUnrealizedProfit': '0.38660012',
#           'totalWalletBalance': '741.11986881',
#           'updateTime': '0'},
#  'timestamp': None,
#  'total': {'ADA': 0.0,
#            'BNB': 0.0,
#            'BTC': 0.0,
#            'BUSD': 0.0,
#            'DOT': 0.0,
#            'ETH': 0.0,
#            'TUSD': 0.0,
#            'USDC': 0.0,
#            'USDP': 0.0,
#            'USDT': 741.50646893,
#            'XRP': 0.0},
#  'used': {'ADA': 0.0,
#           'BNB': 0.0,
#           'BTC': 0.0,
#           'BUSD': 0.0,
#           'DOT': 0.0,
#           'ETH': 0.0,
#           'TUSD': 0.0,
#           'USDC': 0.0,
#           'USDP': 0.0,
#           'USDT': 25.12769435,
#           'XRP': 0.0}}

# %%
balance.keys()
# Out:
# dict_keys(['info', 'BTC', 'ADA', 'XRP', 'TUSD', 'DOT', 'BNB', 'ETH', 'USDT', 'USDP', 'USDC', 'BUSD', 'timestamp', 'datetime', 'free', 'used', 'total'])

# %%
#print(hprint.to_str('balance["timestamp"] balance["datetime"]'))
key_names = ["timestamp", "datetime"]
hprint.pprint_color(
    subset_dict(balance, key_names))
# Out:
# {'datetime': None, 'timestamp': None}

# %%
# Coins available for trading.
hprint.pprint_color(balance["free"])
# Out:
# {'ADA': 0.0,
#  'BNB': 0.0,
#  'BTC': 0.0,
#  'BUSD': 0.0,
#  'DOT': 0.0,
#  'ETH': 0.0,
#  'TUSD': 0.0,
#  'USDC': 0.0,
#  'USDP': 0.0,
#  'USDT': 716.27859396,
#  'XRP': 0.0}

# %%
# Coins on hold / locked.
hprint.pprint_color(balance["used"])
# Out:
# {'ADA': 0.0,
#  'BNB': 0.0,
#  'BTC': 0.0,
#  'BUSD': 0.0,
#  'DOT': 0.0,
#  'ETH': 0.0,
#  'TUSD': 0.0,
#  'USDC': 0.0,
#  'USDP': 0.0,
#  'USDT': 25.12769435,
#  'XRP': 0.0}

# %%
# Total coins (=free + used).
hprint.pprint_color(balance["total"])
# Out:
# {'ADA': 0.0,
#  'BNB': 0.0,
#  'BTC': 0.0,
#  'BUSD': 0.0,
#  'DOT': 0.0,
#  'ETH': 0.0,
#  'TUSD': 0.0,
#  'USDC': 0.0,
#  'USDP': 0.0,
#  'USDT': 741.50646893,
#  'XRP': 0.0}

# %%
# Indexed by coins.
hprint.pprint_color(balance["BTC"])
# Out:
# {'free': 0.0, 'total': 0.0, 'used': 0.0}

# %%
# `info` contains the response (unparsed) from the exchange.
hprint.pprint_color(balance["info"])
# Out:
# {'assets': [{'asset': 'BTC',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'ADA',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'XRP',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'TUSD',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'DOT',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'BNB',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'ETH',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'USDT',
#              'availableBalance': '700.08760317',
#              'crossUnPnl': '-0.60535210',
#              'crossWalletBalance': '744.76195644',
#              'initialMargin': '43.92421060',
#              'maintMargin': '15.08937103',
#              'marginAvailable': True,
#              'marginBalance': '744.15660434',
#              'maxWithdrawAmount': '700.08760317',
#              'openOrderInitialMargin': '5.04396406',
#              'positionInitialMargin': '38.88024654',
#              'unrealizedProfit': '-0.60535210',
#              'updateTime': '1689066094075',
#              'walletBalance': '744.76195644'},
#             {'asset': 'USDP',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'USDC',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'},
#             {'asset': 'BUSD',
#              'availableBalance': '0.00000000',
#              'crossUnPnl': '0.00000000',
#              'crossWalletBalance': '0.00000000',
#              'initialMargin': '0.00000000',
#              'maintMargin': '0.00000000',
#              'marginAvailable': True,
#              'marginBalance': '0.00000000',
#              'maxWithdrawAmount': '0.00000000',
#              'openOrderInitialMargin': '0.00000000',
#              'positionInitialMargin': '0.00000000',
#              'unrealizedProfit': '0.00000000',
#              'updateTime': '0',
#              'walletBalance': '0.00000000'}],
#  'availableBalance': '700.08760317',
#  'canDeposit': True,
#  'canTrade': True,
#  'canWithdraw': True,
#  'feeTier': '0',
#  'maxWithdrawAmount': '700.08760317',
#  'multiAssetsMargin': False,
#  'positions': [{'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SUSHIUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BTSUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'INJUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'TRXBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'RDNTUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ZRXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'HIGHUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '2.130481791045',
#                 'initialMargin': '2.49455946',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '25',
#                 'maintMargin': '1.24727973',
#                 'maxNotional': '5000',
#                 'notional': '-62.36398670',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-29.3',
#                 'positionInitialMargin': '2.49455946',
#                 'positionSide': 'BOTH',
#                 'symbol': 'WAVESUSDT',
#                 'unrealizedProfit': '0.05912974',
#                 'updateTime': '1689066038440'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SPELLUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '50000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'XTZUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '247.8713333333',
#                 'initialMargin': '0.26339213',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '75',
#                 'maintMargin': '0.09877200',
#                 'maxNotional': '5000',
#                 'notional': '-19.75440000',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-0.08',
#                 'positionInitialMargin': '0.26339213',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BNBUSDT',
#                 'unrealizedProfit': '0.07530666',
#                 'updateTime': '1689066091589'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DARUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'HNTUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'JOEUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '400000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.00',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ETCUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '250000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.000',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'XMRUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ALICEUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'HOOKUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'REEFUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BATUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0651634048927',
#                 'initialMargin': '1.73874694',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '75',
#                 'maintMargin': '0.65202977',
#                 'maxNotional': '5000',
#                 'notional': '130.40595596',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '2003',
#                 'positionInitialMargin': '1.73874694',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DOGEUSDT',
#                 'unrealizedProfit': '-0.11633424',
#                 'updateTime': '1689066031302'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '645000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'TRXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '51.34360000',
#                 'bidNotional': '0',
#                 'entryPrice': '0.3333419354839',
#                 'initialMargin': '1.46282961',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '21',
#                 'maintMargin': '0.41248359',
#                 'maxNotional': '5000',
#                 'notional': '20.62417972',
#                 'openOrderInitialMargin': '0.48072577',
#                 'positionAmt': '62',
#                 'positionInitialMargin': '0.98210384',
#                 'positionSide': 'BOTH',
#                 'symbol': 'STORJUSDT',
#                 'unrealizedProfit': '-0.04301994',
#                 'updateTime': '1689064834804'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SNXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DOTBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'NEARBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '250000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'XLMUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'APEBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'IOTXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.000',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DASHUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'UMAUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '10000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'KAVAUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '39.44700000',
#                 'bidNotional': '0',
#                 'entryPrice': '1.013333333333',
#                 'initialMargin': '2.42394394',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '25',
#                 'maintMargin': '0.21151598',
#                 'maxNotional': '5000',
#                 'notional': '-21.15159858',
#                 'openOrderInitialMargin': '1.57788000',
#                 'positionAmt': '-21',
#                 'positionInitialMargin': '0.84606394',
#                 'positionSide': 'BOTH',
#                 'symbol': 'RUNEUSDT',
#                 'unrealizedProfit': '0.12840135',
#                 'updateTime': '1689065450023'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '1.926485714286',
#                 'initialMargin': '1.34125743',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '50',
#                 'maintMargin': '0.43590866',
#                 'maxNotional': '5000',
#                 'notional': '-67.06287175',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-35',
#                 'positionInitialMargin': '1.34125743',
#                 'positionSide': 'BOTH',
#                 'symbol': 'APEUSDT',
#                 'unrealizedProfit': '0.36412810',
#                 'updateTime': '1689066027168'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BLUEBIRDUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BNXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'CVXBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '600000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'OPUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'KEYUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DGBUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SKLUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.00',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'FOOTBALLUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '50000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'TOMOUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'MTLUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '500000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.000',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'LTCUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DODOBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '400',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.00',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ETHBTC',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'KSMUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'WAVESBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '100000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.00',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BNBBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ETCBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'TRBUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '150000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'MANAUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'FLOWUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'CHRUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'AVAXBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'GALUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '900000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'USDCUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '10.16800000',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0817843871831',
#                 'initialMargin': '2.64030218',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '1.05612087',
#                 'maxNotional': '5000',
#                 'notional': '52.80604372',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '647',
#                 'positionInitialMargin': '2.64030218',
#                 'positionSide': 'BOTH',
#                 'symbol': 'OGNUSDT',
#                 'unrealizedProfit': '-0.10845014',
#                 'updateTime': '1689066094075'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'RNDRUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SCUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
# ...
#                 'notional': '-274.28353403',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-0.009',
#                 'positionInitialMargin': '2.19426827',
#                 'positionSide': 'BOTH',
#                 'symbol': 'BTCUSDT',
#                 'unrealizedProfit': '0.35384453',
#                 'updateTime': '1689066029758'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'OMGUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ICXUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '50000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': '1000PEPEUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'FETUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'LEVERUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': '1000FLOKIUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.2752',
#                 'initialMargin': '0.03854994',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '50',
#                 'maintMargin': '0.01156498',
#                 'maxNotional': '5000',
#                 'notional': '-1.92749704',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-7',
#                 'positionInitialMargin': '0.03854994',
#                 'positionSide': 'BOTH',
#                 'symbol': 'FTMUSDT',
#                 'unrealizedProfit': '-0.00109704',
#                 'updateTime': '1689066058368'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': '1000SHIBBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'AMBUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'AMBBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '100000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DOGEBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0.0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'SXPUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'XEMUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': '1000LUNCBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ZILUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '50',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'AXSUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '1689066028225'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '1.893',
#                 'initialMargin': '0.18414328',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '50',
#                 'maintMargin': '0.09207164',
#                 'maxNotional': '5000',
#                 'notional': '-9.20716423',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '-4.9',
#                 'positionInitialMargin': '0.18414328',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DYDXUSDT',
#                 'unrealizedProfit': '0.06853576',
#                 'updateTime': '1689066031813'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'OCEANUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '0',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'LEVERBUSD',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'CHZUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'DUSKUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '25000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'CTSIUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'},
#                {'askNotional': '0',
#                 'bidNotional': '0',
#                 'entryPrice': '0.0',
#                 'initialMargin': '0',
#                 'isolated': False,
#                 'isolatedWallet': '0',
#                 'leverage': '20',
#                 'maintMargin': '0',
#                 'maxNotional': '5000',
#                 'notional': '0',
#                 'openOrderInitialMargin': '0',
#                 'positionAmt': '0',
#                 'positionInitialMargin': '0',
#                 'positionSide': 'BOTH',
#                 'symbol': 'ACHUSDT',
#                 'unrealizedProfit': '0.00000000',
#                 'updateTime': '0'}],
#  'totalCrossUnPnl': '-0.60535210',
#  'totalCrossWalletBalance': '744.76195644',
#  'totalInitialMargin': '43.92421060',
#  'totalMaintMargin': '15.08937103',
#  'totalMarginBalance': '744.15660434',
#  'totalOpenOrderInitialMargin': '5.04396406',
#  'totalPositionInitialMargin': '38.88024654',
#  'totalUnrealizedProfit': '-0.60535210',
#  'totalWalletBalance': '744.76195644',
#  'updateTime': '0'}

# %%
balance["info"].keys()
# Out:
# dict_keys(['feeTier', 'canTrade', 'canDeposit', 'canWithdraw', 'updateTime', 'multiAssetsMargin', 'totalInitialMargin', 'totalMaintMargin', 'totalWalletBalance', 'totalUnrealizedProfit', 'totalMarginBalance', 'totalPositionInitialMargin', 'totalOpenOrderInitialMargin', 'totalCrossWalletBalance', 'totalCrossUnPnl', 'availableBalance', 'maxWithdrawAmount', 'assets', 'positions'])

# %%
# Print info about one asset.
print(len(balance["info"]["assets"]))
hprint.pprint_color(balance["info"]["assets"][0])
# Out:
# 11
# {'asset': 'BTC',
#  'availableBalance': '0.00000000',
#  'crossUnPnl': '0.00000000',
#  'crossWalletBalance': '0.00000000',
#  'initialMargin': '0.00000000',
#  'maintMargin': '0.00000000',
#  'marginAvailable': True,
#  'marginBalance': '0.00000000',
#  'maxWithdrawAmount': '0.00000000',
#  'openOrderInitialMargin': '0.00000000',
#  'positionInitialMargin': '0.00000000',
#  'unrealizedProfit': '0.00000000',
#  'updateTime': '0',
#  'walletBalance': '0.00000000'}

# %%
# Print info about one position.
print(len(balance["info"]["positions"]))
hprint.pprint_color(balance["info"]["positions"][0])
# Out:
# 239
# {'askNotional': '0',
#  'bidNotional': '0',
#  'entryPrice': '0.0',
#  'initialMargin': '0',
#  'isolated': False,
#  'isolatedWallet': '0',
#  'leverage': '20',
#  'maintMargin': '0',
#  'maxNotional': '25000',
#  'notional': '0',
#  'openOrderInitialMargin': '0',
#  'positionAmt': '0',
#  'positionInitialMargin': '0',
#  'positionSide': 'BOTH',
#  'symbol': 'SUSHIUSDT',
#  'unrealizedProfit': '0.00000000',
#  'updateTime': '0'}

# %%
balance["info"]["feeTier"]
# Out:
# '0'

# %%
# for key in ["canTrade", "canDeposit", "canWithdraw"]:
#     print(hprint.to_str(f'balance["info"]["{key}"]'))
hprint.pprint_color(
    subset_dict(
        balance["info"],
        ["canTrade", "canDeposit", "canWithdraw"]))
# Out:
# {'canDeposit': True, 'canTrade': True, 'canWithdraw': True}

# %%
balance["info"]["updateTime"]
# Out:
# '0'

# %%
# https://www.binance.com/en/support/faq/leverage-and-margin-of-usd%E2%93%A2-m-futures-360033162192
# - USD-M futures: margin and settlement in USDT (Tether) and BUSD (Binance Stable coin)
# - COIN-M futures: margin and settlement in alt-coins

# %%
# for key in ['totalInitialMargin',
#             'totalMaintMargin',
#             'totalWalletBalance', 
#             'totalUnrealizedProfit',
#             'totalMarginBalance',
#             'totalPositionInitialMargin',
#             'totalOpenOrderInitialMargin',
#             'totalCrossWalletBalance',
#             'totalCrossUnPnl', 
#             'availableBalance', 'maxWithdrawAmount']:
#     print(hprint.to_str(f'balance["info"]["{key}"]'))

key_names = ['totalInitialMargin',
             'totalMaintMargin',
             'totalWalletBalance', 
             'totalUnrealizedProfit',
             'totalMarginBalance',
             'totalPositionInitialMargin',
             'totalOpenOrderInitialMargin',
             'totalCrossWalletBalance',
             'totalCrossUnPnl', 
             'availableBalance',
             'maxWithdrawAmount']
hprint.pprint_color(
    subset_dict(balance["info"], key_names))
# Out:
# {'availableBalance': '716.27859396',
#  'maxWithdrawAmount': '716.27859396',
#  'totalCrossUnPnl': '0.38660012',
#  'totalCrossWalletBalance': '741.11986881',
#  'totalInitialMargin': '25.12769435',
#  'totalMaintMargin': '9.43887851',
#  'totalMarginBalance': '741.50646893',
#  'totalOpenOrderInitialMargin': '0.00000000',
#  'totalPositionInitialMargin': '25.12769435',
#  'totalUnrealizedProfit': '0.38660012',
#  'totalWalletBalance': '741.11986881'}

# %% [markdown]
# ## Orders
#
# https://docs.ccxt.com/#/README?id=orders
#
# - You can query orders by an id or symbol
# - Some exchanges might not have all methods

# %%
# for k, v in exchange.has.items():
#     if "order" in k or "Order" in k:
#         print(k, v)

hprint.pprint_color(subset_dict(
    exchange.has, [
    "fetchOrder", "fetchOrders",
    "fetchOpenOrder", "fetchOpenOrders",
    "fetchClosedOrder", "fetchClosedOrders"]))
# Out:
# {'fetchClosedOrder': False,
#  'fetchClosedOrders': 'emulated',
#  'fetchOpenOrder': False,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrders': True}

# %% [markdown]
# ### Understanding the Orders API design
#
# - `fetch{,Open,Canceled}Orders()`
# - `fetchMyTrades()`: history of settled trades
# - `createOrder()`
# - `cancelOrder()`
#
# - All methods returning a list of trades / orders, accept a `since` and `limit` arg
#     - Without `since` the method returns the default set of results from the exchange (e.g., last 24 hours or last N trades
#     - Some exchanges provide pagination through the `params` arg

# %%
orders = exchange.fetchOrders("BTC/USDT", limit=2)

# %%
hprint.pprint_color(orders[0])
# Out:
# {'info': {'orderId': '170783916148',
#           'symbol': 'BTCUSDT',
#           'status': 'CANCELED',
#           'clientOrderId': 'x-xcKtGhcu48111d25c4a7838729d6f2',
#           'price': '30893.50',
#           'avgPrice': '0.00000',
#           'origQty': '0.006',
#           'executedQty': '0',
#           'cumQuote': '0',
#           'timeInForce': 'GTC',
#           'type': 'LIMIT',
#           'reduceOnly': False,
#           'closePosition': False,
#           'side': 'BUY',
#           'positionSide': 'BOTH',
#           'stopPrice': '0',
#           'workingType': 'CONTRACT_PRICE',
#           'priceProtect': False,
#           'origType': 'LIMIT',
#           'time': '1689265527208',
#           'updateTime': '1689265599480'},
#  'id': '170783916148',
#  'clientOrderId': 'x-xcKtGhcu48111d25c4a7838729d6f2',
#  'timestamp': 1689265527208,
#  'datetime': '2023-07-13T16:25:27.208Z',
#  'lastTradeTimestamp': None,
#  'symbol': 'BTC/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'postOnly': False,
#  'reduceOnly': False,
#  'side': 'buy',
#  'price': 30893.5,
#  'stopPrice': None,
#  'amount': 0.006,
#  'cost': 0.0,
#  'average': None,
#  'filled': 0.0,
#  'remaining': 0.006,
#  'status': 'canceled',
#  'fee': None,
#  'trades': [],
#  'fees': []}

# %% [markdown]
# - closed orders are not trades (aka fills)
# - an order doesn't have `fee`
# - trades have `fee` and `cost`

# %%
closed_orders = exchange.fetchClosedOrders("BTC/USDT", limit=2)

# %%
hprint.pprint_color(closed_orders[0])
# Out:
# {'info': {'orderId': '170786184487',
#           'symbol': 'BTCUSDT',
#           'status': 'FILLED',
#           'clientOrderId': 'x-xcKtGhcubbf5e270ce85157b29444b',
#           'price': '30897.50',
#           'avgPrice': '30899.60000',
#           'origQty': '0.004',
#           'executedQty': '0.004',
#           'cumQuote': '123.59840',
#           'timeInForce': 'GTC',
#           'type': 'LIMIT',
#           'reduceOnly': False,
#           'closePosition': False,
#           'side': 'SELL',
#           'positionSide': 'BOTH',
#           'stopPrice': '0',
#           'workingType': 'CONTRACT_PRICE',
#           'priceProtect': False,
#           'origType': 'LIMIT',
#           'time': '1689265828679',
#           'updateTime': '1689265828679'},
#  'id': '170786184487',
#  'clientOrderId': 'x-xcKtGhcubbf5e270ce85157b29444b',
#  'timestamp': 1689265828679,
#  'datetime': '2023-07-13T16:30:28.679Z',
#  'lastTradeTimestamp': None,
#  'symbol': 'BTC/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'postOnly': False,
#  'reduceOnly': False,
#  'side': 'sell',
#  'price': 30897.5,
#  'stopPrice': None,
#  'amount': 0.004,
#  'cost': 123.5984,
#  'average': 30899.6,
#  'filled': 0.004,
#  'remaining': 0.0,
#  'status': 'closed',
#  'fee': None,
#  'trades': [],
#  'fees': []}

# %% [markdown]
# ### Order structure
#
# https://docs.ccxt.com/#/README?id=order-structure

# %%
order = orders[0]

# %%
order.keys()
# Out:
# dict_keys(['info', 'id', 'clientOrderId', 'timestamp', 'datetime', 'lastTradeTimestamp', 'symbol', 'type', 'timeInForce', 'postOnly', 'reduceOnly', 'side', 'price', 'stopPrice', 'amount', 'cost', 'average', 'filled', 'remaining', 'status', 'fee', 'trades', 'fees'])

# %%
var_names = ["id",
             # You can tag the order.
             "clientOrderId",
             "timestamp",
             "datetime",
             "lastTradeTimestamp"]
hprint.pprint_color(
    subset_dict(order, var_names, keep_order=False))
# Out:
# {'id': '170783916148',
#  'clientOrderId': 'x-xcKtGhcu48111d25c4a7838729d6f2',
#  'timestamp': 1689265527208,
#  'datetime': '2023-07-13T16:25:27.208Z',
#  'lastTradeTimestamp': None}

# %%
var_names = [
    # 
    'status',
    'symbol',
    # E.g., market, limit
    'type',
    'timeInForce',
    'side',
    # Price in quote currency.
    'price',
    # Average filling price.
    'average',
    # How much is ordered vs filled vs remaining.
    'amount',
    'filled',
    'remaining',
    # = filled * price
    'cost',
    'fee',
    'fees',
    # List of trades.
    'trades',
    #
    'stopPrice',
    'postOnly',
    'reduceOnly',
]
hprint.pprint_color(subset_dict(order, var_names, keep_order=False))
# Out:
# {'status': 'canceled',
#  'symbol': 'BTC/USDT',
#  'type': 'limit',
#  'timeInForce': 'GTC',
#  'side': 'buy',
#  'price': 30893.5,
#  'average': None,
#  'amount': 0.006,
#  'filled': 0.0,
#  'remaining': 0.006,
#  'cost': 0.0,
#  'fee': None,
#  'fees': [],
#  'trades': [],
#  'stopPrice': None,
#  'postOnly': False,
#  'reduceOnly': False}

# %%
hprint.pprint_color(order["info"])
# Out:
# {'orderId': '170643031299',
#  'symbol': 'BTCUSDT',
#  'status': 'CANCELED',
#  'clientOrderId': 'x-xcKtGhcu6e473c588377f85f69952b',
#  'price': '30400.10',
#  'avgPrice': '0.00000',
#  'origQty': '0.001',
#  'executedQty': '0',
#  'cumQuote': '0',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'reduceOnly': False,
#  'closePosition': False,
#  'side': 'SELL',
#  'positionSide': 'BOTH',
#  'stopPrice': '0',
#  'workingType': 'CONTRACT_PRICE',
#  'priceProtect': False,
#  'origType': 'LIMIT',
#  'time': '1689237027940',
#  'updateTime': '1689237099073'}

# %% [markdown]
# ### Placing orders
#
# https://docs.ccxt.com/#/README?id=placing-orders
#
# - Limit orders
#     - Amount in base currency (how much you want to buy / sell)
#     - Price in quote currency (for which price you want to buy / sell)
# - Trigger orders
#     - Wait for a condition on a market (trigger) and then a market order is placed
# - Stop loss orders / Take profit orders
#     - Like a special trigger order
#     - When price passes a certain value, a market / limit order is triggered

# %% [markdown]
# - `createOrder` is used to place orders:
#   - symbol
#   - side
#       - buy `BTC/USD`, receive quote currency (BTC) for base currency (USD)
#       - sell `BTC/USD`: receive USD for BTC
#   - type
#       - market
#       - limit
#   - amount
#       - Typically expressed in terms of the base currency
#       - For some exchanges it is dependent on the side of the order
#   - price
#       - in units of the quotes currency
#   - params
#       - params specific to the exchange API
#   - a successful order returns an order structure
#
#
# - Limit orders
#     - `create_limit_order`
#     - `create_buy_limit_order`
#     - `create_sell_limit_order`
#     - They are placed on the exchange for a certain price
#     - They are fullfilled (closed) when:
#         - there are no orders at a better price
#         - a market / limit order for a price that matches or exceeds the price of the limit order
#
# - Market orders
#     - Executed immediately using orders from the top of the other side of the book
#       (i.e., orders are chosen with best price available)
#     - You are not guaranteed that the order is executed for the price you observe
#       prior to placing the order because
#         - network latency
#         - high loads on the exchange
#         - price volatility
#         - order walking the book

# %% [markdown]
# ### Editing orders
#
# https://docs.ccxt.com/#/README?id=editing-orders
#
# An order can also be edited
#
# TODO(gp): Unclear what happens. I believe it's cancelled and placed again

# %% [markdown]
# ### Canceling orders
#
# https://docs.ccxt.com/#/README?id=canceling-orders
#
# - `cancelOrder`: cancel a single order
# - `candelOrders`: cancel multiple orders
# - `cancelAllOrders`: cancel all the open orders
#
# It is possible that an order gets executed while the cancel command is being executed
#     - Then a `NetworkError` or `OrderNotFound` are thrown

# %% [markdown]
# ## My trades
#
# https://docs.ccxt.com/#/README?id=my-trades
#
# ### How orders are related to trades
# - A trade is also called a "fill"
# - Each trade is a result of order execution
# - One order may result in several trades
#     - i.e., an order can be filled with one or more trades
#     - one-to-many relationship
#
# - Each trade is a result of an order execution (matching opposing orders)
# - An execution of one order can result in several trades (i.e., filled with
#   multiple trades)
#
# ### Personal trades
# - Typically exchanges use pagination to return all the trades

# %% [markdown]
# ### Trade structure
#
# https://docs.ccxt.com/#/README?id=trade-structure

# %%
order_id = None
trades = exchange.fetch_my_trades(symbol, limit=2)

# %%
trade = trades[0]

# %%
hprint.pprint_color(trade)
# Out:
# {'info': {'symbol': 'BTCUSDT',
#           'id': '3932745371',
#           'orderId': '170669758249',
#           'side': 'BUY',
#           'price': '30536.90',
#           'qty': '0.004',
#           'realizedPnl': '0',
#           'marginAsset': 'USDT',
#           'quoteQty': '122.14760',
#           'commission': '0.02442952',
#           'commissionAsset': 'USDT',
#           'time': '1689243340610',
#           'positionSide': 'BOTH',
#           'buyer': True,
#           'maker': True},
#  'timestamp': 1689243340610,
#  'datetime': '2023-07-13T10:15:40.610Z',
#  'symbol': 'BTC/USDT',
#  'id': '3932745371',
#  'order': '170669758249',
#  'type': None,
#  'side': 'buy',
#  'takerOrMaker': 'maker',
#  'price': 30536.9,
#  'amount': 0.004,
#  'cost': 122.1476,
#  'fee': {'cost': 0.02442952, 'currency': 'USDT'},
#  'fees': [{'currency': 'USDT', 'cost': 0.02442952}]}

# %%
trade.keys()
# Out:
# dict_keys(['info', 'timestamp', 'datetime', 'symbol', 'id', 'order', 'type', 'side', 'takerOrMaker', 'price', 'amount', 'cost', 'fee', 'fees'])

# %%
var_names = ["id",
             "timestamp",
             "datetime"]
hprint.pprint_color(
    subset_dict(trade, var_names, keep_order=False))
# Out:
# {'id': '3932745371',
#  'timestamp': 1689243340610,
#  'datetime': '2023-07-13T10:15:40.610Z'}

# %%
var_names = ["symbol",
             "order",
             "type",
             "side",
             "takerOrMaker",
             # Price in quote currency.
             "price",
             # Amount of base currency.
             "amount",
             # Total cost, i.e., price * amount.
             "cost",
             # Fees.
             "fee",
             "fees"]
hprint.pprint_color(
    subset_dict(trade, var_names, keep_order=False))
# Out:
# {'symbol': 'BTC/USDT',
#  'order': '170669758249',
#  'type': None,
#  'side': 'buy',
#  'takerOrMaker': 'maker',
#  'price': 30536.9,
#  'amount': 0.004,
#  'cost': 122.1476,
#  'fee': {'cost': 0.02442952, 'currency': 'USDT'},
#  'fees': [{'currency': 'USDT', 'cost': 0.02442952}]}

# %%
# Original decoded JSON from the exchange.
var_names = ["info"]
hprint.pprint_color(
    subset_dict(trade, var_names, keep_order=False))
# Out:
# {'info': {'symbol': 'BTCUSDT',
#           'id': '3932745371',
#           'orderId': '170669758249',
#           'side': 'BUY',
#           'price': '30536.90',
#           'qty': '0.004',
#           'realizedPnl': '0',
#           'marginAsset': 'USDT',
#           'quoteQty': '122.14760',
#           'commission': '0.02442952',
#           'commissionAsset': 'USDT',
#           'time': '1689243340610',
#           'positionSide': 'BOTH',
#           'buyer': True,
#           'maker': True}}

# %% [markdown]
# ### Trades by Order id

# %%
# Not supported by Binance.
# order_id = "170643031299"
# trades = exchange.fetch_order_trades(order_id, symbol, limit=2)

# %% [markdown]
# ## Ledger
#
# - = history of changes / actions done by the user affecting the balance
#
# - funding (deposits / withdrawals)
# - profits / losses from trades
# - trading fees
# - rebates, etc.

# %%
# Not supported by Binance.
# exchange.fetchLedger()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [153], line 1
# ----> 1 exchange.fetchLedger()
#
# AttributeError: 'binance' object has no attribute 'fetchLedger'

# %% [markdown]
# ### Ledger entry structure
#
# https://docs.ccxt.com/#/README?id=ledger-entry-structure

# %% [markdown]
# ## Deposit
#
# https://docs.ccxt.com/#/README?id=deposit

# %%
exchange.fetchDeposits()
# Out:
# [{'info': {'id': '3444986436108417024',
#    'amount': '1000',
#    'coin': 'USDT',
#    'network': 'ETH',
#    'status': '1',
#    'address': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#    'addressTag': '',
#    'txId': '0x4886c564a18afe1f91c00f3c5085f3de0c6a9cbdabbb5138cbea32b892813cae',
#    'insertTime': '1683295593000',
#    'transferType': '0',
#    'confirmTimes': '64/6',
#    'unlockConfirm': '64',
#    'walletType': '0'},
#   'id': '3444986436108417024',
#   'txid': '0x4886c564a18afe1f91c00f3c5085f3de0c6a9cbdabbb5138cbea32b892813cae',
#   'timestamp': 1683295593000,
#   'datetime': '2023-05-05T14:06:33.000Z',
#   'network': 'ETH',
#   'address': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#   'addressTo': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#   'addressFrom': None,
#   'tag': None,
#   'tagTo': None,
#   'tagFrom': None,
#   'type': 'deposit',
#   'amount': 1000.0,
#   'currency': 'USDT',
#   'status': 'ok',
#   'updated': None,
#   'internal': False,
#   'fee': None},
#  {'info': {'id': '3532118562884369152',
#    'amount': '500',
#    'coin': 'USDT',
#    'network': 'ETH',
#    'status': '1',
#    'address': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#    'addressTag': '',
#    'txId': '0xdd5f0b84d089201dfbd4bbcffb9b2d36a7efb415f09265788b41025759892b4c',
#    'insertTime': '1688489072000',
#    'transferType': '0',
#    'confirmTimes': '64/6',
#    'unlockConfirm': '64',
#    'walletType': '0'},
#   'id': '3532118562884369152',
#   'txid': '0xdd5f0b84d089201dfbd4bbcffb9b2d36a7efb415f09265788b41025759892b4c',
#   'timestamp': 1688489072000,
#   'datetime': '2023-07-04T16:44:32.000Z',
#   'network': 'ETH',
#   'address': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#   'addressTo': '0x2a17ad951e8d85a24c8330d5db8377daf42e03e3',
#   'addressFrom': None,
#   'tag': None,
#   'tagTo': None,
#   'tagFrom': None,
#   'type': 'deposit',
#   'amount': 500.0,
#   'currency': 'USDT',
#   'status': 'ok',
#   'updated': None,
#   'internal': False,
#   'fee': None}]

# %% [markdown]
# ### Withdraw
#
# ### Transactions
#
# * Trading fees
# - = amount paid to the exchange
# - Typically it is a percentage of volume traded
#
# * Funding fees
# - Fees for depositing and withdrawing
# - Crypto transaction fees

# %%
balance = exchange.fetchBalance()

balance

# %%
balance.keys()

# %% [markdown]
# # CCXT Pro
#
# // https://ccxt.readthedocs.io/en/latest/ccxt.pro.manual.html
#
# - Standard CCXT uses request-response based APIs (e.g., REST)
# - CCXT Pro uses connection-based streaming API (e.g., WebSocket)
#
# - `fetch*` methods are replaced with `watch*` methods
#
# - CCXT Pro manages the connection-based interface transparently to the user
#   - On the first call to a `watch*` method a connection is established
#   - If the connection already exists, it is reused
#   - The library watches the status of the connection and keeps it alive
#
# * Sub interface
# - Allows to subscribe to a stream of data and lister for it
#   - E.g., streaming public market data (e.g., order book, bars)
#
# * Pub interface
# - Allows to send data requests towards the server
#   - E.g., placing / cancelling orders
#
# * Incremental data structures
# - In many cases, the application listening needs to
#   - keep a local snapshot of the data in memory
#   - merge the updates received from the exchange server (aka "deltas")
#
# - CCXT Pro automatically handles this
