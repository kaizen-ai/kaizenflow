# %% [markdown]
# # Imports

# %%
import logging
import os

import pandas as pd

import core.config.config_ as cconconf
import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint
import helpers.hs3 as hs3
import im_v2.ccxt.data.client as icdcl
import im_v2.common.universe as ivcu
import research_amp.cc.statistics as ramccsta
import research_amp.cc.volume as ramccvol

# %%
hdbg.init_logger(verbosity=logging.INFO)

_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])

hprint.config_notebook()

AM_AWS_PROFILE = "am"
# Out:
# INFO: > cmd='/venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-46fcffda-364f-4de0-b0e1-abe69933f58a.json'
# WARNING: Running in Jupyter
# >>ENV<<: is_inside_container=True: code_version=1.0.6, container_version=1.0.6, is_inside_docker=True, is_inside_ci=False, CI_defined=True, CI=''
# >>ENV<<: AM_AWS_PROFILE=True AM_ECR_BASE_PATH=True AM_S3_BUCKET=True AM_TELEGRAM_TOKEN=True AWS_ACCESS_KEY_ID=False AWS_DEFAULT_REGION=False AWS_SECRET_ACCESS_KEY=False GH_ACTION_ACCESS_TOKEN=True
# # Git
#     branch_name='CMTask922_refactor_ccxt_clients'
#     hash='87aafc12f'
#     # Last commits:
#       *   87aafc12f Grisha   Merge branch 'master' into CMTask922_refactor_ccxt_clients        ( 7 minutes ago) Fri Jan 14 12:43:55 2022  (HEAD -> CMTask922_refactor_ccxt_clients, origin/CMTask922_refactor_ccxt_clients)
#       |\
#       | * a560380c1 DanilYachmenev CmTask949: remove data_type from CCXT clients (#958)              (17 minutes ago) Fri Jan 14 12:33:39 2022  (origin/master, origin/HEAD)
#       | * 8762a0b2b jsmerix  Cm task846 implement centralized storage of api keys (#959)       (   2 hours ago) Fri Jan 14 11:11:03 2022
# # Machine info
#     system=Linux
#     node name=808a13a45b67
#     release=5.11.0-1025-aws
#     version=#27~20.04.1-Ubuntu SMP Fri Jan 7 13:09:56 UTC 2022
#     machine=x86_64
#     processor=x86_64
#     cpu count=4
#     cpu freq=scpufreq(current=2499.998, min=0.0, max=0.0)
#     memory=svmem(total=16586833920, available=1403293696, percent=91.5, used=14576472064, free=834101248, active=433057792, inactive=14607417344, buffers=71757824, cached=1104502784, shared=251969536, slab=403001344)
#     disk usage=sdiskusage(total=104021790720, used=69465255936, free=34539757568, percent=66.8)
# # Packages
#     python: 3.8.10
#     gluonnlp: ?
#     gluonts: 0.6.7
#     joblib: 1.1.0
#     mxnet: 1.9.0
#     numpy: 1.22.0
#     pandas: 1.3.5
#     pyarrow: 6.0.1
#     scipy: 1.6.1
#     seaborn: 0.11.2
#     sklearn: 1.0.2
#     statsmodels: 0.13.1
# WARNING: Disabling annoying warnings

# %% [markdown]
# # Config

# %%
def get_cmtask260_config() -> cconconf.Config:
    """
    Get task260-specific config.
    """
    config = cconconf.Config()
    # Load parameters.
    config.add_subconfig("load")
    config["load"]["aws_profile"] = AM_AWS_PROFILE
    config["load"]["data_dir"] = os.path.join(
        hs3.get_s3_bucket_path(AM_AWS_PROFILE), "data"
    )
    # Data parameters.
    config.add_subconfig("data")
    config["data"]["universe_version"] = "v03"
    config["data"]["vendor"] = "CCXT"
    # Column names.
    config.add_subconfig("column_names")
    config["column_names"]["volume"] = "volume"
    config["column_names"]["currency_pair"] = "currency_pair"
    config["column_names"]["exchange"] = "exchange_id"
    config["column_names"]["close"] = "close"
    return config


config = get_cmtask260_config()
print(config)
# Out:
# load:
#   aws_profile: am
#   data_dir: s3://alphamatic-data/data
# data:
#   universe_version: v03
#   vendor: CCXT
# column_names:
#   volume: volume
#   currency_pair: currency_pair
#   exchange: exchange_id
#   close: close

# %% [markdown]
# # Load the data

# %%
vendor_universe = ivcu.get_vendor_universe(
    config["data"]["vendor"],
    version=config["data"]["universe_version"],
    as_full_symbol=True,
)
vendor_universe
# Out:
# ['binance::ADA_USDT',
#  'binance::AVAX_USDT',
#  'binance::BNB_USDT',
#  'binance::BTC_USDT',
#  'binance::DOGE_USDT',
#  'binance::EOS_USDT',
#  'binance::ETH_USDT',
#  'binance::LINK_USDT',
#  'binance::SOL_USDT',
#  'ftx::BNB_USDT',
#  'ftx::BTC_USDT',
#  'ftx::DOGE_USDT',
#  'ftx::ETH_USDT',
#  'ftx::LINK_USDT',
#  'ftx::SOL_USDT',
#  'ftx::XRP_USDT',
#  'gateio::ADA_USDT',
#  'gateio::AVAX_USDT',
#  'gateio::BNB_USDT',
#  'gateio::BTC_USDT',
#  'gateio::DOGE_USDT',
#  'gateio::EOS_USDT',
#  'gateio::ETH_USDT',
#  'gateio::FIL_USDT',
#  'gateio::LINK_USDT',
#  'gateio::SOL_USDT',
#  'gateio::XRP_USDT',
#  'kucoin::ADA_USDT',
#  'kucoin::AVAX_USDT',
#  'kucoin::BNB_USDT',
#  'kucoin::BTC_USDT',
#  'kucoin::DOGE_USDT',
#  'kucoin::EOS_USDT',
#  'kucoin::ETH_USDT',
#  'kucoin::FIL_USDT',
#  'kucoin::LINK_USDT',
#  'kucoin::SOL_USDT',
#  'kucoin::XRP_USDT']

# %%
compute_daily_cumul_volume_ = lambda data: ramccvol.get_daily_cumul_volume(
    data, config, is_notional_volume=False
)

cumul_daily_volume = ramccsta.compute_stats_for_universe(
    vendor_universe, config, compute_daily_cumul_volume_
)
# Out:
# Reading CCXT data for exchange id='binance', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ADA_USDT.csv.gz'...
# Removed 48775 / 1617480 = 3.02% rows
# Index length increased by 53295 = 1622000 - 1568705
# Reading CCXT data for exchange id='binance', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/AVAX_USDT.csv.gz'...
# Removed 26890 / 516274 = 5.21% rows
# Index length increased by 28114 = 517498 - 489384
# Reading CCXT data for exchange id='binance', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BNB_USDT.csv.gz'...
# Removed 1253 / 1617775 = 0.08% rows
# Index length increased by 5773 = 1622295 - 1616522
# Reading CCXT data for exchange id='binance', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BTC_USDT.csv.gz'...
# Removed 210 / 1615122 = 0.01% rows
# Index length increased by 4729 = 1619641 - 1614912
# Reading CCXT data for exchange id='binance', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/DOGE_USDT.csv.gz'...
# Removed 338669 / 1154731 = 29.33% rows
# Index length increased by 341538 = 1157600 - 816062
# Reading CCXT data for exchange id='binance', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/EOS_USDT.csv.gz'...
# Removed 6067 / 1617924 = 0.37% rows
# Index length increased by 10587 = 1622444 - 1611857
# Reading CCXT data for exchange id='binance', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ETH_USDT.csv.gz'...
# Removed 215 / 1615369 = 0.01% rows
# Index length increased by 4735 = 1619889 - 1615154
# Reading CCXT data for exchange id='binance', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/LINK_USDT.csv.gz'...
# Removed 108869 / 1398630 = 7.78% rows
# Index length increased by 112759 = 1402520 - 1289761
# Reading CCXT data for exchange id='binance', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/SOL_USDT.csv.gz'...
# Removed 12528 / 574916 = 2.18% rows
# Index length increased by 13752 = 576140 - 562388
# Reading CCXT data for exchange id='ftx', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BNB_USDT.csv.gz'...
# Removed 40514 / 763283 = 5.31% rows
# Index length increased by 40690 = 763459 - 722769
# Reading CCXT data for exchange id='ftx', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BTC_USDT.csv.gz'...
# Removed 10692 / 780707 = 1.37% rows
# Index length increased by 10859 = 780874 - 770015
# Reading CCXT data for exchange id='ftx', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/DOGE_USDT.csv.gz'...
# Removed 48702 / 362591 = 13.43% rows
# Index length increased by 48737 = 362626 - 313889
# Reading CCXT data for exchange id='ftx', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/ETH_USDT.csv.gz'...
# Removed 3902 / 780749 = 0.50% rows
# Index length increased by 4068 = 780915 - 776847
# Reading CCXT data for exchange id='ftx', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/LINK_USDT.csv.gz'...
# Removed 31879 / 747070 = 4.27% rows
# Index length increased by 32048 = 747239 - 715191
# Reading CCXT data for exchange id='ftx', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/SOL_USDT.csv.gz'...
# Removed 221171 / 607430 = 36.41% rows
# Index length increased by 221322 = 607581 - 386259
# Reading CCXT data for exchange id='ftx', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/XRP_USDT.csv.gz'...
# Removed 83486 / 618181 = 13.51% rows
# Index length increased by 83642 = 618337 - 534695
# Reading CCXT data for exchange id='gateio', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ADA_USDT.csv.gz'...
# Removed 75 / 129365 = 0.06% rows
# Index length increased by 75 = 129365 - 129290
# Reading CCXT data for exchange id='gateio', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/AVAX_USDT.csv.gz'...
# Removed 11938 / 129134 = 9.24% rows
# Index length increased by 11938 = 129134 - 117196
# Reading CCXT data for exchange id='gateio', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BNB_USDT.csv.gz'...
# Index length=129250 has not changed
# Reading CCXT data for exchange id='gateio', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BTC_USDT.csv.gz'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/DOGE_USDT.csv.gz'...
# Removed 4 / 129422 = 0.00% rows
# Index length increased by 4 = 129422 - 129418
# Reading CCXT data for exchange id='gateio', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/EOS_USDT.csv.gz'...
# Removed 2915 / 129192 = 2.26% rows
# Index length increased by 2915 = 129192 - 126277
# Reading CCXT data for exchange id='gateio', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ETH_USDT.csv.gz'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='FIL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/FIL_USDT.csv.gz'...
# Removed 2454 / 129480 = 1.90% rows
# Index length increased by 2454 = 129480 - 127026
# Reading CCXT data for exchange id='gateio', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/LINK_USDT.csv.gz'...
# Removed 292 / 129307 = 0.23% rows
# Index length increased by 292 = 129307 - 129015
# Reading CCXT data for exchange id='gateio', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/SOL_USDT.csv.gz'...
# Removed 9616 / 129595 = 7.42% rows
# Index length increased by 9616 = 129595 - 119979
# Reading CCXT data for exchange id='gateio', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/XRP_USDT.csv.gz'...
# Removed 4 / 129537 = 0.00% rows
# Index length increased by 4 = 129537 - 129533
# Reading CCXT data for exchange id='kucoin', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ADA_USDT.csv.gz'...
# Removed 392028 / 1158284 = 33.85% rows
# Index length increased by 392028 = 1158284 - 766256
# Reading CCXT data for exchange id='kucoin', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/AVAX_USDT.csv.gz'...
# Removed 62942 / 280129 = 22.47% rows
# Index length increased by 62942 = 280129 - 217187
# Reading CCXT data for exchange id='kucoin', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BNB_USDT.csv.gz'...
# Removed 616896 / 1180057 = 52.28% rows
# Index length increased by 616896 = 1180057 - 563161
# Reading CCXT data for exchange id='kucoin', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BTC_USDT.csv.gz'...
# Removed 20711 / 1525290 = 1.36% rows
# Index length increased by 115207 = 1619786 - 1504579
# Reading CCXT data for exchange id='kucoin', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/DOGE_USDT.csv.gz'...
# Removed 10909 / 314817 = 3.47% rows
# Index length increased by 10909 = 314817 - 303908
# Reading CCXT data for exchange id='kucoin', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/EOS_USDT.csv.gz'...
# Removed 204913 / 1389141 = 14.75% rows
# Index length increased by 437203 = 1621431 - 1184228
# Reading CCXT data for exchange id='kucoin', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ETH_USDT.csv.gz'...
# Removed 39881 / 1502412 = 2.65% rows
# Index length increased by 157429 = 1619960 - 1462531
# Reading CCXT data for exchange id='kucoin', currencies='FIL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/FIL_USDT.csv.gz'...
# Removed 130589 / 482205 = 27.08% rows
# Index length increased by 130589 = 482205 - 351616
# Reading CCXT data for exchange id='kucoin', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/LINK_USDT.csv.gz'...
# Removed 83924 / 563664 = 14.89% rows
# Index length increased by 83924 = 563664 - 479740
# Reading CCXT data for exchange id='kucoin', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/SOL_USDT.csv.gz'...
# Removed 2729 / 60509 = 4.51% rows
# Index length increased by 2729 = 60509 - 57780
# Reading CCXT data for exchange id='kucoin', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/XRP_USDT.csv.gz'...
# Removed 196131 / 1357381 = 14.45% rows
# Index length increased by 303138 = 1464388 - 1161250

# %%
_LOG.info(
    "The number of (exchanges, currency pairs) =%s", cumul_daily_volume.shape[0]
)
cumul_daily_volume.head(3)
# Out:
# The number of (exchanges, currency pairs) =19619
#   exchange_id currency_pair        date       volume vendor   weekday
# 0     binance      ADA_USDT  2018-08-17  234081259.8   CCXT    Friday
# 1     binance      ADA_USDT  2018-08-18  213897957.5   CCXT  Saturday
# 2     binance      ADA_USDT  2018-08-19  123775994.1   CCXT    Sunday

# %% [markdown]
# # Compute total volume per exchange

# %%
total_volume_by_exchange = ramccvol.get_total_exchange_volume(
    cumul_daily_volume, config, avg_daily=False
)
print(total_volume_by_exchange)
# Out:
# exchange_id
# binance    2.386682e+12
# kucoin     8.298181e+10
# ftx        4.859562e+10
# gateio     1.790392e+10
# Name: volume, dtype: float64

# %% [markdown]
# # Compute total volume per currency

# %%
total_volume_by_coins = ramccvol.get_total_coin_volume(
    cumul_daily_volume, config, avg_daily=False
)
print(total_volume_by_coins)
# Out:
# currency_pair
# DOGE_USDT    2.028113e+12
# ADA_USDT     3.799003e+11
# XRP_USDT     3.373964e+10
# BTC_USDT     2.721635e+10
# EOS_USDT     2.108020e+10
# ETH_USDT     1.987232e+10
# LINK_USDT    1.032276e+10
# BNB_USDT     7.497324e+09
# SOL_USDT     5.676692e+09
# AVAX_USDT    1.719184e+09
# FIL_USDT     1.025431e+09
# Name: volume, dtype: float64

# %% [markdown]
# # Rolling Plots

# %% [markdown]
# ## By exchange

# %%
rolling_volume_per_exchange = ramccvol.get_rolling_volume_per_exchange(
    cumul_daily_volume, config, window=90
)
print(rolling_volume_per_exchange)
# Out:
#      exchange_id        date        volume  rolling_volume
# 0        binance  2018-08-17  2.521288e+08             NaN
# 1        binance  2018-08-18  2.246712e+08             NaN
# 2        binance  2018-08-19  1.291545e+08             NaN
# 3        binance  2018-08-20  1.486169e+08             NaN
# 4        binance  2018-08-21  1.446853e+08             NaN
# ...          ...         ...           ...             ...
# 2884      kucoin  2021-09-12  1.775510e+08    2.216194e+08
# 2885      kucoin  2021-09-13  2.185123e+08    2.228929e+08
# 2886      kucoin  2021-09-14  1.307721e+08    2.229035e+08
# 2887      kucoin  2021-09-15  9.324934e+07    2.231061e+08
# 2888      kucoin  2021-09-16  7.628892e+02    2.218036e+08
#
# [2889 rows x 4 columns]

# %% [markdown]
# ## By coins

# %%
rolling_volume_per_coin = ramccvol.get_rolling_volume_per_coin(
    cumul_daily_volume, config, window=90
)
print(rolling_volume_per_coin)
# Out:
#      currency_pair        date        volume  rolling_volume
# 0         ADA_USDT  2018-08-17  2.340813e+08             NaN
# 1         ADA_USDT  2018-08-18  2.138980e+08             NaN
# 2         ADA_USDT  2018-08-19  1.237760e+08             NaN
# 3         ADA_USDT  2018-08-20  1.352677e+08             NaN
# 4         ADA_USDT  2018-08-21  1.323278e+08             NaN
# ...            ...         ...           ...             ...
# 9596      XRP_USDT  2021-09-17  2.291351e+07    9.365293e+07
# 9597      XRP_USDT  2021-09-18  1.327311e+07    9.321155e+07
# 9598      XRP_USDT  2021-09-19  1.421631e+07    9.210419e+07
# 9599      XRP_USDT  2021-09-20  4.984011e+07    9.102911e+07
# 9600      XRP_USDT  2021-09-21  1.155732e+07    8.979937e+07
#
# [9601 rows x 4 columns]

# %% [markdown]
# # Compare weekday volumes

# %%
total_volume_by_weekdays = ramccvol.compare_weekday_volumes(
    cumul_daily_volume, config
)
print(total_volume_by_weekdays)
# Out:
# weekday
# Thursday     4.302185e+11
# Friday       4.187045e+11
# Sunday       3.646112e+11
# Saturday     3.525566e+11
# Wednesday    3.441182e+11
# Monday       3.256644e+11
# Tuesday      3.002901e+11
# Name: volume, dtype: float64

# %% [markdown]
# # Compare ATH volumes

# %% [markdown]
# ## Functions

# %%
def get_initial_df_with_volumes(coins, exchange, is_notional_volume):
    """
    Return DataFrame with the volume of all coins for exchange with initial timestamps
    Parameters: list of coins, exchange name
    """
    result = []
    vendor = config["data"]["vendor"]
    universe_version = "v3"
    resample_1min = True
    root_dir = config["load"]["data_dir"]
    extension = "csv.gz"
    ccxt_csv_client = icdcl.CcxtCddCsvParquetByAssetClient(
        vendor,
        universe_version,
        resample_1min,
        root_dir,
        extension,
        aws_profile=config["load"]["aws_profile"],
    )
    for coin in coins:
        # TODO(Grisha): use `FullSymbols` #587.
        full_symbol = f"{exchange}::{coin}"
        start_ts = None
        end_ts = None
        df = ccxt_csv_client.read_data(
            [full_symbol],
            start_ts,
            end_ts,
        )
        if is_notional_volume:
            df["volume"] = df["volume"] * df["close"]
        result.append(df["volume"])
    final_result = pd.concat(result, axis=1)
    return final_result


def plot_ath_volumes_comparison(df_list):
    """
    Return the graph with the comparison of average minute total trading volume
    in ATH vs.

    non-ATH
    Parameters: dataframe with volumes from a given exchange
    """
    plot_df = []
    for df in df_list:
        df_ath = df.iloc[df.index.indexer_between_time("09:30", "16:00")]
        df_not_ath = df.loc[~df.index.isin(df_ath.index)]
        ath_stat = pd.DataFrame()
        ath_stat.loc[df.name, f"minute_avg_total_volume_ath_{df.name}"] = (
            df_ath.sum().sum() / df_ath.shape[0]
        )
        ath_stat.loc[df.name, f"minute_avg_total_volume_not_ath_{df.name}"] = (
            df_not_ath.sum().sum() / df_not_ath.shape[0]
        )
        plot_df.append(ath_stat)
    plot_df = pd.concat(plot_df)
    plot_df.plot.bar(figsize=(15, 7), logy=True)

# %% [markdown]
# ## Load the data

# %%
# get the list of all coin paires for each exchange
binance_coins = ivcu.get_vendor_universe("CCXT", version="v3")["binance"]
ftx_coins = ivcu.get_vendor_universe("CCXT", version="v3")["ftx"]
gateio_coins = ivcu.get_vendor_universe("CCXT", version="v3")["gateio"]
kucoin_coins = ivcu.get_vendor_universe("CCXT", version="v3")["kucoin"]

# load all the dataframes
binance_1 = get_initial_df_with_volumes(
    binance_coins, "binance", is_notional_volume=True
)
ftx_1 = get_initial_df_with_volumes(ftx_coins, "ftx", is_notional_volume=True)
gateio_1 = get_initial_df_with_volumes(
    gateio_coins, "gateio", is_notional_volume=True
)
kucoin_1 = get_initial_df_with_volumes(
    kucoin_coins, "kucoin", is_notional_volume=True
)

# supportive variables
exchange_list = [binance_1, ftx_1, gateio_1, kucoin_1]
binance_1.name = "binance"
ftx_1.name = "ftx"
gateio_1.name = "gateio"
kucoin_1.name = "kucoin"
# Out:
# Reading CCXT data for exchange id='binance', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ADA_USDT.csv.gz'...
# Removed 48775 / 1617480 = 3.02% rows
# Index length increased by 53295 = 1622000 - 1568705
# Reading CCXT data for exchange id='binance', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/AVAX_USDT.csv.gz'...
# Removed 26890 / 516274 = 5.21% rows
# Index length increased by 28114 = 517498 - 489384
# Reading CCXT data for exchange id='binance', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BNB_USDT.csv.gz'...
# Removed 1253 / 1617775 = 0.08% rows
# Index length increased by 5773 = 1622295 - 1616522
# Reading CCXT data for exchange id='binance', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BTC_USDT.csv.gz'...
# Removed 210 / 1615122 = 0.01% rows
# Index length increased by 4729 = 1619641 - 1614912
# Reading CCXT data for exchange id='binance', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/DOGE_USDT.csv.gz'...
# Removed 338669 / 1154731 = 29.33% rows
# Index length increased by 341538 = 1157600 - 816062
# Reading CCXT data for exchange id='binance', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/EOS_USDT.csv.gz'...
# Removed 6067 / 1617924 = 0.37% rows
# Index length increased by 10587 = 1622444 - 1611857
# Reading CCXT data for exchange id='binance', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ETH_USDT.csv.gz'...
# Removed 215 / 1615369 = 0.01% rows
# Index length increased by 4735 = 1619889 - 1615154
# Reading CCXT data for exchange id='binance', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/LINK_USDT.csv.gz'...
# Removed 108869 / 1398630 = 7.78% rows
# Index length increased by 112759 = 1402520 - 1289761
# Reading CCXT data for exchange id='binance', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/SOL_USDT.csv.gz'...
# Removed 12528 / 574916 = 2.18% rows
# Index length increased by 13752 = 576140 - 562388
# Reading CCXT data for exchange id='ftx', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BNB_USDT.csv.gz'...
# Removed 40514 / 763283 = 5.31% rows
# Index length increased by 40690 = 763459 - 722769
# Reading CCXT data for exchange id='ftx', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BTC_USDT.csv.gz'...
# Removed 10692 / 780707 = 1.37% rows
# Index length increased by 10859 = 780874 - 770015
# Reading CCXT data for exchange id='ftx', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/DOGE_USDT.csv.gz'...
# Removed 48702 / 362591 = 13.43% rows
# Index length increased by 48737 = 362626 - 313889
# Reading CCXT data for exchange id='ftx', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/ETH_USDT.csv.gz'...
# Removed 3902 / 780749 = 0.50% rows
# Index length increased by 4068 = 780915 - 776847
# Reading CCXT data for exchange id='ftx', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/LINK_USDT.csv.gz'...
# Removed 31879 / 747070 = 4.27% rows
# Index length increased by 32048 = 747239 - 715191
# Reading CCXT data for exchange id='ftx', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/SOL_USDT.csv.gz'...
# Removed 221171 / 607430 = 36.41% rows
# Index length increased by 221322 = 607581 - 386259
# Reading CCXT data for exchange id='ftx', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/XRP_USDT.csv.gz'...
# Removed 83486 / 618181 = 13.51% rows
# Index length increased by 83642 = 618337 - 534695
# Reading CCXT data for exchange id='gateio', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ADA_USDT.csv.gz'...
# Removed 75 / 129365 = 0.06% rows
# Index length increased by 75 = 129365 - 129290
# Reading CCXT data for exchange id='gateio', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/AVAX_USDT.csv.gz'...
# Removed 11938 / 129134 = 9.24% rows
# Index length increased by 11938 = 129134 - 117196
# Reading CCXT data for exchange id='gateio', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BNB_USDT.csv.gz'...
# Index length=129250 has not changed
# Reading CCXT data for exchange id='gateio', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BTC_USDT.csv.gz'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/DOGE_USDT.csv.gz'...
# Removed 4 / 129422 = 0.00% rows
# Index length increased by 4 = 129422 - 129418
# Reading CCXT data for exchange id='gateio', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/EOS_USDT.csv.gz'...
# Removed 2915 / 129192 = 2.26% rows
# Index length increased by 2915 = 129192 - 126277
# Reading CCXT data for exchange id='gateio', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ETH_USDT.csv.gz'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='FIL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/FIL_USDT.csv.gz'...
# Removed 2454 / 129480 = 1.90% rows
# Index length increased by 2454 = 129480 - 127026
# Reading CCXT data for exchange id='gateio', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/LINK_USDT.csv.gz'...
# Removed 292 / 129307 = 0.23% rows
# Index length increased by 292 = 129307 - 129015
# Reading CCXT data for exchange id='gateio', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/SOL_USDT.csv.gz'...
# Removed 9616 / 129595 = 7.42% rows
# Index length increased by 9616 = 129595 - 119979
# Reading CCXT data for exchange id='gateio', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/XRP_USDT.csv.gz'...
# Removed 4 / 129537 = 0.00% rows
# Index length increased by 4 = 129537 - 129533
# Reading CCXT data for exchange id='kucoin', currencies='ADA_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ADA_USDT.csv.gz'...
# Removed 392028 / 1158284 = 33.85% rows
# Index length increased by 392028 = 1158284 - 766256
# Reading CCXT data for exchange id='kucoin', currencies='AVAX_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/AVAX_USDT.csv.gz'...
# Removed 62942 / 280129 = 22.47% rows
# Index length increased by 62942 = 280129 - 217187
# Reading CCXT data for exchange id='kucoin', currencies='BNB_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BNB_USDT.csv.gz'...
# Removed 616896 / 1180057 = 52.28% rows
# Index length increased by 616896 = 1180057 - 563161
# Reading CCXT data for exchange id='kucoin', currencies='BTC_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BTC_USDT.csv.gz'...
# Removed 20711 / 1525290 = 1.36% rows
# Index length increased by 115207 = 1619786 - 1504579
# Reading CCXT data for exchange id='kucoin', currencies='DOGE_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/DOGE_USDT.csv.gz'...
# Removed 10909 / 314817 = 3.47% rows
# Index length increased by 10909 = 314817 - 303908
# Reading CCXT data for exchange id='kucoin', currencies='EOS_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/EOS_USDT.csv.gz'...
# Removed 204913 / 1389141 = 14.75% rows
# Index length increased by 437203 = 1621431 - 1184228
# Reading CCXT data for exchange id='kucoin', currencies='ETH_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ETH_USDT.csv.gz'...
# Removed 39881 / 1502412 = 2.65% rows
# Index length increased by 157429 = 1619960 - 1462531
# Reading CCXT data for exchange id='kucoin', currencies='FIL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/FIL_USDT.csv.gz'...
# Removed 130589 / 482205 = 27.08% rows
# Index length increased by 130589 = 482205 - 351616
# Reading CCXT data for exchange id='kucoin', currencies='LINK_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/LINK_USDT.csv.gz'...
# Removed 83924 / 563664 = 14.89% rows
# Index length increased by 83924 = 563664 - 479740
# Reading CCXT data for exchange id='kucoin', currencies='SOL_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/SOL_USDT.csv.gz'...
# Removed 2729 / 60509 = 4.51% rows
# Index length increased by 2729 = 60509 - 57780
# Reading CCXT data for exchange id='kucoin', currencies='XRP_USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/XRP_USDT.csv.gz'...
# Removed 196131 / 1357381 = 14.45% rows
# Index length increased by 303138 = 1464388 - 1161250

# %% [markdown]
# ## Plot

# %%
plot_ath_volumes_comparison(exchange_list)
