# %%
from py2neo import Graph, Node, Relationship
import pandas as pd

# %%
# %cd /home/jovyan/work

# Connect to the Neo4j database.
graph = Graph("bolt://neo4j:7687", auth=("neo4j", "password"))
# Out:
# /home/jovyan/work

# %% [markdown]
# ## Cypher Queries
#
# ### Query 1
# Considering the users as Influencial users if they have more than 10000 follower count

# %%
# Query 1: Find influential users based on the number of followers.
query1 = """
MATCH (u:User)
WHERE u.followersCount > 10000
RETURN u.id AS user_id, u.screenName AS user_name, u.followersCount AS followers_count
ORDER BY u.followersCount DESC
"""

result3 = graph.run(query1).data()
print("\nInfluential Users:")
for record in result3:
    print(record)
# Out:
# Influential Users:
# {'user_id': 94038, 'user_name': '"""JennyJohnsonHi5"""', 'followers_count': 412132}
# {'user_id': 40978, 'user_name': '"""LVCVA"""', 'followers_count': 41307}
# {'user_id': 66485, 'user_name': '"""VxArc"""', 'followers_count': 36906}
# {'user_id': 78664, 'user_name': '"""monstershockey"""', 'followers_count': 30442}
# {'user_id': 20241, 'user_name': '"""ImChrisRich"""', 'followers_count': 26172}
# {'user_id': 77221, 'user_name': '"""Intermountain"""', 'followers_count': 20584}
# {'user_id': 47424, 'user_name': '"""LuckoftheDraw86"""', 'followers_count': 20038}
# {'user_id': 58778, 'user_name': '"""shinyyylove"""', 'followers_count': 19646}
# {'user_id': 11005, 'user_name': '"""AlfredAngelo"""', 'followers_count': 18602}
# {'user_id': 87755, 'user_name': '"""NicoleTaffer"""', 'followers_count': 18599}
# {'user_id': 83498, 'user_name': '"""julieroginsky"""', 'followers_count': 16828}
# {'user_id': 12275, 'user_name': '"""craicful"""', 'followers_count': 16113}
# {'user_id': 43214, 'user_name': '"""iteenagestyles"""', 'followers_count': 13170}
# {'user_id': 67113, 'user_name': '"""AMILLION4JESUS"""', 'followers_count': 10999}

# %% [markdown]
# ### Query 2
# Considering popular tags based on the number of times the tag has been mentioned

# %%
# Query 2: Find popular tags and their usage count.
query2 = """
MATCH (t:Tag)<-[:HAS_TAG]-(:User)
RETURN t.name AS tag_name, COUNT(*) AS usage_count
ORDER BY usage_count DESC
LIMIT 10
"""

result4 = graph.run(query2).data()
print("\nPopular Tags:")
for record in result4:
    print(record)
# Out:
# Popular Tags:
# {'tag_name': '[ ""#nationaldogday"" ]', 'usage_count': 221}
# {'tag_name': '[ ""#respecttylerjoseph"" ]', 'usage_count': 38}
# {'tag_name': '[ ""#respecttylerjoseph', 'usage_count': 3}
# {'tag_name': '[ ""#happybirthdaydylanobrien"" ]', 'usage_count': 3}
# {'tag_name': '[ ""bournemouth"" ]', 'usage_count': 2}
# {'tag_name': '[ ""#bundesliga"" ]', 'usage_count': 2}
# {'tag_name': '[ ""#belgiangp"" ]', 'usage_count': 2}
# {'tag_name': '[ ""#isac2016"" ]', 'usage_count': 2}
# {'tag_name': '[ ""harry potter"" ]', 'usage_count': 2}
# {'tag_name': '[ ""#happybirthdayliampayne"" ]', 'usage_count': 2}

# %% [markdown]
# ### Query 3
# Checking for users who have common tags and counts how often these tags occur together.

# %%
# Query 3: Find co-occurrence of tags.
query3 = """
MATCH (u:User)-[:HAS_TAG]->(t1:Tag)<-[:HAS_TAG]-(other_user:User)-[:HAS_TAG]->(t2:Tag)
WHERE id(u) < id(other_user) AND id(t1) < id(t2)
WITH t1, t2, count(*) AS co_occurrences
RETURN t1.name AS tag1, t2.name AS tag2, co_occurrences
ORDER BY co_occurrences DESC
"""

result = graph.run(query3).data()

print("\nTag Co-Occurrences:")
for record in result:
    print("Tag 1:", record['tag1'])
    print("Tag 2:", record['tag2'])
    print("Co-Occurrences:", record['co_occurrences'])
    print()
# Out:
# Tag Co-Occurrences:
# Tag 1: [ ""#respecttylerjoseph
# Tag 2: #confidentfor5sos"" ]
# Co-Occurrences: 2
#
# Tag 1: [ ""#nationaldogday
# Tag 2: #respecttylerjoseph"" ]
# Co-Occurrences: 1
#
# Tag 1: [ ""#respecttylerjoseph
# Tag 2: halsey"" ]
# Co-Occurrences: 1

# %% [markdown]
# ### Query 4
#
# Checking if two users have a common friend between them.

# %%
# Query 4: Find common connections between two users.
query5 = """
MATCH (u1:User)-[:FRIENDS_WITH]->(f:User)<-[:FRIENDS_WITH]-(u2:User)
WHERE id(u1) < id(u2)
WITH u1, u2, f, count(f) AS common_connections
RETURN u1.id AS user1_id, u1.screenName AS user1_screen_name, u2.id AS user2_id, u2.screenName AS user2_screen_name, f.id AS common_friend_id, f.screenName AS common_friend_screen_name, common_connections
"""

result = graph.run(query4).data()

print("\nCommon Connections:")
for record in result:
    print("User 1:", record['user1_id'], "-", record['user1_screen_name'])
    print("User 2:", record['user2_id'], "-", record['user2_screen_name'])
    print("Common Friend:", record['common_friend_id'], "-", record['common_friend_screen_name'])
    print("Number of Common Connections:", record['common_connections'])
    print()
# Out:
# Common Connections:
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 94979 - """WoffordKaleigh"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 83420 - """Fix8Limited"""
# User 2: 37440 - """FilmFiends"""
# Common Friend: 76425 - """SLBistro"""
# Number of Common Connections: 1
#
# User 1: 42136 - """AliAftab_"""
# User 2: 52658 - """YammineTannous"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 71397 - """MargaretGrant22"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 71397 - """MargaretGrant22"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 64488 - """Tarattee"""
# User 2: 51051 - """kenzi_cummings"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 52658 - """YammineTannous"""
# User 2: 10988 - """sirdeeck"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 42136 - """AliAftab_"""
# User 2: 10988 - """sirdeeck"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 83420 - """Fix8Limited"""
# User 2: 11331 - """ItsJeseniaCuhh"""
# Common Friend: 82823 - """camvaleska"""
# Number of Common Connections: 1
#
# User 1: 47424 - """LuckoftheDraw86"""
# User 2: 29374 - """cyndelrmadsen"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 37440 - """FilmFiends"""
# User 2: 89709 - """Paigemorris_57"""
# Common Friend: 89999 - """anabellac34"""
# Number of Common Connections: 1
#
# User 1: 54515 - """dogsandcoffee_"""
# User 2: 89663 - """paige_jordan4"""
# Common Friend: 58446 - """NikkBarajas"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 89663 - """paige_jordan4"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 89663 - """paige_jordan4"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 89663 - """paige_jordan4"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 69897 - """atlantictroye"""
# User 2: 89663 - """paige_jordan4"""
# Common Friend: 29374 - """cyndelrmadsen"""
# Number of Common Connections: 1
#
# User 1: 29374 - """cyndelrmadsen"""
# User 2: 60240 - """JustRoRoBackUp"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 47424 - """LuckoftheDraw86"""
# User 2: 60240 - """JustRoRoBackUp"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 60240 - """JustRoRoBackUp"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 29374 - """cyndelrmadsen"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 47424 - """LuckoftheDraw86"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 33862 - """MannyL47"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 37440 - """FilmFiends"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 76425 - """SLBistro"""
# Number of Common Connections: 1
#
# User 1: 83420 - """Fix8Limited"""
# User 2: 79366 - """turrranichelle"""
# Common Friend: 76425 - """SLBistro"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 93041 - """aloyolma"""
# Common Friend: 10988 - """sirdeeck"""
# Number of Common Connections: 1
#
# User 1: 63336 - """HarleyNMoore"""
# User 2: 78827 - """dankremnitzer"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 62524 - """twiitchhin"""
# User 2: 68647 - """vmormino"""
# Common Friend: 55957 - """MeggMitchelll"""
# Number of Common Connections: 1
#
# User 1: 29577 - """decayisdead"""
# User 2: 90963 - """fabminseok"""
# Common Friend: 94979 - """WoffordKaleigh"""
# Number of Common Connections: 1
#
# User 1: 89709 - """Paigemorris_57"""
# User 2: 88635 - """valbunny008"""
# Common Friend: 89999 - """anabellac34"""
# Number of Common Connections: 1
#
# User 1: 37440 - """FilmFiends"""
# User 2: 88635 - """valbunny008"""
# Common Friend: 89999 - """anabellac34"""
# Number of Common Connections: 1
#
# User 1: 29577 - """decayisdead"""
# User 2: 84423 - """missmarleesa"""
# Common Friend: 90627 - """TomlinsonEli"""
# Number of Common Connections: 1
#
# User 1: 51051 - """kenzi_cummings"""
# User 2: 53165 - """jacklynrw1"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 76435 - """VafFunGhoul_"""
# User 2: 69283 - """barefootNurse24"""
# Common Friend: 78664 - """monstershockey"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 69283 - """barefootNurse24"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 11331 - """ItsJeseniaCuhh"""
# User 2: 69283 - """barefootNurse24"""
# Common Friend: 82823 - """camvaleska"""
# Number of Common Connections: 1
#
# User 1: 83420 - """Fix8Limited"""
# User 2: 69283 - """barefootNurse24"""
# Common Friend: 82823 - """camvaleska"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 33127 - """madeoffwax"""
# Common Friend: 58446 - """NikkBarajas"""
# Number of Common Connections: 1
#
# User 1: 54515 - """dogsandcoffee_"""
# User 2: 33127 - """madeoffwax"""
# Common Friend: 58446 - """NikkBarajas"""
# Number of Common Connections: 1
#
# User 1: 68647 - """vmormino"""
# User 2: 25953 - """JonClempner"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 79366 - """turrranichelle"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 33862 - """MannyL47"""
# User 2: 67355 - """DooubleeOhhGee"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 51051 - """kenzi_cummings"""
# User 2: 72301 - """Laura_Cuentas"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 64488 - """Tarattee"""
# User 2: 72301 - """Laura_Cuentas"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 88635 - """valbunny008"""
# User 2: 82547 - """tommothood"""
# Common Friend: 52658 - """YammineTannous"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 54841 - """jamesdaine_"""
# Common Friend: 25961 - """JeLouis1991"""
# Number of Common Connections: 1
#
# User 1: 53165 - """jacklynrw1"""
# User 2: 54841 - """jamesdaine_"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 51051 - """kenzi_cummings"""
# User 2: 54841 - """jamesdaine_"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 80605 - """s_sasek"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 38132 - """graceefergusonn"""
# Common Friend: 29374 - """cyndelrmadsen"""
# Number of Common Connections: 1
#
# User 1: 69897 - """atlantictroye"""
# User 2: 38132 - """graceefergusonn"""
# Common Friend: 29374 - """cyndelrmadsen"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 36652 - """Supt_Lora"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 36652 - """Supt_Lora"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 19411 - """NyzairRountree"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 19411 - """NyzairRountree"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 11331 - """ItsJeseniaCuhh"""
# User 2: 62296 - """EKSEVENTS"""
# Common Friend: 46510 - """BreadAndRosesCA"""
# Number of Common Connections: 1
#
# User 1: 36652 - """Supt_Lora"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96293 - """jackieannak"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 69283 - """barefootNurse24"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 36652 - """Supt_Lora"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42474 - """daniellebabiex3"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 54841 - """jamesdaine_"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 25961 - """JeLouis1991"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 25961 - """JeLouis1991"""
# Number of Common Connections: 1
#
# User 1: 79366 - """turrranichelle"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 60240 - """JustRoRoBackUp"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 29374 - """cyndelrmadsen"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 47424 - """LuckoftheDraw86"""
# User 2: 87211 - """richmagoo"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 33127 - """madeoffwax"""
# User 2: 98246 - """fugly_breana"""
# Common Friend: 72669 - """rachelhark"""
# Number of Common Connections: 1
#
# User 1: 60709 - """alisha_toogood"""
# User 2: 98246 - """fugly_breana"""
# Common Friend: 68647 - """vmormino"""
# Number of Common Connections: 1
#
# User 1: 54515 - """dogsandcoffee_"""
# User 2: 98246 - """fugly_breana"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 12873 - """batpoet"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 79366 - """turrranichelle"""
# User 2: 12873 - """batpoet"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 33862 - """MannyL47"""
# User 2: 12873 - """batpoet"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 10988 - """sirdeeck"""
# User 2: 12873 - """batpoet"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 52658 - """YammineTannous"""
# User 2: 12873 - """batpoet"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 42136 - """AliAftab_"""
# User 2: 12873 - """batpoet"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 12354 - """TrueTxCutie"""
# User 2: 56195 - """911Advocate"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 82512 - """signsofnate"""
# User 2: 56195 - """911Advocate"""
# Common Friend: 60709 - """alisha_toogood"""
# Number of Common Connections: 1
#
# User 1: 42474 - """daniellebabiex3"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 36652 - """Supt_Lora"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 42582 - """callieviolet29"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 12873 - """batpoet"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 10988 - """sirdeeck"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 52658 - """YammineTannous"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 42136 - """AliAftab_"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 83420 - """Fix8Limited"""
# Number of Common Connections: 1
#
# User 1: 85096 - """ItzellDestiny"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 79366 - """turrranichelle"""
# Number of Common Connections: 1
#
# User 1: 92454 - """lizethgodinez_"""
# User 2: 32006 - """ashreve99"""
# Common Friend: 42136 - """AliAftab_"""
# Number of Common Connections: 1
#
# User 1: 32006 - """ashreve99"""
# User 2: 10365 - """SubySalt"""
# Common Friend: 42582 - """callieviolet29"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 42474 - """daniellebabiex3"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 36652 - """Supt_Lora"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 60709 - """alisha_toogood"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 55957 - """MeggMitchelll"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 76070 - """suggscure"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 76119 - """geekalabama"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 42474 - """daniellebabiex3"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 36652 - """Supt_Lora"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 62524 - """twiitchhin"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 90576 - """foreverkiki"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 32006 - """ashreve99"""
# User 2: 11835 - """Loggerswife369"""
# Common Friend: 79366 - """turrranichelle"""
# Number of Common Connections: 1
#
# User 1: 85096 - """ItzellDestiny"""
# User 2: 11835 - """Loggerswife369"""
# Common Friend: 79366 - """turrranichelle"""
# Number of Common Connections: 1
#
# User 1: 42474 - """daniellebabiex3"""
# User 2: 37460 - """lakingsareawso1"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 69283 - """barefootNurse24"""
# User 2: 37460 - """lakingsareawso1"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 37460 - """lakingsareawso1"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 20189 - """21hassler"""
# User 2: 56281 - """miniejm1993"""
# Common Friend: 94775 - """BDLNDSNBHD"""
# Number of Common Connections: 1
#
# User 1: 25953 - """JonClempner"""
# User 2: 56281 - """miniejm1993"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 68647 - """vmormino"""
# User 2: 56281 - """miniejm1993"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 98246 - """fugly_breana"""
# User 2: 56281 - """miniejm1993"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 54515 - """dogsandcoffee_"""
# User 2: 56281 - """miniejm1993"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 88635 - """valbunny008"""
# User 2: 16426 - """ShaneAllison"""
# Common Friend: 78307 - """Victori19992001"""
# Number of Common Connections: 1
#
# User 1: 19411 - """NyzairRountree"""
# User 2: 16426 - """ShaneAllison"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 16426 - """ShaneAllison"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 32006 - """ashreve99"""
# User 2: 41761 - """MarylandGirl85"""
# Common Friend: 76435 - """VafFunGhoul_"""
# Number of Common Connections: 1
#
# User 1: 16426 - """ShaneAllison"""
# User 2: 31523 - """Epona_love"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 19411 - """NyzairRountree"""
# User 2: 31523 - """Epona_love"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 31523 - """Epona_love"""
# Common Friend: 83740 - """OnlyA_Y"""
# Number of Common Connections: 1
#
# User 1: 11835 - """Loggerswife369"""
# User 2: 31523 - """Epona_love"""
# Common Friend: 87211 - """richmagoo"""
# Number of Common Connections: 1
#
# User 1: 25953 - """JonClempner"""
# User 2: 31523 - """Epona_love"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 29577 - """decayisdead"""
# User 2: 21779 - """DarcECulp"""
# Common Friend: 33862 - """MannyL47"""
# Number of Common Connections: 1
#
# User 1: 87527 - """Takemysoul_BTS"""
# User 2: 21779 - """DarcECulp"""
# Common Friend: 96245 - """dmgiveawayss"""
# Number of Common Connections: 1
#
# User 1: 87211 - """richmagoo"""
# User 2: 27142 - """slwtowns"""
# Common Friend: 25953 - """JonClempner"""
# Number of Common Connections: 1
#
# User 1: 19411 - """NyzairRountree"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 56195 - """911Advocate"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 12354 - """TrueTxCutie"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 75509 - """baileyofbagend"""
# Number of Common Connections: 1
#
# User 1: 32006 - """ashreve99"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 42136 - """AliAftab_"""
# Number of Common Connections: 1
#
# User 1: 92454 - """lizethgodinez_"""
# User 2: 58992 - """jetbIackjoseph"""
# Common Friend: 42136 - """AliAftab_"""
# Number of Common Connections: 1
#
# User 1: 56195 - """911Advocate"""
# User 2: 32662 - """_keezybabyy"""
# Common Friend: 60709 - """alisha_toogood"""
# Number of Common Connections: 1
#
# User 1: 82512 - """signsofnate"""
# User 2: 32662 - """_keezybabyy"""
# Common Friend: 60709 - """alisha_toogood"""
# Number of Common Connections: 1
#
# User 1: 54841 - """jamesdaine_"""
# User 2: 35931 - """trblrene"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 53165 - """jacklynrw1"""
# User 2: 35931 - """trblrene"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 51051 - """kenzi_cummings"""
# User 2: 35931 - """trblrene"""
# Common Friend: 23526 - """unareid14"""
# Number of Common Connections: 1
#
# User 1: 31523 - """Epona_love"""
# User 2: 48852 - """SBCSDrguillen"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 25953 - """JonClempner"""
# User 2: 48852 - """SBCSDrguillen"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 12873 - """batpoet"""
# User 2: 48852 - """SBCSDrguillen"""
# Common Friend: 31366 - """avac4do"""
# Number of Common Connections: 1
#
# User 1: 37460 - """lakingsareawso1"""
# User 2: 13783 - """TheKeepArchives"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 42474 - """daniellebabiex3"""
# User 2: 13783 - """TheKeepArchives"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 69283 - """barefootNurse24"""
# User 2: 13783 - """TheKeepArchives"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 43430 - """Nick_Hofer1"""
# User 2: 13783 - """TheKeepArchives"""
# Common Friend: 60240 - """JustRoRoBackUp"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 56281 - """miniejm1993"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 25953 - """JonClempner"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 68647 - """vmormino"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 89663 - """paige_jordan4"""
# Number of Common Connections: 1
#
# User 1: 87527 - """Takemysoul_BTS"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 37440 - """FilmFiends"""
# Number of Common Connections: 1
#
# User 1: 98246 - """fugly_breana"""
# User 2: 29874 - """ShawnCraig"""
# Common Friend: 95625 - """increziblezayn"""
# Number of Common Connections: 1
#
# User 1: 41761 - """MarylandGirl85"""
# User 2: 73172 - """emmyluvsyou"""
# Common Friend: 76435 - """VafFunGhoul_"""
# Number of Common Connections: 1
#
# User 1: 32006 - """ashreve99"""
# User 2: 73172 - """emmyluvsyou"""
# Common Friend: 76435 - """VafFunGhoul_"""
# Number of Common Connections: 1
#
# User 1: 58992 - """jetbIackjoseph"""
# User 2: 73172 - """emmyluvsyou"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 19411 - """NyzairRountree"""
# User 2: 73172 - """emmyluvsyou"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 73172 - """emmyluvsyou"""
# Common Friend: 48114 - """_ughcrying"""
# Number of Common Connections: 1
#
# User 1: 48852 - """SBCSDrguillen"""
# User 2: 27712 - """Lauravxo__"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 31523 - """Epona_love"""
# User 2: 27712 - """Lauravxo__"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 25953 - """JonClempner"""
# User 2: 27712 - """Lauravxo__"""
# Common Friend: 64013 - """sianbehr"""
# Number of Common Connections: 1
#
# User 1: 69283 - """barefootNurse24"""
# User 2: 45660 - """jbaade95"""
# Common Friend: 78664 - """monstershockey"""
# Number of Common Connections: 1
#
# User 1: 76435 - """VafFunGhoul_"""
# User 2: 45660 - """jbaade95"""
# Common Friend: 78664 - """monstershockey"""
# Number of Common Connections: 1
#
# User 1: 72301 - """Laura_Cuentas"""
# User 2: 96860 - """byrdaroo22"""
# Common Friend: 67355 - """DooubleeOhhGee"""
# Number of Common Connections: 1
#
# User 1: 78827 - """dankremnitzer"""
# User 2: 96860 - """byrdaroo22"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 63336 - """HarleyNMoore"""
# User 2: 96860 - """byrdaroo22"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 56195 - """911Advocate"""
# User 2: 96860 - """byrdaroo22"""
# Common Friend: 33127 - """madeoffwax"""
# Number of Common Connections: 1
#
# User 1: 90963 - """fabminseok"""
# User 2: 60199 - """lovethatvato"""
# Common Friend: 94979 - """WoffordKaleigh"""
# Number of Common Connections: 1
#
# User 1: 29577 - """decayisdead"""
# User 2: 60199 - """lovethatvato"""
# Common Friend: 94979 - """WoffordKaleigh"""
# Number of Common Connections: 1
#
# User 1: 56281 - """miniejm1993"""
# User 2: 60199 - """lovethatvato"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 98246 - """fugly_breana"""
# User 2: 60199 - """lovethatvato"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 54515 - """dogsandcoffee_"""
# User 2: 60199 - """lovethatvato"""
# Common Friend: 69897 - """atlantictroye"""
# Number of Common Connections: 1
#
# User 1: 31523 - """Epona_love"""
# User 2: 54445 - """arlenethebean_"""
# Common Friend: 50776 - """sykio_cat"""
# Number of Common Connections: 1
#
# User 1: 58992 - """jetbIackjoseph"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 56195 - """911Advocate"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 12354 - """TrueTxCutie"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 51051 - """kenzi_cummings"""
# Number of Common Connections: 1
#
# User 1: 12873 - """batpoet"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 79366 - """turrranichelle"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 33862 - """MannyL47"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 93033 - """nicole_kayden"""
# Number of Common Connections: 1
#
# User 1: 56170 - """KayJaneOfficial"""
# User 2: 57903 - """alexvromeroo"""
# Common Friend: 43430 - """Nick_Hofer1"""
# Number of Common Connections: 1
#
# User 1: 53463 - """BriaQuesadilla"""
# User 2: 40635 - """__Tann"""
# Common Friend: 72423 - """_laurenhamblen"""
# Number of Common Connections: 1
#
# User 1: 72301 - """Laura_Cuentas"""
# User 2: 40635 - """__Tann"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 51051 - """kenzi_cummings"""
# User 2: 40635 - """__Tann"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 64488 - """Tarattee"""
# User 2: 40635 - """__Tann"""
# Common Friend: 25063 - """dizzy__dontae"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 94452 - """DJBake91"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 60709 - """alisha_toogood"""
# User 2: 94452 - """DJBake91"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 21779 - """DarcECulp"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 96245 - """dmgiveawayss"""
# Number of Common Connections: 1
#
# User 1: 87527 - """Takemysoul_BTS"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 96245 - """dmgiveawayss"""
# Number of Common Connections: 1
#
# User 1: 87211 - """richmagoo"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 79366 - """turrranichelle"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 60240 - """JustRoRoBackUp"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 29374 - """cyndelrmadsen"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 47424 - """LuckoftheDraw86"""
# User 2: 32472 - """MXIMVS"""
# Common Friend: 97667 - """itsathirahnasir"""
# Number of Common Connections: 1
#
# User 1: 89709 - """Paigemorris_57"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 26779 - """BeingEliza"""
# Number of Common Connections: 1
#
# User 1: 11835 - """Loggerswife369"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 54841 - """jamesdaine_"""
# Number of Common Connections: 1
#
# User 1: 54445 - """arlenethebean_"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 50776 - """sykio_cat"""
# Number of Common Connections: 1
#
# User 1: 31523 - """Epona_love"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 50776 - """sykio_cat"""
# Number of Common Connections: 1
#
# User 1: 58649 - """Abrielle_Says"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 48852 - """SBCSDrguillen"""
# Number of Common Connections: 1
#
# User 1: 45660 - """jbaade95"""
# User 2: 67930 - """_trashtbh_"""
# Common Friend: 92304 - """nateholland10"""
# Number of Common Connections: 1
#
# User 1: 27294 - """CallumYoung87"""
# User 2: 90531 - """wtk_allie"""
# Common Friend: 64488 - """Tarattee"""
# Number of Common Connections: 1
#
# User 1: 94452 - """DJBake91"""
# User 2: 90531 - """wtk_allie"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 90531 - """wtk_allie"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 60709 - """alisha_toogood"""
# User 2: 90531 - """wtk_allie"""
# Common Friend: 21299 - """keannacichon_"""
# Number of Common Connections: 1
#
# User 1: 96860 - """byrdaroo22"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 78827 - """dankremnitzer"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 63336 - """HarleyNMoore"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 68531 - """emaggg"""
# Number of Common Connections: 1
#
# User 1: 96860 - """byrdaroo22"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 67355 - """DooubleeOhhGee"""
# Number of Common Connections: 1
#
# User 1: 72301 - """Laura_Cuentas"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 67355 - """DooubleeOhhGee"""
# Number of Common Connections: 1
#
# User 1: 29874 - """ShawnCraig"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 73719 - """Morgan1975Andy"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 47359 - """spookyhaleigh"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 47359 - """spookyhaleigh"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 47359 - """spookyhaleigh"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 47359 - """spookyhaleigh"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 47359 - """spookyhaleigh"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# ...
# Number of Common Connections: 1
#
# User 1: 94038 - """JennyJohnsonHi5"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 83473 - """mykaelabrock"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 11818 - """RKEpstein"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 74346 - """llKarishma"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 73719 - """Morgan1975Andy"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 29874 - """ShawnCraig"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 26641 - """smolpeachlwt"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 77735 - """miriamlass7"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 87009 - """LauraMcEwan61"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 30236 - """daisy__meyer"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 11257 - """ParkerDonovan"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 77221 - """Intermountain"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 87009 - """LauraMcEwan61"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 30034 - """kojibarnaby"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 30236 - """daisy__meyer"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94038 - """JennyJohnsonHi5"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 87628 - """mrtgonzal"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 12976 - """snohoflyfishing"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 11818 - """RKEpstein"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 74346 - """llKarishma"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 89663 - """paige_jordan4"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 71397 - """MargaretGrant22"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 94979 - """WoffordKaleigh"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 44897 - """Justine_D_Davis"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 42059 - """Devin_McKnight3"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 87009 - """LauraMcEwan61"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 30236 - """daisy__meyer"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 94038 - """JennyJohnsonHi5"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 97686 - """emmacoburn24"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 11818 - """RKEpstein"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 74346 - """llKarishma"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 47359 - """spookyhaleigh"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 85096 - """ItzellDestiny"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 86186 - """noah_rosado58"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 87009 - """LauraMcEwan61"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 30236 - """daisy__meyer"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 94038 - """JennyJohnsonHi5"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 28737 - """TheRealGMoney76"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 50748 - """cee_mamii"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 11818 - """RKEpstein"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 74346 - """llKarishma"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 90576 - """foreverkiki"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 76119 - """geekalabama"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 42582 - """callieviolet29"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 96293 - """jackieannak"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 80605 - """s_sasek"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 67355 - """DooubleeOhhGee"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 63336 - """HarleyNMoore"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18756 - """btsxoxojimin"""
# Number of Common Connections: 1
#
# User 1: 57429 - """picklemags"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 51555 - """calieee_lynnn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 66485 - """VxArc"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 85885 - """VINCommunity"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 68054 - """jennrilloraza"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 96464 - """aryana_vanessa"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 87009 - """LauraMcEwan61"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 30236 - """daisy__meyer"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 94038 - """JennyJohnsonHi5"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 64963 - """sadxdad"""
# Number of Common Connections: 1
#
# User 1: 63078 - """kkennynicole"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 18884 - """siighirwin"""
# Number of Common Connections: 1
#
# User 1: 33250 - """lilbeanfinn"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 90531 - """wtk_allie"""
# Number of Common Connections: 1
#
# User 1: 88912 - """xokaits_"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 90531 - """wtk_allie"""
# Number of Common Connections: 1
#
# User 1: 84273 - """princeforaday"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 90531 - """wtk_allie"""
# Number of Common Connections: 1
#
# User 1: 59244 - """avisbassnotes_"""
# User 2: 96540 - """whatsmma"""
# Common Friend: 90531 - """wtk_allie"""
# Number of Common Connections: 1
#
# User 1: 45954 - """AtlanticRock"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 86991 - """tswiftky"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 84273 - """princeforaday"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 65654 - """__LoWo"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 54813 - """QTTaybooty"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 34181 - """calscastaways"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 84702 - """Daniel_L_Rivas"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
#
# User 1: 88635 - """valbunny008"""
# User 2: 29417 - """mrdhey16"""
# Common Friend: 78827 - """dankremnitzer"""
# Number of Common Connections: 1
