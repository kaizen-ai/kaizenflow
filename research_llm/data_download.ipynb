# %% [markdown]
# # Data Download
#
# We deal with downloading data from the following sources:
# - [goperigon.com](https://goperigon.com)
# - [newsdata.io](https://newsdata.io)
# - [mediastack.com](https://mediastack.com)
# - [thenewsapi.com](https://thenewsapi.com)
# - [marketaux.com](https://marketaux.com)

# %%
import requests
import logging
import json

_LOG = logging.getLogger(__name__)

# %% [markdown]
# ## goperigon.com pipeline

# %%
class goperigonPipeline:
    """
    Handles fetching data from the goperigon.com API.
    """
    def __init__(self, api_key: str = 'f745aea8-78bf-4a63-b98d-ba22320b90ad'):
        """
        Initializes the pipeline.

        :param api_key: API key for authentication.
        """
        self.api_key = api_key
        self.base_url = "https://api.goperigon.com/v1/"
        self.headers = {"Authorization": f"Bearer {api_key}"}
        _LOG.debug(f"{self.__class__.__name__} initialized with API key: {api_key}")

    def set_query_params(self, endpoint: str = 'all', **kwargs) -> None:
        """
        Specify the API endpoint and the query parameters for fetching data.

        :param endpoint: The API endpoint to fetch data from.
            - 'all'        : Provides functionality for searching and filtering all 
                             news articles available on the API.
            - 'stories/all': Fetches data from all the sources.
            - 'sources'    : Provides functionality to search and filter for media 
                             sources from around the world.
            - 'journalists': Provides functionality for searching and filtering all journalists 
                             available on the database. 
            - 'people/all' : Search and retrieve additional information on known persons that 
                             exist within Perigon's 
                             entity database and as referenced in any article response object.
            - 'companies'  : Search and retrieve additional information on companies that exist within Perigon's 
                             entity database and as referenced in any article response object.
        :param **kwargs: The query parameters to be passed. E.g., 'category', 'topic', etc. Visit 
                        `https://docs.goperigon.com/docs/getting-started` for more information on query params for each endpoint.
        """
        # Check if kwargs is empty and assign default query params.
        if not kwargs:  
            self.params = {
            "category": 'Finance',
            "topic": 'Cryptocurrency'
            }
        else:
            self.params = kwargs
        # Assign the input endpoint as an instance variable.
        if endpoint in ['all', 'stories/all', 'sources', 'journalists', 'people/all', 'companies']:
            self.endpoint = endpoint
        else:
            raise ValueError(f"Invalid endpoint: {endpoint}")
        
    def fetch_data(self) -> dict:
        """
        Fetches data from a specified endpoint of the goperigon.com API.

        :return: The JSON response from the API.
        """
        # Create the URL to fetch the data specifying the endpoint.
        url = self.base_url + self.endpoint
        # Fetch data from the API endpoint with the passed parameters.
        try:
            response = requests.get(url=url, headers=self.headers, params=self.params)
            _LOG.debug(f"Fetching data from {response.request.url}")
            response.raise_for_status()
            _LOG.info("Data fetched successfully.")
            return response.json()
        except requests.RequestException as e:
            _LOG.error(f"Error fetching data: {e}")
            raise

# %% [markdown]
# ### Sample data

# %%
datapipeline_1 = goperigonPipeline()
datapipeline_1.set_query_params()
response_1 = datapipeline_1.fetch_data()
print(json.dumps(response_1, indent = 4))
# Out:
# {
#     "status": 200,
#     "numResults": 10000,
#     "articles": [
#         {
#             "url": "https://www.marketpulse.com/20210820/commodities-cryptos-oil-struggles-demand-outlook-strong-dollar-gold-hits-wall-bitcoin-coiling/",
#             "authorsByline": "",
#             "articleId": "9be5702e780b472da9abee76c30d65c3",
#             "clusterId": "445e1bf9ea2e4fb0bc2065e55c78311e",
#             "source": {
#                 "domain": "marketpulse.com",
#                 "location": null
#             },
#             "imageUrl": "https://www.marketpulse.com/wp-content/uploads/2021/06/AdobeStock_224470162.jpeg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-20T15:34:07+00:00",
#             "addDate": "2021-08-22T05:50:35.021786+00:00",
#             "refreshDate": "2021-08-22T05:50:35.021786+00:00",
#             "score": 2.0,
#             "title": "Commodities and Cryptos: Oil struggles over demand outlook and strong dollar, Gold hits a wall, Bitcoin coiling up",
#             "description": "Commodities and Cryptos: Oil struggles over demand outlook and strong dollar, Gold hits a wall, Bitcoin coiling up  MarketPulse",
#             "content": "Delta variant cases continue to wreak havoc over the short-term crude demand outlook. Oil prices have been in freefall as Wall Street turns cautious over delta variant jitters and as Fed taper expecta... [3313 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "overall equities exposure",
#                     "weight": 0.08665211
#                 },
#                 {
#                     "name": "delta variant jitters",
#                     "weight": 0.07696954
#                 },
#                 {
#                     "name": "Fed Chair Powell",
#                     "weight": 0.074482255
#                 },
#                 {
#                     "name": "Delta variant cases",
#                     "weight": 0.0736213
#                 },
#                 {
#                     "name": "September 1st",
#                     "weight": 0.07168974
#                 },
#                 {
#                     "name": "Fed taper expectations",
#                     "weight": 0.07140076
#                 },
#                 {
#                     "name": "Wall Street",
#                     "weight": 0.07022602
#                 },
#                 {
#                     "name": "Fed",
#                     "weight": 0.06344405
#                 },
#                 {
#                     "name": "many active traders",
#                     "weight": 0.063404724
#                 },
#                 {
#                     "name": "crude prices",
#                     "weight": 0.058125477
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Markets"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Powell",
#                     "type": "PERSON",
#                     "mentions": 3
#                 },
#                 {
#                     "data": "Fed",
#                     "type": "ORG",
#                     "mentions": 5
#                 },
#                 {
#                     "data": "OPEC+",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "Charles Schwab",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Treasury",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "OANDA Corporation",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "US",
#                     "type": "GPE",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Asia",
#                     "type": "LOC",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Jackson Hole",
#                     "type": "EVENT",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.4681173,
#                 "negative": 0.4460738,
#                 "neutral": 0.08580883
#             },
#             "summary": "Oil prices have been in freefall as Wall Street turns cautious over delta variant jitters and as Fed taper expectations boost the dollar. The Charles Schwab Active Trader Pulse Survey showed that active traders that have not changed strategies due to delta are leaning toward increasing their cash exposure and decreasing overall equities exposure. \n\nIf Fed Chair Powell taps the brakes on the Fed\u2019s plans over tapering, that could be the catalyst to take prices above the $1800 level. \n\nThe price of Bitcoin could break above the $50,000 level next week if Fed Chair Powell decides he wants to slow up the Fed\u2019s plans on tapering.",
#             "translation": "",
#             "locations": [],
#             "reprint": false,
#             "places": null
#         },
#         {
#             "url": "https://www.benzinga.com/money/coinbase-vs-voyager/",
#             "authorsByline": "Micah C. Miracle",
#             "articleId": "e3e4a29fc371468683b068bc4b82e25a",
#             "clusterId": "031c8fd7135f42e3acf1404c20781061",
#             "source": {
#                 "domain": "benzinga.com",
#                 "location": null
#             },
#             "imageUrl": "https://cdnwp-s3.benzinga.com/wp-content/uploads/2019/08/23211021/AdobeStock_188417474.jpeg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-20T15:46:20+00:00",
#             "addDate": "2021-08-22T05:47:50.916683+00:00",
#             "refreshDate": "2021-08-22T05:47:50.916683+00:00",
#             "score": 2.0,
#             "title": "Voyager vs. Coinbase \u2022 Exchange Comparison \u2022 Benzinga",
#             "description": "Voyager vs. Coinbase \u2022 Exchange Comparison \u2022 Benzinga  Benzinga",
#             "content": "Want to jump straight to the answer? Voyager is better for staking and Coinbase is better for trading.\n\nWhether you prefer a decentralized exchange (DEX) or a traditional trading platform, the options... [6282 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "cryptocurrency exchanges",
#                     "weight": 0.10764303
#                 },
#                 {
#                     "name": "exchanges",
#                     "weight": 0.099957354
#                 },
#                 {
#                     "name": "stock exchanges",
#                     "weight": 0.099785134
#                 },
#                 {
#                     "name": "multiple exchanges",
#                     "weight": 0.09959504
#                 },
#                 {
#                     "name": "reputable exchanges",
#                     "weight": 0.096862905
#                 },
#                 {
#                     "name": "Coinbase customers",
#                     "weight": 0.087101586
#                 },
#                 {
#                     "name": "Coinbase fees",
#                     "weight": 0.0859258
#                 },
#                 {
#                     "name": "regulated North American exchanges",
#                     "weight": 0.08557153
#                 },
#                 {
#                     "name": "Coinbase Pro",
#                     "weight": 0.082459144
#                 },
#                 {
#                     "name": "Coinbase traffic",
#                     "weight": 0.08056351
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Coinbase"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 },
#                 {
#                     "name": "Tech"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Coinbase",
#                     "type": "ORG",
#                     "mentions": 20
#                 },
#                 {
#                     "data": "Voyager",
#                     "type": "ORG",
#                     "mentions": 11
#                 },
#                 {
#                     "data": "Robinhood",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Voyager",
#                     "type": "PRODUCT",
#                     "mentions": 7
#                 },
#                 {
#                     "data": "Coinbase Pro",
#                     "type": "PRODUCT",
#                     "mentions": 3
#                 },
#                 {
#                     "data": "a Smart Order Router",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Android",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "iPhone",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "U.S.",
#                     "type": "GPE",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "North American",
#                     "type": "NORP",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.05043314,
#                 "negative": 0.035838064,
#                 "neutral": 0.9137288
#             },
#             "summary": "And with a number of altcoins making headlines again, exchanges are pressured to increase their offerings. \n\nA few things stand out for cryptocurrency exchanges when compared to stock exchanges that deal primarily with equities. Most importantly, cryptocurrency exchanges have conformed to the regulatory demands of their specific industry. \n\nWhile some platforms, like Robinhood, allow for the trading of crypto and stocks, cryptocurrency exchanges are more often exclusively geared toward trading digital assets.",
#             "translation": "",
#             "locations": [],
#             "reprint": false,
#             "places": null
#         },
#         {
#             "url": "https://www.investing.com/news/cryptocurrency-news/wells-fargo-and-jpmorgan-both-registered--bitcoin-fund-with-sec-2596106",
#             "authorsByline": "CoinQuora",
#             "articleId": "5557b045741941ba83661eda4e8e613e",
#             "clusterId": "61a5e915fa484c8c842d391aeb86110f",
#             "source": {
#                 "domain": "investing.com",
#                 "location": null
#             },
#             "imageUrl": "https://i-invdn-com.investing.com/news/LYNXMPEDB30UQ_L.jpg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-21T08:00:00+00:00",
#             "addDate": "2021-08-24T06:52:41.800498+00:00",
#             "refreshDate": "2021-08-24T06:52:41.800498+00:00",
#             "score": 2.0,
#             "title": "Wells Fargo and JPMorgan Both Registered Bitcoin Fund With SEC By CoinQuora",
#             "description": "Wells Fargo and JPMorgan Both Registered Bitcoin Fund With SEC By CoinQuora  Investing.com",
#             "content": "Bitcoin (BTC) may be the last thing one might consider when thinking about ways to ensure a clean-energy future. This has especially become the case following a tweet sent by tech...",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "tech",
#                     "weight": 0.15203515
#                 },
#                 {
#                     "name": "ways",
#                     "weight": 0.12833458
#                 },
#                 {
#                     "name": "a clean-energy future",
#                     "weight": 0.10613389
#                 },
#                 {
#                     "name": "BTC",
#                     "weight": 0.07957909
#                 },
#                 {
#                     "name": "the last thing",
#                     "weight": 0.0748607
#                 },
#                 {
#                     "name": "Bitcoin",
#                     "weight": 0.070247345
#                 },
#                 {
#                     "name": "a tweet",
#                     "weight": 0.0471701
#                 },
#                 {
#                     "name": "the case",
#                     "weight": 0.03675601
#                 },
#                 {
#                     "name": "one",
#                     "weight": 0.0
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "JPMorgan"
#                 },
#                 {
#                     "name": "Markets"
#                 },
#                 {
#                     "name": "SEC"
#                 },
#                 {
#                     "name": "Wells Fargo"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [],
#             "sentiment": {
#                 "positive": 0.113863036,
#                 "negative": 0.0703686,
#                 "neutral": 0.81576836
#             },
#             "summary": "Bitcoin (BTC) may be the last thing one might consider when thinking about ways to ensure a clean-energy future. This has especially become the case following a tweet sent by tech...",
#             "translation": "",
#             "locations": [],
#             "reprint": true,
#             "places": null
#         },
#         {
#             "url": "https://www.benzinga.com/pressreleases/21/08/g22606730/polyplay-integrating-crypto-currencies-to-the-real-world",
#             "authorsByline": "Globe Newswire",
#             "articleId": "29c386004945426394af8a54bfbedc86",
#             "clusterId": "4b9b098299cb4d90bf602a7b1c14758b",
#             "source": {
#                 "domain": "benzinga.com",
#                 "location": null
#             },
#             "imageUrl": "https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/sites/all/themes/bz2/images/bz-icon.png",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-21T19:39:00+00:00",
#             "addDate": "2021-08-24T06:52:41.806063+00:00",
#             "refreshDate": "2021-08-24T06:52:41.806063+00:00",
#             "score": 2.0,
#             "title": "PolyPlay: Integrating Crypto-Currencies To The Real World - Benzinga",
#             "description": "PolyPlay: Integrating Crypto-Currencies To The Real World - Benzinga  Benzinga",
#             "content": "Toronto, Canada, Aug. 21, 2021 (GLOBE NEWSWIRE) -- The last two years have been a game-changer for the e-sport industry, especially within the Blockchain space. In 2020, the general e-sport industry g... [4316 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "E-sport tournaments",
#                     "weight": 0.082520135
#                 },
#                 {
#                     "name": "e-sport tournaments",
#                     "weight": 0.082520135
#                 },
#                 {
#                     "name": "PLAY",
#                     "weight": 0.08045774
#                 },
#                 {
#                     "name": "new gaming projects",
#                     "weight": 0.076019704
#                 },
#                 {
#                     "name": "profound skills",
#                     "weight": 0.068887725
#                 },
#                 {
#                     "name": "Gamers",
#                     "weight": 0.0678535
#                 },
#                 {
#                     "name": "gamers",
#                     "weight": 0.0678535
#                 },
#                 {
#                     "name": "gaming",
#                     "weight": 0.06350775
#                 },
#                 {
#                     "name": "amateur players",
#                     "weight": 0.05906137
#                 },
#                 {
#                     "name": "official PolyPlay gear",
#                     "weight": 0.057903588
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Cryptocurrency"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "BC Simon",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Pritesh Kucheira",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "PolyPlay",
#                     "type": "ORG",
#                     "mentions": 18
#                 },
#                 {
#                     "data": "YouTube",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "PCS",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Oxbull",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "DEX",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "CEX",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "PLayBet Casino",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "DOTA2",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "LOL",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "CS:",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "FIFA",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "NFTs Card Game",
#                     "type": "PRODUCT",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Toronto",
#                     "type": "GPE",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Canada",
#                     "type": "GPE",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Cardano",
#                     "type": "GPE",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Elrond",
#                     "type": "GPE",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.19407576,
#                 "negative": 0.010075241,
#                 "neutral": 0.795849
#             },
#             "summary": "\n\n\n\nDuring this period, a new generation of gamers rose, including children who have shown profound skills. \n\nPolyPlay is a blockchain-based e-sports platform created to host e-sport tournaments for amateur players. \n\nPolyPlay aims to host E-sport tournaments for all players in a professional manner despite their skill levels. \n\nThe PolyPlay ecosystem has a native token called PLAY, a total supply of 1 million PLAY.",
#             "translation": "",
#             "locations": [],
#             "reprint": true,
#             "places": null
#         },
#         {
#             "url": "https://kryptomoney.com/wells-fargo-to-launch-bitcoin-investment-fund-for-rich-clients/",
#             "authorsByline": "",
#             "articleId": "4f082111f0fe4af5a45126a7686c3ecc",
#             "clusterId": "6ad7d19bb8c142e49d5fd9885d561e5e",
#             "source": {
#                 "domain": "kryptomoney.com",
#                 "location": null
#             },
#             "imageUrl": "https://kryptomoney.com/wp-content/uploads/2021/01/bitcoin-4481815_640-e1624986314941.jpg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-20T15:47:46+00:00",
#             "addDate": "2021-08-22T05:51:57.680426+00:00",
#             "refreshDate": "2021-08-22T05:51:57.680426+00:00",
#             "score": 2.0,
#             "title": "Wells Fargo To Launch Bitcoin Investment Fund For Rich Clients",
#             "description": "Wells Fargo To Launch Bitcoin Investment Fund For Rich Clients  KryptoMoney",
#             "content": "Wells Fargo has registered a Bitcoin investment fund for its wealthy clients. The mega bank is offering select clients this service to help them access some exposure to Bitcoin.\n\nA Form D (Notice of E... [1353 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "CEO Jamie Dimon",
#                     "weight": 0.11179761
#                 },
#                 {
#                     "name": "FS NYDIG",
#                     "weight": 0.11065052
#                 },
#                 {
#                     "name": "wealthy clients",
#                     "weight": 0.10870049
#                 },
#                 {
#                     "name": "NYDIG",
#                     "weight": 0.10132371
#                 },
#                 {
#                     "name": "Wells Fargo Clearing Services",
#                     "weight": 0.09702056
#                 },
#                 {
#                     "name": "Jamie Dimon",
#                     "weight": 0.096657015
#                 },
#                 {
#                     "name": "clients",
#                     "weight": 0.09642714
#                 },
#                 {
#                     "name": "Wells Fargo",
#                     "weight": 0.093534894
#                 },
#                 {
#                     "name": "alternative assets management service FS Investments",
#                     "weight": 0.08896825
#                 },
#                 {
#                     "name": "\u201cFS NYDIG BITCOIN FUND I",
#                     "weight": 0.08611909
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Wells Fargo"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Jamie Dimon",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Wells Fargo",
#                     "type": "ORG",
#                     "mentions": 3
#                 },
#                 {
#                     "data": "JPMorgan Chase",
#                     "type": "ORG",
#                     "mentions": 3
#                 },
#                 {
#                     "data": "the United States Securities and Exchange Commission",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "SEC",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "FS Investments",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "the New York Digital Investment Group",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "FS NYDIG",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Wells Fargo Clearing Services",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "BNY Mellon",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Morgan Stanley",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Goldman Sachs",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "NYDIG",
#                     "type": "ORG",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.06824432,
#                 "negative": 0.01781426,
#                 "neutral": 0.9139414
#             },
#             "summary": "\n\nA Form D (Notice of Exempt Offering of Securities) filing with the United States Securities and Exchange Commission (SEC) revealed that the fund is provided as part of a limited partnership with alternative assets management service FS Investments, and the New York Digital Investment Group (NYDIG). \n\nThe filing revealed that the fund is dubbed \u201cFS NYDIG BITCOIN FUND I\u201d and also that Wells Fargo Clearing Services will handle servicing and placement fees for clients. Just like Wells Fargo, JPMorgan is restricting access to wealthy clients and is also collaborating with the NYDIG. The bank\u2019s entry into the crypto sector is particularly interesting, considering that CEO Jamie Dimon is popular for his dislike of the crypto sector.",
#             "translation": "",
#             "locations": [],
#             "reprint": true,
#             "places": null
#         },
#         {
#             "url": "https://thegoaspotlight.com/2021/08/21/vaneck-and-proshares-withdraw-ethereum-etf-launch-bids-two-days-after-submission/",
#             "authorsByline": "",
#             "articleId": "4a0e46ce8adc4a889af2a69a22720b35",
#             "clusterId": "9fe93adc88c241eda9d34073cea8f38b",
#             "source": {
#                 "domain": "thegoaspotlight.com",
#                 "location": null
#             },
#             "imageUrl": "",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-21T11:45:35+00:00",
#             "addDate": "2021-08-24T06:41:56.151073+00:00",
#             "refreshDate": "2021-08-24T06:41:56.151073+00:00",
#             "score": 2.0,
#             "title": "VanEck and ProShares Withdraw Ethereum ETF Launch Bids Two Days After Submission",
#             "description": "VanEck and ProShares Withdraw Ethereum ETF Launch Bids Two Days After Submission  The Goa Spotlight",
#             "content": "On August 20, asset managers ProShares and VanEck filed a SEC applications for the withdrawal of applications for the launch of exchange-traded funds Ether Strategy ETF and Ethereum Strategy ETF based... [1352 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "pooled funds",
#                     "weight": 0.10754537
#                 },
#                 {
#                     "name": "Ethereum Strategy ETF",
#                     "weight": 0.10434306
#                 },
#                 {
#                     "name": "funds",
#                     "weight": 0.099455364
#                 },
#                 {
#                     "name": "Ether Strategy ETF",
#                     "weight": 0.09613196
#                 },
#                 {
#                     "name": "applications",
#                     "weight": 0.08833274
#                 },
#                 {
#                     "name": "Bloomberg ETF",
#                     "weight": 0.08513723
#                 },
#                 {
#                     "name": "Ethereum futures",
#                     "weight": 0.082713224
#                 },
#                 {
#                     "name": "exchange-traded funds",
#                     "weight": 0.08092945
#                 },
#                 {
#                     "name": "other exchange-traded products",
#                     "weight": 0.076873
#                 },
#                 {
#                     "name": "VanEck",
#                     "weight": 0.0732723
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Altcoins"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Ethereum"
#                 },
#                 {
#                     "name": "Markets"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Gary Gensler",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Eric Balchunas",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Balchunas",
#                     "type": "PERSON",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "VanEck",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "SEC",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "ProShares",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Commission",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "the Investment Companies Act 1940",
#                     "type": "LAW",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "the Securities Act of 1933",
#                     "type": "LAW",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.05864677,
#                 "negative": 0.05246747,
#                 "neutral": 0.88888574
#             },
#             "summary": "On August 20, asset managers ProShares and VanEck filed a SEC applications for the withdrawal of applications for the launch of exchange-traded funds Ether Strategy ETF and Ethereum Strategy ETF based on Ethereum futures. \n\nIn addition to Ethereum futures, funds were expected to be able to invest in pooled funds and other exchange-traded products with a focus on ether. \n\nCommenting on the rapid withdrawal of applications, Eric Balchunas, senior analyst at Bloomberg ETF, suggested that the companies were given to understand that the products should not be approved. \n\nAt the same time, Balchunas considers this a good sign for potential issuers of exchange-traded funds based on the first cryptocurrency:\n\nRecall that in June, the Commission re-extended the consideration of VanEck\u2019s application for the launch of an ETF based on the first cryptocurrency.",
#             "translation": "",
#             "locations": [],
#             "reprint": true,
#             "places": null
#         },
#         {
#             "url": "https://www.thecoinrepublic.com/2021/08/20/wells-fargo-introduces-a-passive-bitcoin-fund-for-high-net-worth-clients/",
#             "authorsByline": "",
#             "articleId": "51da3160557142c98dc93e9a17582278",
#             "clusterId": "6ad7d19bb8c142e49d5fd9885d561e5e",
#             "source": {
#                 "domain": "thecoinrepublic.com",
#                 "location": null
#             },
#             "imageUrl": "https://www.thecoinrepublic.com/wp-content/uploads/2021/08/Untitled-26.png",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-20T15:07:27+00:00",
#             "addDate": "2021-08-22T05:24:32.765655+00:00",
#             "refreshDate": "2021-08-22T05:24:32.765655+00:00",
#             "score": 2.0,
#             "title": "Wells Fargo Introduces a Passive Bitcoin Fund for High-Net-Worth Clients",
#             "description": "Wells Fargo Introduces a Passive Bitcoin Fund for High-Net-Worth Clients  The Coin Republic",
#             "content": "\n\u2022 Wells Fargo filed a private bitcoin (BTC, +5.42% ) fund with US authorities on Thursday, making it the latest megabank to provide an indirect crypto investment vehicle to its wealthiest clientele\n\u2022... [2438 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "bitcoin funds",
#                     "weight": 0.13378093
#                 },
#                 {
#                     "name": "March last year",
#                     "weight": 0.114868075
#                 },
#                 {
#                     "name": "bitcoin",
#                     "weight": 0.08985737
#                 },
#                 {
#                     "name": "FS NYDIG Bitcoin Fund I",
#                     "weight": 0.08609205
#                 },
#                 {
#                     "name": "March",
#                     "weight": 0.07893371
#                 },
#                 {
#                     "name": "JPMorgan\u2019s passive bitcoin fund",
#                     "weight": 0.07855269
#                 },
#                 {
#                     "name": "Thursday",
#                     "weight": 0.077816084
#                 },
#                 {
#                     "name": "FS Investments",
#                     "weight": 0.07367608
#                 },
#                 {
#                     "name": "widespread recognition",
#                     "weight": 0.07083374
#                 },
#                 {
#                     "name": "Wells Fargo",
#                     "weight": 0.07018814
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Wells Fargo"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Wells Fargo",
#                     "type": "ORG",
#                     "mentions": 5
#                 },
#                 {
#                     "data": "JPMorgan",
#                     "type": "ORG",
#                     "mentions": 3
#                 },
#                 {
#                     "data": "The Securities and Exchange Commission",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "CNBC",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "Morgan Stanley",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "NYDIG",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "CoinDesk",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "FS Investments",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "FS NYDIG Bitcoin Fund I, LP",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "WFII",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "MS.N",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "JPM.N",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "US",
#                     "type": "GPE",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "U.S.",
#                     "type": "GPE",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "China",
#                     "type": "GPE",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.1553974,
#                 "negative": 0.069780804,
#                 "neutral": 0.7748218
#             },
#             "summary": "According to a CNBC story, Morgan Stanley (MS.N) became the first major U.S. bank to provide bitcoin funds to its wealth management customers in March\n\n According to regulatory papers, NYDIG and FS Investments are working with Wells Fargo on the sale; the two have previously collaborated on bitcoin funds. According to a CNBC story, Morgan Stanley (MS.N) became the first major U.S. bank to provide bitcoin funds to its wealth management customers in March. After China prohibited banking and payment institutions from offering cryptocurrency services, bitcoin and ethereum had their worst one-day percentage decline since March last year.",
#             "translation": "",
#             "locations": [],
#             "reprint": false,
#             "places": null
#         },
#         {
#             "url": "https://flipboard.com/topic/finance/market-strategist-stocks-have-confirmed-a-breakdown-bitcoin-to-trade-at-18k/a-AM5397tmRXampWFwruY3xw%3Aa%3A111882296-aab6afcabf%2Ffinbold.com",
#             "authorsByline": "finbold.com - Justinas Baltrusaitis",
#             "articleId": "6f4a19199e7e49eea53a68630c8dcaa5",
#             "clusterId": "009fd8fd4cc444ee80a0dd789e2d0d44",
#             "source": {
#                 "domain": "flipboard.com",
#                 "location": null
#             },
#             "imageUrl": "https://i.ytimg.com/vi/5hZITczEISM/hqdefault.jpg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-20T15:27:51+00:00",
#             "addDate": "2021-08-22T05:24:32.766838+00:00",
#             "refreshDate": "2021-08-22T05:24:32.766838+00:00",
#             "score": 2.0,
#             "title": "Market strategist: Stocks have confirmed a breakdown, Bitcoin to trade at $18k",
#             "description": "Market strategist: Stocks have confirmed a breakdown, Bitcoin to trade at $18k  Flipboard",
#             "content": "When Is The Next Bear Market? 3-Things Will Tell You\n\nThe question I get most often is \u201cwhen is the next bear market?\u201d There are three specific items that tend to predict bear markets and recessions w... [205 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "bear markets",
#                     "weight": 0.27033222
#                 },
#                 {
#                     "name": "recessions",
#                     "weight": 0.24567795
#                 },
#                 {
#                     "name": "The Next Bear Market",
#                     "weight": 0.1617782
#                 },
#                 {
#                     "name": "the next bear market",
#                     "weight": 0.1617782
#                 },
#                 {
#                     "name": "three specific items",
#                     "weight": 0.06499463
#                 },
#                 {
#                     "name": "The question",
#                     "weight": 0.05099076
#                 },
#                 {
#                     "name": "3-Things",
#                     "weight": 0.028853558
#                 },
#                 {
#                     "name": "3",
#                     "weight": 0.0
#                 },
#                 {
#                     "name": "I",
#                     "weight": 0.0
#                 },
#                 {
#                     "name": "You",
#                     "weight": 0.0
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Markets"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [],
#             "sentiment": {
#                 "positive": 0.02314957,
#                 "negative": 0.13683967,
#                 "neutral": 0.8400107
#             },
#             "summary": "When Is The Next Bear Market? 3-Things Will Tell You\n\nThe question I get most often is \u201cwhen is the next bear market?\u201d There are three specific items that tend to predict bear markets and recessions with \u2026",
#             "translation": "",
#             "locations": [],
#             "reprint": false,
#             "places": null
#         },
#         {
#             "url": "https://www.westislandblog.com/evolve-funds-to-become-the-second-bitcoin-etf-in-canada-if-approved/",
#             "authorsByline": "",
#             "articleId": "599aeeaf1ec64c84b94efbeb4e392ab2",
#             "clusterId": "f45f837e3f2243f28c9970ffdcf9c1c9",
#             "source": {
#                 "domain": "westislandblog.com",
#                 "location": null
#             },
#             "imageUrl": "https://www.westislandblog.com/wp-content/uploads/2021/06/tech-14.jpg",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-19T05:54:03+00:00",
#             "addDate": "2021-08-20T02:54:11.416303+00:00",
#             "refreshDate": "2021-08-20T02:54:11.416303+00:00",
#             "score": 2.0,
#             "title": "Evolve Funds to Become the Second Bitcoin ETF in Canada if Approved",
#             "description": "Evolve Funds to Become the Second Bitcoin ETF in Canada if Approved  West Island Blog",
#             "content": "Evolve Funds has filed with Ontario Securities Commission (OSC) for an Evolve Cryptocurrencies exchange-traded funds (ETF). If Evolve is approved, it will become the second Bitcoin ETF in North Americ... [708 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "Evolve Cryptocurrencies ETF",
#                     "weight": 0.11357982
#                 },
#                 {
#                     "name": "CI Global Asset Management",
#                     "weight": 0.10388735
#                 },
#                 {
#                     "name": "TSX",
#                     "weight": 0.10261247
#                 },
#                 {
#                     "name": "ETF",
#                     "weight": 0.09741444
#                 },
#                 {
#                     "name": "North America",
#                     "weight": 0.087855555
#                 },
#                 {
#                     "name": "Evolve Cryptocurrencies",
#                     "weight": 0.08278983
#                 },
#                 {
#                     "name": "Ontario Securities Commission",
#                     "weight": 0.08209255
#                 },
#                 {
#                     "name": "Canadian investors",
#                     "weight": 0.077732906
#                 },
#                 {
#                     "name": "investors",
#                     "weight": 0.07410071
#                 },
#                 {
#                     "name": "OSC",
#                     "weight": 0.073467895
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Bitcoin"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 },
#                 {
#                     "name": "Canada"
#                 },
#                 {
#                     "name": "Markets"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "OSC",
#                     "type": "ORG",
#                     "mentions": 2
#                 },
#                 {
#                     "data": "Evolve Funds",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Ontario Securities Commission",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Evolve Cryptocurrencies",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Evolve",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "the Toronto Stock Exchange",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "TSX",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Purpose Investments",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "CI Global Asset Management",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "North America",
#                     "type": "LOC",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.06923733,
#                 "negative": 0.010226593,
#                 "neutral": 0.9205361
#             },
#             "summary": "Evolve Funds has filed with Ontario Securities Commission (OSC) for an Evolve Cryptocurrencies exchange-traded funds (ETF). The other three Ethereum ETFs approved by OSC trade on TSX. They include Purpose Investments and CI Global Asset Management. \n\nEvolve Cryptocurrencies ETF will take a broader approach when allocating cryptos to investors based on their market cap weightings.",
#             "translation": "",
#             "locations": [],
#             "reprint": false,
#             "places": null
#         },
#         {
#             "url": "https://www.nasdaq.com/articles/robinhood-revenue-more-than-doubles-on-crypto-trading-boom-2021-08-18-0",
#             "authorsByline": "Reuters",
#             "articleId": "c109cf40d7c546bb95390c16ce4fc5a5",
#             "clusterId": "d13c715b5a174c2cb5db12be612e4e4e",
#             "source": {
#                 "domain": "nasdaq.com",
#                 "location": null
#             },
#             "imageUrl": "https://www.nasdaq.com/sites/acquia.prod/files/2021-08-18T133004Z_1_UV7_RTRLXPP_2_LYNXPACKAGER.JPG?2014513188",
#             "country": "us",
#             "language": "en",
#             "pubDate": "2021-08-18T20:07:43+00:00",
#             "addDate": "2021-08-19T16:29:03.528227+00:00",
#             "refreshDate": "2021-08-19T16:29:03.528227+00:00",
#             "score": 2.0,
#             "title": "Robinhood revenue more than doubles on crypto trading boom",
#             "description": "Robinhood revenue more than doubles on crypto trading boom  Nasdaq",
#             "content": "Aug 18 (Reuters) - Robinhood Markets Inc HOOD.O reported a 131% jump in second-quarter revenue on Wednesday as the online brokerage benefited from a surge in cryptocurrency trading through its platfor... [416 symbols]",
#             "medium": "Article",
#             "labels": [],
#             "matchedAuthors": [],
#             "claim": "",
#             "verdict": "",
#             "keywords": [
#                 {
#                     "name": "cryptocurrency trading",
#                     "weight": 0.13574214
#                 },
#                 {
#                     "name": "a total net revenue",
#                     "weight": 0.10820043
#                 },
#                 {
#                     "name": "second-quarter revenue",
#                     "weight": 0.10013861
#                 },
#                 {
#                     "name": "Wednesday",
#                     "weight": 0.086726286
#                 },
#                 {
#                     "name": "Robinhood Markets Inc",
#                     "weight": 0.079171166
#                 },
#                 {
#                     "name": "second-quarter",
#                     "weight": 0.07221433
#                 },
#                 {
#                     "name": "the quarter ended June 30",
#                     "weight": 0.07052585
#                 },
#                 {
#                     "name": "the online brokerage",
#                     "weight": 0.064166725
#                 },
#                 {
#                     "name": "HOOD.O",
#                     "weight": 0.060976822
#                 },
#                 {
#                     "name": "the quarter",
#                     "weight": 0.057843547
#                 }
#             ],
#             "topics": [
#                 {
#                     "name": "Markets"
#                 },
#                 {
#                     "name": "Cryptocurrency"
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Finance"
#                 }
#             ],
#             "entities": [
#                 {
#                     "data": "Reuters",
#                     "type": "ORG",
#                     "mentions": 1
#                 },
#                 {
#                     "data": "Robinhood Markets Inc",
#                     "type": "ORG",
#                     "mentions": 1
#                 }
#             ],
#             "sentiment": {
#                 "positive": 0.93608487,
#                 "negative": 0.044965874,
#                 "neutral": 0.01894924
#             },
#             "summary": "Aug 18 (Reuters) - Robinhood Markets Inc HOOD.O reported a 131% jump in second-quarter revenue on Wednesday as the online brokerage benefited from a surge in cryptocurrency trading through its platform. \n\nThe company, which was at the center of the historic \"meme stock\" trading mania earlier this year, posted a total net revenue of $565 million for the quarter ended June 30 compared to $244 million a year earlier.",
#             "translation": "",
#             "locations": [],
#             "reprint": true,
#             "places": null
#         }
#     ]
# }

# %% [markdown]
# ## newsdata.io pipeline

# %%
class newsdataPipeline:
    """
    Handles fetching data from the newsdata.io API. 
    """
    def __init__(self, api_key: str = 'pub_41599cecccb2e7df362a6da41983f3f8729dd'):
        """
        Initializes the pipeline. 

        :param api_key: API key for authentication.
        """
        self.base_url = 'https://newsdata.io/api/1/'
        self.headers = {"X-ACCESS-KEY": api_key}
        _LOG.debug(f"{self.__class__.__name__} initialized with API key: {api_key}")

    def set_query_params(self, endpoint: str = 'news', **kwargs) -> None:
        """
        Specify the query parameters for fetching data. 
        
        :param endpoint: The API endpoint to fetch data from.
            - 'news'    : Provides access to the latest and breaking news upto the past 48 hrs.
            - 'crypto'  : Provided crypto related news and blog data.
            - 'archive' : Provides access to the old news data upto past 2 years.
            - 'sources' : Provides names of randomly selected 100 domains from a country, category or/and language.
        :param **kwargs: The query parameters to be passed. Visit `https://newsdata.io/documentation` 
                         for more information on query params for each endpoint.
        """
        # Check if kwargs is empty and assign default values.
        if not kwargs:
            self.params = {
                'q': "cryptocurrency"
                 }   
        else:
            self.params = kwargs
         # Assign the input endpoint as an instance variable.
        if endpoint in ['news', 'crypto', 'archive', 'sources']:
            self.endpoint = endpoint
        else:
            raise ValueError(f"Invalid endpoint: {endpoint}")    

    def fetch_data(self) -> dict:
        """
        Fetches news data from NewsData.io.

        :return: The JSON response from the API. 
        """
        # Create the URL to fetch the data specifying.
        url = self.base_url + self.endpoint
        # Fetch data from the API with the passed parameters.
        try:
            response = requests.get(url=url, headers=self.headers, params=self.params)
            _LOG.debug(f"Fetching data from {response.request.url}")
            response.raise_for_status()
            _LOG.info("Data fetched successfully.")
            return response.json()
        except requests.RequestException as e:
            _LOG.error(f"Error fetching data: {e}")
            raise

# %% [markdown]
# ### Sample Data

# %%
datapipeline_2 = newsdataPipeline()
datapipeline_2.set_query_params()
response_2 = datapipeline_2.fetch_data()
print(json.dumps(response_2, indent=4))
# Out:
# {
#     "status": "success",
#     "totalResults": 455,
#     "results": [
#         {
#             "article_id": "fad33bc9ce1fa588f15926d3c1b4aa39",
#             "title": "\u0420\u043e\u0431\u0435\u0440\u0442 \u041a\u0438\u0439\u043e\u0441\u0430\u043a\u0438: \u00ab\u041f\u043e\u043a\u0443\u043f\u0430\u0439\u0442\u0435 \u0431\u0438\u0442\u043a\u043e\u0438\u043d, \u0442\u0430\u043a \u043a\u0430\u043a \u0421\u0428\u0410 \u2013 \u0443\u0436\u0435 \u0431\u0430\u043d\u043a\u0440\u043e\u0442\u00bb",
#             "link": "https://ru.investing.com/news/cryptocurrency-news/article-2396252",
#             "keywords": null,
#             "creator": [
#                 "Bits.media"
#             ],
#             "video_url": null,
#             "description": null,
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:41:45",
#             "image_url": "https://d7-invdn-com.investing.com/content/pic43f9a913f4983ffb3335fc065b378e89.png",
#             "source_id": "investing",
#             "source_priority": 611,
#             "source_url": "https://ru.investing.com",
#             "source_icon": null,
#             "language": "russian",
#             "country": [
#                 "russia"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "050be629352eae4c65ad700c1355fc49",
#             "title": "Binance: \u0423 \u043d\u0430\u0441 \u043d\u0435\u0442 \u0434\u043e\u043b\u0433\u043e\u0432 \u0438 \u043e\u043f\u0430\u0441\u0435\u043d\u0438\u0439 \u0437\u0430 \u0441\u0440\u0435\u0434\u0441\u0442\u0432\u0430 \u043a\u043b\u0438\u0435\u043d\u0442\u043e\u0432",
#             "link": "https://ru.investing.com/news/cryptocurrency-news/article-2396253",
#             "keywords": null,
#             "creator": [
#                 "Bits.media"
#             ],
#             "video_url": null,
#             "description": null,
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:41:45",
#             "image_url": "https://i-invdn-com.investing.com/news/LYNXMPED09124_M.jpg",
#             "source_id": "investing",
#             "source_priority": 611,
#             "source_url": "https://ru.investing.com",
#             "source_icon": null,
#             "language": "russian",
#             "country": [
#                 "russia"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "8074c509d20ded81ed4a0438e0621265",
#             "title": "BlackRock \u0440\u0430\u0441\u0448\u0438\u0440\u0438\u043b\u0430 \u0441\u043f\u0438\u0441\u043e\u043a \u043f\u0430\u0440\u0442\u043d\u0435\u0440\u043e\u0432 \u0441\u043f\u043e\u0442\u043e\u0432\u043e\u0433\u043e \u0444\u043e\u043d\u0434\u0430 Bitcoin Trust",
#             "link": "https://ru.investing.com/news/cryptocurrency-news/article-2396254",
#             "keywords": null,
#             "creator": [
#                 "Bits.media"
#             ],
#             "video_url": null,
#             "description": null,
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:41:44",
#             "image_url": "https://d7-invdn-com.investing.com/content/pica8619bb78fc704b07574478b21307007.png",
#             "source_id": "investing",
#             "source_priority": 611,
#             "source_url": "https://ru.investing.com",
#             "source_icon": null,
#             "language": "russian",
#             "country": [
#                 "russia"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "82255ada36d406c94e30b15b5a77c397",
#             "title": "Is Shibu Inu Set To Skyrocket? Social Buzz And Token Burns Fuel Speculation",
#             "link": "https://www.benzinga.com/markets/cryptocurrency/24/04/38134030/is-shibu-inu-set-to-skyrocket-social-buzz-and-token-burns-fuel-speculation",
#             "keywords": [
#                 "$shib",
#                 "burn rate",
#                 "cryptocurrency",
#                 "news",
#                 "shiba inu",
#                 "top stories",
#                 "markets",
#                 "$shib",
#                 "news",
#                 "cryptocurrency",
#                 "top stories",
#                 "markets",
#                 "benzinga"
#             ],
#             "creator": [
#                 "Bibhu Pattnaik"
#             ],
#             "video_url": null,
#             "description": "Shiba Inu (CRYPTO: SHIB) might be on the verge of a significant price surge. read more",
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:40:01",
#             "image_url": "https://cdn.benzinga.com/files/images/story/2024/04/07/shutterstock_2017387913.jpg?optimize=medium&dpr=1&auto=webp&height=675&width=1200&fit=crop",
#             "source_id": "benzinga",
#             "source_priority": 3903,
#             "source_url": "https://www.benzinga.com",
#             "source_icon": "https://i.bytvi.com/domain_icons/benzinga.png",
#             "language": "english",
#             "country": [
#                 "united states of america"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "b49dfb321a1abe9fc0becc0e0b20b192",
#             "title": "Are NFTs Dead? Unveiling The Truth About the NFT Market Cras",
#             "link": "https://www.tekedia.com/are-nfts-dead-unveiling-the-truth-about-the-nft-market-cras/",
#             "keywords": [
#                 "latest insights | news"
#             ],
#             "creator": [
#                 "Olaseni Kehinde Precious"
#             ],
#             "video_url": null,
#             "description": "In 2021, the NFT market experienced a surge in opportunities. Statistica data indicates a remarkable increase in collectable art sales, soaring from approximately $20 million in 2020 to $2.57 billion. This unprecedented growth created widespread discussion and enthusiasm across various communities, leading to substantial investments in digital art. The market\u2019s rapid growth spurred investors into [\u2026] The post Are NFTs Dead? Unveiling The Truth About the NFT Market Cras appeared first on Tekedia.",
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:33:45",
#             "image_url": "https://tkcdn.tekedia.com/wp-content/uploads/2023/12/20100632/NFT-2-768x432.jpg",
#             "source_id": "tekedia",
#             "source_priority": 422136,
#             "source_url": "https://www.tekedia.com",
#             "source_icon": "https://i.bytvi.com/domain_icons/tekedia.jpg",
#             "language": "english",
#             "country": [
#                 "nigeria"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "ceadae8d9c03cf438a3fb43745918826",
#             "title": "Investors keep the faith in Indian social startups, eye GenAI models",
#             "link": "https://www.livemint.com/ai/investors-keep-the-faith-in-indian-social-startups-eye-genai-models-11712484645441.html",
#             "keywords": null,
#             "creator": null,
#             "video_url": null,
#             "description": "Five startups with AI-driven social products have got cumulative funding of $27.8 million since January",
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:32:53",
#             "image_url": "https://www.livemint.com/lm-img/img/2024/04/07/1600x900/im-24074560_1711335487607_1712506367003.jpg",
#             "source_id": "livemint",
#             "source_priority": 7134,
#             "source_url": "https://www.livemint.com",
#             "source_icon": "https://i.bytvi.com/domain_icons/livemint.png",
#             "language": "english",
#             "country": [
#                 "india"
#             ],
#             "category": [
#                 "science"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "2c8f68cd7df0c231f2382c9e5efaaa28",
#             "title": "\u041c\u0430\u0433\u0430\u0437\u0438\u043d \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0439 Snap Store \u043f\u043e\u043e\u0431\u0435\u0449\u0430\u043b \u043d\u0430\u0447\u0430\u0442\u044c \u0440\u0443\u0447\u043d\u0443\u044e \u043f\u0440\u043e\u0432\u0435\u0440\u043a\u0443 \u043a\u0440\u0438\u043f\u0442\u043e\u043a\u043e\u0448\u0435\u043b\u044c\u043a\u043e\u0432",
#             "link": "https://ru.investing.com/news/cryptocurrency-news/article-2396250",
#             "keywords": null,
#             "creator": [
#                 "Bits.media"
#             ],
#             "video_url": null,
#             "description": null,
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:27:55",
#             "image_url": "https://d7-invdn-com.investing.com/content/pic09850dfe275a3c528ddae987f05c798c.png",
#             "source_id": "investing",
#             "source_priority": 611,
#             "source_url": "https://ru.investing.com",
#             "source_icon": null,
#             "language": "russian",
#             "country": [
#                 "russia"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "fdde0af5de94dee305679311c34879f3",
#             "title": "\u0410\u043d\u0430\u043b\u0438\u0442\u0438\u043a\u0438 \u043f\u0440\u043e\u0433\u043d\u043e\u0437\u0438\u0440\u0443\u044e\u0442 \u0442\u0440\u0451\u0445\u043a\u0440\u0430\u0442\u043d\u044b\u0439 \u0440\u043e\u0441\u0442 \u043a\u0443\u0440\u0441\u0430 Solana \u0437\u0430 \u043c\u0435\u0441\u044f\u0446",
#             "link": "https://ru.investing.com/news/cryptocurrency-news/article-2396251",
#             "keywords": null,
#             "creator": [
#                 "Happy Coin News"
#             ],
#             "video_url": null,
#             "description": null,
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:27:54",
#             "image_url": "https://i-invdn-com.investing.com/news/LYNXMPED9A0RJ-ORUBS_M.jpg",
#             "source_id": "investing",
#             "source_priority": 611,
#             "source_url": "https://ru.investing.com",
#             "source_icon": null,
#             "language": "russian",
#             "country": [
#                 "russia"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "507827fa1492b8c8ceadb8ea5a3daf08",
#             "title": "Nieuw AI-cryptoproject InQubeta bereikt $13 miljoen in lopende presale",
#             "link": "https://invezz.com/nl/nieuws/2024/04/07/nieuw-ai-cryptoproject-inqubeta-bereikt-13-miljoen-in-lopende-presale/",
#             "keywords": [
#                 "wereld",
#                 "gesponsorde"
#             ],
#             "creator": [
#                 "Collaborations"
#             ],
#             "video_url": null,
#             "description": "InQubeta (QUBE) heeft zojuist een grote mijlpaal bereikt door $13 miljoen op te halen in de lopende crypto presale. Dit is een belangrijke prestatie voor het team van InQubeta en benadrukt ook de groeiende belangstelling voor op AI gerichte investeringsmogelijkheden binnen de crypto-ruimte. Maar wat is InQubeta eigenlijk? InQubeta: platform voor investeringen in AI-startups Met [\u2026]",
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:17:02",
#             "image_url": "https://invezz.com/wp-content/uploads/2024/04/inqubeta-presale.png",
#             "source_id": "invezz",
#             "source_priority": 20604,
#             "source_url": "https://invezz.com",
#             "source_icon": null,
#             "language": "dutch",
#             "country": [
#                 "united kingdom"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         },
#         {
#             "article_id": "b7bdd85d7af6e9acb8ac6f7797c1d140",
#             "title": "Ethereum Price Momentum Slows Down",
#             "link": "https://en.coin-turk.com/ethereum-price-momentum-slows-down-3/",
#             "keywords": [
#                 "ethereum (eth)"
#             ],
#             "creator": [
#                 "COINTURK NEWS"
#             ],
#             "video_url": null,
#             "description": "Ethereum's optimism wanes after SEC decisions. Recent developments pull Ethereum price back into formation.Continue Reading:Ethereum Price Momentum Slows Down",
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "pubDate": "2024-04-07 16:09:38",
#             "image_url": "https://en.coin-turk.com/wp-content/uploads/2024/04/ethereum-15.jpg",
#             "source_id": "cointurk",
#             "source_priority": 6230568,
#             "source_url": "https://coin-turk.com",
#             "source_icon": "https://i.bytvi.com/domain_icons/cointurk.png",
#             "language": "english",
#             "country": [
#                 "turkey"
#             ],
#             "category": [
#                 "top"
#             ],
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS"
#         }
#     ],
#     "nextPage": "1712506178732522720"
# }

# %% [markdown]
# ## thenewsapi.com pipeline

# %%
class newsapiPipeline:
    """
    Handles fetching data from the thenewsapi.com API.
    """
    def __init__(self, api_key: str = 'Nr11NvvuUR3VkVqFbWQpDFxdAA9wClTkofsFtQ9l'):
        """
        Intializes the pipeline.

        :param api_key: API key for authentication.
        """
        # Assign the passed API to an instance variable.
        self.api_key = api_key
        self.base_url = 'https://api.thenewsapi.com/v1/news/'
        _LOG.debug(f"{self.__class__.__name__} initialized with API key: {api_key}")

    def set_query_params(self, endpoint: str = 'all', **kwargs) -> None:
        """
        Specify the query parameters for fetching data. 
        
        :param endpoint: The API endpoint to fetch data from.
            - 'headlines' : Get the latest headlines by category.
            - 'top'       : Find live and historical top stories around the world. 
            - 'all'       : Find all live and historical articles.
            - 'similar'   : Find similar stories to a specific article based on its UUID.
            - 'uuid'      : Find specific articles by the UUID.
            - 'sources'   : Find sources to use in your news API requests.
        :param **kwargs: The query parameters to be passed. Visit `https://www.thenewsapi.com/documentation` 
                         for more information on query params for each endpoint.
        """
        # Check if kwargs is empty and assign default values.
        if not kwargs:
            self.params = {
                'api_token': self.api_key,
                'search': "crypto | cryptocurrency"
                 }   
        else:
            self.params = kwargs
            # Pass API key as query paramter.
            self.params['api_token']=self.api_key
         # Assign the input endpoint as an instance variable.
        if endpoint in ['headlines', 'top', 'all', 'similar', 'uuid', 'sources']:
            self.endpoint = endpoint
        else:
            raise ValueError(f"Invalid endpoint: {endpoint}")    

    def fetch_data(self, uuid: str=None) -> dict:
        """
        Fetches top news data from thenewsapi.com.
        
        :param uuid: UUID value if `endpoint = 'similar'` or `endpoint = 'uuid'`.
        :return: The JSON response from the API.
        """
        # Check if endpoint if 'uuid' or 'similar' and create the URL to fetch data.
        if self.endpoint in ['uuid', 'similar']:
            if uuid is not None: 
                url = self.base_url + self.endpoint + '/' + uuid
            else:
                raise ValueError("Enter Valid UUID.")
        else:
            url = self.base_url + self.endpoint        
        # Fetch data from the API with the passed parameters.
        try:
            response = requests.get(url=url, params=self.params)
            _LOG.debug(f"Fetching data from {response.request.url}")
            response.raise_for_status()
            _LOG.info("Data fetched successfully.")
            return response.json()
        except requests.RequestException as e:
            _LOG.error(f"Error fetching data: {e}")
            raise

# %% [markdown]
# ### sample data

# %%
datapipeline_3 = newsapiPipeline()
datapipeline_3.set_query_params()
response_3 = datapipeline_3.fetch_data()
print(json.dumps(response_3, indent=4))
# Out:
# {
#     "meta": {
#         "found": 337213,
#         "returned": 3,
#         "limit": 3,
#         "page": 1
#     },
#     "data": [
#         {
#             "uuid": "c4cf5c7c-aa6f-4aa9-b20f-e143ef18b545",
#             "title": "Cryptocurrency turmoil affects crypto miners",
#             "description": "Cryptocurrency turmoil is affecting crypto miners, who require lots of electricity to operate. Energy costs are up, and demand is down.",
#             "keywords": "",
#             "snippet": "Cryptocurrency turmoil affects crypto miners Cryptocurrency turmoil is affecting crypto miners, who require lots of electricity to operate. Energy costs are up,...",
#             "url": "https://www.npr.org/2022/12/15/1143139773/cryptocurrency-turmoil-affects-crypto-miners",
#             "image_url": "https://media.npr.org/include/images/facebook-default-wide-s1400-c100.jpg",
#             "language": "en",
#             "published_at": "2022-12-15T21:19:46.000000Z",
#             "source": "npr.org",
#             "categories": [
#                 "general",
#                 "politics"
#             ],
#             "relevance_score": 41.495502
#         },
#         {
#             "uuid": "c9e1c666-7008-43bd-a5f6-8bb6153b4370",
#             "title": "Crypto and cryptocurrency",
#             "description": "",
#             "keywords": "",
#             "snippet": "Crypto and cryptocurrency\n\nCrypto and cryptocurrency\n\nstartups are garnering attention in the sphere due to their rapid growth and potential for significant ret...",
#             "url": "https://magnetmartpk.medium.com/crypto-and-cryptocurrency-2a176774c72a",
#             "image_url": "https://miro.medium.com/v2/1*m-R_BkNf1Qjr1YbyOIJY2w.png",
#             "language": "en",
#             "published_at": "2024-02-14T20:37:06.000000Z",
#             "source": "medium.com",
#             "categories": [
#                 "tech",
#                 "science",
#                 "business"
#             ],
#             "relevance_score": 41.131195
#         },
#         {
#             "uuid": "1f6a6370-3cae-4024-b567-4ebc216948a9",
#             "title": "What Is Staking Cryptocurrency (Crypto)?",
#             "description": "Learn about cryptocurrency staking, how it works, and the pros and cons of this investment.",
#             "keywords": "",
#             "snippet": "Earning money while you sleep is the dream.\n\nAnd although there are plenty of passive income opportunities in traditional finance, a fairly new income stream th...",
#             "url": "https://www.moneycrashers.com/staking-cryptocurrency-meaning/",
#             "image_url": "https://www.moneycrashers.com/wp-content/uploads/2021/10/cropped-moneycrashers-square-logo-large-32x32.png",
#             "language": "en",
#             "published_at": "2022-08-03T19:00:00.000000Z",
#             "source": "moneycrashers.com",
#             "categories": [
#                 "business"
#             ],
#             "relevance_score": 40.379425
#         }
#     ]
# }

# %% [markdown]
# ## marketaux.com pipeline

# %%
class marketauxPipeline:
    """
    Handles fetching data from the marketaux.com API.
    """
    def __init__(self, api_key: str = 'shRM7CyfkEGsBK83T3IB7YweAiKbzORMZjEWERtu'):
        """
        Intializes the pipeline.

        :param api_key: API key for authentication.
        """
        # Assign the passed API to an instance variable.
        self.api_key = api_key
        self.base_url = 'https://api.marketaux.com/v1/'
        _LOG.debug(f"{self.__class__.__name__} initialized with API key: {api_key}")

    def set_query_params(self, endpoint: str = 'news/all', **kwargs) -> None:
        """
        Specify the query parameters for fetching data. 
        
        :param endpoint: The API endpoint to fetch data from.
            - 'news/all'       : Find all live and historical articles.
            - 'news/similar'   : Find similar stories to a specific article based on its UUID.
            - 'news/uuid'      : Find specific articles by the UUID.
            - 'news/sources'   : Find sources to use in your news API requests.
            - 'entity/stats'   : Get an intraday view of how well entities performed over 
                                 different intervals using this endpoint.
            - 'entity/stats/aggregation'    : Returns an aggregation of entities for a single time frame, 
                                              rather than being broken down by date.
            - 'entity/trending/aggregation' : Use this endpoint to identify trending entities.
            - 'entity/search'               : Use this endpoint to search for all supported entities.
            - 'entity/type/list'            : Use this endpoint to return all supported entity types.
            - 'entity/industry/list'        : Use this endpoint to return all supported entity industries.
        :param **kwargs: The query parameters to be passed. Visit `https://www.marketaux.com/documentation` 
                         for more information on query params for each endpoint.
        """
        # Check if kwargs is empty and assign default values.
        if not kwargs:
            self.params = {
                'api_token': self.api_key,
                'search': "crypto | cryptocurrency"
                 }   
        else:
            self.params = kwargs
            # Pass API key as query paramter.
            self.params['api_token']=self.api_key
         # Assign the input endpoint as an instance variable.
        if endpoint in ['news/all', 'news/similar', 'news/uuid', 'news/sources', 'entity/stats', 
                        'entity/stats/aggregation', 'entity/tending/aggregation', 'entity/search'
                        'entity/type/list', 'entity/industry/list']:
            self.endpoint = endpoint
        else:
            raise ValueError(f"Invalid endpoint: {endpoint}")    

    def fetch_data(self, uuid: str=None) -> dict:
        """
        Fetches top news data from marketaux.com.
        
        :param uuid: UUID value if `endpoint = 'similar'` or `endpoint = 'uuid'`.
        :return: The JSON response from the API.
        """
        # Check if endpoint if 'uuid' or 'similar' and create the URL to fetch data.
        if self.endpoint in ['uuid', 'similar']:
            if uuid is not None: 
                url = self.base_url + self.endpoint + '/' + uuid
            else:
                raise ValueError("UUID is None.")
        else:
            url = self.base_url + self.endpoint        
        # Fetch data from the API with the passed parameters.
        try:
            response = requests.get(url=url, params=self.params)
            _LOG.debug(f"Fetching data from {response.request.url}")
            response.raise_for_status()
            _LOG.info("Data fetched successfully.")
            return response.json()
        except requests.RequestException as e:
            _LOG.error(f"Error fetching data: {e}")
            raise

# %% [markdown]
# ### sample data

# %%
datapipeline_4 = marketauxPipeline()
datapipeline_4.set_query_params()
response_4 = datapipeline_4.fetch_data()
print(json.dumps(response_4, indent=4))
# Out:
# {
#     "meta": {
#         "found": 212226,
#         "returned": 3,
#         "limit": 3,
#         "page": 1
#     },
#     "data": [
#         {
#             "uuid": "c9e1c666-7008-43bd-a5f6-8bb6153b4370",
#             "title": "Crypto and cryptocurrency",
#             "description": "",
#             "keywords": "",
#             "snippet": "Crypto and cryptocurrency\n\nCrypto and cryptocurrency\n\nstartups are garnering attention in the sphere due to their rapid growth and potential for significant ret...",
#             "url": "https://magnetmartpk.medium.com/crypto-and-cryptocurrency-2a176774c72a",
#             "image_url": "https://miro.medium.com/v2/1*m-R_BkNf1Qjr1YbyOIJY2w.png",
#             "language": "en",
#             "published_at": "2024-02-14T20:37:06.000000Z",
#             "source": "medium.com",
#             "relevance_score": 41.13146,
#             "entities": [],
#             "similar": []
#         },
#         {
#             "uuid": "1f6a6370-3cae-4024-b567-4ebc216948a9",
#             "title": "What Is Staking Cryptocurrency (Crypto)?",
#             "description": "Learn about cryptocurrency staking, how it works, and the pros and cons of this investment.",
#             "keywords": "",
#             "snippet": "Earning money while you sleep is the dream.\n\nAnd although there are plenty of passive income opportunities in traditional finance, a fairly new income stream th...",
#             "url": "https://www.moneycrashers.com/staking-cryptocurrency-meaning/",
#             "image_url": "https://www.moneycrashers.com/wp-content/uploads/2021/10/cropped-moneycrashers-square-logo-large-32x32.png",
#             "language": "en",
#             "published_at": "2022-08-03T19:00:00.000000Z",
#             "source": "moneycrashers.com",
#             "relevance_score": 40.379707,
#             "entities": [
#                 {
#                     "symbol": "CC:ETH",
#                     "name": "Ethereum",
#                     "exchange": null,
#                     "exchange_long": null,
#                     "country": "global",
#                     "type": "cryptocurrency",
#                     "industry": "N/A",
#                     "match_score": 81.21008,
#                     "sentiment_score": 0.6105,
#                     "highlights": [
#                         {
#                             "highlight": "Most new cryptocurrencies are running on PoS-style networks, including <em>Ethereum</em> 2.0, which will migrate <em>Ethereum</em> off the old proof-of-work network.\n\nPros & Cons of Staking Cryptocurrency\n\nStaking cryptocurrency can help create passive income for investors, but can be complicated.",
#                             "sentiment": 0.4215,
#                             "highlighted_in": "main_text"
#                         },
#                         {
#                             "highlight": "For example; Coinbase offers staking of several crypto through staking pools, including <em>Ethereum</em> 2.0, Cosmo (ATOM), and Cardano (ADA). Users can earn up to 5% APY (sometimes more) on staked crypto, with rewards deposited on a different set schedule per asset.",
#                             "sentiment": 0.6808,
#                             "highlighted_in": "main_text"
#                         },
#                         {
#                             "highlight": "Some of the most popular coins include:\n\n<em>Ethereum</em> 2.0 (<em>ETH</em>)\n\nAlgorand (ALGO)\n\nCardano (ADA)\n\nNear Protocol (NEAR)\n\nTezos (XTZ)\n\nThere are dozens of others available, and CoinMarketCap offers an extensive list of the most popular cryptocurrencies that offer staking.\n\nHow Do I Get Started Staking Crypto?",
#                             "sentiment": 0.7292,
#                             "highlighted_in": "main_text"
#                         }
#                     ]
#                 },
#                 {
#                     "symbol": "CC:ADA",
#                     "name": "Cardano",
#                     "exchange": null,
#                     "exchange_long": null,
#                     "country": "global",
#                     "type": "cryptocurrency",
#                     "industry": "N/A",
#                     "match_score": 81.96448,
#                     "sentiment_score": 0.705,
#                     "highlights": [
#                         {
#                             "highlight": "For example; Coinbase offers staking of several crypto through staking pools, including Ethereum 2.0, Cosmo (ATOM), and <em>Cardano</em> (<em>ADA</em>). Users can earn up to 5% APY (sometimes more) on staked crypto, with rewards deposited on a different set schedule per asset.",
#                             "sentiment": 0.6808,
#                             "highlighted_in": "main_text"
#                         },
#                         {
#                             "highlight": "Some of the most popular coins include:\n\nEthereum 2.0 (ETH)\n\nAlgorand (ALGO)\n\n<em>Cardano</em> (<em>ADA</em>)\n\nNear Protocol (NEAR)\n\nTezos (XTZ)\n\nThere are dozens of others available, and CoinMarketCap offers an extensive list of the most popular cryptocurrencies that offer staking.\n\nHow Do I Get Started Staking Crypto?",
#                             "sentiment": 0.7292,
#                             "highlighted_in": "main_text"
#                         }
#                     ]
#                 },
#                 {
#                     "symbol": "CC:XTZ",
#                     "name": "Tezos",
#                     "exchange": null,
#                     "exchange_long": null,
#                     "country": "global",
#                     "type": "cryptocurrency",
#                     "industry": "N/A",
#                     "match_score": 80.41106,
#                     "sentiment_score": 0.7292,
#                     "highlights": [
#                         {
#                             "highlight": "Some of the most popular coins include:\n\nEthereum 2.0 (ETH)\n\nAlgorand (ALGO)\n\nCardano (ADA)\n\nNear Protocol (NEAR)\n\n<em>Tezos</em> (<em>XTZ</em>)\n\nThere are dozens of others available, and CoinMarketCap offers an extensive list of the most popular cryptocurrencies that offer staking.\n\nHow Do I Get Started Staking Crypto?",
#                             "sentiment": 0.7292,
#                             "highlighted_in": "main_text"
#                         }
#                     ]
#                 },
#                 {
#                     "symbol": "CC:ALGO",
#                     "name": "Algorand",
#                     "exchange": null,
#                     "exchange_long": null,
#                     "country": "global",
#                     "type": "cryptocurrency",
#                     "industry": "N/A",
#                     "match_score": 77.365746,
#                     "sentiment_score": 0.7292,
#                     "highlights": [
#                         {
#                             "highlight": "Some of the most popular coins include:\n\nEthereum 2.0 (ETH)\n\n<em>Algorand</em> (<em>ALGO</em>)\n\nCardano (ADA)\n\nNear Protocol (NEAR)\n\nTezos (XTZ)\n\nThere are dozens of others available, and CoinMarketCap offers an extensive list of the most popular cryptocurrencies that offer staking.\n\nHow Do I Get Started Staking Crypto?",
#                             "sentiment": 0.7292,
#                             "highlighted_in": "main_text"
#                         }
#                     ]
#                 },
#                 {
#                     "symbol": "CC:NEAR",
#                     "name": "NEAR Protocol",
#                     "exchange": null,
#                     "exchange_long": null,
#                     "country": "global",
#                     "type": "cryptocurrency",
#                     "industry": "N/A",
#                     "match_score": 78.557976,
#                     "sentiment_score": 0.7292,
#                     "highlights": [
#                         {
#                             "highlight": "Some of the most popular coins include:\n\nEthereum 2.0 (ETH)\n\nAlgorand (ALGO)\n\nCardano (ADA)\n\n<em>Near</em> <em>Protocol</em> (<em>NEAR</em>)\n\nTezos (XTZ)\n\nThere are dozens of others available, and CoinMarketCap offers an extensive list of the most popular cryptocurrencies that offer staking.\n\nHow Do I Get Started Staking Crypto?",
#                             "sentiment": 0.7292,
#                             "highlighted_in": "main_text"
#                         }
#                     ]
#                 }
#             ],
#             "similar": []
#         },
#         {
#             "uuid": "af559e3d-2f89-4b3c-b692-4cd5a599cf0d",
#             "title": "Crypto Statistics 2024: Cryptocurrency Facts",
#             "description": "",
#             "keywords": "",
#             "snippet": "We have gathered some interesting crypto statistics and facts. This article is mainly based on a survey that the Ontario Securities Commission (OSC) embarked on...",
#             "url": "https://www.quantifiedstrategies.com/crypto-statistics/",
#             "image_url": "https://www.quantifiedstrategies.com/wp-content/uploads/2023/09/QS-logo2-500px.png",
#             "language": "en",
#             "published_at": "2024-01-28T00:13:57.000000Z",
#             "source": "quantifiedstrategies.com",
#             "relevance_score": 39.905502,
#             "entities": [],
#             "similar": []
#         }
#     ]
# }
